# %% [markdown]
# Compute VAEP Values & Calculate Player Ratings

# %%
import sys
sys.path.append("/Users/ciaran/Documents/Projects/AFL/git-repositories/afl-player-ratings/")
sys.path.append("/Users/ciaran/Documents/Projects/AFL/git-repositories/expected-score-model/")

# %%
import pandas as pd
import numpy as np
import joblib
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

from config import chain_file_path
from exp_vaep.domain.contracts.modelling_data_contract import ModellingDataContract
from exp_vaep.domain.preprocessing.preprocessing import *
from exp_vaep.domain.preprocessing.formula import *

pd.options.display.max_rows = 999
pd.options.display.max_columns = 999

# %load_ext autoreload
# %autoreload 2

# %%
FEATURES = ModellingDataContract.feature_list_scores

# %% [markdown]
# Load chain data

# %%
chains = pd.read_csv(chain_file_path)
chains.tail()
# Out:
#          Chain_Number Initial_State Final_State   Order  Quarter  \
# 1169201           252        ballUp    turnover  1984.0        4
# 1169202           252        ballUp    turnover  1985.0        4
# 1169203           253      possGain      behind  1986.0        4
# 1169204           253      possGain      behind  1987.0        4
# 1169205           253      possGain      behind  1988.0        4
#
#          Quarter_Duration_Chain_Start  Quarter_Duration       Team_Chain  \
# 1169201                          1937            1942.0         St Kilda
# 1169202                          1937            1945.0         St Kilda
# 1169203                          1949            1949.0  North Melbourne
# 1169204                          1949            1976.0  North Melbourne
# 1169205                          1949            1978.0  North Melbourne
#
#                     Team               Player    AFL_API_Player_ID  \
# 1169201         St Kilda           Dan Butler           Dan_Butler
# 1169202         St Kilda           Dan Butler           Dan_Butler
# 1169203  North Melbourne  Luke Davies-Uniacke  Luke_Davies-Uniacke
# 1169204  North Melbourne  Luke Davies-Uniacke  Luke_Davies-Uniacke
# 1169205  North Melbourne  Luke Davies-Uniacke  Luke_Davies-Uniacke
#
#                     Description     x     y     Disposal Shot_At_Goal  \
# 1169201                    Kick -65.0  14.0      clanger          NaN
# 1169202  Out On Full After Kick -69.0  34.0          NaN          NaN
# 1169203             OOF Kick In  67.0 -34.0          NaN          NaN
# 1169204                    Kick  67.0 -34.0  ineffective         True
# 1169205                  Behind  67.0 -34.0          NaN          NaN
#
#         Behind_Detail  Venue_Width  Venue_Length Home_Team        Away_Team  \
# 1169201           NaN          129           160  St Kilda  North Melbourne
# 1169202           NaN          129           160  St Kilda  North Melbourne
# 1169203           NaN          129           160  St Kilda  North Melbourne
# 1169204           NaN          129           160  St Kilda  North Melbourne
# 1169205      missLeft          129           160  St Kilda  North Melbourne
#
#         Home_Team_Direction_Q1                       Match_ID Round_ID  Year  \
# 1169201                   left  202319_StKilda_NorthMelbourne   202319   NaN
# 1169202                   left  202319_StKilda_NorthMelbourne   202319   NaN
# 1169203                   left  202319_StKilda_NorthMelbourne   202319   NaN
# 1169204                   left  202319_StKilda_NorthMelbourne   202319   NaN
# 1169205                   left  202319_StKilda_NorthMelbourne   202319   NaN
#
#          Season
# 1169201  2023.0
# 1169202  2023.0
# 1169203  2023.0
# 1169204  2023.0
# 1169205  2023.0

# %% [markdown]
# Load Expected Score Data

# %%
expected_score_version = 4
model_location = '/Users/ciaran/Documents/Projects/AFL/git-repositories/expected-score-model/model_outputs/models/'
expected_goal_set_version = 7
expected_behind_set_version = 5
expected_miss_set_version = 4

expected_goal_open_version = 7
expected_behind_open_version = 6
expected_miss_open_version = 5

# %%
expected_goal_set_model = joblib.load(model_location+"expected_goal_set_v"+str(expected_goal_set_version)+".joblib")
expected_behind_set_model = joblib.load(model_location+"expected_behind_set_v"+str(expected_behind_set_version)+".joblib")
expected_miss_set_model = joblib.load(model_location+"expected_miss_set_v"+str(expected_miss_set_version)+".joblib")

expected_goal_open_model = joblib.load(model_location+"expected_goal_open_v"+str(expected_goal_open_version)+".joblib")
expected_behind_open_model = joblib.load(model_location+"expected_behind_open_v"+str(expected_behind_open_version)+".joblib")
expected_miss_open_model = joblib.load(model_location+"expected_miss_open_v"+str(expected_miss_open_version)+".joblib")

# %%
goal_set_features = expected_goal_set_model.xgb_model.get_booster().feature_names
behind_set_features = expected_behind_set_model.xgb_model.get_booster().feature_names
miss_set_features = expected_miss_set_model.xgb_model.get_booster().feature_names

goal_open_features = expected_goal_open_model.xgb_model.get_booster().feature_names
behind_open_features = expected_behind_open_model.xgb_model.get_booster().feature_names
miss_open_features = expected_miss_open_model.xgb_model.get_booster().feature_names

# %%
chains[['ballUp', 'centreBounce', 'kickIn', 'possGain', 'throwIn']] = pd.get_dummies(chains['Initial_State'])

# %%
chains['Event_Type1'] = chains['Description'].shift(1)
shots = chains[chains['Shot_At_Goal'] == True]
shots['Set_Shot'] = shots['Event_Type1'].apply(lambda x: ("Mark" in x) or ("Free" in x))
set_shots = shots[shots['Set_Shot']]
open_shots = shots[~shots['Set_Shot']]

# %%
set_shots = expected_score_feature_engineering(set_shots)
open_shots = expected_score_feature_engineering(open_shots)

# %%
set_shots['xGoals'] = expected_goal_set_model.predict_proba(set_shots[goal_set_features], calibrate=True)
set_shots['xBehinds'] = expected_behind_set_model.predict_proba(set_shots[behind_set_features], calibrate=True)
set_shots['xMiss'] = expected_miss_set_model.predict_proba(set_shots[miss_set_features], calibrate=True)

open_shots['xGoals'] = expected_goal_open_model.predict_proba(open_shots[goal_open_features], calibrate=True)
open_shots['xBehinds'] = expected_behind_open_model.predict_proba(open_shots[behind_open_features], calibrate=True)
open_shots['xMiss'] = expected_miss_open_model.predict_proba(open_shots[miss_open_features], calibrate=True)

# %%
exp_shots = pd.concat([set_shots, open_shots], axis=0)
exp_shots = exp_shots.sort_values(by = ['Match_ID', "Chain_Number", "Order"])
shots = shots.merge(exp_shots[['Chain_Number', 'Order', 'Match_ID', 'xGoals', 'xBehinds', 'xMiss']], how = "left", on = ['Chain_Number', 'Order', 'Match_ID'])

# %%
shots['xGoals_normalised'] = shots['xGoals'] / (shots['xGoals'] + shots['xBehinds'] + shots['xMiss'])
shots['xBehinds_normalised'] = shots['xBehinds'] / (shots['xGoals'] + shots['xBehinds'] + shots['xMiss'])
shots['xMiss_normalised'] = shots['xMiss'] / (shots['xGoals'] + shots['xBehinds'] + shots['xMiss'])
shots['xScore'] = shots['xGoals_normalised']*6 + shots['xBehinds_normalised']

# %%
chains = chains.merge(shots[['Match_ID', 'Chain_Number', 'Order', 'xScore', 'xGoals_normalised']], how="left", on = ['Match_ID', 'Chain_Number', 'Order'])
chains[['xScore', 'xGoals_normalised']] = chains[['xScore', 'xGoals_normalised']].fillna(0)
chains.head()
# Out:
#    Chain_Number Initial_State Final_State  Order  Quarter  \
# 0             1  centreBounce        goal    1.0        1
# 1             1  centreBounce        goal    2.0        1
# 2             1  centreBounce        goal    3.0        1
# 3             1  centreBounce        goal    4.0        1
# 4             1  centreBounce        goal    5.0        1
#
#    Quarter_Duration_Chain_Start  Quarter_Duration      Team_Chain  \
# 0                            13              13.0  Brisbane Lions
# 1                            13              24.0  Brisbane Lions
# 2                            13              24.0  Brisbane Lions
# 3                            13              28.0  Brisbane Lions
# 4                            13              29.0  Brisbane Lions
#
#              Team          Player AFL_API_Player_ID     Description     x  \
# 0             NaN             NaN               NaN   Centre Bounce   0.0
# 1  Brisbane Lions     Dayne Zorko       Dayne_Zorko   Hard Ball Get   8.0
# 2  Brisbane Lions     Dayne Zorko       Dayne_Zorko        Handball   9.0
# 3          Sydney  Oliver Florent    Oliver_Florent  Loose Ball Get  11.0
# 4          Sydney  Oliver Florent    Oliver_Florent        Handball  12.0
#
#      y     Disposal Shot_At_Goal Behind_Detail  Venue_Width  Venue_Length  \
# 0  0.0          NaN          NaN           NaN          138           156
# 1 -5.0          NaN          NaN           NaN          138           156
# 2 -6.0  ineffective          NaN           NaN          138           156
# 3 -7.0          NaN          NaN           NaN          138           156
# 4 -5.0    effective          NaN           NaN          138           156
#
#         Home_Team Away_Team Home_Team_Direction_Q1  \
# 0  Brisbane Lions    Sydney                  right
# 1  Brisbane Lions    Sydney                  right
# 2  Brisbane Lions    Sydney                  right
# 3  Brisbane Lions    Sydney                  right
# 4  Brisbane Lions    Sydney                  right
#
#                       Match_ID Round_ID    Year  Season  ballUp  centreBounce  \
# 0  202101_BrisbaneLions_Sydney   202101  2021.0     NaN       0             1
# 1  202101_BrisbaneLions_Sydney   202101  2021.0     NaN       0             1
# 2  202101_BrisbaneLions_Sydney   202101  2021.0     NaN       0             1
# 3  202101_BrisbaneLions_Sydney   202101  2021.0     NaN       0             1
# 4  202101_BrisbaneLions_Sydney   202101  2021.0     NaN       0             1
#
#    kickIn  possGain  throwIn     Event_Type1  xScore  xGoals_normalised
# 0       0         0        0            None     0.0                0.0
# 1       0         0        0   Centre Bounce     0.0                0.0
# 2       0         0        0   Hard Ball Get     0.0                0.0
# 3       0         0        0        Handball     0.0                0.0
# 4       0         0        0  Loose Ball Get     0.0                0.0

# %% [markdown]
# Preprocess

# %%
schema_chains = convert_chains_to_schema(chains)
gamestate_features = create_gamestate_features(schema_chains)

# %%
schema_chains.head()
# Out:
#                       match_id  chain_number  order  quarter  quarter_seconds  \
# 1  202101_BrisbaneLions_Sydney             1    2.0        1             24.0
# 2  202101_BrisbaneLions_Sydney             1    3.0        1             24.0
# 3  202101_BrisbaneLions_Sydney             1    4.0        1             28.0
# 4  202101_BrisbaneLions_Sydney             1    5.0        1             29.0
# 5  202101_BrisbaneLions_Sydney             1    6.0        1             30.0
#
#    overall_seconds            team          player  start_x  start_y  end_x  \
# 1             24.0  Brisbane Lions     Dayne Zorko      8.0     -5.0    9.0
# 2             24.0  Brisbane Lions     Dayne Zorko      9.0     -6.0  -11.0
# 3             28.0          Sydney  Oliver Florent    -11.0      7.0  -12.0
# 4             29.0          Sydney  Oliver Florent    -12.0      5.0  -14.0
# 5             30.0          Sydney   George Hewett    -14.0      2.0  -22.0
#
#    end_y     action_type outcome_type  xScore
# 1   -6.0   Hard Ball Get    effective     0.0
# 2    7.0        Handball  ineffective     0.0
# 3    5.0  Loose Ball Get    effective     0.0
# 4    2.0        Handball    effective     0.0
# 5    2.0           Carry    effective     0.0

# %%
exp_vaep_modelling_data = pd.concat([schema_chains, gamestate_features], axis=1)

# %%
exp_vaep_features = exp_vaep_modelling_data[FEATURES]

# %% [markdown]
# Load models

# %%
model_file_path = "/Users/ciaran/Documents/Projects/AFL/git-repositories/afl-player-ratings/exp_vaep/model_outputs/models/"
scoring_model = "exp_vaep_scoring_v1.joblib"
conceding_model = "exp_vaep_conceding_v1.joblib"

# %%
exp_score_model = joblib.load(model_file_path + "/" + scoring_model)
exp_concede_model = joblib.load(model_file_path + "/" + conceding_model)

# %% [markdown]
# Make predictions

# %%
schema_chains['scores'] = np.clip(exp_score_model.predict(exp_vaep_features), 0, 6)
schema_chains['concedes'] = np.clip(exp_concede_model.predict(exp_vaep_features), 0, 6)

# %%
schema_chains['scores'].describe()
# Out:
# count    947887.000000
# mean          0.814553
# std           0.848166
# min           0.000000
# 25%           0.233094
# 50%           0.595690
# 75%           1.083073
# max           6.000000
# Name: scores, dtype: float64

# %% [markdown]
# Compute VAEP

# %%
match_list = list(schema_chains['match_id'].unique())
match_vaep_list = []
for match in match_list:
    match_chains = schema_chains[schema_chains['match_id'] == match]
    v = value(match_chains, match_chains['scores'], match_chains['concedes'])
    match_vaep_list.append(v)
    
vaep_values = pd.concat(match_vaep_list, axis=0)

# %%
chain_vaep_data = pd.concat([schema_chains, vaep_values], axis=1)
chain_vaep_data.head(12)
# Out:
#                        match_id  chain_number  order  quarter  \
# 1   202101_BrisbaneLions_Sydney             1    2.0        1
# 2   202101_BrisbaneLions_Sydney             1    3.0        1
# 3   202101_BrisbaneLions_Sydney             1    4.0        1
# 4   202101_BrisbaneLions_Sydney             1    5.0        1
# 5   202101_BrisbaneLions_Sydney             1    6.0        1
# 6   202101_BrisbaneLions_Sydney             1    7.0        1
# 7   202101_BrisbaneLions_Sydney             1    8.0        1
# 8   202101_BrisbaneLions_Sydney             1    9.0        1
# 9   202101_BrisbaneLions_Sydney             1   10.0        1
# 10  202101_BrisbaneLions_Sydney             1   11.0        1
# 15  202101_BrisbaneLions_Sydney             2   16.0        1
# 16  202101_BrisbaneLions_Sydney             2   17.0        1
#
#     quarter_seconds  overall_seconds            team           player  \
# 1              24.0             24.0  Brisbane Lions      Dayne Zorko
# 2              24.0             24.0  Brisbane Lions      Dayne Zorko
# 3              28.0             28.0          Sydney   Oliver Florent
# 4              29.0             29.0          Sydney   Oliver Florent
# 5              30.0             30.0          Sydney    George Hewett
# 6              31.0             31.0          Sydney    George Hewett
# 7              36.0             36.0  Brisbane Lions  Hugh McCluggage
# 8              37.0             37.0  Brisbane Lions  Hugh McCluggage
# 9              38.0             38.0  Brisbane Lions       Zac Bailey
# 10             39.0             39.0  Brisbane Lions       Zac Bailey
# 15             92.0             92.0  Brisbane Lions  Oscar McInerney
# 16             93.0             93.0  Brisbane Lions  Oscar McInerney
#
#     start_x  start_y  end_x  end_y     action_type outcome_type    xScore  \
# 1       8.0     -5.0    9.0   -6.0   Hard Ball Get    effective  0.000000
# 2       9.0     -6.0  -11.0    7.0        Handball  ineffective  0.000000
# 3     -11.0      7.0  -12.0    5.0  Loose Ball Get    effective  0.000000
# 4     -12.0      5.0  -14.0    2.0        Handball    effective  0.000000
# 5     -14.0      2.0  -22.0    2.0           Carry    effective  0.000000
# 6     -22.0      2.0    6.0  -27.0            Kick      clanger  0.000000
# 7       6.0    -27.0   11.0  -26.0          Gather    effective  0.000000
# 8      11.0    -26.0   18.0  -23.0        Handball    effective  0.000000
# 9      18.0    -23.0   26.0  -21.0           Carry    effective  0.000000
# 10     26.0    -21.0   26.0  -21.0            Shot    effective  1.727293
# 15     -1.0      0.0    0.0    0.0   Hard Ball Get    effective  0.000000
# 16      0.0      0.0    0.0    0.0            Kick    effective  0.000000
#
#       scores  concedes  offensive_value  defensive_value  vaep_value
# 1   0.246684  0.158121         0.000000        -0.000000    0.000000
# 2   0.000000  0.362654        -0.246684        -0.204533   -0.451217
# 3   0.668677  0.081827         0.306023        -0.081827    0.224196
# 4   0.456306  0.099139        -0.212371        -0.017312   -0.229683
# 5   1.176206  0.069984         0.719900         0.029155    0.749055
# 6   0.000000  0.438838        -1.176206        -0.368854   -1.545059
# 7   1.003286  0.063453         0.564449        -0.063453    0.500995
# 8   0.499200  0.037909        -0.504086         0.025544   -0.478542
# 9   1.979520  0.048713         1.480319        -0.010804    1.469515
# 10  2.211809  0.129209         0.232290        -0.080495    0.151794
# 15  0.487166  0.076116         0.487166        -0.076116    0.411051
# 16  1.626395  0.031167         1.139228         0.044949    1.184177

# %% [markdown]
# Checks

# %%
chain_vaep_data['vaep_value'].max(), chain_vaep_data['vaep_value'].min()
# Out:
# (5.758547306060791, -5.381438732147217)

# %% [markdown]
# Export

# %%
chain_vaep_data.to_csv("/Users/ciaran/Documents/Projects/AFL/git-repositories/afl-player-ratings/data/schema_chains_exp_vaep_values.csv", index=False)
