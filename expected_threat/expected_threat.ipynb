# %% [markdown]
# Expected Threat (xT) Model for AFL

# %%
import pandas as pd
import numpy as np
from mplfooty.pitch import Pitch
import matplotlib.patheffects as path_effects
import matplotlib.pyplot as plt
from highlight_text import fig_text

import sys
sys.path.append("..")
from config import chain_file_path, shots_file_path

import os
import warnings
warnings.filterwarnings('ignore')
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999

# %%
import matplotlib.font_manager as fm

font_path = "/Users/ciaran/Documents/Projects/AFL/git-repositories/afl-player-ratings/viz/fonts"
for x in os.listdir(font_path):
    if x != ".DS_Store":
        for y in os.listdir(f"{font_path}/{x}"):
            if y.split(".")[-1] == "ttf":
                fm.fontManager.addfont(f"{font_path}/{x}/{y}")
                try:
                    fm.FontProperties(weight=y.split("-")[-1].split(".")[0].lower(), fname=y.split("-")[0])
                except Exception:
                    continue
plt.style.use("/Users/ciaran/Documents/Projects/AFL/git-repositories/afl-player-ratings/viz/mplstyle/dark_theme.mplstyle")

# %% [markdown]
# Load Data

# %%
chains = pd.read_csv(chain_file_path)
chains.tail()
# Out:
#          Chain_Number Initial_State Final_State   Order  Quarter  \
# 1169201           252        ballUp    turnover  1984.0        4
# 1169202           252        ballUp    turnover  1985.0        4
# 1169203           253      possGain      behind  1986.0        4
# 1169204           253      possGain      behind  1987.0        4
# 1169205           253      possGain      behind  1988.0        4
#
#          Quarter_Duration_Chain_Start  Quarter_Duration       Team_Chain  \
# 1169201                          1937            1942.0         St Kilda
# 1169202                          1937            1945.0         St Kilda
# 1169203                          1949            1949.0  North Melbourne
# 1169204                          1949            1976.0  North Melbourne
# 1169205                          1949            1978.0  North Melbourne
#
#                     Team               Player    AFL_API_Player_ID  \
# 1169201         St Kilda           Dan Butler           Dan_Butler
# 1169202         St Kilda           Dan Butler           Dan_Butler
# 1169203  North Melbourne  Luke Davies-Uniacke  Luke_Davies-Uniacke
# 1169204  North Melbourne  Luke Davies-Uniacke  Luke_Davies-Uniacke
# 1169205  North Melbourne  Luke Davies-Uniacke  Luke_Davies-Uniacke
#
#                     Description     x     y     Disposal Shot_At_Goal  \
# 1169201                    Kick -65.0  14.0      clanger          NaN
# 1169202  Out On Full After Kick -69.0  34.0          NaN          NaN
# 1169203             OOF Kick In  67.0 -34.0          NaN          NaN
# 1169204                    Kick  67.0 -34.0  ineffective         True
# 1169205                  Behind  67.0 -34.0          NaN          NaN
#
#         Behind_Detail  Venue_Width  Venue_Length Home_Team        Away_Team  \
# 1169201           NaN          129           160  St Kilda  North Melbourne
# 1169202           NaN          129           160  St Kilda  North Melbourne
# 1169203           NaN          129           160  St Kilda  North Melbourne
# 1169204           NaN          129           160  St Kilda  North Melbourne
# 1169205      missLeft          129           160  St Kilda  North Melbourne
#
#         Home_Team_Direction_Q1                       Match_ID Round_ID  Year  \
# 1169201                   left  202319_StKilda_NorthMelbourne   202319   NaN
# 1169202                   left  202319_StKilda_NorthMelbourne   202319   NaN
# 1169203                   left  202319_StKilda_NorthMelbourne   202319   NaN
# 1169204                   left  202319_StKilda_NorthMelbourne   202319   NaN
# 1169205                   left  202319_StKilda_NorthMelbourne   202319   NaN
#
#          Season
# 1169201  2023.0
# 1169202  2023.0
# 1169203  2023.0
# 1169204  2023.0
# 1169205  2023.0

# %%
shots = pd.read_csv(shots_file_path)
shots.tail()
# Out:
#        Chain_Number Initial_State Final_State   Order  Quarter  \
# 28219           226      possGain        goal  1812.0        4
# 28220           230      possGain        miss  1843.0        4
# 28221           242       throwIn      behind  1931.0        4
# 28222           244       throwIn        goal  1943.0        4
# 28223           253      possGain      behind  1987.0        4
#
#        Quarter_Duration_Chain_Start  Quarter_Duration       Team_Chain  \
# 28219                          1101            1141.0  North Melbourne
# 28220                          1242            1315.0         St Kilda
# 28221                          1590            1597.0         St Kilda
# 28222                          1631            1641.0         St Kilda
# 28223                          1949            1976.0  North Melbourne
#
#                   Team               Player    AFL_API_Player_ID  Description  \
# 28219  North Melbourne         Jack Ziebell         Jack_Ziebell         Kick
# 28220         St Kilda         Jack Higgins         Jack_Higgins         Kick
# 28221         St Kilda         Jack Higgins         Jack_Higgins         Kick
# 28222         St Kilda         Jack Higgins         Jack_Higgins  Ground Kick
# 28223  North Melbourne  Luke Davies-Uniacke  Luke_Davies-Uniacke         Kick
#
#           x     y     Disposal  Shot_At_Goal  Behind_Detail  Venue_Width  \
# 28219  52.0  17.0    effective          True            NaN          129
# 28220  65.0 -13.0  ineffective          True            NaN          129
# 28221  59.0 -24.0  ineffective          True            NaN          129
# 28222  65.0   1.0    effective          True            NaN          129
# 28223  67.0 -34.0  ineffective          True            NaN          129
#
#        Venue_Length Home_Team        Away_Team Home_Team_Direction_Q1  \
# 28219           160  St Kilda  North Melbourne                   left
# 28220           160  St Kilda  North Melbourne                   left
# 28221           160  St Kilda  North Melbourne                   left
# 28222           160  St Kilda  North Melbourne                   left
# 28223           160  St Kilda  North Melbourne                   left
#
#                             Match_ID Round_ID  Year  Season  Goal  Behind  \
# 28219  202319_StKilda_NorthMelbourne   202319   NaN  2023.0     1       0
# 28220  202319_StKilda_NorthMelbourne   202319   NaN  2023.0     0       0
# 28221  202319_StKilda_NorthMelbourne   202319   NaN  2023.0     0       1
# 28222  202319_StKilda_NorthMelbourne   202319   NaN  2023.0     1       0
# 28223  202319_StKilda_NorthMelbourne   202319   NaN  2023.0     0       1
#
#        Miss  Score  Home_Score  Away_Score  Home_Current_Score  \
# 28219     0      6           0           6                52.0
# 28220     1      0           0           0                52.0
# 28221     0      1           1           0                52.0
# 28222     0      6           6           0                53.0
# 28223     0      1           0           1                59.0
#
#        Away_Current_Score  Current_Margin  Event_Type0           Event_Type1  \
# 28219                54.0            -2.0         Kick      Uncontested Mark
# 28220                60.0            -8.0         Kick  Loose Ball Get Crumb
# 28221                60.0            -8.0         Kick     Handball Received
# 28222                60.0            -7.0  Ground Kick              Handball
# 28223                60.0            -1.0         Kick           OOF Kick In
#
#                   Event_Type2            Event_Type3    x0    x1    x2    x3  \
# 28219                    Kick          Hard Ball Get  52.0  57.0  57.0  57.0
# 28220                    Kick           Mark On Lead  65.0  64.0  53.0  59.0
# 28221                Handball      Handball Received  59.0  59.0  57.0  57.0
# 28222          Loose Ball Get  Kick Inside 50 Result  65.0  58.0  56.0  57.0
# 28223  Out On Full After Kick                   Kick  67.0  67.0 -69.0 -65.0
#
#          y0    y1    y2    y3  Quarter_Duration0  Quarter_Duration1  \
# 28219  17.0  12.0  39.0  39.0             1141.0             1105.0
# 28220 -13.0 -10.0 -45.0 -35.0             1315.0             1312.0
# 28221 -24.0 -24.0 -27.0 -27.0             1597.0             1596.0
# 28222   1.0   5.0   6.0  12.0             1641.0             1639.0
# 28223 -34.0 -34.0  34.0  14.0             1976.0             1949.0
#
#        Quarter_Duration2  Quarter_Duration3  Chain_Duration  \
# 28219             1103.0             1101.0            40.0
# 28220             1308.0             1277.0            73.0
# 28221             1594.0             1594.0             7.0
# 28222             1638.0             1635.0            10.0
# 28223             1945.0             1942.0            27.0
#
#        Time_Since_Last_Action  Distance_Since_Last_Action  \
# 28219                    36.0                    7.071068
# 28220                     3.0                    3.162278
# 28221                     1.0                    0.000000
# 28222                     2.0                    8.062258
# 28223                    27.0                    0.000000
#
#        Distance_to_Right_Goal_x  Distance_to_Middle_y  \
# 28219                      28.0                  17.0
# 28220                      15.0                  13.0
# 28221                      21.0                  24.0
# 28222                      15.0                   1.0
# 28223                      13.0                  34.0
#
#        Distance_to_Middle_Goal  Angle_to_Middle_Goal  \
# 28219                32.756679              0.545655
# 28220                19.849433              0.714091
# 28221                31.890437              0.851966
# 28222                15.033296              0.066568
# 28223                36.400549              1.205595
#
#        Angle_to_Middle_Goal_degrees  Visible_Goal_Angle  \
# 28219                     31.263732            0.168618
# 28220                     40.914383            0.250156
# 28221                     48.814075            0.133498
# 28222                      3.814075            0.444939
# 28223                     69.075498            0.063282
#
#        Visible_Goal_Angle_degrees  Visible_Behind_Angle  \
# 28219                    9.661075              0.548102
# 28220                   14.332903              0.954148
# 28221                    7.648847              0.435967
# 28222                   25.493117              2.151823
# 28223                    3.625764              0.202459
#
#        Visible_Behind_Angle_degrees  Squared_Distance_to_Middle_Goal  \
# 28219                     31.403910                            784.0
# 28220                     54.668647                            225.0
# 28221                     24.979086                            441.0
# 28222                    123.290380                            225.0
# 28223                     11.600067                            169.0
#
#        Log_Distance_to_Middle_Goal  Set_Shot  GoalTrainingSet  GoalTestSet  \
# 28219                     3.332205      True             True        False
# 28220                     2.708050     False            False        False
# 28221                     3.044522     False             True        False
# 28222                     2.708050     False             True        False
# 28223                     2.564949     False             True        False
#
#        GoalValidationSet  BehindTrainingSet  BehindTestSet  \
# 28219              False               True          False
# 28220               True               True          False
# 28221              False              False           True
# 28222              False               True          False
# 28223              False              False           True
#
#        BehindValidationSet  MissTrainingSet  MissTestSet  MissValidationSet  \
# 28219                False            False        False               True
# 28220                False             True        False              False
# 28221                False            False         True              False
# 28222                False             True        False              False
# 28223                False             True        False              False
#
#        ballUp  centreBounce  kickIn  possGain  throwIn    xGoals  xBehinds  \
# 28219       0             0       0         1        0  0.628677  0.398786
# 28220       0             0       0         1        0  0.490412  0.329002
# 28221       0             0       0         0        1  0.246542  0.421199
# 28222       0             0       0         0        1  0.668933  0.327296
# 28223       0             0       0         1        0  0.224486  0.425898
#
#           xMiss  xGoals_normalised  xBehinds_normalised  xMiss_normalised  \
# 28219  0.013314           0.604046             0.383161          0.012792
# 28220  0.194007           0.483918             0.324645          0.191438
# 28221  0.312598           0.251487             0.429647          0.318867
# 28222  0.093059           0.614101             0.300468          0.085431
# 28223  0.354327           0.223433             0.423901          0.352666
#
#          xScore
# 28219  4.007439
# 28220  3.228152
# 28221  1.938567
# 28222  3.985076
# 28223  1.764501

# %%
chains = chains.merge(shots[['Chain_Number', 'Order', 'Match_ID', 'Score', 'xScore', 'xGoals_normalised']], how='left', on=['Chain_Number', 'Order', 'Match_ID'])
chains[['Score', 'xScore', 'xGoals_normalised']] = chains[['Score', 'xScore', 'xGoals_normalised']].fillna(0)

# %% [markdown]
# Expected Threat Data

# %%
xthreat_data = chains.copy()

xthreat_data = xthreat_data.dropna(subset=['Player'])
xthreat_data = xthreat_data[~(xthreat_data['Description']=="Kick Into F50")]
xthreat_data = xthreat_data[~(xthreat_data['Description']=="Goal")]

xthreat_data['end_x'] = xthreat_data.groupby('Match_ID')['x'].shift(-1).fillna(0)
xthreat_data['end_y'] = xthreat_data.groupby('Match_ID')['y'].shift(-1).fillna(0)

xthreat_data['type_name'] = np.where(xthreat_data['Description'] == "Handball", "Handball",
                                     np.where((xthreat_data['Description'] == 'Kick') & (xthreat_data['Shot_At_Goal']==True), "Shot",
                                               np.where(xthreat_data['Description']=='Kick', "Kick",
                                                        "Carry")))
xthreat_data['outcome_name'] = (xthreat_data['type_name'] == "Carry") | (xthreat_data['Disposal'] == "effective")
xthreat_data['goal'] = (xthreat_data['type_name'] == "Shot") & (xthreat_data['Final_State'] == "goal")
xthreat_data['shoot'] = xthreat_data['type_name'] == "Shot"
xthreat_data['move'] = xthreat_data['type_name'] != "Shot"

xthreat_data['Year'] = xthreat_data['Match_ID'].apply(lambda x: int(x[:4]))
xthreat_data = xthreat_data[['Match_ID', 'Year', 'Team', 'Player', 'type_name', 'outcome_name', 'x', 'y', 'end_x', 'end_y', 'xScore', 'goal', 'shoot', 'move']]

xthreat_data.head(5)
# Out:
#                       Match_ID  Year            Team          Player  \
# 1  202101_BrisbaneLions_Sydney  2021  Brisbane Lions     Dayne Zorko
# 2  202101_BrisbaneLions_Sydney  2021  Brisbane Lions     Dayne Zorko
# 3  202101_BrisbaneLions_Sydney  2021          Sydney  Oliver Florent
# 4  202101_BrisbaneLions_Sydney  2021          Sydney  Oliver Florent
# 5  202101_BrisbaneLions_Sydney  2021          Sydney   George Hewett
#
#   type_name  outcome_name     x    y  end_x  end_y  xScore   goal  shoot  move
# 1     Carry          True   8.0 -5.0    9.0   -6.0     0.0  False  False  True
# 2  Handball         False   9.0 -6.0   11.0   -7.0     0.0  False  False  True
# 3     Carry          True  11.0 -7.0   12.0   -5.0     0.0  False  False  True
# 4  Handball          True  12.0 -5.0   14.0   -2.0     0.0  False  False  True
# 5     Carry          True  14.0 -2.0   22.0   -2.0     0.0  False  False  True

# %% [markdown]
# Bin the Data

# %%
pitch = Pitch(pitch_width=135, pitch_length=165, line_zorder=2,
              line_colour="white", pitch_colour="#121212", 
              line_width=0.5)
bins = (40, 32)

# %%
shot_probability = pitch.bin_statistic(xthreat_data['x'], xthreat_data['y'], values=xthreat_data['shoot'],
                                       statistic='mean', bins=bins)
move_probability = pitch.bin_statistic(xthreat_data['x'], xthreat_data['y'], values=xthreat_data['move'],
                                       statistic='mean', bins=bins)
goal_probability = pitch.bin_statistic(xthreat_data.loc[xthreat_data['shoot'], 'x'],
                                       xthreat_data.loc[xthreat_data['shoot'], 'y'], 
                                       values=xthreat_data.loc[xthreat_data['shoot'], 'goal'],
                                       statistic='mean', bins=bins)

# %%
shots = xthreat_data[xthreat_data['shoot']]
shot_count = pitch.bin_statistic(shots['x'], shots['y'], bins=bins)
action_count = pitch.bin_statistic(xthreat_data['x'], xthreat_data['y'], bins=bins)

shot_count['statistic'][15][39], action_count['statistic'][15][39]
# Out:
# (67.0, 279.0)

# %%
shot_probability['statistic'][15][39], shot_probability['statistic'][16][39]
# Out:
# (0.24014336917562723, 0.20833333333333334)

# %%
goal_probability['statistic'][15][39], goal_probability['statistic'][16][39]
# Out:
# (0.9701492537313433, 0.9333333333333333)

# %% [markdown]
# Plot Shot Probability

# %%
shot_probability['statistic'].shape
# Out:
# (32, 40)

# %%
fig, ax = pitch.draw()
fig.dpi = 300
shot_heatmap = pitch.heatmap(shot_probability, ax=ax, cmap = "magma")
fig_text(0.15, 0.92, s="Shot Probability", font="Karla", fontsize=16)
label_heatmap = pitch.label_heatmap(shot_probability, ax=ax, str_format='{:.1%}', color="black", fontsize=2, va="center", ha="center")

# plt.savefig(
# 	"figures/20230729_shot_probability.png",
# 	dpi = 300,
# 	facecolor = "#121212",
# 	bbox_inches="tight",
#     edgecolor="none",
# 	transparent = False
# )

# %% [markdown]
# Plot move probability

# %%
fig, ax = pitch.draw()
fig.dpi = 300
move_heatmap = pitch.heatmap(move_probability, ax=ax, cmap = "magma")
label_heatmap = pitch.label_heatmap(move_probability, ax=ax, str_format='{:.1%}', color="black", fontsize=2, va="center", ha="center")

fig_text(0.15, 0.92, s="Move Probability", font="Karla", fontsize=16)

# plt.savefig(
# 	"figures/20230729_move_probability.png",
# 	dpi = 300,
# 	facecolor = "#121212",
# 	bbox_inches="tight",
#     edgecolor="none",
# 	transparent = False
# )

# %% [markdown]
# Plot goal probability

# %%
fig, ax = pitch.draw()
fig.dpi = 300
goal_heatmap = pitch.heatmap(goal_probability, ax=ax, cmap = "magma")
label_heatmap = pitch.label_heatmap(goal_probability, ax=ax, str_format='{:.1%}', color="black", fontsize=2, va="center", ha="center")

fig_text(0.15, 0.92, s="Goal Probability", font="Karla", fontsize=16)

# plt.savefig(
# 	"figures/20230729_goal_probability.png",
# 	dpi = 300,
# 	facecolor = "#121212",
# 	bbox_inches="tight",
#     edgecolor="none",
# 	transparent = False
# )

# %% [markdown]
# Calculate the move transition matrix

# %%
# Get a data frame of move events and filter it so only contains actions inside the pitch
move = xthreat_data[xthreat_data['move']].copy()
bin_start_locations = pitch.bin_statistic(move['x'], move['y'], bins=bins)
move = move[bin_start_locations['inside']].copy()

# get successful moves
bin_end_locations = pitch.bin_statistic(move['end_x'], move['end_y'], bins=bins)
move_success = move[(bin_end_locations['inside']) & (move['outcome_name'] == True)].copy()

# get a dataframe of successful moves and the grid cells they start/end in
bin_success_start = pitch.bin_statistic(move_success['x'], move_success['y'], bins=bins)
bin_success_end = pitch.bin_statistic(move_success['end_x'], move_success['end_y'], bins = bins)
df_bin = pd.DataFrame({
    'x': bin_success_start['binnumber'][0],
    'y': bin_success_start['binnumber'][1],
    'end_x': bin_success_end['binnumber'][0],
    'end_y': bin_success_end['binnumber'][1]
})

# calculate the bin counts for successful moves (number of moves between grid cells)
bin_counts = df_bin.value_counts().reset_index(name='bin_counts')
# create the move_transition_matrix of shape (num_y_bins, num_x_bins, num_y_bins, num_x_bins)
# this is the number of successful moves between grid cells
num_y, num_x = shot_probability['statistic'].shape
move_transition_matrix = np.zeros((num_y, num_x, num_y, num_x))
move_transition_matrix[bin_counts['y'], bin_counts['x'], bin_counts['end_y'], bin_counts['end_x']] = bin_counts['bin_counts'].values

# and divide by the starting locations for all moves to get probability of moving ball successfully
bin_start_locations = pitch.bin_statistic(move['x'], move['y'], bins=bins)
bin_start_locations = np.expand_dims(bin_start_locations['statistic'], (2, 3))
move_transition_matrix = np.divide(move_transition_matrix, bin_start_locations, out=np.zeros_like(move_transition_matrix), where=bin_start_locations != 0)

# %% [markdown]
# Get the matrices

# %%
move_transition_matrix = np.nan_to_num(move_transition_matrix)
shot_probability_matrix = np.nan_to_num(shot_probability['statistic'])
move_probability_matrix = np.nan_to_num(move_probability['statistic'])
goal_probability_matrix = np.nan_to_num(goal_probability['statistic'])

# %% [markdown]
# Calculate xT

# %%
xT = np.multiply(shot_probability_matrix, goal_probability_matrix)
diff=1
iteration=0
while np.any(diff > 0.00001): # iterate until the differences are small
    xT_copy = xT.copy()
    # Calculate the new expected threat
    xT = (np.multiply(shot_probability_matrix, goal_probability_matrix) + 
          np.multiply(move_probability_matrix, 
                      np.multiply(move_transition_matrix, np.expand_dims(xT, axis=(0, 1))).sum(axis=(2,3))))
    diff = (xT - xT_copy)
    iteration += 1
print('Number of iterations: ', iteration)

# %% [markdown]
# Plot xT grid

# %%
path_eff = [path_effects.Stroke(linewidth=1.5, foreground="black"),
            path_effects.Normal()]
# new bin statistic for plotting only
for_plotting = pitch.bin_statistic(xthreat_data['x'], xthreat_data['y'], bins=bins)
for_plotting['statistic'] = xT
fig, ax = pitch.draw()
fig.dpi = 300
heatmap = pitch.heatmap(for_plotting, ax=ax, cmap = "magma")
label_heatmap = pitch.label_heatmap(for_plotting, ax=ax, str_format='{:.1%}', color="black", fontsize=2, va="center", ha="center")

fig_text(0.15, 0.92, s="Expected Threat", font="Karla", fontsize=16)

plt.savefig(
	"figures/20230729_expected_threat.png",
	dpi = 300,
	facecolor = "#121212",
	bbox_inches="tight",
    edgecolor="none",
	transparent = False
)

# %% [markdown]
# Scoring Events

# %%
# Get grid start ad end cells
grid_start = pitch.bin_statistic(move_success['x'], move_success['y'], bins=bins)
grid_end = pitch.bin_statistic(move_success['end_x'], move_success['end_y'], bins=bins)

# Then xT values from start and end grid cell
start_xT = xT[grid_start['binnumber'][1], grid_start['binnumber'][0]]
end_xT = xT[grid_end['binnumber'][1], grid_end['binnumber'][0]]

# calculate added xT
added_xT = end_xT - start_xT
move_success['xT'] = added_xT

# %%
move_success.head()

# %% [markdown]
# Chain data filters

# %%
def split_threat_data(threat):
    
    kick_threat = threat[threat['type_name'] == "Kick"]
    pass_threat = threat[threat['type_name'] == "Handball"]
    carry_threat = threat[threat['type_name'] == "Carry"]
    
    return kick_threat, pass_threat, carry_threat

# %%
threat = move_success.copy()
kick_threat, pass_threat, carry_threat = split_threat_data(threat)

threat_2021 = threat[threat['Year'] == 2021]
kick_threat_2021, pass_threat_2021, carry_threat_2021 = split_threat_data(threat_2021)
threat_2022 = threat[threat['Year'] == 2022]
kick_threat_2022, pass_threat_2022, carry_threat_2022 = split_threat_data(threat_2022)
threat_2023 = threat[threat['Year'] == 2023]
kick_threat_2023, pass_threat_2023, carry_threat_2023 = split_threat_data(threat_2023)

# %%
threat.to_csv("../data/match_chains_202319_expected_threat.csv")

# %% [markdown]
# Expected Threat Total

# %%
def get_total_by_player(threat, top_n=10):
    
    return threat.groupby('Player')['xT'].sum().sort_values(ascending=False).head(top_n)

# %% [markdown]
# **Interpretation**: These are the top players whose actions created the highest cumulative change in xT. These are the players who have increased the likelihood of their team scoring in the next few actions the most across the specified dataset.

# %%
get_total_by_player(threat, top_n=10)

# %%
get_total_by_player(threat_2021, top_n=10)

# %%
get_total_by_player(threat_2022, top_n=10)

# %%
get_total_by_player(threat_2023, top_n=10)

# %% [markdown]
# Kicks

# %%
get_total_by_player(kick_threat, top_n=10)

# %%
get_total_by_player(kick_threat_2021, top_n=10)

# %%
get_total_by_player(kick_threat_2022, top_n=10)

# %%
get_total_by_player(kick_threat_2023, top_n=10)

# %% [markdown]
# Handball

# %%
get_total_by_player(pass_threat)

# %%
get_total_by_player(pass_threat_2021)

# %%
get_total_by_player(pass_threat_2022)

# %%
get_total_by_player(pass_threat_2023)

# %% [markdown]
# Carry

# %%
get_total_by_player(carry_threat)

# %%
get_total_by_player(carry_threat_2021)

# %%
get_total_by_player(carry_threat_2022)

# %%
get_total_by_player(carry_threat_2023)

# %% [markdown]
# Player Profile

# %%
def get_player_threat(threat, player):
    
    player = threat[threat['Player'] == player]
    return player.groupby('type_name')['xT'].sum()

# %%
get_player_threat(threat, "Christian Petracca")

# %%
get_player_threat(threat_2021, "Christian Petracca")

# %%
get_player_threat(threat_2022, "Christian Petracca")

# %%
get_player_threat(threat_2023, "Christian Petracca")

# %% [markdown]
# Expected Threat per Game

# %%
def get_threat_per_game_by_player(threat, top_n=10, min_games = 0):
    
    average_xT = threat.groupby('Player').agg(
        xT = ('xT', 'sum'),
        games = ('Match_ID', 'nunique'))
    average_xT['xTperGame'] = average_xT['xT'] / average_xT['games']
    average_xT = average_xT[average_xT['games'] > min_games]
    average_xT = average_xT.sort_values(by = 'xTperGame', ascending=False)
    return average_xT.head(top_n)

# %%
get_threat_per_game_by_player(threat, top_n=10, min_games=20)

# %%
get_threat_per_game_by_player(threat_2021, top_n=10, min_games=10)

# %%
get_threat_per_game_by_player(threat_2022, top_n=10, min_games=10)

# %%
get_threat_per_game_by_player(threat_2023, top_n=10, min_games=10)

# %% [markdown]
# Expected Threat per Action

# %%
def get_threat_per_action_by_player(threat, top_n=10, min_actions = 0):
    
    average_xT = threat.groupby('Player').agg(
        xT = ('xT', 'sum'),
        actions = ('xT', 'count'))
    average_xT['xTperAction'] = average_xT['xT'] / average_xT['actions']
    average_xT = average_xT[average_xT['actions'] > min_actions]
    average_xT = average_xT.sort_values(by = 'xTperAction', ascending=False)
    return average_xT.head(top_n)

# %%
get_threat_per_action_by_player(threat, top_n=10, min_actions = 1000)

# %%
get_threat_per_action_by_player(threat_2021, top_n=10, min_actions = 500)

# %%
get_threat_per_action_by_player(threat_2022, top_n=10, min_actions = 500)

# %%
get_threat_per_action_by_player(threat_2023, top_n=10, min_actions = 500)
