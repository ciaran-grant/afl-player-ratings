# %% [markdown]
# Create and Test Team Ratings for 2023 Season - Round by Round

# %%
import pandas as pd
import re
import numpy as np
from scipy import stats
from sklearn import metrics

import os
import warnings
warnings.filterwarnings('ignore')
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999
pd.set_option('display.precision', 4)

# %%
player_stats = pd.read_csv("/Users/ciaran/Documents/Projects/AFL/data/scored_player_stats_v2.csv")
player_stats['Season'] = player_stats['Match_ID'].apply(lambda x: int(x[:4]))
player_stats['Player_Season'] = player_stats['Player'] + "_" + player_stats['Season'].astype(str)

player_stats['Score'] = player_stats['Behinds'] + player_stats['Goals']*6
player_stats['xScore_Diff'] = player_stats['Score'] - player_stats['xScore']

player_stats['Home_Team'] = player_stats['Match_ID'].apply(lambda x: x.split("_")[1]).str.replace(r"([A-Z])", r" \1").str.strip()
player_stats['Away_Team'] = player_stats['Match_ID'].apply(lambda x: x.split("_")[-1]).str.replace(r"([A-Z])", r" \1").str.strip()
player_stats['Opponent'] = np.where(player_stats['Team'] == player_stats['Home_Team'], player_stats['Away_Team'], player_stats['Home_Team'])

finals_round_map = {'F1':24,
                    'F2':25,
                    'F3':26,
                    'F4':27}
player_stats['Round_ID'] = player_stats['Round_ID'].astype(str)
player_stats['Round'] = (player_stats['Round_ID'].str[4:].replace(finals_round_map)).astype(int)
player_stats['Round_str'] = player_stats['Round_ID'].str[4:].replace(finals_round_map)
player_stats['Round_ID_num'] = (player_stats['Season'].astype(str) + player_stats['Round'].astype(str)).astype(int)

player_stats.tail()
# Out:
#                         Match_ID        Team               Player Round_ID  \
# 28536  202324_WestCoast_Adelaide  West Coast           Ryan Maric   202324
# 28537  202324_WestCoast_Adelaide  West Coast  Sam Petrevski-Seton   202324
# 28538  202324_WestCoast_Adelaide  West Coast         Shannon Hurn   202324
# 28539  202324_WestCoast_Adelaide  West Coast            Tim Kelly   202324
# 28540  202324_WestCoast_Adelaide  West Coast             Tom Cole   202324
#
#          AFL_API_Player_ID      Player_Type     playerId  Age  Height  Weight  \
# 28536           Ryan_Maric      KEY_FORWARD  CD_I1029416   18     196      93
# 28537  Sam_Petrevski-Seton   MEDIUM_FORWARD   CD_I994539   25     181      78
# 28538         Shannon_Hurn  MEDIUM_DEFENDER   CD_I240283   35     187      95
# 28539            Tim_Kelly       MIDFIELDER   CD_I295898   29     184      83
# 28540             Tom_Cole  MEDIUM_DEFENDER   CD_I993820   26     188      83
#
#        Number Kicking_Foot State_Of_Origin  Draft_Year  Debut_Year  \
# 28536      41        RIGHT             VIC      2023.0      2023.0
# 28537      10        RIGHT              WA      2016.0      2017.0
# 28538      25        RIGHT              SA      2005.0      2006.0
# 28539      11        RIGHT              WA      2017.0      2018.0
# 28540      28        RIGHT             VIC      2015.0      2016.0
#
#                                        Recruited_From  Draft_Position  \
# 28536  Drouin Vic)/Gippsland U18/Box Hill Hawks (VFL)             1.0
# 28537       Halls Creek (WA)/Claremont (WAFL)/Carlton             6.0
# 28538          Angaston (SA)/Central District (SANFL)            13.0
# 28539     Palmyra (WA)/South Fremantle (WAFL)/Geelong            24.0
# 28540                     Sandhurst (Vic)/Bendigo U18            36.0
#
#           Draft_Type                                          Photo_URL  \
# 28536          other  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
# 28537  nationalDraft  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
# 28538  nationalDraft  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
# 28539  nationalDraft  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
# 28540  nationalDraft  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
#
#       Date_Of_Birth  Percent_Played  Behinds  Bounces  \
# 28536    2004-09-06              71        0      0.0
# 28537    1998-02-19              61        0      0.0
# 28538    1987-09-04              83        0      0.0
# 28539    1994-07-26              84        0      2.0
# 28540    1997-05-28              83        0      0.0
#
#        Centre_Bounces_Attended  Centre_Clearances  Clangers  \
# 28536                      NaN                  0         0
# 28537                      NaN                  0         3
# 28538                      NaN                  0         2
# 28539                      NaN                  4         5
# 28540                      NaN                  0         2
#
#        Defensive_Contest_Losses  Defensive_Contest_Loss_Percentage  \
# 28536                       NaN                                NaN
# 28537                       NaN                                NaN
# 28538                       NaN                                NaN
# 28539                       NaN                                NaN
# 28540                       NaN                                NaN
#
#        Defensive_One_On_One_Contests  Contested_Marks  \
# 28536                            NaN                0
# 28537                            NaN                0
# 28538                            NaN                0
# 28539                            NaN                0
# 28540                            NaN                0
#
#        Contested_Possession_Rate  Contested_Possessions  \
# 28536                        NaN                      2
# 28537                        NaN                      6
# 28538                        NaN                      2
# 28539                        NaN                     15
# 28540                        NaN                      4
#
#        Offensive_One_On_One_Contests  Offensive_Contest_Wins  \
# 28536                            NaN                     NaN
# 28537                            NaN                     NaN
# 28538                            NaN                     NaN
# 28539                            NaN                     NaN
# 28540                            NaN                     NaN
#
#        Offensive_Contest_Win_Percentage  Defensive_Half_Pressure_Acts  \
# 28536                               NaN                           NaN
# 28537                               NaN                           NaN
# 28538                               NaN                           NaN
# 28539                               NaN                           NaN
# 28540                               NaN                           NaN
#
#        Disposal_Efficiency  Disposals  AFL_Fantasy_Points  \
# 28536                 77.8          9                  49
# 28537                 83.3         18                  64
# 28538                 95.5         22                  89
# 28539                 77.1         35                 111
# 28540                 81.3         16                  80
#
#        Effective_Disposals  Effective_Kicks  Inside_50_Ground_Ball_Gets  \
# 28536                  NaN              NaN                         NaN
# 28537                  NaN              NaN                         NaN
# 28538                  NaN              NaN                         NaN
# 28539                  NaN              NaN                         NaN
# 28540                  NaN              NaN                         NaN
#
#        Frees_Against  Frees_For  Goal_Accuracy  Goal_Assists  Goals  \
# 28536              0          2            0.0             1      0
# 28537              0          1            0.0             1      0
# 28538              0          1            0.0             0      0
# 28539              1          4            0.0             3      0
# 28540              1          1          100.0             0      1
#
#        Ground_Ball_Gets  Handballs  Hit_Outs  Hit_Outs_To_Advantage  \
# 28536               NaN          3         0                    NaN
# 28537               NaN         12         0                    NaN
# 28538               NaN          4         0                    NaN
# 28539               NaN         13         0                    NaN
# 28540               NaN          5         0                    NaN
#
#        Hit_Outs_To_Advantage_Rate  Hit_Out_Win_Percentage  Inside_50s  \
# 28536                         NaN                     NaN           0
# 28537                         NaN                     NaN           0
# 28538                         NaN                     NaN           0
# 28539                         NaN                     NaN          12
# 28540                         NaN                     NaN           2
#
#        Intercept_Marks  Intercepts  Kick_Efficiency  Kick_Ins  \
# 28536              NaN           1              NaN       NaN
# 28537              NaN           4              NaN       NaN
# 28538              NaN           4              NaN       NaN
# 28539              NaN           4              NaN       NaN
# 28540              NaN           3              NaN       NaN
#
#        Kick_Ins_Played_On  Kicks  Kick_To_Handball_Ratio  Marks  \
# 28536                 NaN      6                     NaN      5
# 28537                 NaN      6                     NaN      3
# 28538                 NaN     18                     NaN      6
# 28539                 NaN     22                     NaN      6
# 28540                 NaN     11                     NaN      7
#
#        Marks_Inside_50  Marks_On_Lead  Metres_Gained  One_Percenters  \
# 28536                0            NaN          114.0               0
# 28537                0            NaN           87.0               1
# 28538                0            NaN          506.0               3
# 28539                0            NaN          831.0               0
# 28540                1            NaN          249.0               1
#
#        Pressure_Acts  Player_Rating_Points  Rebound_50s  Ruck_Contests  \
# 28536            NaN                   NaN            1            NaN
# 28537            NaN                   NaN            2            NaN
# 28538            NaN                   NaN            7            NaN
# 28539            NaN                   NaN            3            NaN
# 28540            NaN                   NaN            4            NaN
#
#        Score_Involvements  Score_Launches  Shots_At_Goal  Spoils  \
# 28536                   3             NaN              0     NaN
# 28537                   2             NaN              0     NaN
# 28538                   2             NaN              0     NaN
# 28539                   8             NaN              0     NaN
# 28540                   3             NaN              1     NaN
#
#        Stoppage_Clearances  Tackles  Tackles_Inside_50  Clearances  \
# 28536                    0        2                  0           0
# 28537                    0        3                  0           0
# 28538                    1        2                  0           1
# 28539                    4        0                  0           8
# 28540                    0        3                  0           0
#
#        Possessions  Turnovers  Uncontested_Possessions AFLCA_Player_ID  \
# 28536           10          2                        8             NaN
# 28537           18          4                       12             NaN
# 28538           12          2                       10             NaN
# 28539           34          7                       19       Tim_Kelly
# 28540           16          2                       12             NaN
#
#        Coaches_Votes                 Position Team_Status Position_Sub_Group  \
# 28536            NaN  Half Forward Flank Left  FINAL_TEAM       Half-Forward
# 28537            NaN              Interchange  FINAL_TEAM        Interchange
# 28538            NaN        Back Pocket Right  FINAL_TEAM        Back-Pocket
# 28539            6.0                   Centre  FINAL_TEAM             Centre
# 28540            NaN     Half Back Flank Left  FINAL_TEAM          Half-Back
#
#       Position_Group  Year  Brownlow_Votes  Season  xScore  xT_created  \
# 28536        Forward   NaN             NaN    2023  0.0000     -0.0587
# 28537    Interchange   NaN             NaN    2023  0.0000     -0.2735
# 28538           Back   NaN             NaN    2023  0.0000     -0.3356
# 28539       Midfield   NaN             NaN    2023  0.0000      1.1046
# 28540           Back   NaN             NaN    2023  2.7773      0.1080
#
#        xT_denied  vaep_value  offensive_value  defensive_value  \
# 28536     0.0408      0.0525          -0.1360           0.1885
# 28537     0.0312     -0.4014          -0.2771          -0.1243
# 28538     0.0329      0.6958           0.1442           0.5515
# 28539     0.2033      2.3888           2.3904          -0.0016
# 28540    -0.0087      0.7950           0.9625          -0.1674
#
#        exp_vaep_value  exp_offensive_value  exp_defensive_value  xT_received  \
# 28536          2.1304               0.9662               1.1643       0.2911
# 28537         -2.3624              -1.7040              -0.6584      -0.1613
# 28538          1.3235               2.1248              -0.8013      -1.5501
# 28539         12.8146              12.1432               0.6714      -0.3468
# 28540          1.1599               3.0247              -1.8648      -0.2037
#
#        xT_prevented  vaep_value_received  exp_vaep_value_received  \
# 28536        0.0000               0.4040                   4.3952
# 28537        0.1136              -0.0440                   0.1591
# 28538        0.1773              -0.4591                  -1.6297
# 28539        0.1719               2.0546                  12.1317
# 28540        0.0082              -0.5325                  -2.1933
#
#                   Player_Season  Score  xScore_Diff   Home_Team Away_Team  \
# 28536           Ryan Maric_2023      0       0.0000  West Coast  Adelaide
# 28537  Sam Petrevski-Seton_2023      0       0.0000  West Coast  Adelaide
# 28538         Shannon Hurn_2023      0       0.0000  West Coast  Adelaide
# 28539            Tim Kelly_2023      0       0.0000  West Coast  Adelaide
# 28540             Tom Cole_2023      6       3.2227  West Coast  Adelaide
#
#        Opponent  Round Round_str  Round_ID_num
# 28536  Adelaide     24        24        202324
# 28537  Adelaide     24        24        202324
# 28538  Adelaide     24        24        202324
# 28539  Adelaide     24        24        202324
# 28540  Adelaide     24        24        202324

# %% [markdown]
# Pre-Season

# %%
def get_previous_round_id(round_id):
    
    finals_round_map = {'F1':24,
                        'F2':25,
                        'F3':26,
                        'F4':27}
    
    season = round_id[:4]
    if 'F' in round_id:
        round_num = finals_round_map[round_id[4:]]
    else:
        round_num = round_id[4:]
    
    previous_round_num = int(round_id[4:])-1
    previous_round_num = str(previous_round_num).zfill(2)
    if previous_round_num == 1:
        previous_season = int(season) - 1
    else:
        previous_season = season
    previous_round_id = str(previous_season) + str(previous_round_num)
    
    return previous_round_id

# %%
def get_score_standard_deviation(data):
    return data.groupby(['Match_ID', 'Team']).sum()['Score'].std()

# %%
def create_team_summary(player_stats, rounds = None):
    
    player_stats_copy = player_stats.copy()
    
    if rounds is not None:
        all_rounds = sorted(list(set(player_stats_copy['Round_ID'])))
        rating_rounds = all_rounds[-rounds:]
        player_stats_copy = player_stats_copy[player_stats_copy['Round_ID'].isin(rating_rounds)]
    
    team_for = player_stats_copy.groupby(['Team']).sum()[['Score', 'xScore','vaep_value', 'vaep_value_received', 'offensive_value', 'defensive_value', 'exp_vaep_value', 'exp_vaep_value_received', 'exp_offensive_value', 'exp_defensive_value']]
    team_for.columns = [x+"_F" for x in list(team_for)]
    team_against = player_stats_copy.groupby(['Opponent']).sum()[['Score', 'xScore', 'vaep_value', 'vaep_value_received', 'offensive_value', 'defensive_value', 'exp_vaep_value', 'exp_vaep_value_received', 'exp_offensive_value', 'exp_defensive_value']]
    team_against.columns = [x+"_A" for x in list(team_against)]
    team_games = player_stats_copy.groupby(['Match_ID', 'Team']).size().reset_index().groupby(['Team']).count()[['Match_ID']]
    team_games.columns = ['Games']
    team_summary = pd.concat([team_games, team_for, team_against], axis=1)
    
    for col in [x.replace("_F", "") for x in list(team_for)]:
        team_summary[col+"_pergame_F"] = team_summary[col+"_F"] / team_summary["Games"]
        team_summary[col+"_pergame_A"] = team_summary[col+"_A"] / team_summary["Games"]

        team_summary[col+"_diff"] = team_summary[col+"_F"] - team_summary[col+"_A"]
        team_summary[col+"_pergame_diff"] = team_summary[col+"_pergame_F"] - team_summary[col+"_pergame_A"]

    return team_summary

# %%
def get_teams(match_id):
    
    home_team = re.sub(r"\B([A-Z])", r" \1", match_id.split("_")[1])
    away_team = re.sub(r"\B([A-Z])", r" \1", match_id.split("_")[-1])

    return home_team, away_team

# %%
def calculate_match_projections(home_attack_rating, home_defence_rating, away_attack_rating, away_defence_rating):
    
    home_projected_score = (home_attack_rating + away_defence_rating)*0.5
    away_projected_score = (home_defence_rating + away_attack_rating)*0.5
    projected_margin = home_projected_score - away_projected_score
    
    return home_projected_score, away_projected_score, projected_margin

# %%
def get_match_ratings(team_summary, home_team, away_team):
    
    match_ratings_dict = {'home_attack_rating':team_summary.loc[home_team]['xScore_pergame_F'],
                          'home_defence_rating':team_summary.loc[home_team]['xScore_pergame_A'],
                          'away_attack_rating':team_summary.loc[away_team]['xScore_pergame_F'],
                          'away_defence_rating':team_summary.loc[away_team]['xScore_pergame_A']}
    
    return match_ratings_dict

# %%
def calculate_projected_probabilities(home_projected_score, away_projected_score, score_std=25):
    
    projected_margin = home_projected_score - away_projected_score
    projected_margin_distribution = stats.norm(loc = projected_margin, scale = score_std)
    
    away_team_win_probability = projected_margin_distribution.cdf(0)
    draw_probability = projected_margin_distribution.pdf(0)
    home_team_win_probability = 1 - away_team_win_probability - draw_probability
    
    return home_team_win_probability, draw_probability, away_team_win_probability

# %%
def get_match_prediction_metrics(projected_margin, margin):
    
    mae = abs(projected_margin - margin)
    mse = ((projected_margin)**2 + (margin)**2)
    rmse = ((projected_margin)**2 + (margin)**2)**0.5
    
    return mae, mse, rmse

# %%
def get_match_result(data, match_id):
    
    home_team, away_team = get_teams(match_id)
    match_player_stats = data[data['Match_ID'] == match_id]
    match_score = match_player_stats.groupby('Team').sum()[['Score', 'xScore']]
    home_score, home_xscore = match_score.loc[home_team]['Score'], match_score.loc[home_team]['xScore']
    away_score, away_xscore = match_score.loc[away_team]['Score'], match_score.loc[away_team]['xScore']
    margin, xmargin = home_score - away_score, home_xscore - away_xscore
    
    return home_score, away_score, margin

# %%
def calculate_match_projection_error(player_stats, match_id, match_ratings_dict, score_std = 25):
    
    home_projected_score, away_projected_score, projected_margin = calculate_match_projections(match_ratings_dict['home_attack_rating'], 
                                                                             match_ratings_dict['home_defence_rating'], 
                                                                             match_ratings_dict['away_attack_rating'], 
                                                                             match_ratings_dict['away_defence_rating'])
    
    home_team_win_probability, draw_probability, away_team_win_probability = calculate_projected_probabilities(home_projected_score, away_projected_score, score_std)
    home_score, away_score, margin = get_match_result(player_stats, match_id)
    
    mae, mse, rmse = get_match_prediction_metrics(projected_margin, margin)
    
    return mae, mse, rmse

# %%
def get_latest_rounds(round_id, player_stats, rounds):
    
    all_rounds = sorted(list(set(player_stats['Round_ID'])))
    rating_rounds = all_rounds[all_rounds.index(round_id)-rounds:all_rounds.index(round_id)]
    player_stats_latest = player_stats[player_stats['Round_ID'].isin(rating_rounds)]
    
    return player_stats_latest

# %%
def update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae):
    
    previous_round_id = get_previous_round_id(round_id)
    player_stats_latest = get_latest_rounds(round_id, player_stats, rounds)
    team_summary = create_team_summary(player_stats_latest, rounds = rounds)
    team_summary = team_summary[['xScore_pergame_F', 'xScore_pergame_A', 'xScore_pergame_diff']]

    round_projection_dict[round_id] = create_round_match_projections(player_stats, team_summary, round_id)
    round_mae[round_id] = np.mean(np.array(list({v['MAE'] for (k, v) in round_projection_dict[round_id].items()})))
    print("Round MAE: {}".format(round_mae[round_id]))
    print("Overall MAE: {}".format(np.mean(np.array(list(round_mae.values())))))
    return team_summary.sort_values('xScore_pergame_diff', ascending = False)

# %%
def create_round_match_projections(player_stats, team_summary, round_id):
    
    player_stats_round = player_stats[player_stats['Round_ID'] == round_id]
    match_id_list = list(player_stats_round['Match_ID'].unique())

    match_projection_dict = {}
    for match_id in match_id_list:
        home_team, away_team = get_teams(match_id)
        match_ratings_dict = get_match_ratings(team_summary, home_team, away_team)
        home_projected_score, away_projected_score, projected_margin = calculate_match_projections(match_ratings_dict['home_attack_rating'], 
                                                                                                    match_ratings_dict['home_defence_rating'], 
                                                                                                    match_ratings_dict['away_attack_rating'], 
                                                                                                    match_ratings_dict['away_defence_rating'])
        home_team_win_probability, draw_probability, away_team_win_probability = calculate_projected_probabilities(home_projected_score, away_projected_score, score_std)
        home_score, away_score, margin = get_match_result(player_stats_round, match_id)
        mae, mse, rmse = calculate_match_projection_error(player_stats_round, match_id, match_ratings_dict, score_std = 25)

        match_projection_dict[match_id] = {}
        if home_projected_score > away_projected_score:
            match_projection_dict[match_id]['tip'] = home_team
            match_projection_dict[match_id]['projected_prob'] = home_team_win_probability
        else:
            match_projection_dict[match_id]['tip'] = away_team
            match_projection_dict[match_id]['projected_prob'] = away_team_win_probability
        match_projection_dict[match_id]['projected_margin'] = abs(projected_margin)
        if home_score > away_score:
            match_projection_dict[match_id]['result'] = home_team
        else:
            match_projection_dict[match_id]['result'] = away_team
        match_projection_dict[match_id]['actual_margin'] = abs(margin)   
        match_projection_dict[match_id]['MAE'] = mae
    
    return match_projection_dict

# %%
score_std = get_score_standard_deviation(player_stats)

# %%
round_projection_dict = {}
round_mae = {}
rounds = 10

# %% [markdown]
# 202301

# %%
round_id = '202301'
player_stats_latest = player_stats[player_stats['Season'] == 2022]
team_summary = create_team_summary(player_stats_latest, rounds = rounds)
team_summary = team_summary[['xScore_pergame_F', 'xScore_pergame_A', 'xScore_pergame_diff']]

round_projection_dict[round_id] = create_round_match_projections(player_stats, team_summary, round_id)
round_mae[round_id] = np.mean(np.array(list({v['MAE'] for (k, v) in round_projection_dict[round_id].items()})))
print("Round MAE: {}".format(round_mae[round_id]))
print("Overall MAE: {}".format(np.mean(np.array(list(round_mae.values())))))
team_summary.sort_values('xScore_pergame_diff', ascending = False)
# Out:
# Round MAE: 31.402605292587793
# Overall MAE: 31.402605292587793
#                         xScore_pergame_F  xScore_pergame_A  \
# Geelong                          98.9063           58.7470
# Richmond                         99.8391           77.7397
# Sydney                           91.2116           73.4233
# Port Adelaide                    91.1296           80.8188
# Melbourne                        84.8261           74.8366
# Western Bulldogs                 80.2241           73.7809
# Brisbane Lions                   85.9923           83.7165
# Fremantle                        73.8515           75.6771
# Carlton                          78.7282           81.4170
# St Kilda                         74.4954           81.1609
# Collingwood                      73.1178           80.8490
# Essendon                         82.7699           90.5684
# Adelaide                         78.9675           88.3706
# Hawthorn                         76.9206           91.1593
# Gold Coast                       81.6543           96.0648
# North Melbourne                  82.0065          106.3449
# West Coast                       62.7690           89.2601
# Greater Western Sydney           65.5689           92.7679
#
#                         xScore_pergame_diff
# Geelong                             40.1593
# Richmond                            22.0994
# Sydney                              17.7883
# Port Adelaide                       10.3107
# Melbourne                            9.9895
# Western Bulldogs                     6.4432
# Brisbane Lions                       2.2759
# Fremantle                           -1.8257
# Carlton                             -2.6887
# St Kilda                            -6.6655
# Collingwood                         -7.7313
# Essendon                            -7.7985
# Adelaide                            -9.4032
# Hawthorn                           -14.2387
# Gold Coast                         -14.4105
# North Melbourne                    -24.3384
# West Coast                         -26.4911
# Greater Western Sydney             -27.1990

# %% [markdown]
# 202302

# %%
round_id = '202302'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 35.666881069044
# Overall MAE: 33.534743180815894
#                         xScore_pergame_F  xScore_pergame_A  \
# Geelong                          98.6147           64.5397
# Port Adelaide                   100.7617           76.2723
# Sydney                           94.1329           73.0418
# Richmond                         96.0286           75.2991
# Melbourne                        87.9351           73.0550
# Western Bulldogs                 79.4495           78.9416
# Fremantle                        74.6111           74.6585
# Carlton                          79.4761           79.7711
# Collingwood                      77.0760           81.9747
# St Kilda                         74.8258           81.5405
# Gold Coast                       83.5156           92.9480
# Brisbane Lions                   80.5392           91.6084
# Adelaide                         82.7028           94.3295
# Essendon                         80.5688           92.8056
# North Melbourne                  85.3104          103.1162
# Greater Western Sydney           72.9300           92.3419
# Hawthorn                         72.9654           97.4390
# West Coast                       65.1064           90.9502
#
#                         xScore_pergame_diff
# Geelong                             34.0750
# Port Adelaide                       24.4894
# Sydney                              21.0911
# Richmond                            20.7295
# Melbourne                           14.8801
# Western Bulldogs                     0.5079
# Fremantle                           -0.0473
# Carlton                             -0.2950
# Collingwood                         -4.8987
# St Kilda                            -6.7147
# Gold Coast                          -9.4324
# Brisbane Lions                     -11.0693
# Adelaide                           -11.6267
# Essendon                           -12.2368
# North Melbourne                    -17.8058
# Greater Western Sydney             -19.4119
# Hawthorn                           -24.4736
# West Coast                         -25.8437

# %% [markdown]
# 202303

# %%
round_id = '202303'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 27.32547382224668
# Overall MAE: 31.464986727959488
#                         xScore_pergame_F  xScore_pergame_A  \
# Geelong                          96.5536           64.7285
# Sydney                           95.0324           72.6641
# Richmond                         99.3067           79.4361
# Port Adelaide                    96.6369           79.0025
# Melbourne                        84.6959           72.2752
# Fremantle                        75.7961           73.9485
# Collingwood                      81.1088           80.3513
# Western Bulldogs                 73.6771           77.2304
# Carlton                          77.2207           81.7039
# St Kilda                         76.2476           80.8263
# Adelaide                         85.2214           90.5939
# Brisbane Lions                   80.2732           89.1815
# Gold Coast                       84.4765           95.9002
# Essendon                         84.8754           96.4913
# Greater Western Sydney           78.0321           90.3048
# North Melbourne                  81.0563           99.2382
# West Coast                       71.3227           94.3615
# Hawthorn                         69.2490          103.0408
#
#                         xScore_pergame_diff
# Geelong                             31.8251
# Sydney                              22.3682
# Richmond                            19.8706
# Port Adelaide                       17.6344
# Melbourne                           12.4207
# Fremantle                            1.8475
# Collingwood                          0.7575
# Western Bulldogs                    -3.5533
# Carlton                             -4.4833
# St Kilda                            -4.5788
# Adelaide                            -5.3725
# Brisbane Lions                      -8.9083
# Gold Coast                         -11.4237
# Essendon                           -11.6159
# Greater Western Sydney             -12.2727
# North Melbourne                    -18.1819
# West Coast                         -23.0387
# Hawthorn                           -33.7918

# %% [markdown]
# 202304

# %%
round_id = '202304'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 31.80961631404953
# Overall MAE: 31.551144124482
#                         xScore_pergame_F  xScore_pergame_A  \
# Geelong                          94.0423           66.1898
# Richmond                         92.5534           75.4413
# Port Adelaide                    98.3566           83.1124
# Sydney                           91.7930           79.6096
# Melbourne                        87.0650           76.5246
# Fremantle                        81.2517           73.3189
# Collingwood                      80.9288           78.3478
# Carlton                          80.0209           77.6718
# Western Bulldogs                 73.2657           72.9528
# Greater Western Sydney           82.3593           85.3604
# Adelaide                         86.5094           92.6030
# St Kilda                         74.2989           80.9096
# Gold Coast                       82.1547           91.4076
# Brisbane Lions                   75.5748           85.0966
# Essendon                         81.1090           98.2122
# North Melbourne                  77.5637           98.5500
# Hawthorn                         72.4105           95.8786
# West Coast                       69.1463           94.8261
#
#                         xScore_pergame_diff
# Geelong                             27.8525
# Richmond                            17.1121
# Port Adelaide                       15.2442
# Sydney                              12.1834
# Melbourne                           10.5404
# Fremantle                            7.9328
# Collingwood                          2.5810
# Carlton                              2.3492
# Western Bulldogs                     0.3128
# Greater Western Sydney              -3.0011
# Adelaide                            -6.0936
# St Kilda                            -6.6108
# Gold Coast                          -9.2529
# Brisbane Lions                      -9.5218
# Essendon                           -17.1032
# North Melbourne                    -20.9863
# Hawthorn                           -23.4681
# West Coast                         -25.6798

# %% [markdown]
# 202305

# %%
round_id = '202305'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 28.115834261643712
# Overall MAE: 30.86408215191434
#                         xScore_pergame_F  xScore_pergame_A  \
# Geelong                          95.8594           66.5469
# Port Adelaide                    98.6028           78.0287
# Melbourne                        89.3564           75.1430
# Sydney                           87.8442           77.5839
# Richmond                         87.0537           78.2537
# Carlton                          82.9471           75.4507
# St Kilda                         83.0272           76.5104
# Fremantle                        80.5905           74.2191
# Collingwood                      81.4597           79.9708
# Western Bulldogs                 74.3630           73.0150
# Adelaide                         88.8770           92.0925
# Essendon                         90.5949           97.2975
# Brisbane Lions                   76.5443           85.8328
# Gold Coast                       82.8278           94.8036
# Greater Western Sydney           81.4446           94.8463
# North Melbourne                  77.0474           94.5929
# West Coast                       68.4283          101.0570
# Hawthorn                         67.6138          103.6766
#
#                         xScore_pergame_diff
# Geelong                             29.3125
# Port Adelaide                       20.5741
# Melbourne                           14.2133
# Sydney                              10.2603
# Richmond                             8.8000
# Carlton                              7.4963
# St Kilda                             6.5168
# Fremantle                            6.3714
# Collingwood                          1.4889
# Western Bulldogs                     1.3480
# Adelaide                            -3.2154
# Essendon                            -6.7026
# Brisbane Lions                      -9.2885
# Gold Coast                         -11.9757
# Greater Western Sydney             -13.4017
# North Melbourne                    -17.5455
# West Coast                         -32.6287
# Hawthorn                           -36.0629

# %% [markdown]
# 202306

# %%
round_id = '202306'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 29.024342550070017
# Overall MAE: 30.557458884940285
#                         xScore_pergame_F  xScore_pergame_A  \
# Geelong                          96.0205           69.1430
# Port Adelaide                    92.1753           77.8385
# Melbourne                        88.8756           78.5226
# Sydney                           90.9195           81.7796
# St Kilda                         81.7763           73.4617
# Essendon                         97.7858           89.5445
# Collingwood                      83.3506           77.7515
# Adelaide                         90.7906           87.3715
# Fremantle                        82.1473           79.2832
# Richmond                         85.1114           85.0040
# Brisbane Lions                   84.1842           84.5779
# Carlton                          79.6405           80.2590
# Western Bulldogs                 74.2113           77.6476
# Gold Coast                       88.0246           92.4922
# Greater Western Sydney           89.0889           96.3625
# West Coast                       73.8779          105.6858
# North Melbourne                  72.6040          104.6877
# Hawthorn                         68.7629          102.3964
#
#                         xScore_pergame_diff
# Geelong                             26.8775
# Port Adelaide                       14.3368
# Melbourne                           10.3530
# Sydney                               9.1398
# St Kilda                             8.3146
# Essendon                             8.2413
# Collingwood                          5.5991
# Adelaide                             3.4191
# Fremantle                            2.8641
# Richmond                             0.1073
# Brisbane Lions                      -0.3937
# Carlton                             -0.6186
# Western Bulldogs                    -3.4363
# Gold Coast                          -4.4677
# Greater Western Sydney              -7.2736
# West Coast                         -31.8079
# North Melbourne                    -32.0837
# Hawthorn                           -33.6335

# %% [markdown]
# 202307

# %%
round_id = '202307'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 32.049244358723655
# Overall MAE: 30.770571095480765
#                         xScore_pergame_F  xScore_pergame_A  \
# Geelong                          94.8594           70.4912
# Essendon                         96.8705           82.6825
# Adelaide                         94.9260           82.3554
# St Kilda                         82.1273           70.1873
# Port Adelaide                    90.6416           79.2592
# Collingwood                      85.4169           76.3061
# Melbourne                        88.2604           81.3130
# Brisbane Lions                   88.7141           83.6817
# Sydney                           84.6666           84.9699
# Western Bulldogs                 75.7156           78.5603
# Carlton                          79.3269           82.9487
# Greater Western Sydney           88.9017           95.0985
# Richmond                         79.4277           85.8000
# Fremantle                        76.7957           84.3896
# Gold Coast                       84.7349           92.4919
# West Coast                       79.7656          103.6711
# Hawthorn                         72.6629           98.1653
# North Melbourne                  72.6037          101.3981
#
#                         xScore_pergame_diff
# Geelong                             24.3682
# Essendon                            14.1879
# Adelaide                            12.5706
# St Kilda                            11.9400
# Port Adelaide                       11.3824
# Collingwood                          9.1108
# Melbourne                            6.9474
# Brisbane Lions                       5.0324
# Sydney                              -0.3032
# Western Bulldogs                    -2.8447
# Carlton                             -3.6218
# Greater Western Sydney              -6.1968
# Richmond                            -6.3723
# Fremantle                           -7.5939
# Gold Coast                          -7.7569
# West Coast                         -23.9055
# Hawthorn                           -25.5024
# North Melbourne                    -28.7944

# %% [markdown]
# 202308

# %%
round_id = '202308'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 20.47108931787254
# Overall MAE: 29.483135873279743
#                         xScore_pergame_F  xScore_pergame_A  \
# Geelong                          97.8527           71.8660
# Melbourne                        92.3359           77.6703
# Adelaide                         92.0196           79.2095
# Carlton                          87.6457           77.0532
# St Kilda                         82.4798           72.0332
# Port Adelaide                    89.5655           80.0214
# Collingwood                      84.0790           75.1478
# Brisbane Lions                   90.0268           81.5947
# Essendon                         95.1386           86.8629
# Sydney                           87.5796           86.3418
# Western Bulldogs                 76.5649           76.5017
# Gold Coast                       83.3222           87.3330
# Richmond                         75.6829           83.1637
# Greater Western Sydney           88.1988           96.1524
# Fremantle                        75.0663           87.7309
# Hawthorn                         71.3160           96.1886
# North Melbourne                  68.9628          101.8038
# West Coast                       74.3248          108.5122
#
#                         xScore_pergame_diff
# Geelong                             25.9867
# Melbourne                           14.6655
# Adelaide                            12.8101
# Carlton                             10.5925
# St Kilda                            10.4466
# Port Adelaide                        9.5440
# Collingwood                          8.9312
# Brisbane Lions                       8.4321
# Essendon                             8.2758
# Sydney                               1.2378
# Western Bulldogs                     0.0633
# Gold Coast                          -4.0109
# Richmond                            -7.4808
# Greater Western Sydney              -7.9536
# Fremantle                          -12.6646
# Hawthorn                           -24.8726
# North Melbourne                    -32.8410
# West Coast                         -34.1874

# %% [markdown]
# 202309

# %%
round_id = '202309'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 39.320484062376764
# Overall MAE: 30.576174560957188
#                         xScore_pergame_F  xScore_pergame_A  \
# Geelong                          96.7026           71.4846
# Port Adelaide                    91.9045           78.3172
# Melbourne                        91.1540           78.2562
# Brisbane Lions                   91.2771           79.2533
# St Kilda                         81.9077           71.1292
# Adelaide                         89.0237           80.1023
# Collingwood                      83.4190           76.1882
# Carlton                          85.1011           78.5599
# Essendon                         91.5448           89.5397
# Sydney                           85.8968           85.7500
# Western Bulldogs                 75.9207           76.0131
# Fremantle                        82.6549           84.2593
# Richmond                         80.1791           82.3464
# Gold Coast                       83.2244           86.2797
# Greater Western Sydney           86.2481           93.0597
# Hawthorn                         69.7254           99.4270
# North Melbourne                  68.4427           98.8162
# West Coast                       74.6124          108.9048
#
#                         xScore_pergame_diff
# Geelong                             25.2180
# Port Adelaide                       13.5872
# Melbourne                           12.8978
# Brisbane Lions                      12.0238
# St Kilda                            10.7784
# Adelaide                             8.9214
# Collingwood                          7.2308
# Carlton                              6.5413
# Essendon                             2.0051
# Sydney                               0.1467
# Western Bulldogs                    -0.0925
# Fremantle                           -1.6044
# Richmond                            -2.1673
# Gold Coast                          -3.0552
# Greater Western Sydney              -6.8116
# Hawthorn                           -29.7016
# North Melbourne                    -30.3735
# West Coast                         -34.2924

# %% [markdown]
# 202310

# %%
round_id = '202310'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 31.011636098881507
# Overall MAE: 30.619720714749622
#                         xScore_pergame_F  xScore_pergame_A  \
# Geelong                          95.5506           73.4511
# Brisbane Lions                   96.0255           75.6949
# Port Adelaide                    93.2109           75.6032
# Melbourne                        91.0735           74.8172
# Collingwood                      86.2535           74.1643
# Adelaide                         90.8262           79.6650
# Gold Coast                       87.2620           80.6109
# St Kilda                         81.2698           74.9200
# Carlton                          82.6825           77.2790
# Fremantle                        84.4265           82.5777
# Western Bulldogs                 74.9330           74.6043
# Richmond                         79.9703           82.2270
# Essendon                         88.1248           90.8542
# Sydney                           83.8014           87.5328
# Greater Western Sydney           84.6498           94.5289
# Hawthorn                         67.2343           98.4273
# North Melbourne                  66.8258           99.3547
# West Coast                       70.2400          110.0890
#
#                         xScore_pergame_diff
# Geelong                             22.0996
# Brisbane Lions                      20.3306
# Port Adelaide                       17.6077
# Melbourne                           16.2563
# Collingwood                         12.0893
# Adelaide                            11.1612
# Gold Coast                           6.6511
# St Kilda                             6.3498
# Carlton                              5.4035
# Fremantle                            1.8487
# Western Bulldogs                     0.3287
# Richmond                            -2.2567
# Essendon                            -2.7294
# Sydney                              -3.7315
# Greater Western Sydney              -9.8790
# Hawthorn                           -31.1930
# North Melbourne                    -32.5289
# West Coast                         -39.8490

# %% [markdown]
# 202311

# %%
round_id = '202311'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 19.084900172415328
# Overall MAE: 29.5711006654465
#                         xScore_pergame_F  xScore_pergame_A  \
# Brisbane Lions                   96.8511           74.4649
# Port Adelaide                    93.9910           75.7690
# Geelong                          93.1771           78.9451
# Collingwood                      86.5088           73.2840
# Melbourne                        89.6923           77.4367
# St Kilda                         83.0172           74.1959
# Western Bulldogs                 77.9364           72.5416
# Adelaide                         87.1413           82.1952
# Sydney                           88.2129           84.9385
# Fremantle                        85.7467           82.5326
# Carlton                          80.9504           78.4317
# Gold Coast                       84.8753           82.9779
# Richmond                         79.6622           81.6399
# Essendon                         86.9480           89.4577
# Greater Western Sydney           82.9528           94.9503
# Hawthorn                         73.1813           91.0172
# North Melbourne                  68.1351           98.0996
# West Coast                       65.6486          111.7506
#
#                         xScore_pergame_diff
# Brisbane Lions                      22.3862
# Port Adelaide                       18.2221
# Geelong                             14.2321
# Collingwood                         13.2249
# Melbourne                           12.2555
# St Kilda                             8.8212
# Western Bulldogs                     5.3949
# Adelaide                             4.9460
# Sydney                               3.2743
# Fremantle                            3.2142
# Carlton                              2.5186
# Gold Coast                           1.8973
# Richmond                            -1.9777
# Essendon                            -2.5097
# Greater Western Sydney             -11.9975
# Hawthorn                           -17.8359
# North Melbourne                    -29.9646
# West Coast                         -46.1019

# %% [markdown]
# 202312

# %%
round_id = '202312'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 20.918241420496795
# Overall MAE: 28.850029061700692
#                         xScore_pergame_F  xScore_pergame_A  \
# Brisbane Lions                  100.1918           69.4360
# Geelong                          92.2238           77.2032
# Port Adelaide                    90.4418           77.5930
# Collingwood                      84.8238           72.0842
# Western Bulldogs                 80.3018           70.1833
# Melbourne                        87.6973           77.8091
# St Kilda                         84.5814           78.0817
# Adelaide                         85.7495           79.9327
# Gold Coast                       86.8285           81.1830
# Carlton                          81.6408           77.5223
# Fremantle                        85.3492           83.9518
# Sydney                           84.7573           85.5509
# Essendon                         85.7966           89.2293
# Richmond                         78.7873           85.5544
# Hawthorn                         77.7925           88.5879
# Greater Western Sydney           81.1980           92.7688
# North Melbourne                  65.8430           98.5758
# West Coast                       63.1204          111.8773
#
#                         xScore_pergame_diff
# Brisbane Lions                      30.7557
# Geelong                             15.0206
# Port Adelaide                       12.8488
# Collingwood                         12.7396
# Western Bulldogs                    10.1185
# Melbourne                            9.8882
# St Kilda                             6.4997
# Adelaide                             5.8168
# Gold Coast                           5.6455
# Carlton                              4.1185
# Fremantle                            1.3973
# Sydney                              -0.7936
# Essendon                            -3.4327
# Richmond                            -6.7671
# Hawthorn                           -10.7954
# Greater Western Sydney             -11.5707
# North Melbourne                    -32.7328
# West Coast                         -48.7569

# %% [markdown]
# 202313

# %%
round_id = '202313'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 29.2442510026805
# Overall MAE: 28.88035382639145
#                         xScore_pergame_F  xScore_pergame_A  \
# Brisbane Lions                  101.7532           69.8074
# Port Adelaide                    96.7303           76.4924
# Geelong                          93.3116           77.2612
# Melbourne                        89.5877           73.6859
# Collingwood                      84.8747           71.0258
# Western Bulldogs                 84.3871           70.5633
# Gold Coast                       87.4495           78.9857
# Adelaide                         85.4381           80.9882
# St Kilda                         85.0872           80.9830
# Fremantle                        87.2872           86.5319
# Carlton                          76.9072           78.7270
# Essendon                         85.2775           88.4165
# Richmond                         80.6180           85.8315
# Sydney                           80.8563           87.4037
# Hawthorn                         80.5926           89.4693
# Greater Western Sydney           81.0171           94.1799
# North Melbourne                  68.3273          101.8904
# West Coast                       59.2862          113.5197
#
#                         xScore_pergame_diff
# Brisbane Lions                      31.9459
# Port Adelaide                       20.2379
# Geelong                             16.0504
# Melbourne                           15.9018
# Collingwood                         13.8489
# Western Bulldogs                    13.8238
# Gold Coast                           8.4638
# Adelaide                             4.4500
# St Kilda                             4.1042
# Fremantle                            0.7553
# Carlton                             -1.8198
# Essendon                            -3.1391
# Richmond                            -5.2135
# Sydney                              -6.5475
# Hawthorn                            -8.8767
# Greater Western Sydney             -13.1628
# North Melbourne                    -33.5632
# West Coast                         -54.2336

# %% [markdown]
# 202314

# %%
round_id = '202314'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 33.7616647988797
# Overall MAE: 29.229018895854892
#                         xScore_pergame_F  xScore_pergame_A  \
# Brisbane Lions                  103.0238           71.4241
# Port Adelaide                    98.3222           73.3442
# Geelong                          95.9727           76.8222
# Melbourne                        87.7182           71.1250
# Adelaide                         89.3383           77.9155
# Western Bulldogs                 84.9832           74.2552
# Collingwood                      83.5072           74.4139
# Gold Coast                       88.1426           80.0550
# St Kilda                         83.9103           79.0224
# Fremantle                        84.8887           85.3661
# Essendon                         86.0529           87.4260
# Carlton                          76.4042           79.7370
# Richmond                         82.4274           85.8315
# Sydney                           77.2033           84.6042
# Greater Western Sydney           84.9485           92.4328
# Hawthorn                         79.4139           90.6786
# North Melbourne                  69.2207          103.7403
# West Coast                       56.1898          117.8892
#
#                         xScore_pergame_diff
# Brisbane Lions                      31.5997
# Port Adelaide                       24.9780
# Geelong                             19.1505
# Melbourne                           16.5933
# Adelaide                            11.4228
# Western Bulldogs                    10.7279
# Collingwood                          9.0933
# Gold Coast                           8.0876
# St Kilda                             4.8879
# Fremantle                           -0.4774
# Essendon                            -1.3731
# Carlton                             -3.3328
# Richmond                            -3.4041
# Sydney                              -7.4009
# Greater Western Sydney              -7.4843
# Hawthorn                           -11.2647
# North Melbourne                    -34.5197
# West Coast                         -61.6994

# %% [markdown]
# 202315

# %%
round_id = '202315'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 44.18979844321796
# Overall MAE: 30.226404199012432
#                         xScore_pergame_F  xScore_pergame_A  \
# Brisbane Lions                  102.7416           69.1831
# Port Adelaide                   102.4413           71.8776
# Melbourne                        84.7903           71.2465
# Collingwood                      83.2456           70.4215
# Western Bulldogs                 86.1808           73.9502
# Adelaide                         89.1659           78.6533
# Geelong                          90.5662           83.1839
# Gold Coast                       87.2490           81.8750
# Carlton                          78.9882           77.7273
# St Kilda                         80.7971           80.4234
# Greater Western Sydney           86.3352           86.4322
# Richmond                         83.6121           84.5178
# Fremantle                        83.3390           86.8011
# Essendon                         82.5772           87.1468
# Hawthorn                         81.8936           87.5331
# Sydney                           75.0585           88.4537
# North Melbourne                  67.7863          104.3957
# West Coast                       54.6518          118.3135
#
#                         xScore_pergame_diff
# Brisbane Lions                      33.5585
# Port Adelaide                       30.5637
# Melbourne                           13.5438
# Collingwood                         12.8241
# Western Bulldogs                    12.2307
# Adelaide                            10.5126
# Geelong                              7.3824
# Gold Coast                           5.3740
# Carlton                              1.2609
# St Kilda                             0.3737
# Greater Western Sydney              -0.0970
# Richmond                            -0.9057
# Fremantle                           -3.4621
# Essendon                            -4.5696
# Hawthorn                            -5.6395
# Sydney                             -13.3953
# North Melbourne                    -36.6094
# West Coast                         -63.6617

# %% [markdown]
# 202316

# %%
round_id = '202316'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 37.79973319339761
# Overall MAE: 30.69973726116151
#                         xScore_pergame_F  xScore_pergame_A  \
# Port Adelaide                   104.5827           72.9619
# Brisbane Lions                   94.8600           70.0367
# Melbourne                        84.9112           68.0849
# Western Bulldogs                 88.8544           72.9259
# Gold Coast                       89.6196           76.0819
# Collingwood                      85.1132           72.2139
# Carlton                          81.1503           74.3735
# Adelaide                         86.1884           81.6784
# Geelong                          86.2181           82.8259
# Richmond                         82.8255           81.3936
# Sydney                           83.5110           82.4452
# St Kilda                         81.2297           82.2142
# Greater Western Sydney           85.1940           88.0049
# Fremantle                        81.6977           84.7951
# Hawthorn                         79.3769           88.8742
# Essendon                         78.4528           88.4556
# North Melbourne                  68.5187           98.5509
# West Coast                       49.8840          126.2717
#
#                         xScore_pergame_diff
# Port Adelaide                       31.6208
# Brisbane Lions                      24.8233
# Melbourne                           16.8263
# Western Bulldogs                    15.9285
# Gold Coast                          13.5378
# Collingwood                         12.8993
# Carlton                              6.7768
# Adelaide                             4.5100
# Geelong                              3.3922
# Richmond                             1.4319
# Sydney                               1.0658
# St Kilda                            -0.9845
# Greater Western Sydney              -2.8109
# Fremantle                           -3.0974
# Hawthorn                            -9.4973
# Essendon                           -10.0028
# North Melbourne                    -30.0323
# West Coast                         -76.3877

# %% [markdown]
# 202317

# %%
round_id = '202317'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 23.892696292042064
# Overall MAE: 30.299323086507425
#                         xScore_pergame_F  xScore_pergame_A  \
# Brisbane Lions                   97.1629           67.1357
# Port Adelaide                   100.4250           74.2477
# Melbourne                        84.4057           63.6614
# Collingwood                      89.8933           70.8299
# Carlton                          83.3147           71.1199
# Sydney                           90.1291           78.2476
# Adelaide                         91.0813           79.4880
# Western Bulldogs                 84.6840           74.3776
# St Kilda                         84.1101           79.6526
# Fremantle                        83.1493           80.6247
# Gold Coast                       83.7206           82.4651
# Greater Western Sydney           81.4954           85.0742
# Richmond                         79.1997           86.1216
# Essendon                         79.4819           86.7988
# Geelong                          82.0204           89.4440
# Hawthorn                         75.6708           90.7219
# North Melbourne                  68.1107          100.4818
# West Coast                       48.8155          126.3780
#
#                         xScore_pergame_diff
# Brisbane Lions                      30.0271
# Port Adelaide                       26.1773
# Melbourne                           20.7442
# Collingwood                         19.0634
# Carlton                             12.1948
# Sydney                              11.8815
# Adelaide                            11.5932
# Western Bulldogs                    10.3065
# St Kilda                             4.4575
# Fremantle                            2.5246
# Gold Coast                           1.2555
# Greater Western Sydney              -3.5788
# Richmond                            -6.9219
# Essendon                            -7.3169
# Geelong                             -7.4236
# Hawthorn                           -15.0511
# North Melbourne                    -32.3710
# West Coast                         -77.5625

# %% [markdown]
# 202318

# %%
round_id = '202318'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 30.033418298236192
# Overall MAE: 30.28455059827013
#                         xScore_pergame_F  xScore_pergame_A  \
# Brisbane Lions                   98.7310           63.5811
# Port Adelaide                   102.6532           72.1975
# Collingwood                      91.9604           71.2080
# Melbourne                        79.4995           65.9768
# Western Bulldogs                 83.9791           76.1224
# Adelaide                         90.9366           84.2684
# Sydney                           86.1721           80.4006
# Carlton                          79.0064           73.3157
# St Kilda                         82.2614           77.0942
# Fremantle                        82.8862           79.9214
# Greater Western Sydney           82.7629           82.2075
# Richmond                         84.4195           85.2346
# Essendon                         81.5497           82.5026
# Geelong                          83.4184           85.6944
# Gold Coast                       82.7537           87.6631
# Hawthorn                         77.1642           91.9508
# North Melbourne                  68.5423          102.7360
# West Coast                       47.7196          124.3410
#
#                         xScore_pergame_diff
# Brisbane Lions                      35.1499
# Port Adelaide                       30.4557
# Collingwood                         20.7524
# Melbourne                           13.5227
# Western Bulldogs                     7.8567
# Adelaide                             6.6681
# Sydney                               5.7715
# Carlton                              5.6907
# St Kilda                             5.1672
# Fremantle                            2.9648
# Greater Western Sydney               0.5555
# Richmond                            -0.8151
# Essendon                            -0.9529
# Geelong                             -2.2761
# Gold Coast                          -4.9095
# Hawthorn                           -14.7866
# North Melbourne                    -34.1937
# West Coast                         -76.6214

# %% [markdown]
# 202319

# %%
round_id = '202319'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 16.408088564130594
# Overall MAE: 29.554210491210153
#                         xScore_pergame_F  xScore_pergame_A  \
# Brisbane Lions                   98.8101           64.6140
# Port Adelaide                   100.4860           77.3805
# Collingwood                      94.2644           71.9542
# Melbourne                        79.2417           66.7855
# Carlton                          84.0894           73.2786
# Sydney                           87.5091           80.0189
# Adelaide                         90.2868           82.8986
# Western Bulldogs                 84.5989           77.2548
# Geelong                          86.2394           82.5924
# Greater Western Sydney           82.9218           81.1845
# St Kilda                         78.6868           78.5621
# Richmond                         84.1542           85.1493
# Hawthorn                         80.5940           81.8492
# Gold Coast                       82.2506           83.9770
# Essendon                         78.6325           82.8874
# Fremantle                        77.9275           84.6513
# North Melbourne                  64.8067          104.0201
# West Coast                       47.6343          124.0756
#
#                         xScore_pergame_diff
# Brisbane Lions                      34.1961
# Port Adelaide                       23.1054
# Collingwood                         22.3101
# Melbourne                           12.4562
# Carlton                             10.8107
# Sydney                               7.4902
# Adelaide                             7.3882
# Western Bulldogs                     7.3441
# Geelong                              3.6470
# Greater Western Sydney               1.7373
# St Kilda                             0.1247
# Richmond                            -0.9951
# Hawthorn                            -1.2552
# Gold Coast                          -1.7265
# Essendon                            -4.2549
# Fremantle                           -6.7238
# North Melbourne                    -39.2134
# West Coast                         -76.4413

# %% [markdown]
# 202320

# %%
round_id = '202320'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 25.840747960228704
# Overall MAE: 29.36853736466108
#                         xScore_pergame_F  xScore_pergame_A  \
# Brisbane Lions                   94.6481           64.4483
# Port Adelaide                    98.3445           77.6816
# Carlton                          91.5799           72.6655
# Collingwood                      88.7442           73.3460
# Sydney                           89.0177           76.3374
# Greater Western Sydney           86.9490           74.9270
# Western Bulldogs                 85.9281           75.9804
# Melbourne                        80.3072           71.7298
# St Kilda                         79.4332           73.7658
# Adelaide                         88.7932           85.5488
# Geelong                          83.7952           80.9937
# Richmond                         86.7512           84.1203
# Hawthorn                         83.3391           83.0985
# Essendon                         77.6435           80.4011
# Fremantle                        74.2460           86.1598
# Gold Coast                       74.5174           92.0711
# North Melbourne                  65.7165          101.7114
# West Coast                       50.5513          125.3185
#
#                         xScore_pergame_diff
# Brisbane Lions                      30.1997
# Port Adelaide                       20.6629
# Carlton                             18.9145
# Collingwood                         15.3982
# Sydney                              12.6803
# Greater Western Sydney              12.0219
# Western Bulldogs                     9.9477
# Melbourne                            8.5773
# St Kilda                             5.6675
# Adelaide                             3.2444
# Geelong                              2.8015
# Richmond                             2.6309
# Hawthorn                             0.2405
# Essendon                            -2.7577
# Fremantle                          -11.9138
# Gold Coast                         -17.5537
# North Melbourne                    -35.9949
# West Coast                         -74.7672

# %% [markdown]
# 202321

# %%
round_id = '202321'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 22.638535881611116
# Overall MAE: 29.048061103563462
#                         xScore_pergame_F  xScore_pergame_A  \
# Brisbane Lions                   91.3100           68.3774
# Carlton                          93.6353           73.3914
# Greater Western Sydney           89.2368           73.0387
# Melbourne                        85.2852           69.9382
# Collingwood                      89.4701           75.4014
# Port Adelaide                    95.0309           81.3773
# Adelaide                         95.0760           81.7957
# Sydney                           89.4536           77.1315
# St Kilda                         79.9225           75.0756
# Geelong                          82.9493           79.3729
# Western Bulldogs                 83.3482           79.7908
# Richmond                         87.6399           89.1990
# Essendon                         78.8333           81.9387
# Gold Coast                       78.4465           88.7331
# Fremantle                        72.6253           85.3139
# Hawthorn                         78.0905           91.8563
# North Melbourne                  65.1980          101.2002
# West Coast                       56.9820          119.6016
#
#                         xScore_pergame_diff
# Brisbane Lions                      22.9327
# Carlton                             20.2439
# Greater Western Sydney              16.1981
# Melbourne                           15.3471
# Collingwood                         14.0687
# Port Adelaide                       13.6536
# Adelaide                            13.2803
# Sydney                              12.3222
# St Kilda                             4.8469
# Geelong                              3.5763
# Western Bulldogs                     3.5574
# Richmond                            -1.5590
# Essendon                            -3.1054
# Gold Coast                         -10.2866
# Fremantle                          -12.6886
# Hawthorn                           -13.7658
# North Melbourne                    -36.0022
# West Coast                         -62.6195

# %% [markdown]
# 202322

# %%
round_id = '202322'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 23.152707868927937
# Overall MAE: 28.780090501989118
#                         xScore_pergame_F  xScore_pergame_A  \
# Brisbane Lions                   90.3510           67.2116
# Carlton                          93.1784           71.1014
# Adelaide                         97.6408           79.1255
# Greater Western Sydney           88.3968           72.6451
# Melbourne                        85.9147           71.1597
# Sydney                           89.8169           78.8830
# Port Adelaide                    94.4570           84.8858
# Western Bulldogs                 88.5820           79.4379
# Collingwood                      86.3901           78.1123
# St Kilda                         75.8817           69.9249
# Geelong                          85.7392           79.7897
# Richmond                         88.4346           92.9994
# Essendon                         77.0941           82.8190
# Fremantle                        73.4632           84.4886
# Hawthorn                         76.8946           89.3763
# Gold Coast                       76.3138           91.0873
# North Melbourne                  65.5671          101.0685
# West Coast                       57.8623          117.8624
#
#                         xScore_pergame_diff
# Brisbane Lions                      23.1394
# Carlton                             22.0770
# Adelaide                            18.5153
# Greater Western Sydney              15.7517
# Melbourne                           14.7550
# Sydney                              10.9339
# Port Adelaide                        9.5712
# Western Bulldogs                     9.1441
# Collingwood                          8.2778
# St Kilda                             5.9568
# Geelong                              5.9495
# Richmond                            -4.5648
# Essendon                            -5.7249
# Fremantle                          -11.0255
# Hawthorn                           -12.4817
# Gold Coast                         -14.7734
# North Melbourne                    -35.5014
# West Coast                         -60.0000

# %% [markdown]
# 202323

# %%
round_id = '202323'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 30.45762127434098
# Overall MAE: 28.85302662252616
#                         xScore_pergame_F  xScore_pergame_A  \
# Carlton                          94.3888           68.2654
# Adelaide                         99.4127           77.9999
# Brisbane Lions                   90.2940           70.5124
# Greater Western Sydney           86.9000           72.4942
# Sydney                           90.2768           78.9524
# Melbourne                        83.0787           72.3701
# Port Adelaide                    91.9709           82.6424
# Western Bulldogs                 86.2583           79.0184
# St Kilda                         77.7723           70.6666
# Geelong                          86.2608           81.0155
# Collingwood                      85.8861           81.8137
# Fremantle                        78.2345           80.9144
# Essendon                         75.1924           80.7696
# Hawthorn                         75.0255           83.0685
# Richmond                         85.0656           93.5140
# Gold Coast                       74.0544           92.2143
# North Melbourne                  63.5177           99.1669
# West Coast                       57.1440          119.2829
#
#                         xScore_pergame_diff
# Carlton                             26.1234
# Adelaide                            21.4128
# Brisbane Lions                      19.7816
# Greater Western Sydney              14.4058
# Sydney                              11.3244
# Melbourne                           10.7086
# Port Adelaide                        9.3285
# Western Bulldogs                     7.2399
# St Kilda                             7.1057
# Geelong                              5.2453
# Collingwood                          4.0724
# Fremantle                           -2.6799
# Essendon                            -5.5771
# Hawthorn                            -8.0429
# Richmond                            -8.4484
# Gold Coast                         -18.1599
# North Melbourne                    -35.6492
# West Coast                         -62.1389

# %% [markdown]
# 202324

# %%
round_id = '202323'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 30.45762127434098
# Overall MAE: 28.85302662252616
#                         xScore_pergame_F  xScore_pergame_A  \
# Carlton                          94.3888           68.2654
# Adelaide                         99.4127           77.9999
# Brisbane Lions                   90.2940           70.5124
# Greater Western Sydney           86.9000           72.4942
# Sydney                           90.2768           78.9524
# Melbourne                        83.0787           72.3701
# Port Adelaide                    91.9709           82.6424
# Western Bulldogs                 86.2583           79.0184
# St Kilda                         77.7723           70.6666
# Geelong                          86.2608           81.0155
# Collingwood                      85.8861           81.8137
# Fremantle                        78.2345           80.9144
# Essendon                         75.1924           80.7696
# Hawthorn                         75.0255           83.0685
# Richmond                         85.0656           93.5140
# Gold Coast                       74.0544           92.2143
# North Melbourne                  63.5177           99.1669
# West Coast                       57.1440          119.2829
#
#                         xScore_pergame_diff
# Carlton                             26.1234
# Adelaide                            21.4128
# Brisbane Lions                      19.7816
# Greater Western Sydney              14.4058
# Sydney                              11.3244
# Melbourne                           10.7086
# Port Adelaide                        9.3285
# Western Bulldogs                     7.2399
# St Kilda                             7.1057
# Geelong                              5.2453
# Collingwood                          4.0724
# Fremantle                           -2.6799
# Essendon                            -5.5771
# Hawthorn                            -8.0429
# Richmond                            -8.4484
# Gold Coast                         -18.1599
# North Melbourne                    -35.6492
# West Coast                         -62.1389
