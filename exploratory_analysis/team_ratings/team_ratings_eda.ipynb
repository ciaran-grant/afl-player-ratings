# %%
import pandas as pd
import re
import numpy as np
from scipy import stats
import scipy as sp
from sklearn import metrics

import os
import warnings
warnings.filterwarnings('ignore')
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999
pd.set_option('display.precision', 4)

# %%
def score_col_splitter(X, score_col):

    quarter = score_col.split("_")[0]
    
    X['Home_Score'] = X[score_col].apply(lambda x: x.split(" - ")[0].split(".")[-1]).astype(int)
    X['Home_Goals'] = X[score_col].apply(lambda x: x.split(" - ")[0].split(".")[0]).astype(int)
    X['Home_Behinds'] = X[score_col].apply(lambda x: x.split(" - ")[0].split(".")[1]).astype(int)
    X['Home_Shots'] = X['Home_Goals'] + X['Home_Behinds']
    X['Home_Conversion'] = X['Home_Goals'] / X['Home_Shots']
    
    X['Away_Score'] = X[score_col].apply(lambda x: x.split(" - ")[1].split(".")[-1]).astype(int)
    X['Away_Goals'] = X[score_col].apply(lambda x: x.split(" - ")[1].split(".")[0]).astype(int)
    X['Away_Behinds'] = X[score_col].apply(lambda x: x.split(" - ")[1].split(".")[1]).astype(int)
    X['Away_Shots'] = X['Away_Goals'] + X['Away_Behinds']
    X['Away_Conversion'] = X['Away_Goals'] / X['Away_Shots']
        
    return X

# %% [markdown]
# Load Match Summary Data

# %%
match_summary = pd.read_csv("/Users/ciaran/Documents/Projects/AFL/data/match_summary.csv")
match_summary = score_col_splitter(match_summary, "Q4_Score")
match_summary['Season'] = match_summary['Match_ID'].apply(lambda x: int(x[:4]))
match_summary.head()
# Out:
#                 Home_Team         Away_Team              Q4_Score  Margin  \
# 0          Brisbane Lions            Sydney  14.10.94 - 19.11.125     -31
# 1             Collingwood  Western Bulldogs     7.11.53 - 10.9.69     -16
# 2                Essendon          Hawthorn    13.13.91 - 14.8.92      -1
# 3  Greater Western Sydney          St Kilda    11.12.78 - 13.8.86      -8
# 4               Melbourne         Fremantle    11.14.80 - 8.10.58      22
#
#    Total Game Score  Home Win              Venue       City  \
# 0               219       0.0              Gabba   Brisbane
# 1               122       0.0             M.C.G.  Melbourne
# 2               183       0.0          Docklands  Melbourne
# 3               164       0.0  Sydney Showground     Sydney
# 4               138       1.0             M.C.G.  Melbourne
#
#                   Date  Attendance  Temperature  Weather_Type  Year Round_ID  \
# 0  2021-03-20 19:45:00           0           18  MOSTLY_SUNNY  2021   202101
# 1  2021-03-19 19:50:00           0           27  MOSTLY_SUNNY  2021   202101
# 2  2021-03-20 19:25:00           0           26  MOSTLY_SUNNY  2021   202101
# 3  2021-03-21 15:20:00           0           22          RAIN  2021   202101
# 4  2021-03-20 13:45:00           0           26  MOSTLY_SUNNY  2021   202101
#
#                               Match_ID  Season  Home_Score  Home_Goals  \
# 0          202101_BrisbaneLions_Sydney    2021          94          14
# 1   202101_Collingwood_WesternBulldogs    2021          53           7
# 2             202101_Essendon_Hawthorn    2021          91          13
# 3  202101_GreaterWesternSydney_StKilda    2021          78          11
# 4           202101_Melbourne_Fremantle    2021          80          11
#
#    Home_Behinds  Home_Shots  Home_Conversion  Away_Score  Away_Goals  \
# 0            10          24           0.5833         125          19
# 1            11          18           0.3889          69          10
# 2            13          26           0.5000          92          14
# 3            12          23           0.4783          86          13
# 4            14          25           0.4400          58           8
#
#    Away_Behinds  Away_Shots  Away_Conversion
# 0            11          30           0.6333
# 1             9          19           0.5263
# 2             8          22           0.6364
# 3             8          21           0.6190
# 4            10          18           0.4444

# %% [markdown]
# Load Player Stats Data

# %%
player_stats = pd.read_csv("/Users/ciaran/Documents/Projects/AFL/data/scored_player_stats.csv")
player_stats['Season'] = player_stats['Match_ID'].apply(lambda x: int(x[:4]))
player_stats['Player_Season'] = player_stats['Player'] + "_" + player_stats['Season'].astype(str)

player_stats['Score'] = player_stats['Behinds'] + player_stats['Goals']*6
player_stats['xScore_Diff'] = player_stats['Score'] - player_stats['xScore']

player_stats['Home_Team'] = player_stats['Match_ID'].apply(lambda x: x.split("_")[1]).str.replace(r"([A-Z])", r" \1").str.strip()
player_stats['Away_Team'] = player_stats['Match_ID'].apply(lambda x: x.split("_")[-1]).str.replace(r"([A-Z])", r" \1").str.strip()
player_stats['Opponent'] = np.where(player_stats['Team'] == player_stats['Home_Team'], player_stats['Away_Team'], player_stats['Home_Team'])

finals_round_map = {'F1':24,
                    'F2':25,
                    'F3':26,
                    'F4':27}
player_stats['Round_ID'] = player_stats['Round_ID'].astype(str)
player_stats['Round'] = (player_stats['Round_ID'].str[4:].replace(finals_round_map)).astype(int)
player_stats['Round_str'] = player_stats['Round_ID'].str[4:].replace(finals_round_map)
player_stats['Round_ID_num'] = (player_stats['Season'].astype(str) + player_stats['Round'].astype(str)).astype(int)

player_stats.tail()
# Out:
#                                Match_ID              Team         Player  \
# 27846  202323_WesternBulldogs_WestCoast  Western Bulldogs    Oskar Baker
# 27847  202323_WesternBulldogs_WestCoast  Western Bulldogs    Rhylee West
# 27848  202323_WesternBulldogs_WestCoast  Western Bulldogs      Rory Lobb
# 27849  202323_WesternBulldogs_WestCoast  Western Bulldogs  Taylor Duryea
# 27850  202323_WesternBulldogs_WestCoast  Western Bulldogs    Tim English
#
#       Round_ID AFL_API_Player_ID      Player_Type     playerId  Age  Height  \
# 27846   202323       Oskar_Baker       MIDFIELDER  CD_I1008855   25     184
# 27847   202323       Rhylee_West   MEDIUM_FORWARD  CD_I1006127   23     183
# 27848   202323         Rory_Lobb      KEY_FORWARD   CD_I990740   30     207
# 27849   202323     Taylor_Duryea  MEDIUM_DEFENDER   CD_I290085   32     181
# 27850   202323       Tim_English             RUCK  CD_I1004592   26     208
#
#        Weight  Number Kicking_Foot State_Of_Origin  Draft_Year  Debut_Year  \
# 27846      87      13        RIGHT             QLD      2017.0      2019.0
# 27847      82      14        RIGHT             VIC      2018.0      2019.0
# 27848     106       7        RIGHT              WA      2013.0      2014.0
# 27849      81      15         LEFT             NSW      2009.0      2013.0
# 27850     107      44        RIGHT              WA      2016.0      2017.0
#
#                                           Recruited_From  Draft_Position  \
# 27846      Wilston Grange (Qld)/Aspley (NEAFL)/Melbourne            48.0
# 27847  Strathmore (Vic)/St Kevin&apos;s College (Vic)...            26.0
# 27848  Bassendean (WA)/Swan Districts (WAFL)/GWS/Frem...            29.0
# 27849  Wahgunyah (Vic)/Caulfield Grammar (Vic)/Murray...            69.0
# 27850      Brookton-Pingelly (WA)/South Fremantle (WAFL)            19.0
#
#           Draft_Type                                          Photo_URL  \
# 27846  nationalDraft  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
# 27847      fatherSon  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
# 27848  nationalDraft  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
# 27849  nationalDraft  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
# 27850  nationalDraft  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
#
#       Date_Of_Birth  Percent_Played  Behinds  Bounces  \
# 27846    1998-05-25             NaN      NaN      NaN
# 27847    2000-07-12             NaN      NaN      NaN
# 27848    1993-02-09             NaN      NaN      NaN
# 27849    1991-04-24             NaN      NaN      NaN
# 27850    1997-08-10             NaN      NaN      NaN
#
#        Centre_Bounces_Attended  Centre_Clearances  Clangers  \
# 27846                      NaN                NaN       NaN
# 27847                      NaN                NaN       NaN
# 27848                      NaN                NaN       NaN
# 27849                      NaN                NaN       NaN
# 27850                      NaN                NaN       NaN
#
#        Defensive_Contest_Losses  Defensive_Contest_Loss_Percentage  \
# 27846                       NaN                                NaN
# 27847                       NaN                                NaN
# 27848                       NaN                                NaN
# 27849                       NaN                                NaN
# 27850                       NaN                                NaN
#
#        Defensive_One_On_One_Contests  Contested_Marks  \
# 27846                            NaN              NaN
# 27847                            NaN              NaN
# 27848                            NaN              NaN
# 27849                            NaN              NaN
# 27850                            NaN              NaN
#
#        Contested_Possession_Rate  Contested_Possessions  \
# 27846                        NaN                    NaN
# 27847                        NaN                    NaN
# 27848                        NaN                    NaN
# 27849                        NaN                    NaN
# 27850                        NaN                    NaN
#
#        Offensive_One_On_One_Contests  Offensive_Contest_Wins  \
# 27846                            NaN                     NaN
# 27847                            NaN                     NaN
# 27848                            NaN                     NaN
# 27849                            NaN                     NaN
# 27850                            NaN                     NaN
#
#        Offensive_Contest_Win_Percentage  Defensive_Half_Pressure_Acts  \
# 27846                               NaN                           NaN
# 27847                               NaN                           NaN
# 27848                               NaN                           NaN
# 27849                               NaN                           NaN
# 27850                               NaN                           NaN
#
#        Disposal_Efficiency  Disposals  AFL_Fantasy_Points  \
# 27846                  NaN        NaN                 NaN
# 27847                  NaN        NaN                 NaN
# 27848                  NaN        NaN                 NaN
# 27849                  NaN        NaN                 NaN
# 27850                  NaN        NaN                 NaN
#
#        Effective_Disposals  Effective_Kicks  Inside_50_Ground_Ball_Gets  \
# 27846                  NaN              NaN                         NaN
# 27847                  NaN              NaN                         NaN
# 27848                  NaN              NaN                         NaN
# 27849                  NaN              NaN                         NaN
# 27850                  NaN              NaN                         NaN
#
#        Frees_Against  Frees_For  Goal_Accuracy  Goal_Assists  Goals  \
# 27846            NaN        NaN            NaN           NaN    NaN
# 27847            NaN        NaN            NaN           NaN    NaN
# 27848            NaN        NaN            NaN           NaN    NaN
# 27849            NaN        NaN            NaN           NaN    NaN
# 27850            NaN        NaN            NaN           NaN    NaN
#
#        Ground_Ball_Gets  Handballs  Hit_Outs  Hit_Outs_To_Advantage  \
# 27846               NaN        NaN       NaN                    NaN
# 27847               NaN        NaN       NaN                    NaN
# 27848               NaN        NaN       NaN                    NaN
# 27849               NaN        NaN       NaN                    NaN
# 27850               NaN        NaN       NaN                    NaN
#
#        Hit_Outs_To_Advantage_Rate  Hit_Out_Win_Percentage  Inside_50s  \
# 27846                         NaN                     NaN         NaN
# 27847                         NaN                     NaN         NaN
# 27848                         NaN                     NaN         NaN
# 27849                         NaN                     NaN         NaN
# 27850                         NaN                     NaN         NaN
#
#        Intercept_Marks  Intercepts  Kick_Efficiency  Kick_Ins  \
# 27846              NaN         NaN              NaN       NaN
# 27847              NaN         NaN              NaN       NaN
# 27848              NaN         NaN              NaN       NaN
# 27849              NaN         NaN              NaN       NaN
# 27850              NaN         NaN              NaN       NaN
#
#        Kick_Ins_Played_On  Kicks  Kick_To_Handball_Ratio  Marks  \
# 27846                 NaN    NaN                     NaN    NaN
# 27847                 NaN    NaN                     NaN    NaN
# 27848                 NaN    NaN                     NaN    NaN
# 27849                 NaN    NaN                     NaN    NaN
# 27850                 NaN    NaN                     NaN    NaN
#
#        Marks_Inside_50  Marks_On_Lead  Metres_Gained  One_Percenters  \
# 27846              NaN            NaN            NaN             NaN
# 27847              NaN            NaN            NaN             NaN
# 27848              NaN            NaN            NaN             NaN
# 27849              NaN            NaN            NaN             NaN
# 27850              NaN            NaN            NaN             NaN
#
#        Pressure_Acts  Player_Rating_Points  Rebound_50s  Ruck_Contests  \
# 27846            NaN                   NaN          NaN            NaN
# 27847            NaN                   NaN          NaN            NaN
# 27848            NaN                   NaN          NaN            NaN
# 27849            NaN                   NaN          NaN            NaN
# 27850            NaN                   NaN          NaN            NaN
#
#        Score_Involvements  Score_Launches  Shots_At_Goal  Spoils  \
# 27846                 NaN             NaN            NaN     NaN
# 27847                 NaN             NaN            NaN     NaN
# 27848                 NaN             NaN            NaN     NaN
# 27849                 NaN             NaN            NaN     NaN
# 27850                 NaN             NaN            NaN     NaN
#
#        Stoppage_Clearances  Tackles  Tackles_Inside_50  Clearances  \
# 27846                  NaN      NaN                NaN         NaN
# 27847                  NaN      NaN                NaN         NaN
# 27848                  NaN      NaN                NaN         NaN
# 27849                  NaN      NaN                NaN         NaN
# 27850                  NaN      NaN                NaN         NaN
#
#        Possessions  Turnovers  Uncontested_Possessions AFLCA_Player_ID  \
# 27846          NaN        NaN                      NaN             NaN
# 27847          NaN        NaN                      NaN             NaN
# 27848          NaN        NaN                      NaN             NaN
# 27849          NaN        NaN                      NaN             NaN
# 27850          NaN        NaN                      NaN             NaN
#
#        Coaches_Votes                  Position Team_Status Position_Sub_Group  \
# 27846            NaN  Half Forward Flank Right  FINAL_TEAM       Half-Forward
# 27847            NaN      Forward Pocket Right  FINAL_TEAM     Forward-Pocket
# 27848            NaN       Forward Pocket Left  FINAL_TEAM     Forward-Pocket
# 27849            NaN         Back Pocket Right  FINAL_TEAM        Back-Pocket
# 27850            NaN                      Ruck  FINAL_TEAM               Ruck
#
#       Position_Group  Year  Brownlow_Votes  Season   xScore  xT_created  \
# 27846        Forward   NaN             NaN    2023   7.9598     -0.3226
# 27847        Forward   NaN             NaN    2023   9.7706      0.1389
# 27848        Forward   NaN             NaN    2023  17.1166     -0.1439
# 27849           Back   NaN             NaN    2023   0.0000      0.1609
# 27850           Ruck   NaN             NaN    2023   3.0435     -0.0350
#
#        xT_denied  vaep_value  offensive_value  defensive_value  \
# 27846     0.0167      0.3991           0.7006          -0.3015
# 27847     0.0000      0.5694           0.6452          -0.0758
# 27848    -0.0025      1.7295           1.8518          -0.1224
# 27849     0.0000      0.2253           0.1578           0.0675
# 27850     0.0320      1.4000           1.3565           0.0435
#
#        exp_vaep_value  exp_offensive_value  exp_defensive_value  xT_received  \
# 27846          2.8523               3.8194              -0.9671      -0.3267
# 27847          7.0749               7.4761              -0.4012       0.4868
# 27848         11.1693              12.7523              -1.5830       0.4878
# 27849          1.4341               1.4510              -0.0170      -0.1781
# 27850          6.4647               4.8051               1.6596      -0.1352
#
#        xT_prevented  vaep_value_received  exp_vaep_value_received  \
# 27846        0.0713               1.0483                   3.4625
# 27847        0.0043               0.9269                   6.2204
# 27848       -0.0002               1.1501                  10.5511
# 27849        0.0223              -0.0554                  -1.4566
# 27850        0.0585               1.3824                   5.9993
#
#             Player_Season  Score  xScore_Diff         Home_Team   Away_Team  \
# 27846    Oskar Baker_2023    NaN          NaN  Western Bulldogs  West Coast
# 27847    Rhylee West_2023    NaN          NaN  Western Bulldogs  West Coast
# 27848      Rory Lobb_2023    NaN          NaN  Western Bulldogs  West Coast
# 27849  Taylor Duryea_2023    NaN          NaN  Western Bulldogs  West Coast
# 27850    Tim English_2023    NaN          NaN  Western Bulldogs  West Coast
#
#          Opponent  Round Round_str  Round_ID_num
# 27846  West Coast     23        23        202323
# 27847  West Coast     23        23        202323
# 27848  West Coast     23        23        202323
# 27849  West Coast     23        23        202323
# 27850  West Coast     23        23        202323

# %% [markdown]
# Create Match Level Expected Data from Player Stats

# %%
match_stats = player_stats.groupby(['Match_ID', 'Team', 'Home_Team']).sum()[['Score', 'xScore', 'vaep_value', 'offensive_value', 'defensive_value', 'exp_vaep_value', 'exp_offensive_value', 'exp_defensive_value']].reset_index()
match_stats['Home_Away'] = np.where(match_stats['Team'] == match_stats['Home_Team'], 'Home', 'Away')
match_stats = match_stats.pivot(index = 'Match_ID', columns = 'Home_Away', values = ['xScore', 'vaep_value', 'offensive_value', 'defensive_value', 'exp_vaep_value', 'exp_offensive_value', 'exp_defensive_value'])
match_stats.columns = ['_'.join((y, x)) for (x, y) in match_stats.columns]
match_stats.head()
# Out:
#                                      Away_xScore  Home_xScore  \
# Match_ID
# 202101_BrisbaneLions_Sydney              92.4685      69.7281
# 202101_Collingwood_WesternBulldogs       89.9581      60.3994
# 202101_Essendon_Hawthorn                 90.4045      93.4030
# 202101_GreaterWesternSydney_StKilda      80.1441      92.1888
# 202101_Melbourne_Fremantle               68.4989      98.1589
#
#                                      Away_vaep_value  Home_vaep_value  \
# Match_ID
# 202101_BrisbaneLions_Sydney                  24.2606          19.2363
# 202101_Collingwood_WesternBulldogs           15.9335          13.9565
# 202101_Essendon_Hawthorn                     21.0892          20.2102
# 202101_GreaterWesternSydney_StKilda          20.6573          18.4181
# 202101_Melbourne_Fremantle                   12.3997          14.5982
#
#                                      Away_offensive_value  \
# Match_ID
# 202101_BrisbaneLions_Sydney                       22.3104
# 202101_Collingwood_WesternBulldogs                13.1114
# 202101_Essendon_Hawthorn                          18.6803
# 202101_GreaterWesternSydney_StKilda               16.8530
# 202101_Melbourne_Fremantle                        10.7470
#
#                                      Home_offensive_value  \
# Match_ID
# 202101_BrisbaneLions_Sydney                       16.3960
# 202101_Collingwood_WesternBulldogs                10.0669
# 202101_Essendon_Hawthorn                          15.8776
# 202101_GreaterWesternSydney_StKilda               15.0227
# 202101_Melbourne_Fremantle                        11.9639
#
#                                      Away_defensive_value  \
# Match_ID
# 202101_BrisbaneLions_Sydney                        1.9501
# 202101_Collingwood_WesternBulldogs                 2.8221
# 202101_Essendon_Hawthorn                           2.4089
# 202101_GreaterWesternSydney_StKilda                3.8042
# 202101_Melbourne_Fremantle                         1.6527
#
#                                      Home_defensive_value  \
# Match_ID
# 202101_BrisbaneLions_Sydney                        2.8403
# 202101_Collingwood_WesternBulldogs                 3.8897
# 202101_Essendon_Hawthorn                           4.3326
# 202101_GreaterWesternSydney_StKilda                3.3954
# 202101_Melbourne_Fremantle                         2.6343
#
#                                      Away_exp_vaep_value  Home_exp_vaep_value  \
# Match_ID
# 202101_BrisbaneLions_Sydney                     121.0789             100.5702
# 202101_Collingwood_WesternBulldogs              126.5315              99.6866
# 202101_Essendon_Hawthorn                        117.6707             118.2525
# 202101_GreaterWesternSydney_StKilda             111.5834             127.2029
# 202101_Melbourne_Fremantle                       85.5965             115.5518
#
#                                      Away_exp_offensive_value  \
# Match_ID
# 202101_BrisbaneLions_Sydney                          114.2657
# 202101_Collingwood_WesternBulldogs                   112.0616
# 202101_Essendon_Hawthorn                             109.9257
# 202101_GreaterWesternSydney_StKilda                  104.5752
# 202101_Melbourne_Fremantle                            83.4532
#
#                                      Home_exp_offensive_value  \
# Match_ID
# 202101_BrisbaneLions_Sydney                           87.4443
# 202101_Collingwood_WesternBulldogs                    84.0031
# 202101_Essendon_Hawthorn                             105.5508
# 202101_GreaterWesternSydney_StKilda                  109.8564
# 202101_Melbourne_Fremantle                           106.5428
#
#                                      Away_exp_defensive_value  \
# Match_ID
# 202101_BrisbaneLions_Sydney                            6.8132
# 202101_Collingwood_WesternBulldogs                    14.4699
# 202101_Essendon_Hawthorn                               7.7450
# 202101_GreaterWesternSydney_StKilda                    7.0082
# 202101_Melbourne_Fremantle                             2.1433
#
#                                      Home_exp_defensive_value
# Match_ID
# 202101_BrisbaneLions_Sydney                           13.1260
# 202101_Collingwood_WesternBulldogs                    15.6836
# 202101_Essendon_Hawthorn                              12.7016
# 202101_GreaterWesternSydney_StKilda                   17.3465
# 202101_Melbourne_Fremantle                             9.0090

# %% [markdown]
# Merge Match Summary and Stats Data

# %%
match_summary_stats = match_summary.merge(match_stats, how = "left", on = "Match_ID")

# %%
match_summary_stats.head()
# Out:
#                 Home_Team         Away_Team              Q4_Score  Margin  \
# 0          Brisbane Lions            Sydney  14.10.94 - 19.11.125     -31
# 1             Collingwood  Western Bulldogs     7.11.53 - 10.9.69     -16
# 2                Essendon          Hawthorn    13.13.91 - 14.8.92      -1
# 3  Greater Western Sydney          St Kilda    11.12.78 - 13.8.86      -8
# 4               Melbourne         Fremantle    11.14.80 - 8.10.58      22
#
#    Total Game Score  Home Win              Venue       City  \
# 0               219       0.0              Gabba   Brisbane
# 1               122       0.0             M.C.G.  Melbourne
# 2               183       0.0          Docklands  Melbourne
# 3               164       0.0  Sydney Showground     Sydney
# 4               138       1.0             M.C.G.  Melbourne
#
#                   Date  Attendance  Temperature  Weather_Type  Year Round_ID  \
# 0  2021-03-20 19:45:00           0           18  MOSTLY_SUNNY  2021   202101
# 1  2021-03-19 19:50:00           0           27  MOSTLY_SUNNY  2021   202101
# 2  2021-03-20 19:25:00           0           26  MOSTLY_SUNNY  2021   202101
# 3  2021-03-21 15:20:00           0           22          RAIN  2021   202101
# 4  2021-03-20 13:45:00           0           26  MOSTLY_SUNNY  2021   202101
#
#                               Match_ID  Season  Home_Score  Home_Goals  \
# 0          202101_BrisbaneLions_Sydney    2021          94          14
# 1   202101_Collingwood_WesternBulldogs    2021          53           7
# 2             202101_Essendon_Hawthorn    2021          91          13
# 3  202101_GreaterWesternSydney_StKilda    2021          78          11
# 4           202101_Melbourne_Fremantle    2021          80          11
#
#    Home_Behinds  Home_Shots  Home_Conversion  Away_Score  Away_Goals  \
# 0            10          24           0.5833         125          19
# 1            11          18           0.3889          69          10
# 2            13          26           0.5000          92          14
# 3            12          23           0.4783          86          13
# 4            14          25           0.4400          58           8
#
#    Away_Behinds  Away_Shots  Away_Conversion  Away_xScore  Home_xScore  \
# 0            11          30           0.6333      92.4685      69.7281
# 1             9          19           0.5263      89.9581      60.3994
# 2             8          22           0.6364      90.4045      93.4030
# 3             8          21           0.6190      80.1441      92.1888
# 4            10          18           0.4444      68.4989      98.1589
#
#    Away_vaep_value  Home_vaep_value  Away_offensive_value  \
# 0          24.2606          19.2363               22.3104
# 1          15.9335          13.9565               13.1114
# 2          21.0892          20.2102               18.6803
# 3          20.6573          18.4181               16.8530
# 4          12.3997          14.5982               10.7470
#
#    Home_offensive_value  Away_defensive_value  Home_defensive_value  \
# 0               16.3960                1.9501                2.8403
# 1               10.0669                2.8221                3.8897
# 2               15.8776                2.4089                4.3326
# 3               15.0227                3.8042                3.3954
# 4               11.9639                1.6527                2.6343
#
#    Away_exp_vaep_value  Home_exp_vaep_value  Away_exp_offensive_value  \
# 0             121.0789             100.5702                  114.2657
# 1             126.5315              99.6866                  112.0616
# 2             117.6707             118.2525                  109.9257
# 3             111.5834             127.2029                  104.5752
# 4              85.5965             115.5518                   83.4532
#
#    Home_exp_offensive_value  Away_exp_defensive_value  \
# 0                   87.4443                    6.8132
# 1                   84.0031                   14.4699
# 2                  105.5508                    7.7450
# 3                  109.8564                    7.0082
# 4                  106.5428                    2.1433
#
#    Home_exp_defensive_value
# 0                   13.1260
# 1                   15.6836
# 2                   12.7016
# 3                   17.3465
# 4                    9.0090

# %% [markdown]
# Home Advantage

# %%
match_summary_stats['Home Win'].mean()
# Out:
# 0.5683690280065898

# %%
match_summary_stats.groupby('Season').mean()['Home Win']
# Out:
# Season
# 2021    0.5218
# 2022    0.6014
# 2023    0.5825
# Name: Home Win, dtype: float64

# %%
match_summary_stats.groupby('Home Win').mean()['Margin'].sum()
# Out:
# 4.311273679694736

# %%
match_summary_stats.groupby(['Season', 'Home Win']).mean()['Margin'].groupby('Season').sum()
# Out:
# Season
# 2021     6.4198
# 2022    -3.6583
# 2023    10.4268
# Name: Margin, dtype: float64

# %%
starting_home_advantage = match_summary_stats[match_summary_stats['Season']==2021]['Home Win'].mean() / 0.5
starting_home_advantage
# Out:
# 1.0436893203883495

# %% [markdown]
# Team Ratings

# %% [markdown]
# Team Ratings are going to be normally distributed, around some mean value with a standard deviation (average rating and confidence/variance in that rating/future performance.)
#
# Team ratings should not account for Home advantage, but should get updated compared to their pre-match expectations. (Bayesian update)
#
# Team performances will be the team rating + some home advantage modifier + consideration of opposition team rating and will be normally distributed.
#
# Team Ratings are based on Expected Scores and Expected VAEP Values for each match by a team, the HA-neutralised ones.
#
# Team Ratings highly depend on the individual Player Ratings that are playing for that team in that match.
# Ideally Team Ratings are the sum of individual Player Ratings.
#
# Player Ratings are normally distributed, around some mean value with a standard deviation (average rating and variance in performance).
#
# Player ratings should not account for Home advantage, but should get updated compared to their pre-match expectations. (Bayesian update)
#
# Player performances will be the Player rating + some home advantage modifier + consideration of opposition team rating and will be normally distributed.
#
# Player Ratings are based on Expected Vaep Values for each match by a player. These will be scaled/proportioned into the HA-neutralised Expected Score of the team.

# %% [markdown]
# - Individual player ratings based on past Expected VAEP values
# - Team ratings are the combined player ratings for whoever is playing
# - Home advantage is some multiplier/adjustment that is applied to home/away team
# - Predicted match outcome, probability, margin is based on both team's ratings
# - Match happens
# - Actual match outcome, margin is available
# - Expected VAEP values for each player is available for latest game
# - Player ratings are updated based on their Expected VAEP in the match compared to their prior Expected VAEP (HA-neutral)
# - Team ratings are (either) updated based on new player ratings (or) updated based on actual margin compared to predicted margin (HA-neutral)

# %% [markdown]
# Player Values

# %%
starting_player_values = player_stats[player_stats['Season'] == 2021].groupby(['Player', 'Team']).mean()[['exp_vaep_value', 'exp_offensive_value', 'exp_defensive_value']].reset_index()
starting_player_values.sort_values(by = 'exp_vaep_value',ascending = False).head(10)
# Out:
#                  Player                    Team  exp_vaep_value  \
# 599         Toby Greene  Greater Western Sydney         12.1438
# 154         Dayne Zorko          Brisbane Lions         10.6815
# 568         Shai Bolton                Richmond         10.4440
# 112      Clayton Oliver               Melbourne         10.4249
# 42       Ben Cunnington         North Melbourne         10.2914
# 110  Christian Petracca               Melbourne         10.2715
# 268       Jake Stringer                Essendon         10.2214
# 245         Jack Steele                St Kilda          9.8891
# 232         Jack Macrae        Western Bulldogs          9.8434
# 178          Elliot Yeo              West Coast          9.8165
#
#      exp_offensive_value  exp_defensive_value
# 599              12.8986              -0.7548
# 154              10.2189               0.4626
# 568              10.7751              -0.3311
# 112               9.9593               0.4657
# 42                9.5541               0.7373
# 110              10.8995              -0.6280
# 268              10.8140              -0.5926
# 245               9.2413               0.6478
# 232               9.1868               0.6566
# 178               8.9443               0.8722

# %%
starting_player_stds = player_stats[player_stats['Season'] == 2021].groupby('Player').std()[['exp_offensive_value', 'exp_defensive_value']].reset_index()
starting_player_stds.columns = ['Player', 'exp_offensive_value_std', 'exp_defensive_value_std']
starting_player_stds.sort_values(by = 'exp_offensive_value_std', ascending = False).head(10)
# Out:
#                   Player  exp_offensive_value_std  exp_defensive_value_std
# 2         Aaron Naughton                   6.7558                   0.8957
# 72       Brendon Ah Chee                   6.4003                   1.1516
# 177           Eddie Ford                   6.0882                   0.3139
# 590        Taylor Walker                   5.9785                   1.1573
# 617         Tom J. Lynch                   5.9632                   1.0408
# 494      Orazio Fantasia                   5.8227                   0.7301
# 504  Patrick Dangerfield                   5.8206                   1.2537
# 45              Ben King                   5.8037                   0.6249
# 305       Jeremy Cameron                   5.5116                   0.6970
# 113       Cody Weightman                   5.5093                   0.6889

# %% [markdown]
# Match Level Player Ratings & Team Ratings

# %%
match_player_stats = player_stats[player_stats['Match_ID'] == "202201_Melbourne_WesternBulldogs"]
home_players = list(match_player_stats[match_player_stats['Team'] == match_player_stats['Home_Team']]['Player'].unique())
away_players = list(match_player_stats[match_player_stats['Team'] != match_player_stats['Home_Team']]['Player'].unique())
home_rating = starting_player_values[starting_player_values['Player'].isin(home_players)]['exp_vaep_value'].sum()
away_rating = starting_player_values[starting_player_values['Player'].isin(away_players)]['exp_vaep_value'].sum()
home_offensive_rating = starting_player_values[starting_player_values['Player'].isin(home_players)]['exp_offensive_value'].sum()
home_defensive_rating = starting_player_values[starting_player_values['Player'].isin(home_players)]['exp_defensive_value'].sum()
away_offensive_rating = starting_player_values[starting_player_values['Player'].isin(away_players)]['exp_offensive_value'].sum()
away_defensive_rating = starting_player_values[starting_player_values['Player'].isin(away_players)]['exp_defensive_value'].sum()

# %% [markdown]
# Home Advantage Adjusted Home Team Ratings

# %%
home_rating_ha = home_rating * starting_home_advantage
home_offensive_rating_ha = home_offensive_rating * starting_home_advantage
home_defensive_rating_ha = home_defensive_rating * starting_home_advantage

# %%
home_rating, home_rating_ha, away_rating
# Out:
# (120.65547921207504, 125.92683509998122, 127.9830847182428)

# %%
home_offensive_rating, home_offensive_rating_ha, away_offensive_rating
# Out:
# (110.98500927333592, 115.83386890178264, 114.55473838595543)

# %%
home_defensive_rating, home_defensive_rating_ha, away_defensive_rating
# Out:
# (9.670469945826618, 10.092966205595742, 13.42834638390561)

# %%
home_match_rating = home_offensive_rating_ha - away_defensive_rating
away_match_rating = away_offensive_rating - home_defensive_rating_ha
home_match_rating, away_match_rating
# Out:
# (102.40552251787703, 104.46177218035969)

# %% [markdown]
# Team Standard Deviation Estimate

# %%
match_summary_stats[['Home_exp_vaep_value', 'Away_exp_vaep_value']].std()
# Out:
# Home_exp_vaep_value    21.9364
# Away_exp_vaep_value    20.8923
# dtype: float64

# %%
starting_std_value = 20

# %% [markdown]
# Turn Team Ratings into Match Predictions

# %%
def calculate_probabilities(home_mean, home_std, away_mean, away_std):
    
    mean = home_mean - away_mean
    std = home_std + away_std
    diff = stats.norm(loc = mean, scale = std)
    
    away_prob = diff.cdf(0)
    draw_prob = diff.pdf(0)
    home_prob = 1 - away_prob - draw_prob
    
    return home_prob, draw_prob, away_prob

# %%
home_predicted_prob, draw_predicted_prob, away_predicted_prob = calculate_probabilities(home_match_rating, starting_std_value, away_match_rating, starting_std_value)
home_predicted_prob, draw_predicted_prob, away_predicted_prob
# Out:
# (0.46954051800881047, 0.009960387643086611, 0.5204990943481029)

# %% [markdown]
# Get Actual Match Result

# %%
match_player_stats.head()
# Out:
#                               Match_ID       Team            Player Round_ID  \
# 9759  202201_Melbourne_WesternBulldogs  Melbourne    Adam Tomlinson   202201
# 9760  202201_Melbourne_WesternBulldogs  Melbourne  Alex Neal-Bullen   202201
# 9761  202201_Melbourne_WesternBulldogs  Melbourne    Angus Brayshaw   202201
# 9762  202201_Melbourne_WesternBulldogs  Melbourne    Bayley Fritsch   202201
# 9763  202201_Melbourne_WesternBulldogs  Melbourne         Ben Brown   202201
#
#      AFL_API_Player_ID      Player_Type     playerId  Age  Height  Weight  \
# 9759    Adam_Tomlinson     KEY_DEFENDER   CD_I291819   28     194      95
# 9760  Alex_Neal-Bullen   MEDIUM_FORWARD   CD_I296420   26     183      81
# 9761    Angus_Brayshaw  MEDIUM_DEFENDER   CD_I298279   26     187      92
# 9762    Bayley_Fritsch   MEDIUM_FORWARD  CD_I1001438   25     188      84
# 9763         Ben_Brown      KEY_FORWARD   CD_I291867   29     200     101
#
#       Number Kicking_Foot State_Of_Origin  Draft_Year  Debut_Year  \
# 9759      20        RIGHT             VIC      2011.0      2012.0
# 9760      30        RIGHT              SA      2014.0      2015.0
# 9761      10        RIGHT             VIC      2014.0      2015.0
# 9762      31         LEFT             VIC      2017.0      2018.0
# 9763      50        RIGHT             TAS      2013.0      2014.0
#
#                                          Recruited_From  Draft_Position  \
# 9759  Canterbury (Vic)/Trinity Grammar (Vic)/Oakleig...             9.0
# 9760                      Plympton (SA)/Glenelg (SANFL)            40.0
# 9761               Hampton Rovers (Vic)/Sandringham U18             3.0
# 9762                       Coldstream (Vic)/Casey (VFL)            31.0
# 9763  Devonport (Tas)/Tasmania U18/Werribee (VFL)/No...            47.0
#
#          Draft_Type                                          Photo_URL  \
# 9759  nationalDraft  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
# 9760  nationalDraft  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
# 9761  nationalDraft  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
# 9762  nationalDraft  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
# 9763  nationalDraft  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
#
#      Date_Of_Birth  Percent_Played  Behinds  Bounces  Centre_Bounces_Attended  \
# 9759    1993-08-10           100.0      0.0      0.0                      0.0
# 9760    1996-01-09            88.0      1.0      2.0                      5.0
# 9761    1996-01-09            83.0      0.0      0.0                      0.0
# 9762    1996-12-06            81.0      2.0      0.0                      0.0
# 9763    1992-11-20            86.0      3.0      0.0                      0.0
#
#       Centre_Clearances  Clangers  Defensive_Contest_Losses  \
# 9759                0.0       2.0                       0.0
# 9760                0.0       1.0                       0.0
# 9761                0.0       4.0                       1.0
# 9762                0.0       2.0                       0.0
# 9763                0.0       1.0                       0.0
#
#       Defensive_Contest_Loss_Percentage  Defensive_One_On_One_Contests  \
# 9759                                0.0                            0.0
# 9760                                0.0                            0.0
# 9761                              100.0                            1.0
# 9762                                0.0                            0.0
# 9763                                0.0                            0.0
#
#       Contested_Marks  Contested_Possession_Rate  Contested_Possessions  \
# 9759              0.0                       33.3                    3.0
# 9760              1.0                       44.4                    8.0
# 9761              0.0                       17.4                    4.0
# 9762              1.0                       37.5                    3.0
# 9763              2.0                       46.2                    6.0
#
#       Offensive_One_On_One_Contests  Offensive_Contest_Wins  \
# 9759                            0.0                     0.0
# 9760                            0.0                     0.0
# 9761                            0.0                     0.0
# 9762                            3.0                     0.0
# 9763                            1.0                     0.0
#
#       Offensive_Contest_Win_Percentage  Defensive_Half_Pressure_Acts  \
# 9759                               0.0                           3.0
# 9760                               0.0                          12.0
# 9761                               0.0                           3.0
# 9762                               0.0                           1.0
# 9763                               0.0                           0.0
#
#       Disposal_Efficiency  Disposals  AFL_Fantasy_Points  Effective_Disposals  \
# 9759                 75.0        8.0                35.0                  6.0
# 9760                 72.2       18.0                85.0                 13.0
# 9761                 65.2       23.0                86.0                 15.0
# 9762                 55.6        9.0                53.0                  5.0
# 9763                 61.5       13.0                77.0                  8.0
#
#       Effective_Kicks  Inside_50_Ground_Ball_Gets  Frees_Against  Frees_For  \
# 9759              4.0                         0.0            1.0        0.0
# 9760              6.0                         1.0            0.0        1.0
# 9761              9.0                         0.0            1.0        1.0
# 9762              4.0                         2.0            1.0        0.0
# 9763              5.0                         1.0            1.0        0.0
#
#       Goal_Accuracy  Goal_Assists  Goals  Ground_Ball_Gets  Handballs  \
# 9759            0.0           0.0    0.0               2.0        2.0
# 9760            0.0           3.0    0.0               6.0        8.0
# 9761            0.0           0.0    0.0               3.0       11.0
# 9762           40.0           1.0    2.0               2.0        1.0
# 9763           50.0           0.0    3.0               3.0        4.0
#
#       Hit_Outs  Hit_Outs_To_Advantage  Hit_Outs_To_Advantage_Rate  \
# 9759       0.0                    0.0                         0.0
# 9760       0.0                    0.0                         0.0
# 9761       0.0                    0.0                         0.0
# 9762       0.0                    0.0                         0.0
# 9763       0.0                    0.0                         0.0
#
#       Hit_Out_Win_Percentage  Inside_50s  Intercept_Marks  Intercepts  \
# 9759                     0.0         0.0              1.0         3.0
# 9760                     0.0         6.0              1.0         4.0
# 9761                     0.0         2.0              3.0         7.0
# 9762                     0.0         2.0              0.0         0.0
# 9763                     0.0         1.0              0.0         0.0
#
#       Kick_Efficiency  Kick_Ins  Kick_Ins_Played_On  Kicks  \
# 9759             66.7       0.0                 0.0    6.0
# 9760             60.0       0.0                 0.0   10.0
# 9761             75.0       0.0                 0.0   12.0
# 9762             50.0       0.0                 0.0    8.0
# 9763             55.6       0.0                 0.0    9.0
#
#       Kick_To_Handball_Ratio  Marks  Marks_Inside_50  Marks_On_Lead  \
# 9759                     3.0    4.0              0.0            0.0
# 9760                     1.3    3.0              0.0            0.0
# 9761                     1.1    6.0              0.0            0.0
# 9762                     8.0    4.0              3.0            1.0
# 9763                     2.3    8.0              6.0            3.0
#
#       Metres_Gained  One_Percenters  Pressure_Acts  Player_Rating_Points  \
# 9759          151.0             4.0            4.0                   2.9
# 9760          320.0             2.0           29.0                  12.1
# 9761          272.0             1.0            7.0                   3.3
# 9762          245.0             0.0            4.0                   6.1
# 9763          245.0             2.0            5.0                  11.5
#
#       Rebound_50s  Ruck_Contests  Score_Involvements  Score_Launches  \
# 9759          1.0            0.0                 0.0             0.0
# 9760          0.0            0.0                 8.0             3.0
# 9761          2.0            0.0                 3.0             0.0
# 9762          0.0            0.0                 6.0             0.0
# 9763          0.0            2.0                11.0             1.0
#
#       Shots_At_Goal  Spoils  Stoppage_Clearances  Tackles  Tackles_Inside_50  \
# 9759            0.0     3.0                  0.0      1.0                0.0
# 9760            1.0     1.0                  0.0      7.0                1.0
# 9761            0.0     1.0                  0.0      3.0                0.0
# 9762            5.0     0.0                  0.0      1.0                0.0
# 9763            6.0     2.0                  0.0      0.0                0.0
#
#       Clearances  Possessions  Turnovers  Uncontested_Possessions  \
# 9759         0.0          9.0        3.0                      6.0
# 9760         0.0         18.0        4.0                     10.0
# 9761         0.0         23.0        3.0                     19.0
# 9762         0.0          8.0        2.0                      5.0
# 9763         0.0         13.0        1.0                      7.0
#
#      AFLCA_Player_ID  Coaches_Votes                  Position Team_Status  \
# 9759             NaN            NaN          Centre Half Back  FINAL_TEAM
# 9760             NaN            NaN  Half Forward Flank Right  FINAL_TEAM
# 9761             NaN            NaN     Half Back Flank Right  FINAL_TEAM
# 9762             NaN            NaN       Forward Pocket Left  FINAL_TEAM
# 9763       Ben_Brown            6.0              Full Forward  FINAL_TEAM
#
#      Position_Sub_Group Position_Group  Year  Brownlow_Votes  Season   xScore  \
# 9759           Key-Back           Back   NaN             NaN    2022   0.0000
# 9760       Half-Forward        Forward   NaN             NaN    2022   3.4007
# 9761          Half-Back           Back   NaN             NaN    2022   0.0000
# 9762     Forward-Pocket        Forward   NaN             NaN    2022  15.6341
# 9763        Key-Forward        Forward   NaN             NaN    2022  17.2676
#
#       xT_created  xT_denied  vaep_value  offensive_value  defensive_value  \
# 9759     -0.3239     0.0341     -0.1268          -0.0088          -0.1180
# 9760      0.0735     0.0579      0.6447           0.6378           0.0069
# 9761     -0.2260     0.0612      0.1956           0.2423          -0.0467
# 9762      0.0558     0.0000      1.2048           1.3072          -0.1023
# 9763     -0.4876    -0.0608      1.9923           2.0882          -0.0959
#
#       exp_vaep_value  exp_offensive_value  exp_defensive_value  xT_received  \
# 9759          1.7637               0.8481               0.9156      -0.2138
# 9760          6.2626               5.6120               0.6506       0.3239
# 9761          1.6399               2.3615              -0.7215      -0.2951
# 9762         11.7597              12.3270              -0.5673       0.4324
# 9763          5.2001               6.1275              -0.9274       0.8272
#
#       xT_prevented  vaep_value_received  exp_vaep_value_received  \
# 9759        0.1927              -0.3206                  -0.1645
# 9760        0.0689               1.1375                   6.8563
# 9761        0.2156               0.0937                  -0.7763
# 9762        0.0000               2.2274                  13.9852
# 9763        0.1234               1.7815                  13.9368
#
#               Player_Season  Score  xScore_Diff  Home_Team         Away_Team  \
# 9759    Adam Tomlinson_2022    0.0       0.0000  Melbourne  Western Bulldogs
# 9760  Alex Neal-Bullen_2022    1.0      -2.4007  Melbourne  Western Bulldogs
# 9761    Angus Brayshaw_2022    0.0       0.0000  Melbourne  Western Bulldogs
# 9762    Bayley Fritsch_2022   14.0      -1.6341  Melbourne  Western Bulldogs
# 9763         Ben Brown_2022   21.0       3.7324  Melbourne  Western Bulldogs
#
#               Opponent  Round Round_str  Round_ID_num
# 9759  Western Bulldogs      1        01         20221
# 9760  Western Bulldogs      1        01         20221
# 9761  Western Bulldogs      1        01         20221
# 9762  Western Bulldogs      1        01         20221
# 9763  Western Bulldogs      1        01         20221

# %%
home_actual_offensive_rating_ha = match_player_stats[match_player_stats['Team'] == match_player_stats['Home_Team']]['exp_offensive_value'].sum()
home_actual_defensive_rating_ha = match_player_stats[match_player_stats['Team'] == match_player_stats['Home_Team']]['exp_defensive_value'].sum()

home_actual_offensive_rating = home_actual_offensive_rating_ha / starting_home_advantage
home_actual_defensive_rating = home_actual_defensive_rating_ha / starting_home_advantage

away_actual_offensive_rating = match_player_stats[match_player_stats['Team'] != match_player_stats['Home_Team']]['exp_offensive_value'].sum()
away_actual_defensive_rating = match_player_stats[match_player_stats['Team'] != match_player_stats['Home_Team']]['exp_defensive_value'].sum()

home_actual_offensive_rating_ha, home_actual_offensive_rating, home_actual_defensive_rating_ha, home_actual_defensive_rating, away_actual_offensive_rating, away_actual_defensive_rating
# Out:
# (122.60482858083999,
#  117.47253343094437,
#  16.601954696773,
#  15.906989151326687,
#  82.1030578907,
#  11.745696560322028)

# %%
home_actual_rating = home_actual_offensive_rating_ha - away_actual_defensive_rating
away_actual_rating = away_actual_offensive_rating - home_actual_defensive_rating_ha
home_actual_rating, away_actual_rating
# Out:
# (110.85913202051796, 65.50110319392701)

# %% [markdown]
# Checking if Player Value Aggregation is the same

# %%
home_actual_player_values = match_player_stats[match_player_stats['Team'] == match_player_stats['Home_Team']][['Player', 'Team', 'exp_vaep_value', 'exp_offensive_value', 'exp_defensive_value']]
home_actual_player_values = home_actual_player_values.rename(columns = {
    'exp_vaep_value':'actual_exp_vaep_value_ha',
    'exp_offensive_value':'actual_exp_offensive_value_ha',
    'exp_defensive_value':'actual_exp_defensive_value_ha'})
away_actual_player_values = match_player_stats[match_player_stats['Team'] != match_player_stats['Home_Team']][['Player', 'Team', 'exp_vaep_value', 'exp_offensive_value', 'exp_defensive_value']]
away_actual_player_values = away_actual_player_values.rename(columns = {
    'exp_vaep_value':'actual_exp_vaep_value',
    'exp_offensive_value':'actual_exp_offensive_value',
    'exp_defensive_value':'actual_exp_defensive_value'})

# %%
assert home_actual_player_values['actual_exp_offensive_value_ha'].sum() == home_actual_offensive_rating_ha

# %%
home_actual_player_values['actual_exp_offensive_value'] = home_actual_player_values['actual_exp_offensive_value_ha'] / starting_home_advantage

# %%
assert round(home_actual_player_values['actual_exp_offensive_value'].sum(), 5), round(home_actual_offensive_rating, 5)

# %% [markdown]
# Bayesian Value Updating

# %%
home_prior_player_values = starting_player_values[starting_player_values['Player'].isin(home_players)]
home_prior_player_stds = starting_player_stds[starting_player_stds['Player'].isin(home_players)]
home_prior_player_values = home_prior_player_values.merge(home_prior_player_stds, how = 'left', on = ['Player'])
away_prior_player_values = starting_player_values[starting_player_values['Player'].isin(away_players)]
away_prior_player_stds = starting_player_stds[starting_player_stds['Player'].isin(away_players)]
away_prior_player_values = away_prior_player_values.merge(away_prior_player_stds, how = 'left', on = ['Player'])

# %%
home_player_values = home_prior_player_values.merge(home_actual_player_values, how = 'left', on = ['Player', 'Team'])
home_player_values[['Player', 'exp_offensive_value', 'exp_offensive_value_std', 'actual_exp_offensive_value']]
# Out:
#                 Player  exp_offensive_value  exp_offensive_value_std  \
# 0       Adam Tomlinson               0.8936                   1.7327
# 1     Alex Neal-Bullen               3.9892                   2.9122
# 2       Angus Brayshaw               4.2726                   3.0944
# 3       Bayley Fritsch               7.3858                   3.7099
# 4            Ben Brown               7.2357                   3.4335
# 5       Charlie Spargo               4.5879                   3.3124
# 6   Christian Petracca              10.8995                   4.8021
# 7      Christian Salem               4.9484                   3.0850
# 8       Clayton Oliver               9.9593                   4.8195
# 9           Ed Langdon               4.7460                   2.9428
# 10          Jack Viney               5.1972                   3.3762
# 11          Jake Bowey               3.1792                   2.2294
# 12        James Harmes               5.4956                   4.0933
# 13        James Jordon               2.9048                   3.7954
# 14         Jayden Hunt               3.9311                   2.3106
# 15          Joel Smith               0.2553                   1.0303
# 16     Kysaiah Pickett               6.7655                   4.0534
# 17        Luke Jackson               4.6823                   3.9635
# 18            Max Gawn               7.2455                   3.8378
# 19          Steven May               1.7959                   2.2706
# 20        Tom McDonald               6.8412                   3.8150
# 21         Tom Sparrow               3.7732                   2.7169
#
#     actual_exp_offensive_value
# 0                       0.8481
# 1                       5.6120
# 2                       2.3615
# 3                      12.3270
# 4                       6.1275
# 5                       8.1413
# 6                      16.7451
# 7                       0.4968
# 8                      10.7714
# 9                       8.1605
# 10                      9.7111
# 11                      1.8394
# 12                      3.0531
# 13                      1.3667
# 14                      2.9897
# 15                     -0.7798
# 16                      2.8322
# 17                      8.3498
# 18                      6.6892
# 19                      3.4570
# 20                      1.7196
# 21                      6.2129

# %% [markdown]
# posterior = (likelihood * prior) / evidence

# %% [markdown]
# - prior - probability distribution based on our current view of mean and variance
# - likelihood - probability density of getting the new value
# - evidence - probability that the new value is produced

# %%
import matplotlib.pyplot as plt

# %%
player = "Christian Petracca"
mu = np.linspace(-5, 25, num=10000)

# prior
prior_mean = home_player_values[home_player_values['Player'] == player]['exp_offensive_value'].iloc[0]
prior_std = home_player_values[home_player_values['Player'] == player]['exp_offensive_value_std'].iloc[0]
prior_dist = stats.norm.pdf(mu, loc = prior_mean, scale = prior_std)
# prior_dist = prior_dist/prior_dist.sum()
print((prior_mean, prior_std))
plt.plot(mu, prior_dist)
# Out:
# (10.899465060152, 4.802073529629512)

# %%
compute_percentile(mu, prior_dist, percentile=0.5)
# Out:
# 10.904590459045904

# %%
# likelihood
new_data = home_player_values[home_player_values['Player'] == player]['actual_exp_offensive_value'].iloc[0]
def likelihood_func(data, mu, sigma):
    likelihood_out = stats.norm.pdf(data, mu, scale=sigma)
    return likelihood_out / likelihood_out.sum()

likelihood_out = likelihood_func(new_data, mu, prior_std)

plt.plot(mu, likelihood_out)

# %%
# evidence
unnormalized_posterior = likelihood_out * prior_dist
p_data = sp.integrate.trapz(unnormalized_posterior, mu)
normalized_posterior = unnormalized_posterior / p_data
print(sp.integrate.trapz(unnormalized_posterior, mu), sp.integrate.trapz(normalized_posterior, mu))
plt.plot(mu, normalized_posterior)
# Out:
# 0.00012706111888684292 1.0

# %%
posterior_mean = (((1/prior_std)*prior_mean) + ((1/prior_std)*new_data)) / ((1/prior_std) + (1/prior_std))
posterior_std = (prior_std*prior_std)/(prior_std+prior_std)

# %%
def compute_percentile(parameter_values, distribution_values, percentile=0.5):
    cumulative_distribution = sp.integrate.cumtrapz(
        distribution_values, parameter_values)
    percentile_index = np.searchsorted(cumulative_distribution, percentile)
    return parameter_values[percentile_index]

# %%
plt.plot(mu, normalized_posterior, label = 'Final Posterior Model')
plt.axvline(x = compute_percentile(mu, normalized_posterior, 0.005), ls = '--', color = 'y', label = '99% Conf Int')
plt.axvline(x = compute_percentile(mu, normalized_posterior, 0.995), ls = '--', color = 'y')
plt.legend()
