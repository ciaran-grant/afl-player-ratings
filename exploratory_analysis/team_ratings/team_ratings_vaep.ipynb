# %% [markdown]
# Create and Test Team Ratings for 2023 Season - Round by Round

# %%
import pandas as pd
import re
import numpy as np
from scipy import stats
from sklearn import metrics

import os
import warnings
warnings.filterwarnings('ignore')
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999
pd.set_option('display.precision', 4)

# %%
player_stats = pd.read_csv("/Users/ciaran/Documents/Projects/AFL/data/scored_player_stats_v2.csv")
player_stats['Season'] = player_stats['Match_ID'].apply(lambda x: int(x[:4]))
player_stats['Player_Season'] = player_stats['Player'] + "_" + player_stats['Season'].astype(str)

player_stats['Score'] = player_stats['Behinds'] + player_stats['Goals']*6
player_stats['xScore_Diff'] = player_stats['Score'] - player_stats['xScore']

player_stats['Home_Team'] = player_stats['Match_ID'].apply(lambda x: x.split("_")[1]).str.replace(r"([A-Z])", r" \1").str.strip()
player_stats['Away_Team'] = player_stats['Match_ID'].apply(lambda x: x.split("_")[-1]).str.replace(r"([A-Z])", r" \1").str.strip()
player_stats['Opponent'] = np.where(player_stats['Team'] == player_stats['Home_Team'], player_stats['Away_Team'], player_stats['Home_Team'])

finals_round_map = {'F1':24,
                    'F2':25,
                    'F3':26,
                    'F4':27}
player_stats['Round_ID'] = player_stats['Round_ID'].astype(str)
player_stats['Round'] = (player_stats['Round_ID'].str[4:].replace(finals_round_map)).astype(int)
player_stats['Round_str'] = player_stats['Round_ID'].str[4:].replace(finals_round_map)
player_stats['Round_ID_num'] = (player_stats['Season'].astype(str) + player_stats['Round'].astype(str)).astype(int)

player_stats.tail()
# Out:
#                         Match_ID        Team               Player Round_ID  \
# 28536  202324_WestCoast_Adelaide  West Coast           Ryan Maric   202324
# 28537  202324_WestCoast_Adelaide  West Coast  Sam Petrevski-Seton   202324
# 28538  202324_WestCoast_Adelaide  West Coast         Shannon Hurn   202324
# 28539  202324_WestCoast_Adelaide  West Coast            Tim Kelly   202324
# 28540  202324_WestCoast_Adelaide  West Coast             Tom Cole   202324
#
#          AFL_API_Player_ID      Player_Type     playerId  Age  Height  Weight  \
# 28536           Ryan_Maric      KEY_FORWARD  CD_I1029416   18     196      93
# 28537  Sam_Petrevski-Seton   MEDIUM_FORWARD   CD_I994539   25     181      78
# 28538         Shannon_Hurn  MEDIUM_DEFENDER   CD_I240283   35     187      95
# 28539            Tim_Kelly       MIDFIELDER   CD_I295898   29     184      83
# 28540             Tom_Cole  MEDIUM_DEFENDER   CD_I993820   26     188      83
#
#        Number Kicking_Foot State_Of_Origin  Draft_Year  Debut_Year  \
# 28536      41        RIGHT             VIC      2023.0      2023.0
# 28537      10        RIGHT              WA      2016.0      2017.0
# 28538      25        RIGHT              SA      2005.0      2006.0
# 28539      11        RIGHT              WA      2017.0      2018.0
# 28540      28        RIGHT             VIC      2015.0      2016.0
#
#                                        Recruited_From  Draft_Position  \
# 28536  Drouin Vic)/Gippsland U18/Box Hill Hawks (VFL)             1.0
# 28537       Halls Creek (WA)/Claremont (WAFL)/Carlton             6.0
# 28538          Angaston (SA)/Central District (SANFL)            13.0
# 28539     Palmyra (WA)/South Fremantle (WAFL)/Geelong            24.0
# 28540                     Sandhurst (Vic)/Bendigo U18            36.0
#
#           Draft_Type                                          Photo_URL  \
# 28536          other  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
# 28537  nationalDraft  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
# 28538  nationalDraft  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
# 28539  nationalDraft  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
# 28540  nationalDraft  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
#
#       Date_Of_Birth  Percent_Played  Behinds  Bounces  \
# 28536    2004-09-06              71        0      0.0
# 28537    1998-02-19              61        0      0.0
# 28538    1987-09-04              83        0      0.0
# 28539    1994-07-26              84        0      2.0
# 28540    1997-05-28              83        0      0.0
#
#        Centre_Bounces_Attended  Centre_Clearances  Clangers  \
# 28536                      NaN                  0         0
# 28537                      NaN                  0         3
# 28538                      NaN                  0         2
# 28539                      NaN                  4         5
# 28540                      NaN                  0         2
#
#        Defensive_Contest_Losses  Defensive_Contest_Loss_Percentage  \
# 28536                       NaN                                NaN
# 28537                       NaN                                NaN
# 28538                       NaN                                NaN
# 28539                       NaN                                NaN
# 28540                       NaN                                NaN
#
#        Defensive_One_On_One_Contests  Contested_Marks  \
# 28536                            NaN                0
# 28537                            NaN                0
# 28538                            NaN                0
# 28539                            NaN                0
# 28540                            NaN                0
#
#        Contested_Possession_Rate  Contested_Possessions  \
# 28536                        NaN                      2
# 28537                        NaN                      6
# 28538                        NaN                      2
# 28539                        NaN                     15
# 28540                        NaN                      4
#
#        Offensive_One_On_One_Contests  Offensive_Contest_Wins  \
# 28536                            NaN                     NaN
# 28537                            NaN                     NaN
# 28538                            NaN                     NaN
# 28539                            NaN                     NaN
# 28540                            NaN                     NaN
#
#        Offensive_Contest_Win_Percentage  Defensive_Half_Pressure_Acts  \
# 28536                               NaN                           NaN
# 28537                               NaN                           NaN
# 28538                               NaN                           NaN
# 28539                               NaN                           NaN
# 28540                               NaN                           NaN
#
#        Disposal_Efficiency  Disposals  AFL_Fantasy_Points  \
# 28536                 77.8          9                  49
# 28537                 83.3         18                  64
# 28538                 95.5         22                  89
# 28539                 77.1         35                 111
# 28540                 81.3         16                  80
#
#        Effective_Disposals  Effective_Kicks  Inside_50_Ground_Ball_Gets  \
# 28536                  NaN              NaN                         NaN
# 28537                  NaN              NaN                         NaN
# 28538                  NaN              NaN                         NaN
# 28539                  NaN              NaN                         NaN
# 28540                  NaN              NaN                         NaN
#
#        Frees_Against  Frees_For  Goal_Accuracy  Goal_Assists  Goals  \
# 28536              0          2            0.0             1      0
# 28537              0          1            0.0             1      0
# 28538              0          1            0.0             0      0
# 28539              1          4            0.0             3      0
# 28540              1          1          100.0             0      1
#
#        Ground_Ball_Gets  Handballs  Hit_Outs  Hit_Outs_To_Advantage  \
# 28536               NaN          3         0                    NaN
# 28537               NaN         12         0                    NaN
# 28538               NaN          4         0                    NaN
# 28539               NaN         13         0                    NaN
# 28540               NaN          5         0                    NaN
#
#        Hit_Outs_To_Advantage_Rate  Hit_Out_Win_Percentage  Inside_50s  \
# 28536                         NaN                     NaN           0
# 28537                         NaN                     NaN           0
# 28538                         NaN                     NaN           0
# 28539                         NaN                     NaN          12
# 28540                         NaN                     NaN           2
#
#        Intercept_Marks  Intercepts  Kick_Efficiency  Kick_Ins  \
# 28536              NaN           1              NaN       NaN
# 28537              NaN           4              NaN       NaN
# 28538              NaN           4              NaN       NaN
# 28539              NaN           4              NaN       NaN
# 28540              NaN           3              NaN       NaN
#
#        Kick_Ins_Played_On  Kicks  Kick_To_Handball_Ratio  Marks  \
# 28536                 NaN      6                     NaN      5
# 28537                 NaN      6                     NaN      3
# 28538                 NaN     18                     NaN      6
# 28539                 NaN     22                     NaN      6
# 28540                 NaN     11                     NaN      7
#
#        Marks_Inside_50  Marks_On_Lead  Metres_Gained  One_Percenters  \
# 28536                0            NaN          114.0               0
# 28537                0            NaN           87.0               1
# 28538                0            NaN          506.0               3
# 28539                0            NaN          831.0               0
# 28540                1            NaN          249.0               1
#
#        Pressure_Acts  Player_Rating_Points  Rebound_50s  Ruck_Contests  \
# 28536            NaN                   NaN            1            NaN
# 28537            NaN                   NaN            2            NaN
# 28538            NaN                   NaN            7            NaN
# 28539            NaN                   NaN            3            NaN
# 28540            NaN                   NaN            4            NaN
#
#        Score_Involvements  Score_Launches  Shots_At_Goal  Spoils  \
# 28536                   3             NaN              0     NaN
# 28537                   2             NaN              0     NaN
# 28538                   2             NaN              0     NaN
# 28539                   8             NaN              0     NaN
# 28540                   3             NaN              1     NaN
#
#        Stoppage_Clearances  Tackles  Tackles_Inside_50  Clearances  \
# 28536                    0        2                  0           0
# 28537                    0        3                  0           0
# 28538                    1        2                  0           1
# 28539                    4        0                  0           8
# 28540                    0        3                  0           0
#
#        Possessions  Turnovers  Uncontested_Possessions AFLCA_Player_ID  \
# 28536           10          2                        8             NaN
# 28537           18          4                       12             NaN
# 28538           12          2                       10             NaN
# 28539           34          7                       19       Tim_Kelly
# 28540           16          2                       12             NaN
#
#        Coaches_Votes                 Position Team_Status Position_Sub_Group  \
# 28536            NaN  Half Forward Flank Left  FINAL_TEAM       Half-Forward
# 28537            NaN              Interchange  FINAL_TEAM        Interchange
# 28538            NaN        Back Pocket Right  FINAL_TEAM        Back-Pocket
# 28539            6.0                   Centre  FINAL_TEAM             Centre
# 28540            NaN     Half Back Flank Left  FINAL_TEAM          Half-Back
#
#       Position_Group  Year  Brownlow_Votes  Season  xScore  xT_created  \
# 28536        Forward   NaN             NaN    2023  0.0000     -0.0587
# 28537    Interchange   NaN             NaN    2023  0.0000     -0.2735
# 28538           Back   NaN             NaN    2023  0.0000     -0.3356
# 28539       Midfield   NaN             NaN    2023  0.0000      1.1046
# 28540           Back   NaN             NaN    2023  2.7773      0.1080
#
#        xT_denied  vaep_value  offensive_value  defensive_value  \
# 28536     0.0408      0.0525          -0.1360           0.1885
# 28537     0.0312     -0.4014          -0.2771          -0.1243
# 28538     0.0329      0.6958           0.1442           0.5515
# 28539     0.2033      2.3888           2.3904          -0.0016
# 28540    -0.0087      0.7950           0.9625          -0.1674
#
#        exp_vaep_value  exp_offensive_value  exp_defensive_value  xT_received  \
# 28536          2.1304               0.9662               1.1643       0.2911
# 28537         -2.3624              -1.7040              -0.6584      -0.1613
# 28538          1.3235               2.1248              -0.8013      -1.5501
# 28539         12.8146              12.1432               0.6714      -0.3468
# 28540          1.1599               3.0247              -1.8648      -0.2037
#
#        xT_prevented  vaep_value_received  exp_vaep_value_received  \
# 28536        0.0000               0.4040                   4.3952
# 28537        0.1136              -0.0440                   0.1591
# 28538        0.1773              -0.4591                  -1.6297
# 28539        0.1719               2.0546                  12.1317
# 28540        0.0082              -0.5325                  -2.1933
#
#                   Player_Season  Score  xScore_Diff   Home_Team Away_Team  \
# 28536           Ryan Maric_2023      0       0.0000  West Coast  Adelaide
# 28537  Sam Petrevski-Seton_2023      0       0.0000  West Coast  Adelaide
# 28538         Shannon Hurn_2023      0       0.0000  West Coast  Adelaide
# 28539            Tim Kelly_2023      0       0.0000  West Coast  Adelaide
# 28540             Tom Cole_2023      6       3.2227  West Coast  Adelaide
#
#        Opponent  Round Round_str  Round_ID_num
# 28536  Adelaide     24        24        202324
# 28537  Adelaide     24        24        202324
# 28538  Adelaide     24        24        202324
# 28539  Adelaide     24        24        202324
# 28540  Adelaide     24        24        202324

# %% [markdown]
# Pre-Season

# %%
def get_previous_round_id(round_id):
    
    finals_round_map = {'F1':24,
                        'F2':25,
                        'F3':26,
                        'F4':27}
    
    season = round_id[:4]
    if 'F' in round_id:
        round_num = finals_round_map[round_id[4:]]
    else:
        round_num = round_id[4:]
    
    previous_round_num = int(round_id[4:])-1
    previous_round_num = str(previous_round_num).zfill(2)
    if previous_round_num == 1:
        previous_season = int(season) - 1
    else:
        previous_season = season
    previous_round_id = str(previous_season) + str(previous_round_num)
    
    return previous_round_id

# %%
def get_score_standard_deviation(data):
    return data.groupby(['Match_ID', 'Team']).sum()['Score'].std()

# %%
def create_team_summary(player_stats, rounds = None):
    
    player_stats_copy = player_stats.copy()
    
    if rounds is not None:
        all_rounds = sorted(list(set(player_stats_copy['Round_ID'])))
        rating_rounds = all_rounds[-rounds:]
        player_stats_copy = player_stats_copy[player_stats_copy['Round_ID'].isin(rating_rounds)]
    
    team_for = player_stats_copy.groupby(['Team']).sum()[['Score', 'xScore','vaep_value', 'vaep_value_received', 'offensive_value', 'defensive_value', 'exp_vaep_value', 'exp_vaep_value_received', 'exp_offensive_value', 'exp_defensive_value']]
    team_for.columns = [x+"_F" for x in list(team_for)]
    team_against = player_stats_copy.groupby(['Opponent']).sum()[['Score', 'xScore', 'vaep_value', 'vaep_value_received', 'offensive_value', 'defensive_value', 'exp_vaep_value', 'exp_vaep_value_received', 'exp_offensive_value', 'exp_defensive_value']]
    team_against.columns = [x+"_A" for x in list(team_against)]
    team_games = player_stats_copy.groupby(['Match_ID', 'Team']).size().reset_index().groupby(['Team']).count()[['Match_ID']]
    team_games.columns = ['Games']
    team_summary = pd.concat([team_games, team_for, team_against], axis=1)
    
    for col in [x.replace("_F", "") for x in list(team_for)]:
        team_summary[col+"_pergame_F"] = team_summary[col+"_F"] / team_summary["Games"]
        team_summary[col+"_pergame_A"] = team_summary[col+"_A"] / team_summary["Games"]

        team_summary[col+"_diff"] = team_summary[col+"_F"] - team_summary[col+"_A"]
        team_summary[col+"_pergame_diff"] = team_summary[col+"_pergame_F"] - team_summary[col+"_pergame_A"]

    return team_summary

# %%
def get_teams(match_id):
    
    home_team = re.sub(r"\B([A-Z])", r" \1", match_id.split("_")[1])
    away_team = re.sub(r"\B([A-Z])", r" \1", match_id.split("_")[-1])

    return home_team, away_team

# %%
def calculate_match_projections(home_attack_rating, home_defence_rating, away_attack_rating, away_defence_rating):
    
    home_projected_score = (home_attack_rating + away_defence_rating)*0.5
    away_projected_score = (home_defence_rating + away_attack_rating)*0.5
    projected_margin = home_projected_score - away_projected_score
    
    return home_projected_score, away_projected_score, projected_margin

# %%
def get_match_ratings(team_summary, home_team, away_team):
    
    match_ratings_dict = {'home_attack_rating':team_summary.loc[home_team]['exp_vaep_value_pergame_F'],
                          'home_defence_rating':team_summary.loc[home_team]['exp_vaep_value_pergame_A'],
                          'away_attack_rating':team_summary.loc[away_team]['exp_vaep_value_pergame_F'],
                          'away_defence_rating':team_summary.loc[away_team]['exp_vaep_value_pergame_A']}
    
    return match_ratings_dict

# %%
def calculate_projected_probabilities(home_projected_score, away_projected_score, score_std=25):
    
    projected_margin = home_projected_score - away_projected_score
    projected_margin_distribution = stats.norm(loc = projected_margin, scale = score_std)
    
    away_team_win_probability = projected_margin_distribution.cdf(0)
    draw_probability = projected_margin_distribution.pdf(0)
    home_team_win_probability = 1 - away_team_win_probability - draw_probability
    
    return home_team_win_probability, draw_probability, away_team_win_probability

# %%
def get_match_prediction_metrics(projected_margin, margin):
    
    mae = abs(projected_margin - margin)
    mse = ((projected_margin)**2 + (margin)**2)
    rmse = ((projected_margin)**2 + (margin)**2)**0.5
    
    return mae, mse, rmse

# %%
def get_match_result(data, match_id):
    
    home_team, away_team = get_teams(match_id)
    match_player_stats = data[data['Match_ID'] == match_id]
    match_score = match_player_stats.groupby('Team').sum()[['Score', 'xScore']]
    home_score, home_xscore = match_score.loc[home_team]['Score'], match_score.loc[home_team]['xScore']
    away_score, away_xscore = match_score.loc[away_team]['Score'], match_score.loc[away_team]['xScore']
    margin, xmargin = home_score - away_score, home_xscore - away_xscore
    
    return home_score, away_score, margin

# %%
def calculate_match_projection_error(player_stats, match_id, match_ratings_dict, score_std = 25):
    
    home_projected_score, away_projected_score, projected_margin = calculate_match_projections(match_ratings_dict['home_attack_rating'], 
                                                                             match_ratings_dict['home_defence_rating'], 
                                                                             match_ratings_dict['away_attack_rating'], 
                                                                             match_ratings_dict['away_defence_rating'])
    
    home_team_win_probability, draw_probability, away_team_win_probability = calculate_projected_probabilities(home_projected_score, away_projected_score, score_std)
    home_score, away_score, margin = get_match_result(player_stats, match_id)
    
    mae, mse, rmse = get_match_prediction_metrics(projected_margin, margin)
    
    return mae, mse, rmse

# %%
def get_latest_rounds(round_id, player_stats, rounds):
    
    all_rounds = sorted(list(set(player_stats['Round_ID'])))
    rating_rounds = all_rounds[all_rounds.index(round_id)-rounds:all_rounds.index(round_id)]
    player_stats_latest = player_stats[player_stats['Round_ID'].isin(rating_rounds)]
    
    return player_stats_latest

# %%
def update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae):
    
    previous_round_id = get_previous_round_id(round_id)
    player_stats_latest = get_latest_rounds(round_id, player_stats, rounds)
    team_summary = create_team_summary(player_stats_latest, rounds = rounds)
    team_summary = team_summary[['exp_vaep_value_pergame_F', 'exp_vaep_value_pergame_A', 'exp_vaep_value_pergame_diff']]

    round_projection_dict[round_id] = create_round_match_projections(player_stats, team_summary, round_id)
    round_mae[round_id] = np.mean(np.array(list({v['MAE'] for (k, v) in round_projection_dict[round_id].items()})))
    print("Round MAE: {}".format(round_mae[round_id]))
    print("Overall MAE: {}".format(np.mean(np.array(list(round_mae.values())))))
    return team_summary.sort_values('exp_vaep_value_pergame_diff', ascending = False)

# %%
def create_round_match_projections(player_stats, team_summary, round_id):
    
    player_stats_round = player_stats[player_stats['Round_ID'] == round_id]
    match_id_list = list(player_stats_round['Match_ID'].unique())

    match_projection_dict = {}
    for match_id in match_id_list:
        home_team, away_team = get_teams(match_id)
        match_ratings_dict = get_match_ratings(team_summary, home_team, away_team)
        home_projected_score, away_projected_score, projected_margin = calculate_match_projections(match_ratings_dict['home_attack_rating'], 
                                                                                                    match_ratings_dict['home_defence_rating'], 
                                                                                                    match_ratings_dict['away_attack_rating'], 
                                                                                                    match_ratings_dict['away_defence_rating'])
        home_team_win_probability, draw_probability, away_team_win_probability = calculate_projected_probabilities(home_projected_score, away_projected_score, score_std)
        home_score, away_score, margin = get_match_result(player_stats_round, match_id)
        mae, mse, rmse = calculate_match_projection_error(player_stats_round, match_id, match_ratings_dict, score_std = 25)

        match_projection_dict[match_id] = {}
        if home_projected_score > away_projected_score:
            match_projection_dict[match_id]['tip'] = home_team
            match_projection_dict[match_id]['projected_prob'] = home_team_win_probability
        else:
            match_projection_dict[match_id]['tip'] = away_team
            match_projection_dict[match_id]['projected_prob'] = away_team_win_probability
        match_projection_dict[match_id]['projected_margin'] = abs(projected_margin)
        if home_score > away_score:
            match_projection_dict[match_id]['result'] = home_team
        else:
            match_projection_dict[match_id]['result'] = away_team
        match_projection_dict[match_id]['actual_margin'] = abs(margin)   
        match_projection_dict[match_id]['MAE'] = mae
    
    return match_projection_dict

# %%
score_std = get_score_standard_deviation(player_stats)

# %%
round_projection_dict = {}
round_mae = {}
rounds = 10

# %% [markdown]
# 202301

# %%
round_id = '202301'
player_stats_latest = player_stats[player_stats['Season'] == 2022]
team_summary = create_team_summary(player_stats_latest, rounds = rounds)
team_summary = team_summary[['exp_vaep_value_pergame_F', 'exp_vaep_value_pergame_A', 'exp_vaep_value_pergame_diff']]

round_projection_dict[round_id] = create_round_match_projections(player_stats, team_summary, round_id)
round_mae[round_id] = np.mean(np.array(list({v['MAE'] for (k, v) in round_projection_dict[round_id].items()})))
print("Round MAE: {}".format(round_mae[round_id]))
print("Overall MAE: {}".format(np.mean(np.array(list(round_mae.values())))))
team_summary.sort_values('exp_vaep_value_pergame_diff', ascending = False)
# Out:
# Round MAE: 30.9274858993962
# Overall MAE: 30.9274858993962
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Geelong                                  97.5972                   60.1562
# Richmond                                103.6260                   83.8944
# Sydney                                   96.0714                   78.9025
# Melbourne                                92.8762                   81.9898
# Port Adelaide                            88.8701                   78.2676
# Western Bulldogs                         83.6125                   78.8754
# Brisbane Lions                           90.7450                   88.4753
# Fremantle                                82.7621                   84.6183
# Carlton                                  85.5714                   88.5205
# St Kilda                                 73.1233                   78.8976
# Essendon                                 89.7414                   95.7605
# Collingwood                              85.9278                   94.2075
# Adelaide                                 83.0334                   92.3986
# Hawthorn                                 75.5959                   88.3738
# Gold Coast                               81.8597                   96.0052
# North Melbourne                          85.8020                  108.1833
# Greater Western Sydney                   70.8768                   95.7461
# West Coast                               67.1183                   92.9261
#
#                         exp_vaep_value_pergame_diff
# Geelong                                     37.4410
# Richmond                                    19.7316
# Sydney                                      17.1689
# Melbourne                                   10.8864
# Port Adelaide                               10.6025
# Western Bulldogs                             4.7371
# Brisbane Lions                               2.2697
# Fremantle                                   -1.8562
# Carlton                                     -2.9491
# St Kilda                                    -5.7744
# Essendon                                    -6.0191
# Collingwood                                 -8.2797
# Adelaide                                    -9.3652
# Hawthorn                                   -12.7780
# Gold Coast                                 -14.1455
# North Melbourne                            -22.3813
# Greater Western Sydney                     -24.8692
# West Coast                                 -25.8079

# %% [markdown]
# 202302

# %%
round_id = '202302'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 35.576048534553564
# Overall MAE: 33.25176721697488
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Geelong                                  98.6166                   66.9557
# Port Adelaide                           100.8720                   76.9784
# Sydney                                   98.0524                   77.7449
# Richmond                                102.9924                   84.5656
# Melbourne                                95.2197                   79.5552
# Fremantle                                85.5871                   85.5930
# Carlton                                  91.9053                   92.2559
# Western Bulldogs                         83.1429                   83.7953
# Collingwood                              89.3065                   94.8560
# St Kilda                                 78.6978                   84.4191
# Gold Coast                               82.3670                   92.4128
# Essendon                                 88.3031                   98.4878
# Brisbane Lions                           88.7420                   99.4393
# Adelaide                                 84.8777                   96.0016
# North Melbourne                          88.8642                  105.4755
# Greater Western Sydney                   79.1392                   96.6571
# Hawthorn                                 73.4740                   96.1841
# West Coast                               70.1361                   94.9612
#
#                         exp_vaep_value_pergame_diff
# Geelong                                     31.6608
# Port Adelaide                               23.8936
# Sydney                                      20.3075
# Richmond                                    18.4267
# Melbourne                                   15.6645
# Fremantle                                   -0.0058
# Carlton                                     -0.3506
# Western Bulldogs                            -0.6524
# Collingwood                                 -5.5496
# St Kilda                                    -5.7213
# Gold Coast                                 -10.0458
# Essendon                                   -10.1847
# Brisbane Lions                             -10.6973
# Adelaide                                   -11.1238
# North Melbourne                            -16.6113
# Greater Western Sydney                     -17.5179
# Hawthorn                                   -22.7101
# West Coast                                 -24.8251

# %% [markdown]
# 202303

# %%
round_id = '202303'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 26.986897106906575
# Overall MAE: 31.16347718028545
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Geelong                                  97.5937                   67.7773
# Sydney                                   98.1927                   76.8651
# Richmond                                105.6618                   87.8921
# Port Adelaide                            97.0635                   80.0527
# Melbourne                                92.5107                   79.5346
# Fremantle                                85.3002                   83.2904
# Collingwood                              92.4037                   92.3898
# Carlton                                  89.5683                   93.1946
# Western Bulldogs                         81.7246                   85.6429
# St Kilda                                 82.9982                   87.0801
# Adelaide                                 88.7034                   94.1085
# Brisbane Lions                           89.6914                   98.8282
# Essendon                                 93.4120                  103.5858
# Gold Coast                               85.7044                   96.8428
# Greater Western Sydney                   84.6946                   96.7251
# North Melbourne                          86.7202                  104.3423
# West Coast                               76.0676                   97.3042
# Hawthorn                                 71.4589                  102.3280
#
#                         exp_vaep_value_pergame_diff
# Geelong                                     29.8164
# Sydney                                      21.3276
# Richmond                                    17.7697
# Port Adelaide                               17.0108
# Melbourne                                   12.9761
# Fremantle                                    2.0098
# Collingwood                                  0.0140
# Carlton                                     -3.6264
# Western Bulldogs                            -3.9182
# St Kilda                                    -4.0819
# Adelaide                                    -5.4051
# Brisbane Lions                              -9.1368
# Essendon                                   -10.1737
# Gold Coast                                 -11.1384
# Greater Western Sydney                     -12.0305
# North Melbourne                            -17.6222
# West Coast                                 -21.2366
# Hawthorn                                   -30.8692

# %% [markdown]
# 202304

# %%
round_id = '202304'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 31.871101116934614
# Overall MAE: 31.34038316444774
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Geelong                                  96.3415                   70.4081
# Richmond                                101.2497                   86.0793
# Port Adelaide                           100.7599                   86.0460
# Sydney                                   96.5317                   84.1790
# Melbourne                                92.9513                   82.4493
# Fremantle                                90.4024                   82.3066
# Carlton                                  97.1355                   94.3673
# Collingwood                              93.3198                   91.6018
# Western Bulldogs                         84.3222                   84.5933
# Greater Western Sydney                   94.8038                   98.6888
# Adelaide                                 92.4729                   98.3652
# St Kilda                                 84.9066                   91.6128
# Gold Coast                               84.4296                   94.0952
# Brisbane Lions                           87.1998                   96.9192
# Essendon                                 90.6124                  105.3320
# North Melbourne                          81.1651                  101.4372
# Hawthorn                                 75.8860                   96.9352
# West Coast                               76.5812                   99.4800
#
#                         exp_vaep_value_pergame_diff
# Geelong                                     25.9334
# Richmond                                    15.1704
# Port Adelaide                               14.7139
# Sydney                                      12.3527
# Melbourne                                   10.5020
# Fremantle                                    8.0959
# Carlton                                      2.7682
# Collingwood                                  1.7180
# Western Bulldogs                            -0.2711
# Greater Western Sydney                      -3.8850
# Adelaide                                    -5.8923
# St Kilda                                    -6.7062
# Gold Coast                                  -9.6657
# Brisbane Lions                              -9.7194
# Essendon                                   -14.7196
# North Melbourne                            -20.2720
# Hawthorn                                   -21.0492
# West Coast                                 -22.8988

# %% [markdown]
# 202305

# %%
round_id = '202305'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 28.035373001976353
# Overall MAE: 30.67938113195346
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Geelong                                  98.5179                   71.1659
# Port Adelaide                           102.8668                   82.9092
# Melbourne                                91.9962                   78.3282
# Sydney                                   94.0996                   83.8823
# Richmond                                 96.0495                   88.5719
# Carlton                                  96.4235                   89.6325
# Fremantle                                89.1332                   82.7033
# St Kilda                                 92.3485                   86.4056
# Collingwood                              92.7283                   91.4318
# Western Bulldogs                         84.7374                   83.9349
# Adelaide                                 93.3715                   95.9014
# Essendon                                 97.6684                  103.0785
# Brisbane Lions                           85.6623                   95.5623
# Gold Coast                               83.8809                   96.3602
# Greater Western Sydney                   92.5502                  105.7447
# North Melbourne                          83.7073                   99.8193
# West Coast                               74.0713                  103.9303
# Hawthorn                                 71.8458                  104.8585
#
#                         exp_vaep_value_pergame_diff
# Geelong                                     27.3520
# Port Adelaide                               19.9576
# Melbourne                                   13.6680
# Sydney                                      10.2173
# Richmond                                     7.4776
# Carlton                                      6.7910
# Fremantle                                    6.4299
# St Kilda                                     5.9429
# Collingwood                                  1.2964
# Western Bulldogs                             0.8025
# Adelaide                                    -2.5299
# Essendon                                    -5.4101
# Brisbane Lions                              -9.9000
# Gold Coast                                 -12.4792
# Greater Western Sydney                     -13.1945
# North Melbourne                            -16.1120
# West Coast                                 -29.8590
# Hawthorn                                   -33.0127

# %% [markdown]
# 202306

# %%
round_id = '202306'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 29.388271495686038
# Overall MAE: 30.464196192575557
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Geelong                                  97.3908                   72.3332
# Port Adelaide                            97.4139                   83.0702
# Melbourne                                92.5335                   82.2901
# Sydney                                   93.3332                   84.4868
# St Kilda                                 96.3348                   88.1328
# Essendon                                105.2212                   97.1033
# Collingwood                              94.8932                   89.6400
# Fremantle                                91.2351                   87.8814
# Adelaide                                 95.6365                   92.7448
# Richmond                                 93.1216                   93.1049
# Carlton                                  96.0167                   96.7488
# Brisbane Lions                           92.5793                   94.7729
# Western Bulldogs                         81.4991                   84.5713
# Gold Coast                               89.3065                   94.8786
# Greater Western Sydney                   92.1788                  100.4305
# North Melbourne                          78.6448                  107.4224
# West Coast                               77.3009                  106.5239
# Hawthorn                                 69.0929                  100.1018
#
#                         exp_vaep_value_pergame_diff
# Geelong                                     25.0577
# Port Adelaide                               14.3437
# Melbourne                                   10.2434
# Sydney                                       8.8464
# St Kilda                                     8.2020
# Essendon                                     8.1179
# Collingwood                                  5.2532
# Fremantle                                    3.3537
# Adelaide                                     2.8917
# Richmond                                     0.0167
# Carlton                                     -0.7321
# Brisbane Lions                              -2.1937
# Western Bulldogs                            -3.0722
# Gold Coast                                  -5.5720
# Greater Western Sydney                      -8.2517
# North Melbourne                            -28.7776
# West Coast                                 -29.2231
# Hawthorn                                   -31.0089

# %% [markdown]
# 202307

# %%
round_id = '202307'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 32.76034249388358
# Overall MAE: 30.792217092762417
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Geelong                                  96.7085                   73.7005
# Essendon                                106.9643                   93.4170
# Adelaide                                100.5992                   88.5823
# St Kilda                                100.2739                   88.3386
# Port Adelaide                            98.9440                   88.1865
# Collingwood                              96.7861                   88.2694
# Melbourne                                91.6634                   84.6493
# Brisbane Lions                           96.0742                   92.9646
# Sydney                                   89.3943                   89.3792
# Western Bulldogs                         84.2191                   86.5943
# Carlton                                  93.7203                   97.9879
# Richmond                                 88.5377                   94.3809
# Fremantle                                86.0533                   92.8126
# Greater Western Sydney                   91.3642                   98.7938
# Gold Coast                               86.5097                   94.2062
# West Coast                               84.8301                  106.5695
# Hawthorn                                 73.4660                   96.6621
# North Melbourne                          77.9724                  104.6256
#
#                         exp_vaep_value_pergame_diff
# Geelong                                     23.0079
# Essendon                                    13.5474
# Adelaide                                    12.0169
# St Kilda                                    11.9353
# Port Adelaide                               10.7575
# Collingwood                                  8.5166
# Melbourne                                    7.0141
# Brisbane Lions                               3.1096
# Sydney                                       0.0150
# Western Bulldogs                            -2.3752
# Carlton                                     -4.2676
# Richmond                                    -5.8431
# Fremantle                                   -6.7593
# Greater Western Sydney                      -7.4295
# Gold Coast                                  -7.6965
# West Coast                                 -21.7394
# Hawthorn                                   -23.1961
# North Melbourne                            -26.6531

# %% [markdown]
# 202308

# %%
round_id = '202308'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 20.85408245604121
# Overall MAE: 29.549950263172267
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Geelong                                  98.1368                   73.3047
# Melbourne                                94.5257                   80.7757
# Adelaide                                 97.3045                   84.7444
# St Kilda                                 95.6360                   85.4810
# Port Adelaide                            94.5713                   85.2754
# Carlton                                  98.0067                   89.2300
# Collingwood                              94.6721                   86.6199
# Essendon                                102.7094                   95.1055
# Brisbane Lions                           96.0122                   89.5663
# Sydney                                   89.7118                   88.4934
# Western Bulldogs                         83.4258                   83.1832
# Gold Coast                               89.4259                   93.7080
# Richmond                                 88.0554                   94.9695
# Greater Western Sydney                   90.3120                   98.8942
# Fremantle                                83.1616                   94.6314
# Hawthorn                                 71.9375                   94.5878
# North Melbourne                          76.2121                  106.0890
# West Coast                               77.9519                  109.0203
#
#                         exp_vaep_value_pergame_diff
# Geelong                                     24.8321
# Melbourne                                   13.7501
# Adelaide                                    12.5601
# St Kilda                                    10.1550
# Port Adelaide                                9.2959
# Carlton                                      8.7767
# Collingwood                                  8.0522
# Essendon                                     7.6038
# Brisbane Lions                               6.4459
# Sydney                                       1.2183
# Western Bulldogs                             0.2425
# Gold Coast                                  -4.2821
# Richmond                                    -6.9141
# Greater Western Sydney                      -8.5822
# Fremantle                                  -11.4698
# Hawthorn                                   -22.6503
# North Melbourne                            -29.8769
# West Coast                                 -31.0684

# %% [markdown]
# 202309

# %%
round_id = '202309'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 39.905910065500876
# Overall MAE: 30.700612463431
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Geelong                                  98.0431                   73.5967
# Port Adelaide                            96.8783                   83.5242
# Melbourne                                97.8156                   86.2576
# St Kilda                                 92.8360                   82.1686
# Brisbane Lions                           98.8216                   88.7110
# Adelaide                                 94.6695                   86.3013
# Collingwood                              92.9078                   86.4783
# Carlton                                  95.1290                   89.4809
# Essendon                                 98.7789                   97.3457
# Sydney                                   88.2359                   87.9027
# Western Bulldogs                         82.9025                   82.7370
# Fremantle                                89.3705                   90.8598
# Richmond                                 90.8965                   93.0314
# Gold Coast                               91.9737                   95.6198
# Greater Western Sydney                   88.9747                   96.4374
# Hawthorn                                 71.4819                   98.5016
# North Melbourne                          74.0583                  101.9824
# West Coast                               78.1410                  109.2407
#
#                         exp_vaep_value_pergame_diff
# Geelong                                     24.4464
# Port Adelaide                               13.3541
# Melbourne                                   11.5581
# St Kilda                                    10.6674
# Brisbane Lions                              10.1106
# Adelaide                                     8.3683
# Collingwood                                  6.4295
# Carlton                                      5.6481
# Essendon                                     1.4332
# Sydney                                       0.3332
# Western Bulldogs                             0.1655
# Fremantle                                   -1.4894
# Richmond                                    -2.1350
# Gold Coast                                  -3.6461
# Greater Western Sydney                      -7.4627
# Hawthorn                                   -27.0197
# North Melbourne                            -27.9241
# West Coast                                 -31.0998

# %% [markdown]
# 202310

# %%
round_id = '202310'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 30.94024523678825
# Overall MAE: 30.724575740766728
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Geelong                                  95.0707                   73.4393
# Brisbane Lions                          102.0190                   84.1928
# Port Adelaide                            98.6814                   81.5660
# Melbourne                                96.8259                   81.9690
# Collingwood                              91.8563                   81.0726
# Adelaide                                 93.3046                   82.7393
# St Kilda                                 88.5480                   82.1927
# Gold Coast                               94.5085                   88.9878
# Carlton                                  93.7176                   89.1063
# Fremantle                                90.5260                   88.9974
# Western Bulldogs                         83.2588                   82.7025
# Richmond                                 89.5190                   91.7630
# Essendon                                 95.6564                   98.6241
# Sydney                                   84.8129                   88.3188
# Greater Western Sydney                   85.7194                   95.2939
# Hawthorn                                 68.8351                   97.4357
# North Melbourne                          73.1519                  103.2184
# West Coast                               73.4511                  109.8569
#
#                         exp_vaep_value_pergame_diff
# Geelong                                     21.6314
# Brisbane Lions                              17.8262
# Port Adelaide                               17.1154
# Melbourne                                   14.8569
# Collingwood                                 10.7838
# Adelaide                                    10.5653
# St Kilda                                     6.3553
# Gold Coast                                   5.5207
# Carlton                                      4.6114
# Fremantle                                    1.5285
# Western Bulldogs                             0.5563
# Richmond                                    -2.2440
# Essendon                                    -2.9677
# Sydney                                      -3.5059
# Greater Western Sydney                      -9.5745
# Hawthorn                                   -28.6005
# North Melbourne                            -30.0665
# West Coast                                 -36.4059

# %% [markdown]
# 202311

# %%
round_id = '202311'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 19.264495571041323
# Overall MAE: 29.68275027079169
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Brisbane Lions                          102.4191                   82.4252
# Port Adelaide                            97.7565                   80.1495
# Geelong                                  95.0592                   80.5002
# Collingwood                              92.6886                   80.9382
# Melbourne                                93.8834                   82.7154
# St Kilda                                 90.3787                   81.5305
# Western Bulldogs                         84.4224                   79.3196
# Adelaide                                 88.8614                   83.9549
# Sydney                                   89.8153                   86.7755
# Fremantle                                92.4038                   89.7225
# Carlton                                  92.3188                   90.2136
# Gold Coast                               91.7093                   90.6911
# Richmond                                 88.7151                   90.5863
# Essendon                                 94.0903                   96.9097
# Greater Western Sydney                   84.7045                   96.4500
# Hawthorn                                 73.5748                   89.9154
# North Melbourne                          73.9297                  101.7684
# West Coast                               68.3292                  110.4944
#
#                         exp_vaep_value_pergame_diff
# Brisbane Lions                              19.9939
# Port Adelaide                               17.6070
# Geelong                                     14.5590
# Collingwood                                 11.7504
# Melbourne                                   11.1680
# St Kilda                                     8.8482
# Western Bulldogs                             5.1029
# Adelaide                                     4.9065
# Sydney                                       3.0398
# Fremantle                                    2.6812
# Carlton                                      2.1052
# Gold Coast                                   1.0183
# Richmond                                    -1.8711
# Essendon                                    -2.8194
# Greater Western Sydney                     -11.7455
# Hawthorn                                   -16.3406
# North Melbourne                            -27.8387
# West Coast                                 -42.1651

# %% [markdown]
# 202312

# %%
round_id = '202312'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 21.28371698946209
# Overall MAE: 28.982830830680893
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Brisbane Lions                          103.4053                   75.5943
# Geelong                                  93.5493                   78.1675
# Port Adelaide                            92.5992                   80.0800
# Collingwood                              90.6193                   79.5175
# Western Bulldogs                         89.5700                   79.7110
# Melbourne                                92.9536                   83.9933
# St Kilda                                 89.2189                   82.6058
# Adelaide                                 87.6154                   81.9168
# Gold Coast                               95.6238                   91.0720
# Carlton                                  91.6310                   87.8381
# Fremantle                                90.0401                   88.8919
# Sydney                                   87.0380                   88.5464
# Essendon                                 93.4031                   96.9909
# Richmond                                 85.4953                   91.7793
# Hawthorn                                 76.6199                   86.4601
# Greater Western Sydney                   83.2507                   94.4172
# North Melbourne                          71.3841                  101.6330
# West Coast                               66.8985                  111.7005
#
#                         exp_vaep_value_pergame_diff
# Brisbane Lions                              27.8110
# Geelong                                     15.3818
# Port Adelaide                               12.5192
# Collingwood                                 11.1018
# Western Bulldogs                             9.8590
# Melbourne                                    8.9603
# St Kilda                                     6.6132
# Adelaide                                     5.6986
# Gold Coast                                   4.5519
# Carlton                                      3.7928
# Fremantle                                    1.1482
# Sydney                                      -1.5084
# Essendon                                    -3.5877
# Richmond                                    -6.2840
# Hawthorn                                    -9.8402
# Greater Western Sydney                     -11.1664
# North Melbourne                            -30.2489
# West Coast                                 -44.8020

# %% [markdown]
# 202313

# %%
round_id = '202313'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 29.363209095760674
# Overall MAE: 29.012090697225492
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Brisbane Lions                          104.3092                   75.3670
# Port Adelaide                           100.5532                   81.0009
# Geelong                                  94.6366                   78.3585
# Melbourne                                94.0305                   79.7024
# Western Bulldogs                         90.2803                   76.8539
# Collingwood                              92.7670                   80.5018
# Gold Coast                               96.5133                   89.5935
# Adelaide                                 87.1948                   82.7484
# St Kilda                                 86.6605                   82.2834
# Fremantle                                91.4728                   91.3647
# Carlton                                  87.7971                   89.3990
# Essendon                                 92.5381                   95.8947
# Richmond                                 84.7809                   89.7410
# Sydney                                   83.7795                   90.4011
# Hawthorn                                 80.4005                   88.8231
# Greater Western Sydney                   81.4351                   93.5641
# North Melbourne                          73.9407                  104.3839
# West Coast                               63.4153                  113.8433
#
#                         exp_vaep_value_pergame_diff
# Brisbane Lions                              28.9422
# Port Adelaide                               19.5523
# Geelong                                     16.2781
# Melbourne                                   14.3282
# Western Bulldogs                            13.4263
# Collingwood                                 12.2652
# Gold Coast                                   6.9198
# Adelaide                                     4.4465
# St Kilda                                     4.3771
# Fremantle                                    0.1081
# Carlton                                     -1.6019
# Essendon                                    -3.3566
# Richmond                                    -4.9601
# Sydney                                      -6.6216
# Hawthorn                                    -8.4226
# Greater Western Sydney                     -12.1291
# North Melbourne                            -30.4432
# West Coast                                 -50.4281

# %% [markdown]
# 202314

# %%
round_id = '202314'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 32.980000762508304
# Overall MAE: 29.295512844745694
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Brisbane Lions                          105.7597                   77.2895
# Port Adelaide                           100.9887                   77.0585
# Geelong                                  96.8732                   77.4153
# Melbourne                                94.3077                   78.8655
# Adelaide                                 90.8863                   79.9007
# Western Bulldogs                         89.7907                   79.1383
# Collingwood                              92.1188                   84.5611
# Gold Coast                               97.5873                   91.2698
# St Kilda                                 81.8127                   76.5823
# Fremantle                                89.9293                   91.5207
# Essendon                                 93.5352                   95.7181
# Richmond                                 87.5639                   90.2904
# Carlton                                  86.8254                   89.7783
# Greater Western Sydney                   80.4114                   86.7904
# Sydney                                   78.5305                   85.9268
# Hawthorn                                 80.9174                   91.4693
# North Melbourne                          72.3429                  104.0415
# West Coast                               60.8521                  118.3678
#
#                         exp_vaep_value_pergame_diff
# Brisbane Lions                              28.4702
# Port Adelaide                               23.9302
# Geelong                                     19.4579
# Melbourne                                   15.4422
# Adelaide                                    10.9856
# Western Bulldogs                            10.6524
# Collingwood                                  7.5576
# Gold Coast                                   6.3175
# St Kilda                                     5.2304
# Fremantle                                   -1.5915
# Essendon                                    -2.1829
# Richmond                                    -2.7265
# Carlton                                     -2.9528
# Greater Western Sydney                      -6.3791
# Sydney                                      -7.3962
# Hawthorn                                   -10.5519
# North Melbourne                            -31.6986
# West Coast                                 -57.5157

# %% [markdown]
# 202315

# %%
round_id = '202315'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 44.89929573806301
# Overall MAE: 30.335765037633514
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Brisbane Lions                          106.3305                   75.5574
# Port Adelaide                           104.4109                   75.6739
# Melbourne                                93.1176                   80.4664
# Western Bulldogs                         90.9761                   78.8633
# Collingwood                              92.1205                   81.6090
# Adelaide                                 91.6838                   81.5859
# Geelong                                  92.3970                   83.9040
# Gold Coast                               98.0245                   93.7971
# Carlton                                  88.3247                   86.8629
# St Kilda                                 78.0313                   77.3735
# Greater Western Sydney                   81.9219                   81.4475
# Richmond                                 87.5950                   87.7719
# Fremantle                                89.1751                   93.4499
# Hawthorn                                 83.8572                   88.9324
# Essendon                                 91.5529                   96.8017
# Sydney                                   77.2698                   90.1082
# North Melbourne                          69.4400                  103.5669
# West Coast                               60.4515                  119.8510
#
#                         exp_vaep_value_pergame_diff
# Brisbane Lions                              30.7731
# Port Adelaide                               28.7370
# Melbourne                                   12.6512
# Western Bulldogs                            12.1129
# Collingwood                                 10.5115
# Adelaide                                    10.0979
# Geelong                                      8.4930
# Gold Coast                                   4.2274
# Carlton                                      1.4618
# St Kilda                                     0.6578
# Greater Western Sydney                       0.4744
# Richmond                                    -0.1769
# Fremantle                                   -4.2748
# Hawthorn                                    -5.0752
# Essendon                                    -5.2488
# Sydney                                     -12.8384
# North Melbourne                            -34.1268
# West Coast                                 -59.3995

# %% [markdown]
# 202316

# %%
round_id = '202316'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 37.727383643780975
# Overall MAE: 30.797741200517727
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Port Adelaide                           106.3762                   76.5035
# Brisbane Lions                           98.2818                   75.5196
# Melbourne                                91.9424                   76.3254
# Western Bulldogs                         93.5060                   77.9900
# Gold Coast                              100.9179                   88.6688
# Collingwood                              89.5026                   78.9579
# Carlton                                  89.4250                   82.9601
# Adelaide                                 86.3684                   81.6019
# Geelong                                  89.0688                   84.3602
# Richmond                                 87.5407                   85.6091
# St Kilda                                 74.5466                   75.0903
# Sydney                                   84.0573                   84.6682
# Greater Western Sydney                   82.1311                   83.9428
# Fremantle                                85.6237                   89.6328
# Hawthorn                                 84.0076                   93.0387
# Essendon                                 85.3353                   95.7957
# North Melbourne                          69.7126                   97.9613
# West Coast                               57.1422                  126.8602
#
#                         exp_vaep_value_pergame_diff
# Port Adelaide                               29.8727
# Brisbane Lions                              22.7622
# Melbourne                                   15.6170
# Western Bulldogs                            15.5160
# Gold Coast                                  12.2491
# Collingwood                                 10.5446
# Carlton                                      6.4650
# Adelaide                                     4.7665
# Geelong                                      4.7086
# Richmond                                     1.9316
# St Kilda                                    -0.5437
# Sydney                                      -0.6109
# Greater Western Sydney                      -1.8117
# Fremantle                                   -4.0090
# Hawthorn                                    -9.0312
# Essendon                                   -10.4603
# North Melbourne                            -28.2487
# West Coast                                 -69.7179

# %% [markdown]
# 202317

# %%
round_id = '202317'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 24.512817766605643
# Overall MAE: 30.42803982205231
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Brisbane Lions                          103.2378                   76.3636
# Port Adelaide                           102.8802                   77.9923
# Melbourne                                89.7572                   69.9734
# Collingwood                              93.2834                   77.2311
# Carlton                                  91.6355                   79.6536
# Adelaide                                 90.0838                   78.7233
# Sydney                                   89.1533                   78.9911
# Western Bulldogs                         89.0498                   79.0680
# St Kilda                                 76.5288                   72.6781
# Fremantle                                86.7017                   85.1765
# Gold Coast                               96.8143                   95.9233
# Greater Western Sydney                   77.2537                   79.9200
# Richmond                                 86.9101                   92.4026
# Geelong                                  83.3917                   89.4561
# Essendon                                 86.2397                   94.2119
# Hawthorn                                 81.5171                   95.7756
# North Melbourne                          68.4249                   98.6133
# West Coast                               55.1541                  125.8633
#
#                         exp_vaep_value_pergame_diff
# Brisbane Lions                              26.8741
# Port Adelaide                               24.8878
# Melbourne                                   19.7839
# Collingwood                                 16.0523
# Carlton                                     11.9819
# Adelaide                                    11.3605
# Sydney                                      10.1622
# Western Bulldogs                             9.9818
# St Kilda                                     3.8507
# Fremantle                                    1.5252
# Gold Coast                                   0.8910
# Greater Western Sydney                      -2.6663
# Richmond                                    -5.4925
# Geelong                                     -6.0644
# Essendon                                    -7.9722
# Hawthorn                                   -14.2586
# North Melbourne                            -30.1884
# West Coast                                 -70.7092

# %% [markdown]
# 202318

# %%
round_id = '202318'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 29.76040906561913
# Overall MAE: 30.39094922447269
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Brisbane Lions                          106.0574                   74.5964
# Port Adelaide                           108.4585                   79.5724
# Collingwood                              95.5367                   77.6122
# Melbourne                                84.4726                   71.1015
# Western Bulldogs                         88.9191                   81.2046
# Adelaide                                 91.4280                   84.7646
# Carlton                                  87.8971                   82.0686
# St Kilda                                 77.4171                   72.5640
# Sydney                                   85.2687                   80.6277
# Fremantle                                86.1358                   83.8248
# Greater Western Sydney                   80.8560                   79.5815
# Richmond                                 87.8000                   87.6929
# Geelong                                  84.9467                   86.6464
# Essendon                                 90.5629                   92.4782
# Gold Coast                               94.0483                   99.0146
# Hawthorn                                 85.2597                   99.5843
# North Melbourne                          66.8963                   99.0981
# West Coast                               56.3677                  126.2963
#
#                         exp_vaep_value_pergame_diff
# Brisbane Lions                              31.4610
# Port Adelaide                               28.8861
# Collingwood                                 17.9245
# Melbourne                                   13.3711
# Western Bulldogs                             7.7145
# Adelaide                                     6.6634
# Carlton                                      5.8285
# St Kilda                                     4.8531
# Sydney                                       4.6410
# Fremantle                                    2.3110
# Greater Western Sydney                       1.2745
# Richmond                                     0.1071
# Geelong                                     -1.6997
# Essendon                                    -1.9153
# Gold Coast                                  -4.9663
# Hawthorn                                   -14.3246
# North Melbourne                            -32.2017
# West Coast                                 -69.9285

# %% [markdown]
# 202319

# %%
round_id = '202319'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 16.78125344605202
# Overall MAE: 29.67464944666107
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Brisbane Lions                          106.6688                   75.8044
# Port Adelaide                           105.6259                   83.7781
# Collingwood                              97.3185                   77.9595
# Melbourne                                81.9009                   69.6496
# Carlton                                  91.6896                   81.6571
# Adelaide                                 91.7535                   83.7177
# Western Bulldogs                         89.9208                   82.9202
# Sydney                                   87.5021                   81.2575
# Geelong                                  86.1543                   82.7229
# Greater Western Sydney                   81.7632                   79.5720
# Richmond                                 87.9792                   87.8930
# St Kilda                                 76.5490                   76.7164
# Gold Coast                               92.5534                   94.1725
# Hawthorn                                 90.2647                   92.1410
# Essendon                                 87.1904                   91.9272
# Fremantle                                80.8226                   87.1947
# North Melbourne                          66.8883                  103.5538
# West Coast                               56.5678                  126.4754
#
#                         exp_vaep_value_pergame_diff
# Brisbane Lions                              30.8645
# Port Adelaide                               21.8478
# Collingwood                                 19.3589
# Melbourne                                   12.2514
# Carlton                                     10.0325
# Adelaide                                     8.0358
# Western Bulldogs                             7.0006
# Sydney                                       6.2446
# Geelong                                      3.4314
# Greater Western Sydney                       2.1912
# Richmond                                     0.0862
# St Kilda                                    -0.1674
# Gold Coast                                  -1.6190
# Hawthorn                                    -1.8763
# Essendon                                    -4.7368
# Fremantle                                   -6.3721
# North Melbourne                            -36.6656
# West Coast                                 -69.9076

# %% [markdown]
# 202320

# %%
round_id = '202320'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 25.148231009831424
# Overall MAE: 29.44832852481959
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Brisbane Lions                          102.1761                   74.9592
# Port Adelaide                           104.1877                   84.5200
# Carlton                                  96.4999                   78.9629
# Collingwood                              95.8108                   82.4580
# Sydney                                   90.5190                   79.4049
# Greater Western Sydney                   90.4545                   79.4590
# Western Bulldogs                         91.1806                   81.9848
# Melbourne                                83.4586                   75.0978
# St Kilda                                 81.3767                   75.9941
# Adelaide                                 93.3435                   89.1270
# Richmond                                 90.6039                   87.0510
# Geelong                                  84.0937                   81.6026
# Hawthorn                                 93.1955                   93.6092
# Essendon                                 87.5607                   90.6603
# Fremantle                                78.9700                   90.2116
# Gold Coast                               89.2581                  105.5021
# North Melbourne                          67.9975                  101.8412
# West Coast                               59.4489                  127.6902
#
#                         exp_vaep_value_pergame_diff
# Brisbane Lions                              27.2169
# Port Adelaide                               19.6677
# Carlton                                     17.5371
# Collingwood                                 13.3529
# Sydney                                      11.1141
# Greater Western Sydney                      10.9956
# Western Bulldogs                             9.1958
# Melbourne                                    8.3608
# St Kilda                                     5.3826
# Adelaide                                     4.2166
# Richmond                                     3.5529
# Geelong                                      2.4911
# Hawthorn                                    -0.4137
# Essendon                                    -3.0996
# Fremantle                                  -11.2416
# Gold Coast                                 -16.2440
# North Melbourne                            -33.8437
# West Coast                                 -68.2413

# %% [markdown]
# 202321

# %%
round_id = '202321'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 22.343135812214097
# Overall MAE: 29.10998601469552
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Brisbane Lions                          101.1718                   80.7040
# Carlton                                  97.4137                   78.4687
# Greater Western Sydney                   91.0372                   76.0057
# Melbourne                                88.6229                   73.8579
# Port Adelaide                           105.2364                   91.5167
# Adelaide                                102.3990                   89.5687
# Collingwood                              95.3167                   83.3717
# Sydney                                   93.1714                   82.4506
# St Kilda                                 79.9061                   75.3581
# Western Bulldogs                         89.0562                   85.5339
# Geelong                                  82.6043                   79.4413
# Richmond                                 90.2476                   90.8159
# Essendon                                 90.7103                   94.1169
# Gold Coast                               95.0028                  104.4978
# Fremantle                                76.8087                   88.7223
# Hawthorn                                 88.0416                  101.5410
# North Melbourne                          66.9915                  101.1452
# West Coast                               66.1401                  122.7618
#
#                         exp_vaep_value_pergame_diff
# Brisbane Lions                              20.4678
# Carlton                                     18.9450
# Greater Western Sydney                      15.0315
# Melbourne                                   14.7650
# Port Adelaide                               13.7196
# Adelaide                                    12.8303
# Collingwood                                 11.9450
# Sydney                                      10.7208
# St Kilda                                     4.5480
# Western Bulldogs                             3.5223
# Geelong                                      3.1631
# Richmond                                    -0.5684
# Essendon                                    -3.4066
# Gold Coast                                  -9.4950
# Fremantle                                  -11.9136
# Hawthorn                                   -13.4994
# North Melbourne                            -34.1537
# West Coast                                 -56.6216

# %% [markdown]
# 202322

# %%
round_id = '202322'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 23.55839191173264
# Overall MAE: 28.857640828197205
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Brisbane Lions                          101.6860                   80.6337
# Carlton                                  96.3980                   75.8998
# Adelaide                                104.2276                   86.7073
# Greater Western Sydney                   90.4817                   75.6750
# Melbourne                                87.4094                   72.7507
# Port Adelaide                           106.2557                   96.4091
# Sydney                                   92.3315                   82.6444
# Western Bulldogs                         90.9759                   82.6241
# Collingwood                              93.2040                   86.5850
# Geelong                                  87.0677                   81.8012
# St Kilda                                 76.6545                   71.4466
# Richmond                                 90.7925                   94.0202
# Essendon                                 87.6737                   93.3743
# Fremantle                                77.8939                   88.4228
# Hawthorn                                 87.8142                   99.9223
# Gold Coast                               89.8596                  103.1823
# North Melbourne                          65.5039                   99.8035
# West Coast                               65.3975                  119.7252
#
#                         exp_vaep_value_pergame_diff
# Brisbane Lions                              21.0523
# Carlton                                     20.4982
# Adelaide                                    17.5203
# Greater Western Sydney                      14.8068
# Melbourne                                   14.6587
# Port Adelaide                                9.8466
# Sydney                                       9.6871
# Western Bulldogs                             8.3519
# Collingwood                                  6.6191
# Geelong                                      5.2665
# St Kilda                                     5.2079
# Richmond                                    -3.2277
# Essendon                                    -5.7005
# Fremantle                                  -10.5289
# Hawthorn                                   -12.1081
# Gold Coast                                 -13.3226
# North Melbourne                            -34.2996
# West Coast                                 -54.3277

# %% [markdown]
# 202323

# %%
round_id = '202323'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 29.90137976829087
# Overall MAE: 28.90302078211432
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Carlton                                 100.1338                   76.0314
# Adelaide                                104.5013                   84.3277
# Brisbane Lions                          100.5817                   82.6688
# Greater Western Sydney                   90.0976                   76.9175
# Melbourne                                87.5410                   76.4865
# Sydney                                   91.9967                   81.3789
# Port Adelaide                           102.6765                   92.9898
# Western Bulldogs                         89.0814                   82.8727
# St Kilda                                 78.2519                   72.2465
# Geelong                                  88.1127                   83.7873
# Collingwood                              91.9324                   89.1162
# Fremantle                                81.8744                   84.5699
# Essendon                                 85.4091                   90.6225
# Richmond                                 88.8864                   95.1630
# Hawthorn                                 85.1755                   92.7627
# Gold Coast                               85.1852                  102.1226
# North Melbourne                          62.7522                   97.5389
# West Coast                               63.1302                  119.2551
#
#                         exp_vaep_value_pergame_diff
# Carlton                                     24.1025
# Adelaide                                    20.1736
# Brisbane Lions                              17.9129
# Greater Western Sydney                      13.1801
# Melbourne                                   11.0545
# Sydney                                      10.6178
# Port Adelaide                                9.6867
# Western Bulldogs                             6.2087
# St Kilda                                     6.0054
# Geelong                                      4.3253
# Collingwood                                  2.8163
# Fremantle                                   -2.6955
# Essendon                                    -5.2134
# Richmond                                    -6.2765
# Hawthorn                                    -7.5872
# Gold Coast                                 -16.9373
# North Melbourne                            -34.7867
# West Coast                                 -56.1249

# %% [markdown]
# 202324

# %%
round_id = '202324'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 28.265758009291986
# Overall MAE: 28.876468166580057
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Carlton                                  99.8665                   75.4271
# Brisbane Lions                          101.3622                   82.2778
# Greater Western Sydney                   95.9020                   78.1049
# Sydney                                   96.5375                   83.2222
# Melbourne                                85.4065                   73.6813
# Adelaide                                 96.8168                   86.5251
# Western Bulldogs                         89.5850                   80.5466
# St Kilda                                 82.2219                   73.5852
# Port Adelaide                           100.2039                   91.8267
# Collingwood                              93.3839                   88.1215
# Geelong                                  84.9212                   85.8987
# Fremantle                                79.1073                   82.9240
# Richmond                                 88.6879                   94.1110
# Hawthorn                                 80.4844                   92.4901
# Essendon                                 80.4802                   94.5377
# Gold Coast                               86.5321                  102.3762
# North Melbourne                          66.6573                   97.9421
# West Coast                               64.4520                  111.2766
#
#                         exp_vaep_value_pergame_diff
# Carlton                                     24.4394
# Brisbane Lions                              19.0845
# Greater Western Sydney                      17.7971
# Sydney                                      13.3153
# Melbourne                                   11.7253
# Adelaide                                    10.2917
# Western Bulldogs                             9.0384
# St Kilda                                     8.6367
# Port Adelaide                                8.3772
# Collingwood                                  5.2623
# Geelong                                     -0.9775
# Fremantle                                   -3.8167
# Richmond                                    -5.4232
# Hawthorn                                   -12.0057
# Essendon                                   -14.0576
# Gold Coast                                 -15.8442
# North Melbourne                            -31.2848
# West Coast                                 -46.8246
