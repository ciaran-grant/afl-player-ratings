# %% [markdown]
# Creating Match Projections using OOP

# %%
import pandas as pd
import numpy as np

from data_preparation import load_match_summary
from data_preparation import load_player_stats
from data_preparation import aggregate_player_to_match_stats
from data_preparation import load_team_info
from data_preparation import load_venue_info
from data_preparation import create_match_summary_stats

from player import Player
from match import Match
from team import Team
from rating_calculator import PlayerRatingCalculator, TeamRatingCalculator
from projector import Projector

from match_projections import initialise_teams_players, update_ratings, actual_vs_expected

import warnings
warnings.filterwarnings('ignore')
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999
pd.set_option('display.precision', 4)
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# 1. load expected vaep data and player data
# 2. simulate initial updating process
# 3. put into a function
# 4. create objective function
# 5. run optuna optimisation to find update parameters

# %% [markdown]
# Load in player and match stats

# %%
match_summary = load_match_summary()
player_stats = load_player_stats()
match_stats = aggregate_player_to_match_stats(player_stats)
team_info, home_team_info, away_team_info = load_team_info()
venue_info, away_venue_info = load_venue_info()
match_summary_stats = create_match_summary_stats(match_summary, match_stats, home_team_info, away_team_info, away_venue_info)

# %% [markdown]
# Updating Process:
#
# 1. Sum up projected player values from each game as the projected rating for that team
# 2. Get difference in match expected vaep values as the actual rating for that match
# 3. Take into account home advantage for home team
# 4. Update term player ratings based on actual v projected value

# %%
round_id_list = ['2020F4', '202101', '202102', '2022F1', '202304', '202105', '2023F2']

# %%
def get_latest_available_round_id(round_id_list):
    latest_available_season = np.max(np.array([int(x[:4]) for x in round_id_list]))
    latest_season_round_id_list = [x for x in round_id_list if str(latest_available_season) in x]
    latest_season_round_list = [x[4:] for x in latest_season_round_id_list]
    
    if latest_available_season == 2023:
        finals_round_map = {
            'F1':25,
            'F2':26,
            'F3':27,
            'F4':28}
        reverse_finals_round_map ={
            25:'F1',
            26:'F2',
            27:'F3',
            28:'F4'
        }
        last_round = 24
    else:
        finals_round_map = {
            'F1':24,
            'F2':25,
            'F3':26,
            'F4':27}
        reverse_finals_round_map ={
            24:'F1',
            25:'F2',
            26:'F3',
            27:'F4'
        }
        last_round = 23
            
    latest_season_round_num_list = [int(finals_round_map[x]) if 'F' in x else int(x) for x in latest_season_round_list]           

    latest_season_round_num = np.max(np.array(latest_season_round_num_list))
    if latest_season_round_num > last_round:
        latest_season_round = reverse_finals_round_map[latest_season_round_num]
    else:
        latest_season_round = str(latest_season_round_num).zfill(2)
    latest_available_round_id = str(latest_available_season) + str(latest_season_round)
    return latest_available_round_id

# %%
get_latest_available_round_id(round_id_list)
# Out:
# '2023F2'

# %% [markdown]
# ## Initialise Players

# %% [markdown]
# * Players have ratings
# * Teams are made up of players in the squad for a given match (teams have players, players don't have teams)
# * Matches are two teams playing each other at a specific venue
# * Teams ratings are the sum of their players ratings for a given match (teams only have ratings in the context of a match)
# * Rounds are made up of matches
# * Seasons are made up of rounds

# %%
from dataclasses import dataclass, field, make_dataclass
from typing import List, Dict, Optional

@dataclass
class Player:
    name: str
    rating: Dict = field(default_factory=lambda: {})
    
    def __repr__(self) -> str:
        return 'Player({})'.format(self.name)
    
    def get_rating(self, round_id):
        try:
            return self.rating[round_id]
        except:
            raise KeyError("Round {} not available.".format(round_id)) from None
        
    def get_latest_available_rating(self):
        available_rounds = list(self.rating.keys())
            
    def add_rating(self, round_id, rating_value):
        self.rating[round_id] = rating_value 
    
@dataclass
class Team:
    name: str
    players: Dict[str, Player]
    
    def __repr__(self) -> str:
        return 'Team({})'.format(self.name)
    
    def get_player_ratings(self) -> pd.DataFrame:
        return pd.DataFrame().from_dict({k: v.rating for (k, v) in self.players.items()}, orient = 'index')
        
    
@dataclass
class Match:
    match_id: str
    home_team: Team
    away_team: Team
    venue: str
    match_summary: Optional[pd.DataFrame] = None
    player_stats: Optional[pd.DataFrame] = None
    
    def __post_init__(self):
    
        if self.match_summary is not None:
            self.match_summary = self.match_summary[self.match_summary['Match_ID'] == self.match_id]
        if self.player_stats is not None:
            self.player_stats = self.player_stats[self.player_stats['Match_ID'] == self.match_id]
            self.match_stats = self.aggregate_player_to_match_stats()
        self.season = int(self.match_id.split("_")[0][:4])
        self.round_id = self.match_id.split("_")[0]
        self.previous_round_id = self.get_previous_round_id()
        
    def __repr__(self) -> str:
        return 'Match({} v {} @ {} in {})'.format(self.home_team.name, self.away_team.name, self.venue, self.round_id)
        
    def aggregate_player_to_match_stats(self) -> pd.DataFrame:
    
        self.match_stats = self.player_stats.groupby(['Match_ID', 'Team', 'Home_Team']).sum()[['Score', 'xScore', 'exp_vaep_value', 'exp_offensive_value', 'exp_defensive_value']].reset_index()
        self.match_stats['Home_Away'] = np.where(self.match_stats['Team'] == self.match_stats['Home_Team'], 'Home', 'Away')
        self.match_stats = self.match_stats.pivot(index = 'Match_ID', columns = 'Home_Away', values = ['Score', 'xScore', 'exp_vaep_value', 'exp_offensive_value', 'exp_defensive_value'])
        self.match_stats.columns = ['_'.join((y, x)) for (x, y) in self.match_stats.columns]
        
        return self.match_stats
        
    def get_previous_round_id(self):
        
        season = int(self.round_id[:4])
        if season == 2023:
            finals_round_map = {
                'F1':25,
                'F2':26,
                'F3':27,
                'F4':28}
            reverse_finals_round_map ={
                25:'F1',
                26:'F2',
                27:'F3',
                28:'F4'
            }
            last_round = 24
        else:
            finals_round_map = {
                'F1':24,
                'F2':25,
                'F3':26,
                'F4':27}
            reverse_finals_round_map ={
                24:'F1',
                25:'F2',
                26:'F3',
                27:'F4'
            }
            last_round = 23      

        if 'F' in self.round_id:
            round_num = int(finals_round_map[self.round_id[4:]])
        else:
            round_num = int(self.round_id[4:])
        
        previous_round_num = round_num-1
        if previous_round_num > last_round:
            previous_round = reverse_finals_round_map[previous_round_num]
        else:
            previous_round = str(previous_round_num)
        previous_round = previous_round.zfill(2)

        if round_num == 1:
            previous_season = int(season) - 1
            previous_round = 'F4'
        else:
            previous_season = season
        self.previous_round_id = str(previous_season) + str(previous_round)
        
        return self.previous_round_id
    
@dataclass
class Round:
    round_id: str
    matches: Dict[str, Match]
    
    def __repr__(self) -> str:
        return 'Round({})'.format(self.round_id)
    
@dataclass
class Season:
    season: int
    rounds: Dict[str, Round]
    
    def __repr__(self) -> str:
        return 'Season({})'.format(self.season)

# %%
darcy_moore = Player(name = "Darcy Moore", rating = {})
nick_daicos = Player(name = "Nick Daicos")
charlie_cameron = Player(name = "Charlie Cameron")
lachie_neale = Player(name = "Lachie Neale")

# %%
darcy_moore
# Out:
# Player(Darcy Moore)

# %%
collingwood = Team("Collingwood", {'Darcy Moore': darcy_moore})
brisbane = Team("Brisbane Lions", {'Charlie Cameron': charlie_cameron})
collingwood, brisbane
# Out:
# (Team(Collingwood), Team(Brisbane Lions))

# %%
collingwood.players['Darcy Moore'].rating
# Out:
# {}

# %%
collingwood_brisbane_2023F4 = Match("2023F4_Collingwood_BrisbaneLions",
                                    collingwood,
                                    brisbane,
                                    "MCG")
                                    # match_summary, player_stats)

# %%
collingwood_brisbane_2023F4
# Out:
# Match(Collingwood v Brisbane Lions @ MCG in 2023F4)

# %%
round_2023F4 = Round(round_id = '2023F4',
                     matches={collingwood_brisbane_2023F4.match_id: collingwood_brisbane_2023F4})
round_2023F4.matches['2023F4_Collingwood_BrisbaneLions']
# Out:
# Match(Collingwood v Brisbane Lions @ MCG in 2023F4)

# %%
season_2023 = Season(season = 2023,
                     rounds = {'2023F4':round_2023F4})
season_2023
# Out:
# Season(2023)

# %% [markdown]
# Create Player Database

# %%
from typing import Optional

# %%
@dataclass
class PlayerDatabase:
    player: Optional[Player]
    
    def add_player(self, name, Player):
        self.__setattr__(name, Player)
        
    def get_player(self, name):
        return self.__getattribute__(name)
    
    def get_players_in_database(self) -> List[str]:
        return [x for x in dir(self) if (("player" not in x) & ("__" not in x))]
    
    def get_player_ratings_dataframe(self) -> pd.DataFrame:
        players_in_database = self.get_players_in_database()
        player_dataframe_list = []
        for player in players_in_database:
            player_rating_dataframe = pd.DataFrame.from_dict(self.get_player(player).rating, orient='index')
            player_rating_dataframe.columns = [player]
            player_dataframe_list.append(player_rating_dataframe.T)
        return pd.concat(player_dataframe_list)

# %%
pd.DataFrame.from_dict(player_database.get_player('Christian Petracca').rating, orient='index')
# Out:
#              0
# 2020F4  4.0000
# 202101  4.7214
# 202102  4.9984
# 202103  5.1032
# 202104  6.4188
# 202105  6.1238
# 202106  6.7278
# 202107  7.0238
# 202108  6.7134
# 202109  6.1050
# 202110  6.5445
# 202111  7.2797
# 202112  7.9718
# 202113  7.9023
# 202114  6.3218
# 202115  5.9432
# 202116  5.8171
# 202117  7.6166
# 202118  7.7317
# 202119  7.6684
# 202120  7.3708
# 202121  8.0176
# 202122  7.6501
# 202123  6.5498
# 2021F1  7.4082
# 2021F2  5.9266
# 2021F3  7.1925
# 2021F4  8.1757

# %%
pd.DataFrame().from_dict({k: v.rating for (k, v) in player_database.get_player('Christian Petracca').rating.items()}, orient = 'index')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[272], line 1
# ----> 1 pd.DataFrame().from_dict({k: v.rating for (k, v) in player_database.get_player('Christian Petracca').rating.items()}, orient = 'index')
#
# Cell In[272], line 1, in <dictcomp>(.0)
# ----> 1 pd.DataFrame().from_dict({k: v.rating for (k, v) in player_database.get_player('Christian Petracca').rating.items()}, orient = 'index')
#
# AttributeError: 'int' object has no attribute 'rating'

# %%
player_database_list = [x for x in dir(player_database) if (("player" not in x) & ("__" not in x))]
player_database_list
# Out:
# ['Aaron Francis',
#  'Aaron Hall',
#  'Aaron Naughton',
#  'Aaron vandenBerg',
#  'Adam Cerra',
#  'Adam Kennedy',
#  'Adam Saad',
#  'Adam Tomlinson',
#  'Adam Treloar',
#  'Aidan Corr',
#  'Aiden Bonar',
#  'Alec Waterman',
#  'Alex Davies',
#  'Alex Keath',
#  'Alex Neal-Bullen',
#  'Alex Pearce',
#  'Alex Sexton',
#  'Alex Witherden',
#  'Aliir Aliir',
#  'Andrew Brayshaw',
#  'Andrew Gaff',
#  'Andrew McGrath',
#  'Andrew McPherson',
#  'Andrew Phillips',
#  'Angus Brayshaw',
#  'Anthony McDonald-Tipungwuti',
#  'Anthony Scott',
#  'Anton Tohill',
#  'Archie Perkins',
#  'Atu Bosenavulagi',
#  'Bachar Houli',
#  'Bailey Banfield',
#  'Bailey Dale',
#  'Bailey J. Williams',
#  'Bailey Scott',
#  'Bailey Smith',
#  'Bailey Williams',
#  'Bayley Fritsch',
#  'Beau McCreery',
#  'Ben Ainsworth',
#  'Ben Brown',
#  'Ben Cavarra',
#  'Ben Cunnington',
#  'Ben Davis',
#  'Ben Keays',
#  'Ben King',
#  'Ben Long',
#  'Ben McEvoy',
#  'Ben McKay',
#  'Ben Miller',
#  'Ben Ronke',
#  'Billy Frampton',
#  'Blake Acres',
#  'Blake Hardwick',
#  'Bobby Hill',
#  'Boyd Woodcock',
#  'Brad Close',
#  'Brad Crouch',
#  'Brad Sheppard',
#  'Bradley Hill',
#  'Braeden Campbell',
#  'Brandan Parfitt',
#  'Brandon Ellis',
#  'Brandon Starcevich',
#  'Brandon Walker',
#  'Brandon Zerk-Thatcher',
#  'Brayden Ainsworth',
#  'Brayden Cook',
#  'Brayden Fiorini',
#  'Brayden Ham',
#  'Brayden Maynard',
#  'Brayden Sier',
#  'Brendon Ah Chee',
#  'Brennan Cox',
#  'Brent Daniels',
#  'Brett Bewley',
#  'Brodie Grundy',
#  'Brodie Kemp',
#  'Brodie Smith',
#  'Brody Mihocek',
#  'Buku Khamis',
#  'Cale Hooker',
#  'Caleb Daniel',
#  'Caleb Graham',
#  'Caleb Poulter',
#  'Caleb Serong',
#  'Callan Ward',
#  'Callum Ah Chee',
#  'Callum Coleman-Jones',
#  'Callum L. Brown',
#  'Callum M. Brown',
#  'Callum Mills',
#  'Callum Sinclair',
#  'Callum Wilkie',
#  'Cameron Guthrie',
#  'Cameron Zurhaar',
#  'Chad Warner',
#  'Chad Wingard',
#  'Changkuoth Jiath',
#  'Charlie Ballard',
#  'Charlie Cameron',
#  'Charlie Comben',
#  'Charlie Constable',
#  'Charlie Curnow',
#  'Charlie Dixon',
#  'Charlie Lazzaro',
#  'Charlie Spargo',
#  'Chayce Jones',
#  'Chris Burgess',
#  'Chris Mayne',
#  'Christian Petracca',
#  'Christian Salem',
#  'Clayton Oliver',
#  'Cody Weightman',
#  "Colin O'Riordan",
#  'Connor Ballenden',
#  'Connor Blakely',
#  'Connor Budarick',
#  'Connor Downie',
#  'Connor Idun',
#  'Connor Menadue',
#  'Connor Rozee',
#  'Connor West',
#  'Conor Nash',
#  'Conor Stone',
#  'Cooper Sharman',
#  'Corey Durdin',
#  'Curtis Taylor',
#  'Damon Greaves',
#  'Dan Butler',
#  'Dan Hannebery',
#  'Dan Houston',
#  'Dane Rampe',
#  'Daniel Howe',
#  'Daniel Lloyd',
#  'Daniel McKenzie',
#  'Daniel McStay',
#  'Daniel Rich',
#  'Daniel Rioli',
#  'Darcy Byrne-Jones',
#  'Darcy Cameron',
#  'Darcy Fogarty',
#  'Darcy Gardiner',
#  'Darcy MacPherson',
#  'Darcy Moore',
#  'Darcy Parish',
#  'Darcy Tucker',
#  'Darragh Joyce',
#  'David Astbury',
#  'David Cuningham',
#  'David Mackay',
#  'David Mundy',
#  'David Swallow',
#  'David Zaharakis',
#  'Dayne Zorko',
#  'Dean Kent',
#  'Denver Grainger-Barras',
#  'Derek Eggmolesse-Smith',
#  'Deven Robertson',
#  'Devon Smith',
#  'Dion Prestia',
#  'Dom Sheed',
#  'Dom Tyson',
#  'Dougal Howard',
#  'Dustin Martin',
#  'Dylan Clarke',
#  'Dylan Grimes',
#  'Dylan Moore',
#  'Dylan Shiel',
#  'Dylan Stephens',
#  'Dylan Williams',
#  'Dyson Heppell',
#  'Easton Wood',
#  'Ed Curnow',
#  'Ed Langdon',
#  'Ed Richards',
#  'Eddie Betts',
#  'Eddie Ford',
#  'Elliot Yeo',
#  'Elliott Himmelberg',
#  'Emerson Jeka',
#  'Eric Hipwood',
#  'Errol Gulden',
#  'Esava Ratugolea',
#  'Ethan Hughes',
#  'Finlay Macrae',
#  'Finn Maginness',
#  'Francis Evans',
#  'Gary Rohan',
#  'George Hewett',
#  'Grant Birchall',
#  'Griffin Logue',
#  'Gryan Miers',
#  'Hamish Hartlett',
#  'Harris Andrews',
#  'Harrison Jones',
#  'Harrison Petty',
#  'Harry Cunningham',
#  'Harry Edwards',
#  'Harry Himmelberg',
#  'Harry McKay',
#  'Harry Morrison',
#  'Harry Perryman',
#  'Harry Schoenberg',
#  'Harry Sharp',
#  'Hayden Crozier',
#  'Hayden McLean',
#  'Hayden Young',
#  'Heath Chapman',
#  'Hugh Greenwood',
#  'Hugh McCluggage',
#  'Hugo Ralphsmith',
#  'Hunter Clark',
#  'Isaac Cumming',
#  'Isaac Heeney',
#  'Isaac Quaynor',
#  'Isaac Smith',
#  'Isiah Winder',
#  'Izak Rankine',
#  'Jack Billings',
#  'Jack Bowes',
#  'Jack Buckley',
#  'Jack Bytel',
#  'Jack Crisp',
#  'Jack Darling',
#  'Jack Ginnivan',
#  'Jack Graham',
#  'Jack Gunston',
#  'Jack Henry',
#  'Jack Higgins',
#  'Jack Lonie',
#  'Jack Lukosius',
#  'Jack Macrae',
#  'Jack Madgen',
#  'Jack Mahony',
#  'Jack Martin',
#  'Jack Newnes',
#  'Jack Payne',
#  'Jack Petruccelle',
#  'Jack Redden',
#  'Jack Riewoldt',
#  'Jack Ross',
#  'Jack Scrimshaw',
#  'Jack Silvagni',
#  'Jack Sinclair',
#  'Jack Steele',
#  'Jack Viney',
#  'Jack Ziebell',
#  'Jackson Hately',
#  'Jackson Nelson',
#  'Jacob Hopper',
#  'Jacob Koschitzke',
#  'Jacob Townsend',
#  'Jacob Weitering',
#  'Jade Gresham',
#  "Jaeger O'Meara",
#  'Jai Newcombe',
#  'Jaidyn Stephenson',
#  'Jake Aarts',
#  'Jake Bowey',
#  'Jake Carlisle',
#  'Jake Kelly',
#  'Jake Kolodjashnij',
#  'Jake Lever',
#  'Jake Lloyd',
#  'Jake Melksham',
#  'Jake Riccardi',
#  'Jake Stein',
#  'Jake Stringer',
#  'Jake Waterman',
#  'Jamaine Jones',
#  'Jamarra Ugle-Hagan',
#  'James Aish',
#  'James Bell',
#  'James Cousins',
#  'James Frawley',
#  'James Harmes',
#  'James Jordon',
#  'James Madden',
#  'James Peatling',
#  'James Rowbottom',
#  'James Rowe',
#  'James Stewart',
#  'James Worpel',
#  'Jamie Cripps',
#  'Jamie Elliott',
#  'Jared Polec',
#  'Jarman Impey',
#  'Jarrod Berry',
#  'Jarrod Brander',
#  'Jarrod Harbrow',
#  'Jarrod Lienert',
#  'Jarrod Witts',
#  'Jarryd Lyons',
#  'Jarryn Geary',
#  'Jason Castagna',
#  'Jason Johannisen',
#  'Jaxon Prior',
#  'Jay Rantall',
#  'Jayden Hunt',
#  'Jayden Laverde',
#  'Jayden Short',
#  'Jed Anderson',
#  'Jed Bews',
#  'Jed McEntee',
#  'Jeremy Cameron',
#  'Jeremy Finlayson',
#  'Jeremy Howe',
#  'Jeremy McGovern',
#  'Jeremy Sharp',
#  'Jesse Hogan',
#  'Jimmy Webster',
#  'Joe Daniher',
#  'Joel Amartey',
#  'Joel Hamling',
#  'Joel Jeffrey',
#  'Joel Selwood',
#  'Joel Smith',
#  'Joel Western',
#  'John Noble',
#  'Jonathon Ceglar',
#  'Jordan Clark',
#  'Jordan Dawson',
#  'Jordan De Goey',
#  'Jordan Ridley',
#  'Jordan Roughead',
#  'Jordon Butts',
#  'Jordon Sweet',
#  'Josh Battle',
#  'Josh Bruce',
#  'Josh Caddy',
#  'Josh Corbett',
#  'Josh Daicos',
#  'Josh Dunkley',
#  'Josh Honey',
#  'Josh J. Kennedy',
#  'Josh Kelly',
#  'Josh Morris',
#  'Josh P. Kennedy',
#  'Josh Rotham',
#  'Josh Schache',
#  'Josh Thomas',
#  'Josh Treacy',
#  'Josh Walker',
#  'Josh Worrell',
#  'Justin McInerney',
#  'Jy Farrar',
#  'Jy Simpkin',
#  'Jye Caldwell',
#  'Kade Chandler',
#  'Kaiden Brand',
#  'Kamdyn McIntosh',
#  'Kane Farrell',
#  'Kane Lambert',
#  'Karl Amon',
#  'Kayne Turner',
#  'Keidean Coleman',
#  'Kieran Strachan',
#  'Kieren Briggs',
#  'Kyle Hartigan',
#  'Kyle Langford',
#  'Kyron Hayden',
#  'Kysaiah Pickett',
#  'Lachie Ash',
#  'Lachie Fogarty',
#  'Lachie Henderson',
#  'Lachie Hunter',
#  'Lachie Jones',
#  'Lachie Neale',
#  'Lachie Plowman',
#  'Lachie Schultz',
#  'Lachie Weller',
#  'Lachie Whitfield',
#  'Lachie Young',
#  'Lachlan Bramble',
#  'Lachlan Gollant',
#  'Lachlan Keeffe',
#  'Lachlan McNeil',
#  'Lachlan Murphy',
#  'Lachlan Sholl',
#  'Laitham Vandermeer',
#  'Lance Franklin',
#  'Leo Connolly',
#  'Levi Casboult',
#  'Levi Greenwood',
#  'Lewis Melican',
#  'Lewis Taylor',
#  'Lewis Young',
#  'Liam Baker',
#  'Liam Duggan',
#  'Liam Henry',
#  'Liam Jones',
#  'Liam Ryan',
#  'Liam Shiels',
#  'Liam Stocker',
#  'Lin Jong',
#  'Lincoln McCarthy',
#  'Lloyd Meek',
#  "Lochie O'Brien",
#  'Logan McDonald',
#  'Louis Butler',
#  'Luke Breust',
#  'Luke Brown',
#  'Luke Dahlhaus',
#  'Luke Davies-Uniacke',
#  'Luke Dunstan',
#  'Luke Edwards',
#  'Luke Foley',
#  'Luke Jackson',
#  'Luke McDonald',
#  'Luke Parker',
#  'Luke Parks',
#  'Luke Pedlar',
#  'Luke Ryan',
#  'Luke Shuey',
#  'Mabior Chol',
#  'Malcolm Rosas',
#  'Marc Murphy',
#  'Marc Pittonet',
#  'Marcus Adams',
#  'Marcus Bontempelli',
#  'Mark Blicavs',
#  'Mark Hutchings',
#  'Mark Keane',
#  "Mark O'Connor",
#  'Marlion Pickett',
#  'Martin Frederick',
#  'Martin Gleeson',
#  'Mason Cox',
#  'Mason Redman',
#  'Mason Wood',
#  'Matt Buntine',
#  'Matt Flynn',
#  'Matt Guelfi',
#  'Matt Rowell',
#  'Matt Taberner',
#  'Matt de Boer',
#  'Matthew Cottrell',
#  'Matthew Kennedy',
#  'Matthew Ling',
#  'Matthew Owies',
#  'Matthew Parker',
#  'Maurice Rioli',
#  'Max Gawn',
#  'Max Holmes',
#  'Max King',
#  'Max Lynch',
#  'Michael Frederick',
#  'Michael Gibbons',
#  'Michael Hartley',
#  'Michael Hibberd',
#  'Michael Walters',
#  'Miles Bergman',
#  'Mitch Brown',
#  'Mitch Crowden',
#  'Mitch Duncan',
#  'Mitch Georgiades',
#  'Mitch Hannan',
#  'Mitch Lewis',
#  'Mitch McGovern',
#  'Mitch Robinson',
#  'Mitch Wallis',
#  'Nakia Cockatoo',
#  'Nat Fyfe',
#  'Nathan Broad',
#  'Nathan Jones',
#  'Nathan Kreuger',
#  'Nathan Murphy',
#  'Nathan Vardy',
#  'Nathan Wilson',
#  'Ned Cahill',
#  'Ned McHenry',
#  'Ned Reeves',
#  'Neville Jetta',
#  'Nic Naitanui',
#  'Nic Newman',
#  'Nick Blakey',
#  'Nick Bryan',
#  'Nick Coffield',
#  'Nick Haynes',
#  'Nick Hind',
#  'Nick Holman',
#  'Nick Larkey',
#  'Nick Murray',
#  'Nick Shipley',
#  'Nick Vlastuin',
#  'Nik Cox',
#  'Noah Anderson',
#  'Noah Balta',
#  'Oleg Markov',
#  'Oliver Florent',
#  'Oliver Hanrahan',
#  'Oliver Henry',
#  'Ollie Wines',
#  'Orazio Fantasia',
#  'Oscar Allen',
#  'Oscar Clavarino',
#  'Oscar McDonald',
#  'Oscar McInerney',
#  'Oskar Baker',
#  'Paddy Dow',
#  'Paddy Ryder',
#  'Patrick Ambrose',
#  'Patrick Cripps',
#  'Patrick Dangerfield',
#  'Patrick Lipinski',
#  'Patrick Naish',
#  'Paul Hunter',
#  'Paul Seedsman',
#  'Peter Ladhams',
#  'Peter Wright',
#  'Phil Davis',
#  'Phoenix Spicer',
#  'Quinton Narkle',
#  'Reece Conca',
#  "Reilly O'Brien",
#  'Rhyan Mansell',
#  'Rhylee West',
#  'Rhys Mathieson',
#  'Rhys Stanley',
#  'Riley Bonner',
#  'Riley Collier-Dawkins',
#  'Riley Garcia',
#  'Riley Thilthorpe',
#  'Roarke Smith',
#  'Robbie Fox',
#  'Robbie Gray',
#  'Robbie Tarrant',
#  "Ronin O'Connor",
#  'Rory Atkins',
#  'Rory Laird',
#  'Rory Lobb',
#  'Rory Sloane',
#  'Rowan Marshall',
#  'Ryan Burton',
#  'Ryan Byrnes',
#  'Ryan Clarke',
#  'Ryan Gardner',
#  'Ryan Garthwaite',
#  'Ryan Lester',
#  'Sam Berry',
#  'Sam Collins',
#  'Sam Day',
#  'Sam De Koning',
#  'Sam Docherty',
#  'Sam Draper',
#  'Sam Durham',
#  'Sam Flanders',
#  'Sam Frost',
#  'Sam J. Reid',
#  'Sam Mayes',
#  'Sam Menegola',
#  'Sam Petrevski-Seton',
#  'Sam Powell-Pepper',
#  'Sam Reid',
#  'Sam Simpson',
#  'Sam Sturt',
#  'Sam Switkowski',
#  'Sam Taylor',
#  'Sam Walsh',
#  'Sam Weideman',
#  'Sam Wicks',
#  'Samson Ryan',
#  'Scott Lycett',
#  'Scott Pendlebury',
#  'Sean Darcy',
#  'Sean Lemmens',
#  'Sebastian Ross',
#  'Shai Bolton',
#  'Shane Edwards',
#  'Shane McAdam',
#  'Shane Mumford',
#  'Shannon Hurn',
#  'Shaun Atley',
#  'Shaun Burgoyne',
#  'Shaun Higgins',
#  'Shaun McKernan',
#  'Steele Sidebottom',
#  'Stefan Giro',
#  'Stefan Martin',
#  'Stephen Coniglio',
#  'Steven May',
#  'Steven Motlop',
#  'Sydney Stack',
#  'Tanner Bruhn',
#  'Tarryn Thomas',
#  'Taylin Duman',
#  'Taylor Adams',
#  'Taylor Duryea',
#  'Taylor Garner',
#  'Taylor Walker',
#  'Thomas Berry',
#  'Thomson Dow',
#  'Tim English',
#  'Tim Kelly',
#  'Tim Membrey',
#  "Tim O'Brien",
#  'Tim Taranto',
#  'Tobe Watson',
#  'Toby Greene',
#  'Toby McLean',
#  'Toby Nankervis',
#  'Todd Goldstein',
#  'Todd Marshall',
#  'Tom Atkins',
#  'Tom Barrass',
#  'Tom Campbell',
#  'Tom Clurey',
#  'Tom Cole',
#  'Tom Cutler',
#  'Tom De Koning',
#  'Tom Doedee',
#  'Tom Fullarton',
#  'Tom Green',
#  'Tom Hawkins',
#  'Tom Hickey',
#  'Tom Highmore',
#  'Tom J. Lynch',
#  'Tom Jonas',
#  'Tom Liberatore',
#  'Tom Lynch',
#  'Tom McCartin',
#  'Tom McDonald',
#  'Tom Mitchell',
#  'Tom Papley',
#  'Tom Phillips',
#  'Tom Powell',
#  'Tom Rockliff',
#  'Tom Sparrow',
#  'Tom Stewart',
#  'Tom Williamson',
#  'Tom Wilson',
#  'Touk Miller',
#  'Travis Boak',
#  'Travis Colyer',
#  'Trent Bianco',
#  'Trent Cotchin',
#  'Trent Dumont',
#  'Trent McKenzie',
#  'Trent Rivers',
#  'Trey Ruscoe',
#  'Tristan Xerri',
#  'Tyler Brockman',
#  'Tyler Brown',
#  'Wil Powell',
#  'Will Brodie',
#  'Will Day',
#  'Will Hamill',
#  'Will Hayward',
#  'Will Hoskin-Elliott',
#  'Will Kelly',
#  'Will Martyn',
#  'Will Phillips',
#  'Will Setterfield',
#  'Will Snelling',
#  'Willem Drew',
#  'Xavier Duursma',
#  "Xavier O'Halloran",
#  "Xavier O'Neill",
#  'Zac Bailey',
#  'Zac Fisher',
#  'Zac Langdon',
#  'Zac Smith',
#  'Zac Williams',
#  'Zach Guthrie',
#  'Zach Merrett',
#  'Zach Reid',
#  'Zach Sproule',
#  'Zach Tuohy',
#  'Zaine Cordy',
#  'Zak Butters',
#  'Zak Jones']

# %%
player_database = PlayerDatabase(player = Player("Player"))
# player_database.add_player('Darcy Moore', Player("Darcy Moore"))

# %% [markdown]
# Round 202101

# %%
round_id = '202101'

# %% [markdown]
# Get Round Matches

# %%
def get_round_match_ids(player_stats, round_id):
    
    round_player_stats = player_stats[player_stats['Round_ID'] == round_id]
    
    return list(round_player_stats['Match_ID'].unique())

# %%
round_match_ids = get_round_match_ids(player_stats, round_id)
match_id = round_match_ids[-1]
match_id
# Out:
# '202101_WestCoast_GoldCoast'

# %% [markdown]
# Get Single Match

# %%
def get_match(player_stats, match_id):
    
    return player_stats[player_stats['Match_ID'] == match_id]

# %%
match_player_stats = get_match(player_stats, match_id)

# %% [markdown]
# Get Teams in Match

# %%
import re
def get_teams(match_id):
    
    home_team = re.sub(r"(?<=\w)([A-Z])", r" \1", match_id.split("_")[1])
    away_team = re.sub(r"(?<=\w)([A-Z])", r" \1", match_id.split("_")[-1])
    
    return home_team, away_team

# %%
home_team, away_team = get_teams(match_id)

# %% [markdown]
# Get Playing Squad for each Match

# %%
def get_home_team_squad_list(match_player_stats):
    return list(match_player_stats[match_player_stats['Team'] == match_player_stats['Home_Team']]['Player'].unique())

def get_away_team_squad_list(match_player_stats):
    return list(match_player_stats[match_player_stats['Team'] != match_player_stats['Home_Team']]['Player'].unique())

# %%
home_team_squad_list = get_home_team_squad_list(match_player_stats)
away_team_squad_list = get_away_team_squad_list(match_player_stats)

# %% [markdown]
# Add New Players to Database

# %%
for player in home_team_squad_list + away_team_squad_list:
    if ~hasattr(player_database, player):
        player_database.add_player(player, Player(player, rating={'2020F4':4}))

# %%
player_database.get_player("Tim Kelly")
# Out:
# Player(Tim Kelly)

# %% [markdown]
# Create Home and Away Teams for Match with defined squads

# %%
home_team_squad_dict = {}
for player in home_team_squad_list:
    home_team_squad_dict[player] = player_database.get_player(player)
    
home = Team(home_team, home_team_squad_dict)

away_team_squad_dict = {}
for player in away_team_squad_list:
    away_team_squad_dict[player] = player_database.get_player(player)
    
away = Team(away_team, away_team_squad_dict)

# %%
home, away
# Out:
# (Team(West Coast), Team(Gold Coast))

# %%
home.get_player_ratings()
# Out:
#                   2020F4
# Andrew Gaff            4
# Brad Sheppard          4
# Dom Sheed              4
# Jack Darling           4
# Jack Petruccelle       4
# Jack Redden            4
# Jackson Nelson         4
# Jamaine Jones          4
# Jamie Cripps           4
# Jeremy McGovern        4
# Josh J. Kennedy        4
# Josh Rotham            4
# Liam Duggan            4
# Liam Ryan              4
# Nathan Vardy           4
# Nic Naitanui           4
# Oscar Allen            4
# Shannon Hurn           4
# Tim Kelly              4
# Tom Barrass            4
# Tom Cole               4
# Xavier O'Neill         4
# Zac Langdon            4

# %% [markdown]
# Get Venue

# %%
venue = match_summary[match_summary['Match_ID'] == match_id]['Venue'].iloc[0]

# %% [markdown]
# Create Match Object (before Match takes place)

# %%
westcoast_goldcoast = Match(match_id, home, away, venue)
westcoast_goldcoast
# Out:
# Match(West Coast v Gold Coast @ Perth Stadium in 202101)

# %%
westcoast_goldcoast.home_team.get_player_ratings()
# Out:
#                   2020F4
# Andrew Gaff            4
# Brad Sheppard          4
# Dom Sheed              4
# Jack Darling           4
# Jack Petruccelle       4
# Jack Redden            4
# Jackson Nelson         4
# Jamaine Jones          4
# Jamie Cripps           4
# Jeremy McGovern        4
# Josh J. Kennedy        4
# Josh Rotham            4
# Liam Duggan            4
# Liam Ryan              4
# Nathan Vardy           4
# Nic Naitanui           4
# Oscar Allen            4
# Shannon Hurn           4
# Tim Kelly              4
# Tom Barrass            4
# Tom Cole               4
# Xavier O'Neill         4
# Zac Langdon            4

# %% [markdown]
# Player Projections are Player Ratings from previous round

# %%
class Projector:
    def __init__(self,
                 Match: Match,
                 std: int = 35) -> None:
        self.Match = Match
        self.std = std
        
        self.previous_round_id = self.Match.get_previous_round_id()
        
    def calculate_home_team_rating(self):
        home_team_player_ratings = self.Match.home_team.get_player_ratings()
        home_team_player_projection = home_team_player_ratings.loc[:, self.previous_round_id]
        self.home_team_rating = home_team_player_projection.sum()
        
    def get_home_team_rating(self):
        return round(self.home_team_rating, 3)

    def calculate_away_team_rating(self):
        away_team_player_ratings = self.Match.away_team.get_player_ratings()
        away_team_player_projection = away_team_player_ratings.loc[:, self.previous_round_id]
        self.away_team_rating = away_team_player_projection.sum()
    
    def get_away_team_rating(self):
        return round(self.away_team_rating, 3)

# %%
match_projector = Projector(westcoast_goldcoast, std = 35)

# %% [markdown]
# Sum Home and Away Squad Ratings

# %%
match_projector.calculate_home_team_rating()
match_projector.get_home_team_rating()
# Out:
# 92

# %%
match_projector.calculate_away_team_rating()
match_projector.get_away_team_rating()
# Out:
# 92

# %% [markdown]
# Create Match Object (with actual match stats)

# %%
westcoast_goldcoast = Match(match_id, home, away, venue, match_summary, player_stats)
westcoast_goldcoast
# Out:
# Match(West Coast v Gold Coast @ Perth Stadium in 202101)

# %%
westcoast_goldcoast.round_id
# Out:
# '202101'

# %% [markdown]
# Get Actual Match Results (player expected VAEP values from match)

# %%
westcoast_goldcoast.player_stats.head()
# Out:
#                        Match_ID        Team           Player Round_ID  \
# 322  202101_WestCoast_GoldCoast  Gold Coast      Alex Sexton   202101
# 323  202101_WestCoast_GoldCoast  Gold Coast         Ben King   202101
# 324  202101_WestCoast_GoldCoast  Gold Coast    Brandon Ellis   202101
# 325  202101_WestCoast_GoldCoast  Gold Coast  Charlie Ballard   202101
# 326  202101_WestCoast_GoldCoast  Gold Coast  Connor Budarick   202101
#
#     AFL_API_Player_ID      Player_Type     playerId  Age  Height  Weight  \
# 322       Alex_Sexton   MEDIUM_FORWARD   CD_I294643   28     186      82
# 323          Ben_King      KEY_FORWARD  CD_I1006144   21     202      96
# 324     Brandon_Ellis       MIDFIELDER   CD_I293713   28     181      82
# 325   Charlie_Ballard     KEY_DEFENDER  CD_I1008882   22     196      93
# 326   Connor_Budarick  MEDIUM_DEFENDER  CD_I1008454   20     175      74
#
#      Number Kicking_Foot State_Of_Origin  Draft_Year  Debut_Year  \
# 322       6        RIGHT             QLD      2011.0      2012.0
# 323      34        RIGHT             VIC      2018.0      2019.0
# 324       4        RIGHT             VIC      2011.0      2012.0
# 325      10        RIGHT              SA      2017.0      2018.0
# 326      35        RIGHT             QLD      2019.0      2020.0
#
#                                         Recruited_From  Draft_Position  \
# 322                   Springwood (Qld)/Redland (NEAFL)            88.0
# 323  East Sandr (Vic)/Old Haileybury (Vic)/H&apos;b...             6.0
# 324              West Coburg (Vic)/Calder U18/Richmond            15.0
# 325  Mitcham Hawks (SA)/Sacred Heart College (SA)/S...            42.0
# 326                  Labrador (Qld)/Gold Coast (NEAFL)            16.0
#
#           Draft_Type                                          Photo_URL  \
# 322             zone  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
# 323    nationalDraft  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
# 324    nationalDraft  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
# 325    nationalDraft  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
# 326  rookieElevation  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
#
#     Date_Of_Birth  Percent_Played  Behinds  Bounces  Centre_Bounces_Attended  \
# 322    1993-12-03              83        1      3.0                      0.0
# 323    2000-07-07              89        1      0.0                      0.0
# 324    1993-08-03              87        0      4.0                      0.0
# 325    1999-07-23              94        0      0.0                      0.0
# 326    2001-04-06              83        0      0.0                      0.0
#
#      Centre_Clearances  Clangers  Defensive_Contest_Losses  \
# 322                  0         1                       0.0
# 323                  0         4                       0.0
# 324                  0         2                       0.0
# 325                  0         5                       1.0
# 326                  0         4                       1.0
#
#      Defensive_Contest_Loss_Percentage  Defensive_One_On_One_Contests  \
# 322                                0.0                            0.0
# 323                                0.0                            0.0
# 324                                0.0                            0.0
# 325                               33.3                            3.0
# 326                              100.0                            1.0
#
#      Contested_Marks  Contested_Possession_Rate  Contested_Possessions  \
# 322                0                       30.8                      4
# 323                1                       33.3                      4
# 324                0                       15.0                      3
# 325                1                       19.0                      4
# 326                0                       30.8                      4
#
#      Offensive_One_On_One_Contests  Offensive_Contest_Wins  \
# 322                            0.0                     0.0
# 323                            3.0                     1.0
# 324                            0.0                     0.0
# 325                            0.0                     0.0
# 326                            0.0                     0.0
#
#      Offensive_Contest_Win_Percentage  Defensive_Half_Pressure_Acts  \
# 322                               0.0                           2.0
# 323                              33.3                           1.0
# 324                               0.0                          10.0
# 325                               0.0                           7.0
# 326                               0.0                           4.0
#
#      Disposal_Efficiency  Disposals  AFL_Fantasy_Points  Effective_Disposals  \
# 322                 83.3         12                  62                 10.0
# 323                 66.7         12                  75                  8.0
# 324                 78.9         19                  84                 15.0
# 325                 90.5         21                  90                 19.0
# 326                 83.3         12                  44                 10.0
#
#      Effective_Kicks  Inside_50_Ground_Ball_Gets  Frees_Against  Frees_For  \
# 322              7.0                         1.0              0          0
# 323              6.0                         1.0              0          2
# 324             10.0                         0.0              1          0
# 325             15.0                         0.0              2          1
# 326              6.0                         0.0              3          0
#
#      Goal_Accuracy  Goal_Assists  Goals  Ground_Ball_Gets  Handballs  \
# 322           50.0             2      1               3.0          3
# 323           75.0             0      3               1.0          3
# 324            0.0             1      0               2.0          5
# 325            0.0             0      0               2.0          4
# 326            0.0             0      0               4.0          5
#
#      Hit_Outs  Hit_Outs_To_Advantage  Hit_Outs_To_Advantage_Rate  \
# 322         0                    0.0                         0.0
# 323         0                    0.0                         0.0
# 324         0                    0.0                         0.0
# 325         0                    0.0                         0.0
# 326         0                    0.0                         0.0
#
#      Hit_Out_Win_Percentage  Inside_50s  Intercept_Marks  Intercepts  \
# 322                     0.0           6              0.0           1
# 323                     0.0           5              0.0           0
# 324                     0.0           4              0.0           2
# 325                     0.0           0              1.0           4
# 326                     0.0           1              0.0           4
#
#      Kick_Efficiency  Kick_Ins  Kick_Ins_Played_On  Kicks  \
# 322             77.8       0.0                 0.0      9
# 323             66.7       0.0                 0.0      9
# 324             71.4       0.0                 0.0     14
# 325             88.2       0.0                 0.0     17
# 326             85.7       1.0                 0.0      7
#
#      Kick_To_Handball_Ratio  Marks  Marks_Inside_50  Marks_On_Lead  \
# 322                     3.0      6                1            1.0
# 323                     3.0      7                3            2.0
# 324                     2.8      9                0            0.0
# 325                     4.3     12                0            0.0
# 326                     1.4      6                0            0.0
#
#      Metres_Gained  One_Percenters  Pressure_Acts  Player_Rating_Points  \
# 322          393.0               1           10.0                  10.1
# 323          281.0               0            8.0                   6.4
# 324          292.0               1           14.0                   5.4
# 325          191.0               6            7.0                   4.2
# 326          140.0               0            6.0                   1.8
#
#      Rebound_50s  Ruck_Contests  Score_Involvements  Score_Launches  \
# 322            1            0.0                   6             1.0
# 323            0            0.0                   5             0.0
# 324            0            0.0                   2             0.0
# 325            1            0.0                   2             1.0
# 326            1            0.0                   2             1.0
#
#      Shots_At_Goal  Spoils  Stoppage_Clearances  Tackles  Tackles_Inside_50  \
# 322              2     0.0                    0        1                  1
# 323              4     0.0                    0        0                  0
# 324              0     0.0                    0        2                  0
# 325              0     6.0                    0        0                  0
# 326              0     0.0                    0        1                  0
#
#      Clearances  Possessions  Turnovers  Uncontested_Possessions  \
# 322           0           13          3                        9
# 323           0           12          4                        8
# 324           0           20          3                       17
# 325           0           21          1                       17
# 326           0           13          3                        9
#
#     AFLCA_Player_ID  Coaches_Votes          Position Team_Status  \
# 322               0            0.0       Interchange  FINAL_TEAM
# 323               0            0.0      Full Forward  FINAL_TEAM
# 324               0            0.0         Wing Left  FINAL_TEAM
# 325               0            0.0  Centre Half Back  FINAL_TEAM
# 326               0            0.0  Back Pocket Left  FINAL_TEAM
#
#     Position_Sub_Group Position_Group    Year  Brownlow_Votes  Season  \
# 322        Interchange    Interchange  2021.0             0.0    2021
# 323        Key-Forward        Forward  2021.0             0.0    2021
# 324               Wing       Midfield  2021.0             0.0    2021
# 325           Key-Back           Back  2021.0             0.0    2021
# 326        Back-Pocket           Back  2021.0             0.0    2021
#
#       xScore  xT_created  xT_denied  vaep_value  offensive_value  \
# 322   6.9863      0.3767     0.0000      1.2053           1.2222
# 323  18.6175      0.2611    -0.0156      1.7298           1.8813
# 324   0.0000      0.3525    -0.0704      0.1027           0.0974
# 325   0.0000     -0.4694     0.0189      0.5776           0.1560
# 326   0.0000      0.2150    -0.0377     -0.0873           0.1192
#
#      defensive_value  exp_vaep_value  exp_offensive_value  \
# 322          -0.0169          8.8085               9.1348
# 323          -0.1515          7.1877               8.1785
# 324           0.0053          1.9506               1.8040
# 325           0.4217          2.4546               0.6291
# 326          -0.2065          0.0103               1.8632
#
#      exp_defensive_value  xT_received  xT_prevented  vaep_value_received  \
# 322              -0.3264       0.4946        0.0000               1.6381
# 323              -0.9908       0.9206        0.0000               3.1032
# 324               0.1467       0.0418        0.0585               0.4671
# 325               1.8255      -0.4872        0.1218               0.0020
# 326              -1.8529      -0.0171        0.0070               0.3564
#
#      exp_vaep_value_received         Player_Season  Score  xScore_Diff  \
# 322                   7.7601      Alex Sexton_2021      7       0.0137
# 323                  18.8993         Ben King_2021     19       0.3825
# 324                   5.5437    Brandon Ellis_2021      0       0.0000
# 325                   0.4015  Charlie Ballard_2021      0       0.0000
# 326                   2.2086  Connor Budarick_2021      0       0.0000
#
#       Home_Team   Away_Team    Opponent  Round Round_str  Round_ID_num
# 322  West Coast  Gold Coast  West Coast      1        01         20211
# 323  West Coast  Gold Coast  West Coast      1        01         20211
# 324  West Coast  Gold Coast  West Coast      1        01         20211
# 325  West Coast  Gold Coast  West Coast      1        01         20211
# 326  West Coast  Gold Coast  West Coast      1        01         20211

# %% [markdown]
# Calculate Error

# %%
class Evaluator:
    def __init__(self, Match, Projector) -> None:
        
        self.Match = Match
        self.Projector = Projector
        self.home_players = list(self.Match.home_team.players.keys())
        self.away_players = list(self.Match.away_team.players.keys())
        self.player_stats = self.Match.player_stats
        self.player_projections = pd.concat([self.Match.home_team.get_player_ratings(), self.Match.away_team.get_player_ratings()], axis=0)
        self.previous_round_id = self.Match.get_previous_round_id()
        
    def get_player_projection(self, player: str):
        return self.player_projections.loc[player, self.previous_round_id]
    
    def get_player_actual(self, player: str):
        return self.player_stats[self.player_stats['Player'] == player]['exp_vaep_value'].iloc[0]
    
    def get_player_error(self, player):
        return self.get_player_actual(player) - self.get_player_projection(player)
    
    def get_player_absolute_error(self, player):
        return abs(self.get_player_error(player))
    
    def get_match_absolute_error(self):
        match_abs_error = 0
        for player in self.home_players + self.away_players:
            match_abs_error += self.get_player_absolute_error(player)
        return match_abs_error
    
    def get_match_mean_absolute_error(self):
        match_abs_error = 0
        for player in self.home_players + self.away_players:
            match_abs_error += self.get_player_absolute_error(player)
        return match_abs_error / (len(self.home_players) + len(self.away_players))
    
    def evaluate(self):
        
        return round(self.get_match_mean_absolute_error(), 3)

# %%
match_evaluator = Evaluator(westcoast_goldcoast, match_projector)
match_evaluator.evaluate()
# Out:
# 2.914

# %% [markdown]
# Calculate new Player Values

# %%
class Updater:
    def __init__(self, Match: Match, Projector: Projector) -> None:
        
        self.Match = Match
        self.Projector = Projector
        self.home_players = list(self.Match.home_team.players.keys())
        self.away_players = list(self.Match.away_team.players.keys())
        self.previous_round_id = self.Match.get_previous_round_id()
        self.player_stats = self.Match.player_stats
        self.player_projections = pd.concat([self.Match.home_team.get_player_ratings(), self.Match.away_team.get_player_ratings()], axis=0)
        
    def get_home_players(self):
        return self.home_players

    def get_away_players(self):
        return self.away_players
    
    def get_player_projection(self, player: str):
        return self.player_projections.loc[player, self.previous_round_id]
    
    def get_player_actual(self, player: str):
        return self.player_stats[self.player_stats['Player'] == player]['exp_vaep_value'].iloc[0]
    
    def calculate_posterior_mean(self, prior_mean: float, actual_mean: float, prior_std: float = 10, actual_std: float = 25):
        return ((actual_std**2 * prior_mean) + ((prior_std**2) * actual_mean)) / (prior_std**2 + actual_std**2)
    
    def calculate_new_rating(self, player, projection_std, actual_std):
        
        projection = self.get_player_projection(player)
        actual = self.get_player_actual(player)
        new_rating = self.calculate_posterior_mean(projection, actual, projection_std, actual_std)
        
        return round(new_rating, 4)

    def update_player_rating(self, player, projection_std = 10, actual_std = 25):
        
        new_rating = self.calculate_new_rating(player, projection_std, actual_std)
        
        if player in self.home_players:
            self.Match.home_team.players[player].add_rating(self.Match.round_id, new_rating)
        if player in self.away_players:
            self.Match.away_team.players[player].add_rating(self.Match.round_id, new_rating) 
                   
    def update(self, projection_std, actual_std):
        
        for player in self.home_players + self.away_players:
            self.update_player_rating(player, projection_std, actual_std)

# %%
match_updater = Updater(westcoast_goldcoast, match_projector)
player = "Tim Kelly"
match_updater.get_player_projection(player), match_updater.get_player_actual(player)
# Out:
# (4, 14.1100223402)

# %% [markdown]
# Update Player Values (actual v expected)

# %%
match_updater.calculate_new_rating(player, 10, 25)
# Out:
# 5.3945

# %%
match_updater.update_player_rating(player, 10, 25)

# %%
player_database.get_player(player).rating
# Out:
# {'2020F4': 4, '202101': 5.3945}

# %%
match_updater.update(10, 25)

# %% [markdown]
# Initialise player database again

# %%
player_database = PlayerDatabase(player = Player("Player"))

# %% [markdown]
# Update All Matches in Round 202101

# %%
def get_match_information(match_id, player_stats):
    
    print(match_id)
    # Get Match Information
    home_team, away_team = get_teams(match_id)
    match_player_stats = get_match(player_stats, match_id)
    home_team_squad_list = get_home_team_squad_list(match_player_stats)
    away_team_squad_list = get_away_team_squad_list(match_player_stats)
    
    return home_team, away_team, match_player_stats, home_team_squad_list, away_team_squad_list

# %%
def add_new_players(home_team_squad_list, away_team_squad_list, previous_round_id):
    
    for player in home_team_squad_list + away_team_squad_list:
        if not hasattr(player_database, player):
            player_database.add_player(player, Player(player, rating={previous_round_id:4}))

# %%
def create_team(team_name, team_squad_list):
    
    team_squad_dict = {}
    for player in team_squad_list:
        team_squad_dict[player] = player_database.get_player(player)
            
    return Team(team_name, team_squad_dict)

# %%
def get_match_venue(match_summary, match_id):
    return match_summary[match_summary['Match_ID'] == match_id]['Venue'].iloc[0]

# %%
def get_round_id(match_id):
    return match_id.split('_')[0]

# %%
def get_previous_round_id(round_id):
    
    season = int(round_id[:4])
    if season == 2023:
        finals_round_map = {
            'F1':25,
            'F2':26,
            'F3':27,
            'F4':28}
        reverse_finals_round_map ={
            25:'F1',
            26:'F2',
            27:'F3',
            28:'F4'
        }
        last_round = 24
    else:
        finals_round_map = {
            'F1':24,
            'F2':25,
            'F3':26,
            'F4':27}
        reverse_finals_round_map ={
            24:'F1',
            25:'F2',
            26:'F3',
            27:'F4'
        }
        last_round = 23      

    if 'F' in round_id:
        round_num = int(finals_round_map[round_id[4:]])
    else:
        round_num = int(round_id[4:])
    
    previous_round_num = round_num-1
    if previous_round_num > last_round:
        previous_round = reverse_finals_round_map[previous_round_num]
    else:
        previous_round = str(previous_round_num)
    previous_round = previous_round.zfill(2)

    if round_num == 1:
        previous_season = int(season) - 1
        previous_round = 'F4'
    else:
        previous_season = season
    previous_round_id = str(previous_season) + str(previous_round)
    
    return previous_round_id

# %%
def add_missing_player_ratings(home_team_squad_list, away_team_squad_list, previous_round_id):
    
    for player in home_team_squad_list + away_team_squad_list:
        if (hasattr(player_database, player)):
            available_rounds = list(player_database.get_player(player).rating.keys())
            if previous_round_id not in available_rounds:
                latest_available_round_id = get_latest_available_round_id(available_rounds)
                latest_available_rating = player_database.get_player(player).rating[latest_available_round_id]
                
                latest_available_rating_decayed = latest_available_rating * 0.8
                player_database.get_player(player).add_rating(previous_round_id, latest_available_rating_decayed)

# %%
def run_match_scenario(match_id, match_std = 35, projection_std = 10, actual_std = 25):
    
    round_id = get_round_id(match_id)
    previous_round_id = get_previous_round_id(round_id)
    
    print(match_id)
    # Get Match Information
    home_team, away_team = get_teams(match_id)
    match_player_stats = get_match(player_stats, match_id)
    home_team_squad_list = get_home_team_squad_list(match_player_stats)
    away_team_squad_list = get_away_team_squad_list(match_player_stats)
    
    # Set up Players
    add_new_players(home_team_squad_list, away_team_squad_list, previous_round_id)
    
    # Update missing player values
    add_missing_player_ratings(home_team_squad_list, away_team_squad_list, previous_round_id)
    
    # Get Players for each Team        
    home = create_team(home_team, home_team_squad_list)
    away = create_team(away_team, away_team_squad_list)
    
    # Set Venue
    venue = get_match_venue(match_summary, match_id)
    
    # Set up Projections
    match_object = Match(match_id, home, away, venue)
    match_projector = Projector(match_object, std = match_std)
    
    match_projector.calculate_home_team_rating()
    print('Home Team Rating: {}'.format(match_projector.get_home_team_rating()))
    match_projector.calculate_away_team_rating()
    print('Away Team Rating: {}'.format(match_projector.get_away_team_rating()))
    
    # Get Actual Stats
    match_stats_object = Match(match_id, home, away, venue, match_summary, player_stats)
    
    # Calculate Error
    match_evaluator = Evaluator(match_stats_object, match_projector)
    print("Match player MSE: {}".format(match_evaluator.evaluate()))
    
    # Update Player Ratings
    match_updater = Updater(match_stats_object, match_projector)
    match_updater.update(projection_std=projection_std, actual_std=actual_std)

# %%
round_id = '202101'
previous_round_id = '2020F4'
round_match_ids = get_round_match_ids(player_stats, round_id)

for match_id in round_match_ids:
    run_match_scenario(match_id, match_std = 35, projection_std = 10, actual_std = 25)
# Out:
# 202101_BrisbaneLions_Sydney
# Home Team Rating: 92
# Away Team Rating: 92
# Match player MSE: 3.068
# 202101_Collingwood_WesternBulldogs
# Home Team Rating: 92
# Away Team Rating: 92
# Match player MSE: 2.76
# 202101_Essendon_Hawthorn
# Home Team Rating: 92
# Away Team Rating: 92
# Match player MSE: 2.89
# 202101_GreaterWesternSydney_StKilda
# Home Team Rating: 92
# Away Team Rating: 92
# Match player MSE: 2.611
# 202101_Melbourne_Fremantle
# Home Team Rating: 92
# Away Team Rating: 92
# Match player MSE: 2.847
# 202101_NorthMelbourne_PortAdelaide
# Home Team Rating: 92
# Away Team Rating: 92
# Match player MSE: 2.733
# 202101_Richmond_Carlton
# Home Team Rating: 92
# Away Team Rating: 92
# Match player MSE: 2.946
# 202101_WestCoast_GoldCoast
# Home Team Rating: 92
# Away Team Rating: 92
# Match player MSE: 2.914

# %% [markdown]
# 202102

# %%
round_id = '202102'
previous_round_id = '202101'
round_match_ids = get_round_match_ids(player_stats, round_id)

for match_id in round_match_ids:
    run_match_scenario(match_id, match_std = 35, projection_std = 10, actual_std = 25)
# Out:
# 202102_Carlton_Collingwood
# Home Team Rating: 91.187
# Away Team Rating: 89.088
# Match player MSE: 3.135
# 202102_Fremantle_GreaterWesternSydney
# Home Team Rating: 90.468
# Away Team Rating: 94.473
# Match player MSE: 2.64
# 202102_Geelong_BrisbaneLions
# Home Team Rating: 92
# Away Team Rating: 90.685
# Match player MSE: 2.779
# 202102_GoldCoast_NorthMelbourne
# Home Team Rating: 90.511
# Away Team Rating: 91.456
# Match player MSE: 2.98
# 202102_Hawthorn_Richmond
# Home Team Rating: 92.055
# Away Team Rating: 96.227
# Match player MSE: 2.388
# 202102_PortAdelaide_Essendon
# Home Team Rating: 95.107
# Away Team Rating: 90.873
# Match player MSE: 2.499
# 202102_StKilda_Melbourne
# Home Team Rating: 93.14
# Away Team Rating: 93.055
# Match player MSE: 3.008
# 202102_Sydney_Adelaide
# Home Team Rating: 92.702
# Away Team Rating: 92
# Match player MSE: 3.432
# 202102_WesternBulldogs_WestCoast
# Home Team Rating: 93.077
# Away Team Rating: 94.274
# Match player MSE: 3.484

# %%
round_id = '202103'
previous_round_id = get_previous_round_id(round_id)
round_match_ids = get_round_match_ids(player_stats, round_id)

for match_id in round_match_ids:
    run_match_scenario(match_id, match_std = 35, projection_std = 10, actual_std = 25)
# Out:
# 202103_Adelaide_GoldCoast
# Home Team Rating: 95.498
# Away Team Rating: 93.699
# Match player MSE: 3.256
# 202103_Carlton_Fremantle
# Home Team Rating: 92.16
# Away Team Rating: 92.979
# Match player MSE: 2.931
# 202103_Collingwood_BrisbaneLions
# Home Team Rating: 93.474
# Away Team Rating: 90.513
# Match player MSE: 2.72
# 202103_Essendon_StKilda
# Home Team Rating: 89.486
# Away Team Rating: 91.52
# Match player MSE: 2.493
# 202103_Geelong_Hawthorn
# Home Team Rating: 92.172
# Away Team Rating: 89.495
# Match player MSE: 2.942
# 202103_GreaterWesternSydney_Melbourne
# Home Team Rating: 91.847
# Away Team Rating: 96.502
# Match player MSE: 2.693
# 202103_NorthMelbourne_WesternBulldogs
# Home Team Rating: 83.959
# Away Team Rating: 95.724
# Match player MSE: 3.355
# 202103_Richmond_Sydney
# Home Team Rating: 97.389
# Away Team Rating: 94.819
# Match player MSE: 2.878
# 202103_WestCoast_PortAdelaide
# Home Team Rating: 94.607
# Away Team Rating: 96.744
# Match player MSE: 2.615

# %%
round_id = '202104'
previous_round_id = get_previous_round_id(round_id)
round_match_ids = get_round_match_ids(player_stats, round_id)

for match_id in round_match_ids:
    run_match_scenario(match_id, match_std = 35, projection_std = 10, actual_std = 25)
# Out:
# 202104_Collingwood_GreaterWesternSydney
# Home Team Rating: 94.163
# Away Team Rating: 88.311
# Match player MSE: 2.595
# 202104_Fremantle_Hawthorn
# Home Team Rating: 89.159
# Away Team Rating: 91.037
# Match player MSE: 2.65
# 202104_GoldCoast_Carlton
# Home Team Rating: 93.15
# Away Team Rating: 96.196
# Match player MSE: 2.934
# 202104_Melbourne_Geelong
# Home Team Rating: 97.589
# Away Team Rating: 91.885
# Match player MSE: 2.838
# 202104_NorthMelbourne_Adelaide
# Home Team Rating: 79.409
# Away Team Rating: 94.639
# Match player MSE: 2.994
# 202104_PortAdelaide_Richmond
# Home Team Rating: 99.279
# Away Team Rating: 91.574
# Match player MSE: 2.821
# 202104_StKilda_WestCoast
# Home Team Rating: 87.872
# Away Team Rating: 95.175
# Match player MSE: 3.298
# 202104_Sydney_Essendon
# Home Team Rating: 95.15
# Away Team Rating: 93.373
# Match player MSE: 2.733
# 202104_WesternBulldogs_BrisbaneLions
# Home Team Rating: 103.072
# Away Team Rating: 91.702
# Match player MSE: 2.858

# %%
season_2021 = list(player_stats[player_stats['Season'] == 2021]['Round_ID'].unique())
for round_id in season_2021:
    
    previous_round_id = get_previous_round_id(round_id)
    round_match_ids = get_round_match_ids(player_stats, round_id)

    for match_id in round_match_ids:
        run_match_scenario(match_id, match_std = 35, projection_std = 10, actual_std = 25)
# Out:
# 202101_BrisbaneLions_Sydney
# Home Team Rating: 92
# Away Team Rating: 92
# Match player MSE: 3.068
# 202101_Collingwood_WesternBulldogs
# Home Team Rating: 92
# Away Team Rating: 92
# Match player MSE: 2.76
# 202101_Essendon_Hawthorn
# Home Team Rating: 92
# Away Team Rating: 92
# Match player MSE: 2.89
# 202101_GreaterWesternSydney_StKilda
# Home Team Rating: 92
# Away Team Rating: 92
# Match player MSE: 2.611
# 202101_Melbourne_Fremantle
# Home Team Rating: 92
# Away Team Rating: 92
# Match player MSE: 2.847
# 202101_NorthMelbourne_PortAdelaide
# Home Team Rating: 92
# Away Team Rating: 92
# Match player MSE: 2.733
# 202101_Richmond_Carlton
# Home Team Rating: 92
# Away Team Rating: 92
# Match player MSE: 2.946
# 202101_WestCoast_GoldCoast
# Home Team Rating: 92
# Away Team Rating: 92
# Match player MSE: 2.914
# 202102_Carlton_Collingwood
# Home Team Rating: 91.187
# Away Team Rating: 89.088
# Match player MSE: 3.135
# 202102_Fremantle_GreaterWesternSydney
# Home Team Rating: 90.468
# Away Team Rating: 94.473
# Match player MSE: 2.64
# 202102_Geelong_BrisbaneLions
# Home Team Rating: 92
# Away Team Rating: 90.685
# Match player MSE: 2.779
# 202102_GoldCoast_NorthMelbourne
# Home Team Rating: 90.511
# Away Team Rating: 91.456
# Match player MSE: 2.98
# 202102_Hawthorn_Richmond
# Home Team Rating: 92.055
# Away Team Rating: 96.227
# Match player MSE: 2.388
# 202102_PortAdelaide_Essendon
# Home Team Rating: 95.107
# Away Team Rating: 90.873
# Match player MSE: 2.499
# 202102_StKilda_Melbourne
# Home Team Rating: 93.14
# Away Team Rating: 93.055
# Match player MSE: 3.008
# 202102_Sydney_Adelaide
# Home Team Rating: 92.702
# Away Team Rating: 92
# Match player MSE: 3.432
# 202102_WesternBulldogs_WestCoast
# Home Team Rating: 93.077
# Adam Treloar        5.7413  5.5464  5.9030   5.2408     NaN     NaN     NaN
# Bayley Fritsch      4.3399  3.5750  3.9994   3.9707  4.8775  4.8278  3.1245
# Jake Lever          4.5748  4.7569  4.3004   4.0745  5.1855  4.6982  5.1788
# Bailey Smith        4.5449  4.7111  5.2790   5.5377  5.5230  5.5687  4.5542
#
#                     202120  202121  202122  202123  2021F1  202113  202114  \
# Christian Petracca  7.3708  8.0176  7.6501  6.5498  7.4082  7.9023  6.3218
# Jack Macrae         7.2086  8.3176  7.8837  7.4541  8.6486  6.6949  6.4634
# Marcus Bontempelli  7.5022  7.7806  7.2558  7.2012  6.7012  7.5726  7.4210
# Clayton Oliver      8.4151  8.0704  7.3830  8.0598  8.9270  8.7843  7.0274
# Max Gawn            5.7609  5.5914  6.1271  6.5300  6.4642  5.1414  4.1131
# Tom Liberatore      5.8057  5.2492  5.7915  5.2664  5.0958  5.2530  6.3020
# Adam Treloar        4.1926  4.1070  3.5982  3.4249  4.6742     NaN     NaN
# Bayley Fritsch      2.9376  3.2192  4.7045  4.7251  5.1265  4.2310  3.3848
# Jake Lever          5.4063  5.4725  5.5296  6.4255  6.5919  4.2462  3.3970
# Bailey Smith        4.1570  4.1444  4.1091  4.3030  3.8697  4.4550  4.3455
#
#                     202115  202116  202117  202118  2021F2  2021F3  2021F4
# Christian Petracca  5.9432  5.8171  7.6166  7.7317  5.9266  7.1925  8.1757
# Jack Macrae         6.4618  6.6283  6.5964  7.3161  9.1861  9.0866  7.6908
# Marcus Bontempelli  7.6946  7.6653  7.2409  6.8561  7.2518  7.2878  7.3518
# Clayton Oliver      6.6614  6.2104  6.8044  6.9454  7.1416  6.8727  6.9466
# Max Gawn            4.2770  4.8456  4.8082  4.3943  5.1714  7.2695  6.5124
# Tom Liberatore      6.3639  6.9662  6.4961  5.1969  5.4285  5.3987  6.0707
# Adam Treloar           NaN     NaN     NaN     NaN  4.5125  5.4399  5.7549
# Bayley Fritsch      3.3747  3.7331  3.3970  3.8030  4.1012  4.8393  5.0283
# Jake Lever          3.8737  4.4790  4.0994  4.9471  5.2735  5.4293  4.4961
# Bailey Smith        4.9950  4.6716  5.5268  4.4837  3.5354  4.6415  4.4819

# %%
player_database.get_player("Marcus Bontempelli").rating
# Out:
# {'2020F4': 4,
#  '202101': 4.0039,
#  '202102': 5.3814,
#  '202103': 5.4942,
#  '202104': 6.2469,
#  '202105': 6.6551,
#  '202106': 7.8715,
#  '202107': 8.4442,
#  '202108': 8.589,
#  '202109': 8.8886,
#  '202110': 10.2204,
#  '202111': 9.1357,
#  '202112': 9.4658,
#  '202113': 7.57264,
#  '202114': 7.421,
#  '202115': 7.6946,
#  '202116': 7.6653,
#  '202117': 7.2409,
#  '202118': 6.8561,
#  '202119': 7.5003,
#  '202120': 7.5022,
#  '202121': 7.7806,
#  '202122': 7.2558,
#  '202123': 7.2012,
#  '2021F1': 6.7012,
#  '2021F2': 7.2518,
#  '2021F3': 7.2878,
#  '2021F4': 7.3518}
