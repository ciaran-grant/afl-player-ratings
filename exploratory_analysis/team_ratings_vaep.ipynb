# %% [markdown]
# Create and Test Team Ratings for 2023 Season - Round by Round

# %%
import pandas as pd
import re
import numpy as np
from scipy import stats
from sklearn import metrics

import os
import warnings
warnings.filterwarnings('ignore')
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999
pd.set_option('display.precision', 4)

# %%
player_stats = pd.read_csv("/Users/ciaran/Documents/Projects/AFL/data/scored_player_stats.csv")
player_stats['Season'] = player_stats['Match_ID'].apply(lambda x: int(x[:4]))
player_stats['Player_Season'] = player_stats['Player'] + "_" + player_stats['Season'].astype(str)

player_stats['Score'] = player_stats['Behinds'] + player_stats['Goals']*6
player_stats['xScore_Diff'] = player_stats['Score'] - player_stats['xScore']

player_stats['Home_Team'] = player_stats['Match_ID'].apply(lambda x: x.split("_")[1]).str.replace(r"([A-Z])", r" \1").str.strip()
player_stats['Away_Team'] = player_stats['Match_ID'].apply(lambda x: x.split("_")[-1]).str.replace(r"([A-Z])", r" \1").str.strip()
player_stats['Opponent'] = np.where(player_stats['Team'] == player_stats['Home_Team'], player_stats['Away_Team'], player_stats['Home_Team'])

finals_round_map = {'F1':24,
                    'F2':25,
                    'F3':26,
                    'F4':27}
player_stats['Round_ID'] = player_stats['Round_ID'].astype(str)
player_stats['Round'] = (player_stats['Round_ID'].str[4:].replace(finals_round_map)).astype(int)
player_stats['Round_str'] = player_stats['Round_ID'].str[4:].replace(finals_round_map)
player_stats['Round_ID_num'] = (player_stats['Season'].astype(str) + player_stats['Round'].astype(str)).astype(int)

player_stats.tail()
# Out:
#                                Match_ID              Team         Player  \
# 27846  202323_WesternBulldogs_WestCoast  Western Bulldogs    Oskar Baker
# 27847  202323_WesternBulldogs_WestCoast  Western Bulldogs    Rhylee West
# 27848  202323_WesternBulldogs_WestCoast  Western Bulldogs      Rory Lobb
# 27849  202323_WesternBulldogs_WestCoast  Western Bulldogs  Taylor Duryea
# 27850  202323_WesternBulldogs_WestCoast  Western Bulldogs    Tim English
#
#       Round_ID AFL_API_Player_ID      Player_Type     playerId  Age  Height  \
# 27846   202323       Oskar_Baker       MIDFIELDER  CD_I1008855   25     184
# 27847   202323       Rhylee_West   MEDIUM_FORWARD  CD_I1006127   23     183
# 27848   202323         Rory_Lobb      KEY_FORWARD   CD_I990740   30     207
# 27849   202323     Taylor_Duryea  MEDIUM_DEFENDER   CD_I290085   32     181
# 27850   202323       Tim_English             RUCK  CD_I1004592   26     208
#
#        Weight  Number Kicking_Foot State_Of_Origin  Draft_Year  Debut_Year  \
# 27846      87      13        RIGHT             QLD      2017.0      2019.0
# 27847      82      14        RIGHT             VIC      2018.0      2019.0
# 27848     106       7        RIGHT              WA      2013.0      2014.0
# 27849      81      15         LEFT             NSW      2009.0      2013.0
# 27850     107      44        RIGHT              WA      2016.0      2017.0
#
#                                           Recruited_From  Draft_Position  \
# 27846      Wilston Grange (Qld)/Aspley (NEAFL)/Melbourne            48.0
# 27847  Strathmore (Vic)/St Kevin&apos;s College (Vic)...            26.0
# 27848  Bassendean (WA)/Swan Districts (WAFL)/GWS/Frem...            29.0
# 27849  Wahgunyah (Vic)/Caulfield Grammar (Vic)/Murray...            69.0
# 27850      Brookton-Pingelly (WA)/South Fremantle (WAFL)            19.0
#
#           Draft_Type                                          Photo_URL  \
# 27846  nationalDraft  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
# 27847      fatherSon  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
# 27848  nationalDraft  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
# 27849  nationalDraft  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
# 27850  nationalDraft  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
#
#       Date_Of_Birth  Percent_Played  Behinds  Bounces  \
# 27846    1998-05-25             NaN      NaN      NaN
# 27847    2000-07-12             NaN      NaN      NaN
# 27848    1993-02-09             NaN      NaN      NaN
# 27849    1991-04-24             NaN      NaN      NaN
# 27850    1997-08-10             NaN      NaN      NaN
#
#        Centre_Bounces_Attended  Centre_Clearances  Clangers  \
# 27846                      NaN                NaN       NaN
# 27847                      NaN                NaN       NaN
# 27848                      NaN                NaN       NaN
# 27849                      NaN                NaN       NaN
# 27850                      NaN                NaN       NaN
#
#        Defensive_Contest_Losses  Defensive_Contest_Loss_Percentage  \
# 27846                       NaN                                NaN
# 27847                       NaN                                NaN
# 27848                       NaN                                NaN
# 27849                       NaN                                NaN
# 27850                       NaN                                NaN
#
#        Defensive_One_On_One_Contests  Contested_Marks  \
# 27846                            NaN              NaN
# 27847                            NaN              NaN
# 27848                            NaN              NaN
# 27849                            NaN              NaN
# 27850                            NaN              NaN
#
#        Contested_Possession_Rate  Contested_Possessions  \
# 27846                        NaN                    NaN
# 27847                        NaN                    NaN
# 27848                        NaN                    NaN
# 27849                        NaN                    NaN
# 27850                        NaN                    NaN
#
#        Offensive_One_On_One_Contests  Offensive_Contest_Wins  \
# 27846                            NaN                     NaN
# 27847                            NaN                     NaN
# 27848                            NaN                     NaN
# 27849                            NaN                     NaN
# 27850                            NaN                     NaN
#
#        Offensive_Contest_Win_Percentage  Defensive_Half_Pressure_Acts  \
# 27846                               NaN                           NaN
# 27847                               NaN                           NaN
# 27848                               NaN                           NaN
# 27849                               NaN                           NaN
# 27850                               NaN                           NaN
#
#        Disposal_Efficiency  Disposals  AFL_Fantasy_Points  \
# 27846                  NaN        NaN                 NaN
# 27847                  NaN        NaN                 NaN
# 27848                  NaN        NaN                 NaN
# 27849                  NaN        NaN                 NaN
# 27850                  NaN        NaN                 NaN
#
#        Effective_Disposals  Effective_Kicks  Inside_50_Ground_Ball_Gets  \
# 27846                  NaN              NaN                         NaN
# 27847                  NaN              NaN                         NaN
# 27848                  NaN              NaN                         NaN
# 27849                  NaN              NaN                         NaN
# 27850                  NaN              NaN                         NaN
#
#        Frees_Against  Frees_For  Goal_Accuracy  Goal_Assists  Goals  \
# 27846            NaN        NaN            NaN           NaN    NaN
# 27847            NaN        NaN            NaN           NaN    NaN
# 27848            NaN        NaN            NaN           NaN    NaN
# 27849            NaN        NaN            NaN           NaN    NaN
# 27850            NaN        NaN            NaN           NaN    NaN
#
#        Ground_Ball_Gets  Handballs  Hit_Outs  Hit_Outs_To_Advantage  \
# 27846               NaN        NaN       NaN                    NaN
# 27847               NaN        NaN       NaN                    NaN
# 27848               NaN        NaN       NaN                    NaN
# 27849               NaN        NaN       NaN                    NaN
# 27850               NaN        NaN       NaN                    NaN
#
#        Hit_Outs_To_Advantage_Rate  Hit_Out_Win_Percentage  Inside_50s  \
# 27846                         NaN                     NaN         NaN
# 27847                         NaN                     NaN         NaN
# 27848                         NaN                     NaN         NaN
# 27849                         NaN                     NaN         NaN
# 27850                         NaN                     NaN         NaN
#
#        Intercept_Marks  Intercepts  Kick_Efficiency  Kick_Ins  \
# 27846              NaN         NaN              NaN       NaN
# 27847              NaN         NaN              NaN       NaN
# 27848              NaN         NaN              NaN       NaN
# 27849              NaN         NaN              NaN       NaN
# 27850              NaN         NaN              NaN       NaN
#
#        Kick_Ins_Played_On  Kicks  Kick_To_Handball_Ratio  Marks  \
# 27846                 NaN    NaN                     NaN    NaN
# 27847                 NaN    NaN                     NaN    NaN
# 27848                 NaN    NaN                     NaN    NaN
# 27849                 NaN    NaN                     NaN    NaN
# 27850                 NaN    NaN                     NaN    NaN
#
#        Marks_Inside_50  Marks_On_Lead  Metres_Gained  One_Percenters  \
# 27846              NaN            NaN            NaN             NaN
# 27847              NaN            NaN            NaN             NaN
# 27848              NaN            NaN            NaN             NaN
# 27849              NaN            NaN            NaN             NaN
# 27850              NaN            NaN            NaN             NaN
#
#        Pressure_Acts  Player_Rating_Points  Rebound_50s  Ruck_Contests  \
# 27846            NaN                   NaN          NaN            NaN
# 27847            NaN                   NaN          NaN            NaN
# 27848            NaN                   NaN          NaN            NaN
# 27849            NaN                   NaN          NaN            NaN
# 27850            NaN                   NaN          NaN            NaN
#
#        Score_Involvements  Score_Launches  Shots_At_Goal  Spoils  \
# 27846                 NaN             NaN            NaN     NaN
# 27847                 NaN             NaN            NaN     NaN
# 27848                 NaN             NaN            NaN     NaN
# 27849                 NaN             NaN            NaN     NaN
# 27850                 NaN             NaN            NaN     NaN
#
#        Stoppage_Clearances  Tackles  Tackles_Inside_50  Clearances  \
# 27846                  NaN      NaN                NaN         NaN
# 27847                  NaN      NaN                NaN         NaN
# 27848                  NaN      NaN                NaN         NaN
# 27849                  NaN      NaN                NaN         NaN
# 27850                  NaN      NaN                NaN         NaN
#
#        Possessions  Turnovers  Uncontested_Possessions AFLCA_Player_ID  \
# 27846          NaN        NaN                      NaN             NaN
# 27847          NaN        NaN                      NaN             NaN
# 27848          NaN        NaN                      NaN             NaN
# 27849          NaN        NaN                      NaN             NaN
# 27850          NaN        NaN                      NaN             NaN
#
#        Coaches_Votes                  Position Team_Status Position_Sub_Group  \
# 27846            NaN  Half Forward Flank Right  FINAL_TEAM       Half-Forward
# 27847            NaN      Forward Pocket Right  FINAL_TEAM     Forward-Pocket
# 27848            NaN       Forward Pocket Left  FINAL_TEAM     Forward-Pocket
# 27849            NaN         Back Pocket Right  FINAL_TEAM        Back-Pocket
# 27850            NaN                      Ruck  FINAL_TEAM               Ruck
#
#       Position_Group  Year  Brownlow_Votes  Season   xScore  xT_created  \
# 27846        Forward   NaN             NaN    2023   7.9598     -0.3226
# 27847        Forward   NaN             NaN    2023   9.7706      0.1389
# 27848        Forward   NaN             NaN    2023  17.1166     -0.1439
# 27849           Back   NaN             NaN    2023   0.0000      0.1609
# 27850           Ruck   NaN             NaN    2023   3.0435     -0.0350
#
#        xT_denied  vaep_value  offensive_value  defensive_value  \
# 27846     0.0167      0.3991           0.7006          -0.3015
# 27847     0.0000      0.5694           0.6452          -0.0758
# 27848    -0.0025      1.7295           1.8518          -0.1224
# 27849     0.0000      0.2253           0.1578           0.0675
# 27850     0.0320      1.4000           1.3565           0.0435
#
#        exp_vaep_value  exp_offensive_value  exp_defensive_value  xT_received  \
# 27846          2.8523               3.8194              -0.9671      -0.3267
# 27847          7.0749               7.4761              -0.4012       0.4868
# 27848         11.1693              12.7523              -1.5830       0.4878
# 27849          1.4341               1.4510              -0.0170      -0.1781
# 27850          6.4647               4.8051               1.6596      -0.1352
#
#        xT_prevented  vaep_value_received  exp_vaep_value_received  \
# 27846        0.0713               1.0483                   3.4625
# 27847        0.0043               0.9269                   6.2204
# 27848       -0.0002               1.1501                  10.5511
# 27849        0.0223              -0.0554                  -1.4566
# 27850        0.0585               1.3824                   5.9993
#
#             Player_Season  Score  xScore_Diff         Home_Team   Away_Team  \
# 27846    Oskar Baker_2023    NaN          NaN  Western Bulldogs  West Coast
# 27847    Rhylee West_2023    NaN          NaN  Western Bulldogs  West Coast
# 27848      Rory Lobb_2023    NaN          NaN  Western Bulldogs  West Coast
# 27849  Taylor Duryea_2023    NaN          NaN  Western Bulldogs  West Coast
# 27850    Tim English_2023    NaN          NaN  Western Bulldogs  West Coast
#
#          Opponent  Round Round_str  Round_ID_num
# 27846  West Coast     23        23        202323
# 27847  West Coast     23        23        202323
# 27848  West Coast     23        23        202323
# 27849  West Coast     23        23        202323
# 27850  West Coast     23        23        202323

# %% [markdown]
# Pre-Season

# %%
def get_previous_round_id(round_id):
    
    finals_round_map = {'F1':24,
                        'F2':25,
                        'F3':26,
                        'F4':27}
    
    season = round_id[:4]
    if 'F' in round_id:
        round_num = finals_round_map[round_id[4:]]
    else:
        round_num = round_id[4:]
    
    previous_round_num = int(round_id[4:])-1
    previous_round_num = str(previous_round_num).zfill(2)
    if previous_round_num == 1:
        previous_season = int(season) - 1
    else:
        previous_season = season
    previous_round_id = str(previous_season) + str(previous_round_num)
    
    return previous_round_id

# %%
def get_score_standard_deviation(data):
    return data.groupby(['Match_ID', 'Team']).sum()['Score'].std()

# %%
def create_team_summary(player_stats, rounds = None):
    
    player_stats_copy = player_stats.copy()
    
    if rounds is not None:
        all_rounds = sorted(list(set(player_stats_copy['Round_ID'])))
        rating_rounds = all_rounds[-rounds:]
        player_stats_copy = player_stats_copy[player_stats_copy['Round_ID'].isin(rating_rounds)]
    
    team_for = player_stats_copy.groupby(['Team']).sum()[['Score', 'xScore','vaep_value', 'vaep_value_received', 'offensive_value', 'defensive_value', 'exp_vaep_value', 'exp_vaep_value_received', 'exp_offensive_value', 'exp_defensive_value']]
    team_for.columns = [x+"_F" for x in list(team_for)]
    team_against = player_stats_copy.groupby(['Opponent']).sum()[['Score', 'xScore', 'vaep_value', 'vaep_value_received', 'offensive_value', 'defensive_value', 'exp_vaep_value', 'exp_vaep_value_received', 'exp_offensive_value', 'exp_defensive_value']]
    team_against.columns = [x+"_A" for x in list(team_against)]
    team_games = player_stats_copy.groupby(['Match_ID', 'Team']).size().reset_index().groupby(['Team']).count()[['Match_ID']]
    team_games.columns = ['Games']
    team_summary = pd.concat([team_games, team_for, team_against], axis=1)
    
    for col in [x.replace("_F", "") for x in list(team_for)]:
        team_summary[col+"_pergame_F"] = team_summary[col+"_F"] / team_summary["Games"]
        team_summary[col+"_pergame_A"] = team_summary[col+"_A"] / team_summary["Games"]

        team_summary[col+"_diff"] = team_summary[col+"_F"] - team_summary[col+"_A"]
        team_summary[col+"_pergame_diff"] = team_summary[col+"_pergame_F"] - team_summary[col+"_pergame_A"]

    return team_summary

# %%
def get_teams(match_id):
    
    home_team = re.sub(r"\B([A-Z])", r" \1", match_id.split("_")[1])
    away_team = re.sub(r"\B([A-Z])", r" \1", match_id.split("_")[-1])

    return home_team, away_team

# %%
def calculate_match_projections(home_attack_rating, home_defence_rating, away_attack_rating, away_defence_rating):
    
    home_projected_score = (home_attack_rating + away_defence_rating)*0.5
    away_projected_score = (home_defence_rating + away_attack_rating)*0.5
    projected_margin = home_projected_score - away_projected_score
    
    return home_projected_score, away_projected_score, projected_margin

# %%
def get_match_ratings(team_summary, home_team, away_team):
    
    match_ratings_dict = {'home_attack_rating':team_summary.loc[home_team]['exp_vaep_value_pergame_F'],
                          'home_defence_rating':team_summary.loc[home_team]['exp_vaep_value_pergame_A'],
                          'away_attack_rating':team_summary.loc[away_team]['exp_vaep_value_pergame_F'],
                          'away_defence_rating':team_summary.loc[away_team]['exp_vaep_value_pergame_A']}
    
    return match_ratings_dict

# %%
def calculate_projected_probabilities(home_projected_score, away_projected_score, score_std=25):
    
    projected_margin = home_projected_score - away_projected_score
    projected_margin_distribution = stats.norm(loc = projected_margin, scale = score_std)
    
    away_team_win_probability = projected_margin_distribution.cdf(0)
    draw_probability = projected_margin_distribution.pdf(0)
    home_team_win_probability = 1 - away_team_win_probability - draw_probability
    
    return home_team_win_probability, draw_probability, away_team_win_probability

# %%
def get_match_prediction_metrics(projected_margin, margin):
    
    mae = abs(projected_margin - margin)
    mse = ((projected_margin)**2 + (margin)**2)
    rmse = ((projected_margin)**2 + (margin)**2)**0.5
    
    return mae, mse, rmse

# %%
def get_match_result(data, match_id):
    
    home_team, away_team = get_teams(match_id)
    match_player_stats = data[data['Match_ID'] == match_id]
    match_score = match_player_stats.groupby('Team').sum()[['Score', 'xScore']]
    home_score, home_xscore = match_score.loc[home_team]['Score'], match_score.loc[home_team]['xScore']
    away_score, away_xscore = match_score.loc[away_team]['Score'], match_score.loc[away_team]['xScore']
    margin, xmargin = home_score - away_score, home_xscore - away_xscore
    
    return home_score, away_score, margin

# %%
def calculate_match_projection_error(player_stats, match_id, match_ratings_dict, score_std = 25):
    
    home_projected_score, away_projected_score, projected_margin = calculate_match_projections(match_ratings_dict['home_attack_rating'], 
                                                                             match_ratings_dict['home_defence_rating'], 
                                                                             match_ratings_dict['away_attack_rating'], 
                                                                             match_ratings_dict['away_defence_rating'])
    
    home_team_win_probability, draw_probability, away_team_win_probability = calculate_projected_probabilities(home_projected_score, away_projected_score, score_std)
    home_score, away_score, margin = get_match_result(player_stats, match_id)
    
    mae, mse, rmse = get_match_prediction_metrics(projected_margin, margin)
    
    return mae, mse, rmse

# %%
def get_latest_rounds(round_id, player_stats, rounds):
    
    all_rounds = sorted(list(set(player_stats['Round_ID'])))
    rating_rounds = all_rounds[all_rounds.index(round_id)-rounds:all_rounds.index(round_id)]
    player_stats_latest = player_stats[player_stats['Round_ID'].isin(rating_rounds)]
    
    return player_stats_latest

# %%
def update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae):
    
    previous_round_id = get_previous_round_id(round_id)
    player_stats_latest = get_latest_rounds(round_id, player_stats, rounds)
    team_summary = create_team_summary(player_stats_latest, rounds = rounds)
    team_summary = team_summary[['exp_vaep_value_pergame_F', 'exp_vaep_value_pergame_A', 'exp_vaep_value_pergame_diff']]

    round_projection_dict[round_id] = create_round_match_projections(player_stats, team_summary, round_id)
    round_mae[round_id] = np.mean(np.array(list({v['MAE'] for (k, v) in round_projection_dict[round_id].items()})))
    print("Round MAE: {}".format(round_mae[round_id]))
    print("Overall MAE: {}".format(np.mean(np.array(list(round_mae.values())))))
    return team_summary.sort_values('exp_vaep_value_pergame_diff', ascending = False)

# %%
def create_round_match_projections(player_stats, team_summary, round_id):
    
    player_stats_round = player_stats[player_stats['Round_ID'] == round_id]
    match_id_list = list(player_stats_round['Match_ID'].unique())

    match_projection_dict = {}
    for match_id in match_id_list:
        home_team, away_team = get_teams(match_id)
        match_ratings_dict = get_match_ratings(team_summary, home_team, away_team)
        home_projected_score, away_projected_score, projected_margin = calculate_match_projections(match_ratings_dict['home_attack_rating'], 
                                                                                                    match_ratings_dict['home_defence_rating'], 
                                                                                                    match_ratings_dict['away_attack_rating'], 
                                                                                                    match_ratings_dict['away_defence_rating'])
        home_team_win_probability, draw_probability, away_team_win_probability = calculate_projected_probabilities(home_projected_score, away_projected_score, score_std)
        home_score, away_score, margin = get_match_result(player_stats_round, match_id)
        mae, mse, rmse = calculate_match_projection_error(player_stats_round, match_id, match_ratings_dict, score_std = 25)

        match_projection_dict[match_id] = {}
        if home_projected_score > away_projected_score:
            match_projection_dict[match_id]['tip'] = home_team
            match_projection_dict[match_id]['projected_prob'] = home_team_win_probability
        else:
            match_projection_dict[match_id]['tip'] = away_team
            match_projection_dict[match_id]['projected_prob'] = away_team_win_probability
        match_projection_dict[match_id]['projected_margin'] = abs(projected_margin)
        if home_score > away_score:
            match_projection_dict[match_id]['result'] = home_team
        else:
            match_projection_dict[match_id]['result'] = away_team
        match_projection_dict[match_id]['actual_margin'] = abs(margin)   
        match_projection_dict[match_id]['MAE'] = mae
    
    return match_projection_dict

# %%
score_std = get_score_standard_deviation(player_stats)

# %%
round_projection_dict = {}
round_mae = {}
rounds = 10

# %% [markdown]
# 202301

# %%
round_id = '202301'
player_stats_latest = player_stats[player_stats['Season'] == 2022]
team_summary = create_team_summary(player_stats_latest, rounds = rounds)
team_summary = team_summary[['exp_vaep_value_pergame_F', 'exp_vaep_value_pergame_A', 'exp_vaep_value_pergame_diff']]

round_projection_dict[round_id] = create_round_match_projections(player_stats, team_summary, round_id)
round_mae[round_id] = np.mean(np.array(list({v['MAE'] for (k, v) in round_projection_dict[round_id].items()})))
print("Round MAE: {}".format(round_mae[round_id]))
print("Overall MAE: {}".format(np.mean(np.array(list(round_mae.values())))))
team_summary.sort_values('exp_vaep_value_pergame_diff', ascending = False)
# Out:
# Round MAE: 30.9059044426566
# Overall MAE: 30.9059044426566
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Geelong                                 121.9777                   82.8621
# Richmond                                131.8787                  112.2374
# Sydney                                  123.2003                  104.7422
# Port Adelaide                           115.9103                  102.4553
# Melbourne                               119.3971                  109.4337
# Western Bulldogs                        109.3955                  101.5918
# Brisbane Lions                          116.5698                  114.6918
# Fremantle                               107.4655                  109.4248
# Carlton                                 105.3546                  109.0419
# St Kilda                                 93.6377                   98.6196
# Essendon                                115.5316                  121.3215
# Collingwood                             108.3419                  117.1372
# Adelaide                                106.5156                  119.4498
# Hawthorn                                 99.3633                  113.3145
# Gold Coast                              106.2972                  121.1043
# North Melbourne                         108.9518                  130.8708
# Greater Western Sydney                   94.2062                  120.5400
# West Coast                               88.2158                  115.9424
#
#                         exp_vaep_value_pergame_diff
# Geelong                                     39.1156
# Richmond                                    19.6413
# Sydney                                      18.4581
# Port Adelaide                               13.4549
# Melbourne                                    9.9634
# Western Bulldogs                             7.8037
# Brisbane Lions                               1.8780
# Fremantle                                   -1.9593
# Carlton                                     -3.6873
# St Kilda                                    -4.9819
# Essendon                                    -5.7899
# Collingwood                                 -8.7953
# Adelaide                                   -12.9342
# Hawthorn                                   -13.9512
# Gold Coast                                 -14.8070
# North Melbourne                            -21.9190
# Greater Western Sydney                     -26.3338
# West Coast                                 -27.7267

# %% [markdown]
# 202302

# %%
round_id = '202302'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 35.74120399780804
# Overall MAE: 33.323554220232324
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Geelong                                 124.7766                   91.7470
# Port Adelaide                           128.9105                  101.3077
# Sydney                                  125.8993                  104.4167
# Richmond                                132.2227                  113.7513
# Melbourne                               122.7672                  107.7734
# Western Bulldogs                        110.4462                  107.2734
# Fremantle                               110.0481                  110.2557
# Carlton                                 114.5739                  115.4642
# St Kilda                                 99.2764                  104.6213
# Collingwood                             112.3491                  118.6902
# Essendon                                111.4724                  121.2518
# Gold Coast                              106.6097                  116.8665
# Brisbane Lions                          113.1572                  125.3736
# Adelaide                                108.6368                  122.7451
# North Melbourne                         111.7258                  127.7042
# Greater Western Sydney                  101.7884                  120.5295
# Hawthorn                                 95.5211                  120.5922
# West Coast                               91.6957                  118.0265
#
#                         exp_vaep_value_pergame_diff
# Geelong                                     33.0296
# Port Adelaide                               27.6029
# Sydney                                      21.4827
# Richmond                                    18.4714
# Melbourne                                   14.9937
# Western Bulldogs                             3.1727
# Fremantle                                   -0.2076
# Carlton                                     -0.8903
# St Kilda                                    -5.3449
# Collingwood                                 -6.3412
# Essendon                                    -9.7794
# Gold Coast                                 -10.2568
# Brisbane Lions                             -12.2165
# Adelaide                                   -14.1082
# North Melbourne                            -15.9785
# Greater Western Sydney                     -18.7411
# Hawthorn                                   -25.0710
# West Coast                                 -26.3308

# %% [markdown]
# 202303

# %%
round_id = '202303'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 27.335637380163387
# Overall MAE: 31.327581940209345
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Geelong                                 123.1681                   92.0849
# Sydney                                  123.5245                  101.4756
# Port Adelaide                           124.1248                  103.6571
# Richmond                                136.4901                  118.5832
# Melbourne                               120.3032                  107.1862
# Fremantle                               110.5797                  109.1249
# Collingwood                             115.9370                  116.4544
# Western Bulldogs                        107.3290                  109.0252
# St Kilda                                104.4450                  107.8744
# Carlton                                 112.0409                  115.5783
# Adelaide                                112.1426                  119.5104
# Essendon                                117.6749                  127.7271
# Brisbane Lions                          113.7961                  124.2892
# Gold Coast                              109.8035                  121.4269
# Greater Western Sydney                  107.6891                  120.5042
# North Melbourne                         110.5223                  126.9887
# West Coast                               99.6485                  122.6175
# Hawthorn                                 91.8166                  125.5475
#
#                         exp_vaep_value_pergame_diff
# Geelong                                     31.0832
# Sydney                                      22.0489
# Port Adelaide                               20.4677
# Richmond                                    17.9069
# Melbourne                                   13.1170
# Fremantle                                    1.4548
# Collingwood                                 -0.5174
# Western Bulldogs                            -1.6962
# St Kilda                                    -3.4294
# Carlton                                     -3.5374
# Adelaide                                    -7.3679
# Essendon                                   -10.0523
# Brisbane Lions                             -10.4930
# Gold Coast                                 -11.6234
# Greater Western Sydney                     -12.8152
# North Melbourne                            -16.4664
# West Coast                                 -22.9690
# Hawthorn                                   -33.7309

# %% [markdown]
# 202304

# %%
round_id = '202304'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 31.594983320067975
# Overall MAE: 31.394432285174005
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Geelong                                 121.1497                   93.7811
# Port Adelaide                           126.7299                  108.9881
# Richmond                                131.9445                  116.5060
# Sydney                                  120.1725                  107.5867
# Melbourne                               119.5246                  108.7604
# Fremantle                               116.7095                  109.3920
# Carlton                                 120.4504                  116.6358
# Western Bulldogs                        110.0005                  108.0723
# Collingwood                             115.8127                  114.4177
# Greater Western Sydney                  117.4618                  122.1467
# St Kilda                                105.1575                  111.2966
# Adelaide                                116.8481                  124.6708
# Gold Coast                              106.8724                  116.7187
# Brisbane Lions                          110.1772                  121.4714
# Essendon                                114.8869                  129.4220
# North Melbourne                         105.8607                  125.7780
# Hawthorn                                 96.8161                  119.9035
# West Coast                              102.5185                  127.4952
#
#                         exp_vaep_value_pergame_diff
# Geelong                                     27.3686
# Port Adelaide                               17.7418
# Richmond                                    15.4385
# Sydney                                      12.5859
# Melbourne                                   10.7642
# Fremantle                                    7.3175
# Carlton                                      3.8146
# Western Bulldogs                             1.9282
# Collingwood                                  1.3951
# Greater Western Sydney                      -4.6849
# St Kilda                                    -6.1391
# Adelaide                                    -7.8227
# Gold Coast                                  -9.8463
# Brisbane Lions                             -11.2942
# Essendon                                   -14.5351
# North Melbourne                            -19.9174
# Hawthorn                                   -23.0874
# West Coast                                 -24.9767

# %% [markdown]
# 202305

# %%
round_id = '202305'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 24.5362252491962
# Overall MAE: 30.022790877978444
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Geelong                                 123.6590                   94.2752
# Port Adelaide                           130.1948                  107.6302
# Melbourne                               117.7806                  104.1680
# Sydney                                  119.6853                  109.3068
# Richmond                                131.2757                  123.1035
# Carlton                                 120.5223                  112.3713
# St Kilda                                115.7853                  108.6041
# Fremantle                               115.7424                  110.1355
# Western Bulldogs                        113.9880                  111.3622
# Collingwood                             114.9040                  113.3895
# Adelaide                                120.2560                  123.9165
# Essendon                                124.7801                  128.9490
# Brisbane Lions                          109.2771                  121.2431
# Gold Coast                              108.5157                  121.7530
# Greater Western Sydney                  116.9888                  132.0398
# North Melbourne                         107.2880                  123.1532
# West Coast                               99.2459                  131.3100
# Hawthorn                                 91.9637                  128.0034
#
#                         exp_vaep_value_pergame_diff
# Geelong                                     29.3839
# Port Adelaide                               22.5646
# Melbourne                                   13.6126
# Sydney                                      10.3785
# Richmond                                     8.1722
# Carlton                                      8.1510
# St Kilda                                     7.1812
# Fremantle                                    5.6069
# Western Bulldogs                             2.6258
# Collingwood                                  1.5145
# Adelaide                                    -3.6606
# Essendon                                    -4.1690
# Brisbane Lions                             -11.9660
# Gold Coast                                 -13.2373
# Greater Western Sydney                     -15.0510
# North Melbourne                            -15.8652
# West Coast                                 -32.0640
# Hawthorn                                   -36.0397

# %% [markdown]
# 202306

# %%
round_id = '202306'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 30.189168428607577
# Overall MAE: 30.05052046974997
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Geelong                                 122.8004                   95.6983
# Port Adelaide                           128.3674                  110.2629
# St Kilda                                121.4818                  109.5306
# Essendon                                134.2646                  124.3983
# Melbourne                               119.3882                  109.9163
# Sydney                                  118.0520                  110.2773
# Collingwood                             116.5742                  110.9692
# Adelaide                                124.6915                  120.9890
# Richmond                                132.1659                  128.8543
# Fremantle                               116.3871                  114.3377
# Carlton                                 120.9854                  120.9849
# Western Bulldogs                        113.9521                  116.7385
# Gold Coast                              113.6986                  119.3988
# Greater Western Sydney                  120.8697                  136.4062
# Brisbane Lions                          109.9403                  125.4857
# North Melbourne                         103.6606                  121.5666
# West Coast                              101.8007                  133.2358
# Hawthorn                                 92.6367                  128.4171
#
#                         exp_vaep_value_pergame_diff
# Geelong                                     27.1020
# Port Adelaide                               18.1045
# St Kilda                                    11.9512
# Essendon                                     9.8663
# Melbourne                                    9.4718
# Sydney                                       7.7747
# Collingwood                                  5.6050
# Adelaide                                     3.7024
# Richmond                                     3.3115
# Fremantle                                    2.0495
# Carlton                                      0.0005
# Western Bulldogs                            -2.7864
# Gold Coast                                  -5.7002
# Greater Western Sydney                     -15.5365
# Brisbane Lions                             -15.5454
# North Melbourne                            -17.9060
# West Coast                                 -31.4351
# Hawthorn                                   -35.7804

# %% [markdown]
# 202307

# %%
round_id = '202307'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 34.3972033669078
# Overall MAE: 30.671475169343946
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Geelong                                 121.4133                   97.3225
# St Kilda                                124.2300                  107.4473
# Essendon                                132.8689                  116.7810
# Port Adelaide                           131.8972                  118.5110
# Adelaide                                133.0057                  119.6507
# Collingwood                             118.3835                  108.9879
# Melbourne                               117.4469                  111.1075
# Western Bulldogs                        117.0308                  119.4972
# Sydney                                  113.3896                  116.0075
# Carlton                                 117.6251                  121.2578
# Richmond                                123.7719                  128.0780
# Gold Coast                              110.3674                  118.1726
# Fremantle                               112.3449                  121.0173
# Brisbane Lions                          114.1368                  123.9147
# Greater Western Sydney                  122.4338                  136.4894
# North Melbourne                         102.1892                  117.5692
# West Coast                              110.8191                  133.4181
# Hawthorn                                 99.8996                  124.0073
#
#                         exp_vaep_value_pergame_diff
# Geelong                                     24.0908
# St Kilda                                    16.7827
# Essendon                                    16.0879
# Port Adelaide                               13.3861
# Adelaide                                    13.3550
# Collingwood                                  9.3956
# Melbourne                                    6.3394
# Western Bulldogs                            -2.4664
# Sydney                                      -2.6179
# Carlton                                     -3.6327
# Richmond                                    -4.3062
# Gold Coast                                  -7.8052
# Fremantle                                   -8.6724
# Brisbane Lions                              -9.7779
# Greater Western Sydney                     -14.0556
# North Melbourne                            -15.3800
# West Coast                                 -22.5990
# Hawthorn                                   -24.1077

# %% [markdown]
# 202308

# %%
round_id = '202308'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 21.262294432725135
# Overall MAE: 29.495327577266593
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Geelong                                 123.7663                   97.8339
# Adelaide                                129.0566                  115.0717
# St Kilda                                121.0471                  107.2730
# Melbourne                               120.4225                  106.8637
# Port Adelaide                           128.2550                  116.5998
# Carlton                                 121.6792                  111.7814
# Essendon                                129.7134                  119.9110
# Collingwood                             116.0610                  107.4689
# Western Bulldogs                        114.5499                  114.2141
# Sydney                                  114.1953                  115.7373
# Gold Coast                              111.1721                  115.5709
# Richmond                                117.7962                  123.0326
# Brisbane Lions                          110.3426                  115.9658
# Fremantle                               106.8804                  120.6920
# Greater Western Sydney                  121.4197                  135.7690
# North Melbourne                         100.4529                  121.6934
# Hawthorn                                 96.4092                  120.1984
# West Coast                              102.8339                  135.2160
#
#                         exp_vaep_value_pergame_diff
# Geelong                                     25.9325
# Adelaide                                    13.9849
# St Kilda                                    13.7740
# Melbourne                                   13.5587
# Port Adelaide                               11.6552
# Carlton                                      9.8978
# Essendon                                     9.8024
# Collingwood                                  8.5920
# Western Bulldogs                             0.3357
# Sydney                                      -1.5420
# Gold Coast                                  -4.3988
# Richmond                                    -5.2364
# Brisbane Lions                              -5.6233
# Fremantle                                  -13.8116
# Greater Western Sydney                     -14.3493
# North Melbourne                            -21.2406
# Hawthorn                                   -23.7892
# West Coast                                 -32.3822

# %% [markdown]
# 202309

# %%
round_id = '202309'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 40.48643312949962
# Overall MAE: 30.71656152751471
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Geelong                                 123.8848                   98.2784
# Port Adelaide                           129.1280                  113.3213
# St Kilda                                119.0907                  105.3687
# Melbourne                               122.1377                  110.9052
# Adelaide                                125.7094                  116.3067
# Collingwood                             114.5663                  107.0672
# Carlton                                 120.3660                  114.0055
# Essendon                                124.7956                  121.8269
# Western Bulldogs                        112.8246                  112.5315
# Richmond                                122.3875                  122.3996
# Brisbane Lions                          113.5621                  114.6232
# Sydney                                  111.4346                  114.1451
# Fremantle                               113.6715                  117.4328
# Gold Coast                              114.2942                  118.0791
# Greater Western Sydney                  118.4673                  130.7660
# North Melbourne                          99.5228                  119.6447
# Hawthorn                                 95.1067                  124.0116
# West Coast                              104.8048                  137.0559
#
#                         exp_vaep_value_pergame_diff
# Geelong                                     25.6064
# Port Adelaide                               15.8067
# St Kilda                                    13.7220
# Melbourne                                   11.2325
# Adelaide                                     9.4028
# Collingwood                                  7.4990
# Carlton                                      6.3605
# Essendon                                     2.9687
# Western Bulldogs                             0.2931
# Richmond                                    -0.0121
# Brisbane Lions                              -1.0611
# Sydney                                      -2.7105
# Fremantle                                   -3.7613
# Gold Coast                                  -3.7849
# Greater Western Sydney                     -12.2986
# North Melbourne                            -20.1219
# Hawthorn                                   -28.9050
# West Coast                                 -32.2511

# %% [markdown]
# 202310

# %%
round_id = '202310'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 31.402608658836634
# Overall MAE: 30.7851662406469
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Geelong                                 121.6921                   99.0824
# Port Adelaide                           130.8866                  110.6298
# Melbourne                               121.5747                  107.1785
# Collingwood                             115.0377                  102.8739
# Adelaide                                124.6441                  112.5121
# Brisbane Lions                          118.2840                  109.1409
# St Kilda                                114.4738                  106.7127
# Gold Coast                              117.5068                  111.6530
# Carlton                                 118.7500                  113.5837
# Western Bulldogs                        112.5340                  111.7860
# Richmond                                119.7443                  120.5771
# Fremantle                               115.9214                  116.9188
# Essendon                                120.4725                  122.8437
# Sydney                                  109.7780                  115.8812
# Greater Western Sydney                  115.4302                  129.6787
# North Melbourne                          98.2197                  122.8086
# Hawthorn                                 92.8890                  123.1441
# West Coast                               99.8536                  137.7395
#
#                         exp_vaep_value_pergame_diff
# Geelong                                     22.6098
# Port Adelaide                               20.2568
# Melbourne                                   14.3963
# Collingwood                                 12.1638
# Adelaide                                    12.1319
# Brisbane Lions                               9.1432
# St Kilda                                     7.7611
# Gold Coast                                   5.8539
# Carlton                                      5.1664
# Western Bulldogs                             0.7479
# Richmond                                    -0.8328
# Fremantle                                   -0.9975
# Essendon                                    -2.3712
# Sydney                                      -6.1032
# Greater Western Sydney                     -14.2485
# North Melbourne                            -24.5889
# Hawthorn                                   -30.2551
# West Coast                                 -37.8858

# %% [markdown]
# 202311

# %%
round_id = '202311'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 19.565182170566604
# Overall MAE: 29.76516768882142
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Port Adelaide                           130.4375                  109.8517
# Geelong                                 119.2973                  104.2894
# Collingwood                             115.4480                  102.2730
# Brisbane Lions                          119.2626                  106.5596
# Melbourne                               119.7021                  109.1001
# St Kilda                                117.2679                  106.6995
# Adelaide                                120.8492                  114.7561
# Western Bulldogs                        114.7758                  109.2770
# Carlton                                 116.6217                  114.0984
# Sydney                                  113.6561                  112.3978
# Gold Coast                              114.3471                  113.1968
# Fremantle                               117.0542                  116.4275
# Richmond                                117.2035                  118.1378
# Essendon                                118.2876                  120.2471
# Hawthorn                                 98.0656                  114.1318
# Greater Western Sydney                  114.4483                  130.7833
# North Melbourne                          98.9291                  121.3947
# West Coast                               94.0716                  137.9133
#
#                         exp_vaep_value_pergame_diff
# Port Adelaide                               20.5858
# Geelong                                     15.0079
# Collingwood                                 13.1750
# Brisbane Lions                              12.7030
# Melbourne                                   10.6020
# St Kilda                                    10.5684
# Adelaide                                     6.0931
# Western Bulldogs                             5.4988
# Carlton                                      2.5233
# Sydney                                       1.2583
# Gold Coast                                   1.1503
# Fremantle                                    0.6267
# Richmond                                    -0.9343
# Essendon                                    -1.9595
# Hawthorn                                   -16.0662
# Greater Western Sydney                     -16.3350
# North Melbourne                            -22.4656
# West Coast                                 -43.8417

# %% [markdown]
# 202312

# %%
round_id = '202312'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 20.432043958353827
# Overall MAE: 28.987407377949122
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Brisbane Lions                          123.0767                  100.0767
# Geelong                                 117.4043                  101.7386
# Port Adelaide                           124.6084                  110.0928
# Collingwood                             111.8774                   99.6859
# Western Bulldogs                        118.2020                  108.1050
# Melbourne                               117.9449                  109.3160
# St Kilda                                115.7592                  107.6798
# Adelaide                                120.7125                  114.4903
# Gold Coast                              116.4186                  111.7024
# Carlton                                 114.8925                  110.7952
# Fremantle                               114.4045                  115.2642
# Essendon                                116.7498                  119.5591
# Sydney                                  109.9518                  113.5006
# Richmond                                112.4443                  118.2166
# Hawthorn                                101.9218                  110.5436
# Greater Western Sydney                  113.4244                  128.8189
# North Melbourne                          96.0336                  121.0953
# West Coast                               90.9118                  137.5703
#
#                         exp_vaep_value_pergame_diff
# Brisbane Lions                              23.0000
# Geelong                                     15.6657
# Port Adelaide                               14.5156
# Collingwood                                 12.1915
# Western Bulldogs                            10.0970
# Melbourne                                    8.6288
# St Kilda                                     8.0794
# Adelaide                                     6.2222
# Gold Coast                                   4.7162
# Carlton                                      4.0972
# Fremantle                                   -0.8597
# Essendon                                    -2.8093
# Sydney                                      -3.5489
# Richmond                                    -5.7722
# Hawthorn                                    -8.6217
# Greater Western Sydney                     -15.3945
# North Melbourne                            -25.0617
# West Coast                                 -46.6585

# %% [markdown]
# 202313

# %%
round_id = '202313'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 28.89171597812939
# Overall MAE: 28.98004650103991
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Brisbane Lions                          123.6476                  100.0885
# Port Adelaide                           133.1460                  111.5724
# Geelong                                 118.7383                  101.8387
# Melbourne                               119.3497                  104.9926
# Collingwood                             114.6281                  100.6005
# Western Bulldogs                        119.6173                  105.6205
# Gold Coast                              117.8507                  110.6334
# St Kilda                                113.7345                  108.4663
# Adelaide                                120.1378                  115.2398
# Carlton                                 110.9660                  112.8212
# Fremantle                               115.3819                  117.3143
# Essendon                                116.6174                  119.0320
# Richmond                                112.2437                  116.4237
# Hawthorn                                107.4180                  114.3652
# Sydney                                  106.9750                  116.7289
# Greater Western Sydney                  112.3747                  129.3012
# North Melbourne                          99.0136                  124.7830
# West Coast                               87.0548                  139.4314
#
#                         exp_vaep_value_pergame_diff
# Brisbane Lions                              23.5591
# Port Adelaide                               21.5736
# Geelong                                     16.8996
# Melbourne                                   14.3572
# Collingwood                                 14.0277
# Western Bulldogs                            13.9969
# Gold Coast                                   7.2173
# St Kilda                                     5.2682
# Adelaide                                     4.8980
# Carlton                                     -1.8552
# Fremantle                                   -1.9324
# Essendon                                    -2.4146
# Richmond                                    -4.1800
# Hawthorn                                    -6.9471
# Sydney                                      -9.7539
# Greater Western Sydney                     -16.9265
# North Melbourne                            -25.7694
# West Coast                                 -52.3766

# %% [markdown]
# 202314

# %%
round_id = '202314'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 32.585329787293006
# Overall MAE: 29.237566735772276
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Port Adelaide                           133.5001                  107.4913
# Brisbane Lions                          126.2874                  103.5165
# Geelong                                 122.7251                  102.6001
# Melbourne                               120.4355                  104.7881
# Adelaide                                124.6274                  112.5568
# Western Bulldogs                        120.2427                  109.1315
# Collingwood                             113.6245                  104.9179
# Gold Coast                              120.3913                  113.7197
# St Kilda                                110.2200                  103.7609
# Essendon                                116.4106                  117.9815
# Richmond                                114.6723                  116.7648
# Fremantle                               112.4501                  115.7024
# Carlton                                 108.1013                  111.4627
# Hawthorn                                107.8958                  117.2913
# Greater Western Sydney                  111.1861                  120.8638
# Sydney                                  103.1055                  114.1286
# North Melbourne                          96.8297                  123.8225
# West Coast                               84.1314                  144.2857
#
#                         exp_vaep_value_pergame_diff
# Port Adelaide                               26.0088
# Brisbane Lions                              22.7709
# Geelong                                     20.1249
# Melbourne                                   15.6474
# Adelaide                                    12.0706
# Western Bulldogs                            11.1112
# Collingwood                                  8.7066
# Gold Coast                                   6.6716
# St Kilda                                     6.4590
# Essendon                                    -1.5710
# Richmond                                    -2.0925
# Fremantle                                   -3.2523
# Carlton                                     -3.3614
# Hawthorn                                    -9.3955
# Greater Western Sydney                      -9.6777
# Sydney                                     -11.0230
# North Melbourne                            -26.9928
# West Coast                                 -60.1543

# %% [markdown]
# 202315

# %%
round_id = '202315'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 45.71939576982021
# Overall MAE: 30.33635533804214
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Port Adelaide                           135.9979                  105.2635
# Brisbane Lions                          126.8367                  101.1651
# Melbourne                               120.1716                  107.2517
# Western Bulldogs                        118.4168                  106.0521
# Collingwood                             113.9306                  102.0940
# Adelaide                                125.1005                  114.2047
# Geelong                                 118.3790                  109.7599
# Gold Coast                              120.5471                  116.0282
# Carlton                                 112.4929                  110.9129
# Richmond                                112.2276                  111.3609
# St Kilda                                104.8322                  104.1818
# Greater Western Sydney                  112.3633                  113.4334
# Hawthorn                                111.6977                  114.2200
# Essendon                                112.9713                  118.1505
# Fremantle                               110.5351                  116.4454
# Sydney                                   99.0229                  115.9990
# North Melbourne                          95.4601                  124.9794
# West Coast                               84.2998                  146.6718
#
#                         exp_vaep_value_pergame_diff
# Port Adelaide                               30.7344
# Brisbane Lions                              25.6716
# Melbourne                                   12.9199
# Western Bulldogs                            12.3647
# Collingwood                                 11.8366
# Adelaide                                    10.8958
# Geelong                                      8.6191
# Gold Coast                                   4.5189
# Carlton                                      1.5801
# Richmond                                     0.8667
# St Kilda                                     0.6504
# Greater Western Sydney                      -1.0701
# Hawthorn                                    -2.5223
# Essendon                                    -5.1792
# Fremantle                                   -5.9103
# Sydney                                     -16.9761
# North Melbourne                            -29.5193
# West Coast                                 -62.3720

# %% [markdown]
# 202316

# %%
round_id = '202316'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 37.538164294727444
# Overall MAE: 30.78646839783497
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Port Adelaide                           136.0845                  104.7420
# Brisbane Lions                          124.3258                   99.9159
# Western Bulldogs                        119.3568                  102.8114
# Melbourne                               120.0662                  104.4232
# Gold Coast                              124.4060                  111.6006
# Collingwood                             113.3914                  102.5108
# Carlton                                 113.0077                  105.7144
# Geelong                                 117.9132                  112.6081
# Adelaide                                119.3389                  114.3400
# Richmond                                112.2276                  111.3609
# Sydney                                  110.5698                  110.1307
# St Kilda                                103.1755                  104.1881
# Greater Western Sydney                  112.3633                  113.4334
# Fremantle                               108.5542                  114.0377
# Hawthorn                                108.5711                  117.6750
# Essendon                                106.0655                  116.6727
# North Melbourne                          95.4601                  124.9794
# West Coast                               81.0651                  154.7986
#
#                         exp_vaep_value_pergame_diff
# Port Adelaide                               31.3425
# Brisbane Lions                              24.4099
# Western Bulldogs                            16.5454
# Melbourne                                   15.6430
# Gold Coast                                  12.8054
# Collingwood                                 10.8806
# Carlton                                      7.2933
# Geelong                                      5.3051
# Adelaide                                     4.9989
# Richmond                                     0.8667
# Sydney                                       0.4392
# St Kilda                                    -1.0125
# Greater Western Sydney                      -1.0701
# Fremantle                                   -5.4835
# Hawthorn                                    -9.1039
# Essendon                                   -10.6072
# North Melbourne                            -29.5193
# West Coast                                 -73.7335

# %% [markdown]
# 202317

# %%
round_id = '202317'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 23.9600398629836
# Overall MAE: 30.38491377813783
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Brisbane Lions                          126.3141                   97.3366
# Port Adelaide                           131.4907                  105.6396
# Melbourne                               119.9198                   99.9427
# Collingwood                             117.4714                  100.5343
# Carlton                                 115.3516                  102.5792
# Adelaide                                122.2731                  109.8137
# Sydney                                  115.5670                  104.6150
# Western Bulldogs                        115.0890                  104.3129
# St Kilda                                106.8225                  102.7558
# Gold Coast                              119.8475                  118.9862
# Fremantle                               110.0557                  109.7699
# Greater Western Sydney                  107.7443                  110.4249
# Geelong                                 112.3975                  117.6053
# Richmond                                109.7868                  116.2112
# Essendon                                107.8851                  115.7278
# Hawthorn                                103.6060                  118.5737
# North Melbourne                          94.6429                  126.2977
# West Coast                               78.2317                  153.3703
#
#                         exp_vaep_value_pergame_diff
# Brisbane Lions                              28.9775
# Port Adelaide                               25.8511
# Melbourne                                   19.9771
# Collingwood                                 16.9371
# Carlton                                     12.7724
# Adelaide                                    12.4595
# Sydney                                      10.9520
# Western Bulldogs                            10.7761
# St Kilda                                     4.0666
# Gold Coast                                   0.8613
# Fremantle                                    0.2859
# Greater Western Sydney                      -2.6806
# Geelong                                     -5.2078
# Richmond                                    -6.4244
# Essendon                                    -7.8427
# Hawthorn                                   -14.9676
# North Melbourne                            -31.6548
# West Coast                                 -75.1385

# %% [markdown]
# 202318

# %%
round_id = '202318'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 29.732271069086885
# Overall MAE: 30.348655849857224
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Brisbane Lions                          128.7390                   95.4175
# Port Adelaide                           135.3091                  105.6904
# Collingwood                             118.9926                  100.0620
# Melbourne                               114.5434                  101.6250
# Western Bulldogs                        115.0842                  106.7942
# Adelaide                                123.6173                  116.2820
# Carlton                                 113.3527                  106.8545
# St Kilda                                107.0202                  101.3697
# Sydney                                  110.5405                  105.7925
# Greater Western Sydney                  110.3546                  108.6876
# Fremantle                               112.4087                  111.1137
# Richmond                                112.7852                  112.9810
# Geelong                                 112.4986                  112.7128
# Essendon                                111.7776                  113.3687
# Gold Coast                              118.6908                  123.5203
# Hawthorn                                107.7809                  122.8723
# North Melbourne                          91.8625                  125.9962
# West Coast                               78.2349                  152.4524
#
#                         exp_vaep_value_pergame_diff
# Brisbane Lions                              33.3215
# Port Adelaide                               29.6187
# Collingwood                                 18.9306
# Melbourne                                   12.9183
# Western Bulldogs                             8.2900
# Adelaide                                     7.3353
# Carlton                                      6.4981
# St Kilda                                     5.6505
# Sydney                                       4.7480
# Greater Western Sydney                       1.6671
# Fremantle                                    1.2950
# Richmond                                    -0.1958
# Geelong                                     -0.2142
# Essendon                                    -1.5911
# Gold Coast                                  -4.8295
# Hawthorn                                   -15.0915
# North Melbourne                            -34.1337
# West Coast                                 -74.2175

# %% [markdown]
# 202319

# %%
round_id = '202319'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 16.56252368106699
# Overall MAE: 29.623069946236683
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Brisbane Lions                          126.1553                   93.7608
# Port Adelaide                           133.9568                  112.2668
# Collingwood                             121.0771                  101.5233
# Melbourne                               110.1686                   98.3108
# Carlton                                 117.6177                  106.1316
# Adelaide                                124.2088                  115.7330
# Western Bulldogs                        117.3660                  109.7343
# Sydney                                  114.7477                  108.0010
# Geelong                                 113.0863                  108.3571
# Greater Western Sydney                  112.4943                  109.4493
# St Kilda                                104.5532                  104.0031
# Richmond                                110.8946                  111.0339
# Gold Coast                              116.6346                  117.9106
# Hawthorn                                113.5758                  115.7683
# Essendon                                108.7450                  112.8133
# Fremantle                               107.4765                  114.7666
# North Melbourne                          90.6417                  129.5621
# West Coast                               76.2878                  150.5618
#
#                         exp_vaep_value_pergame_diff
# Brisbane Lions                              32.3946
# Port Adelaide                               21.6899
# Collingwood                                 19.5538
# Melbourne                                   11.8577
# Carlton                                     11.4861
# Adelaide                                     8.4759
# Western Bulldogs                             7.6317
# Sydney                                       6.7467
# Geelong                                      4.7291
# Greater Western Sydney                       3.0450
# St Kilda                                     0.5501
# Richmond                                    -0.1393
# Gold Coast                                  -1.2760
# Hawthorn                                    -2.1925
# Essendon                                    -4.0683
# Fremantle                                   -7.2902
# North Melbourne                            -38.9204
# West Coast                                 -74.2740

# %% [markdown]
# 202320

# %%
round_id = '202320'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 25.083430264370126
# Overall MAE: 29.396087962143355
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Brisbane Lions                          120.4862                   92.2657
# Carlton                                 121.9958                  102.4502
# Port Adelaide                           131.9383                  113.1795
# Collingwood                             118.3264                  105.1477
# Greater Western Sydney                  118.8288                  106.6133
# Sydney                                  116.7740                  105.5703
# Western Bulldogs                        119.3843                  109.4093
# Melbourne                               110.5383                  102.6931
# St Kilda                                108.3735                  101.2044
# Adelaide                                124.2849                  119.9822
# Richmond                                113.4928                  109.3877
# Geelong                                 109.1543                  105.9920
# Hawthorn                                115.3135                  116.6078
# Essendon                                110.6350                  112.5240
# Fremantle                               105.0458                  116.7930
# Gold Coast                              111.4498                  128.0147
# North Melbourne                          90.8455                  126.4046
# West Coast                               78.1581                  150.7860
#
#                         exp_vaep_value_pergame_diff
# Brisbane Lions                              28.2205
# Carlton                                     19.5456
# Port Adelaide                               18.7588
# Collingwood                                 13.1787
# Greater Western Sydney                      12.2155
# Sydney                                      11.2037
# Western Bulldogs                             9.9750
# Melbourne                                    7.8452
# St Kilda                                     7.1690
# Adelaide                                     4.3027
# Richmond                                     4.1051
# Geelong                                      3.1623
# Hawthorn                                    -1.2943
# Essendon                                    -1.8890
# Fremantle                                  -11.7472
# Gold Coast                                 -16.5649
# North Melbourne                            -35.5590
# West Coast                                 -72.6278

# %% [markdown]
# 202321

# %%
round_id = '202321'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 22.48930304515638
# Overall MAE: 29.067193442286833
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Carlton                                 123.2327                  102.3278
# Brisbane Lions                          118.8919                   97.9885
# Greater Western Sydney                  119.3010                  103.2220
# Melbourne                               116.2886                  101.6900
# Adelaide                                132.8436                  119.1068
# Port Adelaide                           132.0137                  119.9435
# Collingwood                             118.2040                  106.3846
# Sydney                                  121.5443                  110.5486
# St Kilda                                108.2648                  101.6961
# Western Bulldogs                        116.5117                  112.0924
# Geelong                                 108.6447                  104.4758
# Richmond                                115.7695                  115.6074
# Essendon                                116.2779                  118.7617
# Gold Coast                              117.1726                  126.4204
# Fremantle                               103.5296                  116.2834
# Hawthorn                                112.1512                  127.3421
# North Melbourne                          89.6152                  126.0828
# West Coast                               85.3975                  145.6808
#
#                         exp_vaep_value_pergame_diff
# Carlton                                     20.9049
# Brisbane Lions                              20.9034
# Greater Western Sydney                      16.0790
# Melbourne                                   14.5985
# Adelaide                                    13.7369
# Port Adelaide                               12.0703
# Collingwood                                 11.8195
# Sydney                                      10.9957
# St Kilda                                     6.5687
# Western Bulldogs                             4.4193
# Geelong                                      4.1689
# Richmond                                     0.1621
# Essendon                                    -2.4838
# Gold Coast                                  -9.2478
# Fremantle                                  -12.7538
# Hawthorn                                   -15.1908
# North Melbourne                            -36.4676
# West Coast                                 -60.2833

# %% [markdown]
# 202322

# %%
round_id = '202322'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 24.02007047096134
# Overall MAE: 28.837778761772032
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Carlton                                 122.8064                   99.9572
# Brisbane Lions                          116.7188                   95.4721
# Adelaide                                134.9781                  115.5315
# Greater Western Sydney                  118.3891                  103.1571
# Melbourne                               116.9582                  102.1041
# Sydney                                  121.5636                  111.4625
# Western Bulldogs                        121.4984                  111.9916
# Port Adelaide                           132.9116                  124.2638
# Collingwood                             116.9555                  110.0456
# St Kilda                                105.6591                   98.7712
# Geelong                                 111.7919                  105.5480
# Richmond                                117.8592                  120.7352
# Essendon                                115.5489                  120.5730
# Fremantle                               104.4330                  116.1162
# Gold Coast                              114.9529                  128.4076
# Hawthorn                                113.0113                  126.8505
# North Melbourne                          88.9059                  126.2117
# West Coast                               87.2089                  144.9519
#
#                         exp_vaep_value_pergame_diff
# Carlton                                     22.8491
# Brisbane Lions                              21.2467
# Adelaide                                    19.4466
# Greater Western Sydney                      15.2319
# Melbourne                                   14.8541
# Sydney                                      10.1011
# Western Bulldogs                             9.5069
# Port Adelaide                                8.6478
# Collingwood                                  6.9100
# St Kilda                                     6.8880
# Geelong                                      6.2439
# Richmond                                    -2.8760
# Essendon                                    -5.0241
# Fremantle                                  -11.6832
# Gold Coast                                 -13.4547
# Hawthorn                                   -13.8392
# North Melbourne                            -37.3057
# West Coast                                 -57.7430

# %% [markdown]
# 202323

# %%
round_id = '202323'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 32.70128954074598
# Overall MAE: 29.005757491292638
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Carlton                                 126.1233                   99.6131
# Adelaide                                135.6372                  112.5185
# Brisbane Lions                          116.6578                   99.4613
# Greater Western Sydney                  117.4966                  103.7822
# Melbourne                               116.6140                  105.4211
# Sydney                                  122.6422                  111.8105
# Port Adelaide                           129.7329                  121.3605
# St Kilda                                105.9643                   98.3680
# Western Bulldogs                        121.2826                  113.8828
# Geelong                                 111.4686                  106.1801
# Collingwood                             114.0809                  111.5107
# Fremantle                               108.0032                  111.2419
# Essendon                                112.6919                  117.5814
# Richmond                                113.5051                  119.5872
# Hawthorn                                111.5659                  120.7880
# Gold Coast                              111.8103                  128.7319
# North Melbourne                          85.9143                  123.3547
# West Coast                               84.5819                  144.1778
#
#                         exp_vaep_value_pergame_diff
# Carlton                                     26.5102
# Adelaide                                    23.1187
# Brisbane Lions                              17.1966
# Greater Western Sydney                      13.7144
# Melbourne                                   11.1930
# Sydney                                      10.8317
# Port Adelaide                                8.3724
# St Kilda                                     7.5963
# Western Bulldogs                             7.3998
# Geelong                                      5.2884
# Collingwood                                  2.5702
# Fremantle                                   -3.2387
# Essendon                                    -4.8895
# Richmond                                    -6.0821
# Hawthorn                                    -9.2221
# Gold Coast                                 -16.9215
# North Melbourne                            -37.4404
# West Coast                                 -59.5959

# %% [markdown]
# 202324
