# %% [markdown]
# Create and Test Team Ratings for 2022 Season - Round by Round

# %%
import pandas as pd
import re
import numpy as np
from scipy import stats
from sklearn import metrics

import os
import warnings
warnings.filterwarnings('ignore')
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999
pd.set_option('display.precision', 4)

# %%
player_stats = pd.read_csv("/Users/ciaran/Documents/Projects/AFL/data/scored_player_stats.csv")
player_stats['Season'] = player_stats['Match_ID'].apply(lambda x: int(x[:4]))
player_stats['Player_Season'] = player_stats['Player'] + "_" + player_stats['Season'].astype(str)

player_stats['Score'] = player_stats['Behinds'] + player_stats['Goals']*6
player_stats['xScore_Diff'] = player_stats['Score'] - player_stats['xScore']

player_stats['Home_Team'] = player_stats['Match_ID'].apply(lambda x: x.split("_")[1]).str.replace(r"([A-Z])", r" \1").str.strip()
player_stats['Away_Team'] = player_stats['Match_ID'].apply(lambda x: x.split("_")[-1]).str.replace(r"([A-Z])", r" \1").str.strip()
player_stats['Opponent'] = np.where(player_stats['Team'] == player_stats['Home_Team'], player_stats['Away_Team'], player_stats['Home_Team'])

finals_round_map = {'F1':24,
                    'F2':25,
                    'F3':26,
                    'F4':27}
player_stats['Round_ID'] = player_stats['Round_ID'].astype(str)
player_stats['Round'] = (player_stats['Round_ID'].str[4:].replace(finals_round_map)).astype(int)
player_stats['Round_str'] = player_stats['Round_ID'].str[4:].replace(finals_round_map)
player_stats['Round_ID_num'] = (player_stats['Season'].astype(str) + player_stats['Round'].astype(str)).astype(int)

player_stats.tail()
# Out:
#                                Match_ID              Team         Player  \
# 27846  202323_WesternBulldogs_WestCoast  Western Bulldogs    Oskar Baker
# 27847  202323_WesternBulldogs_WestCoast  Western Bulldogs    Rhylee West
# 27848  202323_WesternBulldogs_WestCoast  Western Bulldogs      Rory Lobb
# 27849  202323_WesternBulldogs_WestCoast  Western Bulldogs  Taylor Duryea
# 27850  202323_WesternBulldogs_WestCoast  Western Bulldogs    Tim English
#
#       Round_ID AFL_API_Player_ID      Player_Type     playerId  Age  Height  \
# 27846   202323       Oskar_Baker       MIDFIELDER  CD_I1008855   25     184
# 27847   202323       Rhylee_West   MEDIUM_FORWARD  CD_I1006127   23     183
# 27848   202323         Rory_Lobb      KEY_FORWARD   CD_I990740   30     207
# 27849   202323     Taylor_Duryea  MEDIUM_DEFENDER   CD_I290085   32     181
# 27850   202323       Tim_English             RUCK  CD_I1004592   26     208
#
#        Weight  Number Kicking_Foot State_Of_Origin  Draft_Year  Debut_Year  \
# 27846      87      13        RIGHT             QLD      2017.0      2019.0
# 27847      82      14        RIGHT             VIC      2018.0      2019.0
# 27848     106       7        RIGHT              WA      2013.0      2014.0
# 27849      81      15         LEFT             NSW      2009.0      2013.0
# 27850     107      44        RIGHT              WA      2016.0      2017.0
#
#                                           Recruited_From  Draft_Position  \
# 27846      Wilston Grange (Qld)/Aspley (NEAFL)/Melbourne            48.0
# 27847  Strathmore (Vic)/St Kevin&apos;s College (Vic)...            26.0
# 27848  Bassendean (WA)/Swan Districts (WAFL)/GWS/Frem...            29.0
# 27849  Wahgunyah (Vic)/Caulfield Grammar (Vic)/Murray...            69.0
# 27850      Brookton-Pingelly (WA)/South Fremantle (WAFL)            19.0
#
#           Draft_Type                                          Photo_URL  \
# 27846  nationalDraft  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
# 27847      fatherSon  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
# 27848  nationalDraft  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
# 27849  nationalDraft  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
# 27850  nationalDraft  https://s.afl.com.au/staticfile/AFL Tenant/AFL...
#
#       Date_Of_Birth  Percent_Played  Behinds  Bounces  \
# 27846    1998-05-25             NaN      NaN      NaN
# 27847    2000-07-12             NaN      NaN      NaN
# 27848    1993-02-09             NaN      NaN      NaN
# 27849    1991-04-24             NaN      NaN      NaN
# 27850    1997-08-10             NaN      NaN      NaN
#
#        Centre_Bounces_Attended  Centre_Clearances  Clangers  \
# 27846                      NaN                NaN       NaN
# 27847                      NaN                NaN       NaN
# 27848                      NaN                NaN       NaN
# 27849                      NaN                NaN       NaN
# 27850                      NaN                NaN       NaN
#
#        Defensive_Contest_Losses  Defensive_Contest_Loss_Percentage  \
# 27846                       NaN                                NaN
# 27847                       NaN                                NaN
# 27848                       NaN                                NaN
# 27849                       NaN                                NaN
# 27850                       NaN                                NaN
#
#        Defensive_One_On_One_Contests  Contested_Marks  \
# 27846                            NaN              NaN
# 27847                            NaN              NaN
# 27848                            NaN              NaN
# 27849                            NaN              NaN
# 27850                            NaN              NaN
#
#        Contested_Possession_Rate  Contested_Possessions  \
# 27846                        NaN                    NaN
# 27847                        NaN                    NaN
# 27848                        NaN                    NaN
# 27849                        NaN                    NaN
# 27850                        NaN                    NaN
#
#        Offensive_One_On_One_Contests  Offensive_Contest_Wins  \
# 27846                            NaN                     NaN
# 27847                            NaN                     NaN
# 27848                            NaN                     NaN
# 27849                            NaN                     NaN
# 27850                            NaN                     NaN
#
#        Offensive_Contest_Win_Percentage  Defensive_Half_Pressure_Acts  \
# 27846                               NaN                           NaN
# 27847                               NaN                           NaN
# 27848                               NaN                           NaN
# 27849                               NaN                           NaN
# 27850                               NaN                           NaN
#
#        Disposal_Efficiency  Disposals  AFL_Fantasy_Points  \
# 27846                  NaN        NaN                 NaN
# 27847                  NaN        NaN                 NaN
# 27848                  NaN        NaN                 NaN
# 27849                  NaN        NaN                 NaN
# 27850                  NaN        NaN                 NaN
#
#        Effective_Disposals  Effective_Kicks  Inside_50_Ground_Ball_Gets  \
# 27846                  NaN              NaN                         NaN
# 27847                  NaN              NaN                         NaN
# 27848                  NaN              NaN                         NaN
# 27849                  NaN              NaN                         NaN
# 27850                  NaN              NaN                         NaN
#
#        Frees_Against  Frees_For  Goal_Accuracy  Goal_Assists  Goals  \
# 27846            NaN        NaN            NaN           NaN    NaN
# 27847            NaN        NaN            NaN           NaN    NaN
# 27848            NaN        NaN            NaN           NaN    NaN
# 27849            NaN        NaN            NaN           NaN    NaN
# 27850            NaN        NaN            NaN           NaN    NaN
#
#        Ground_Ball_Gets  Handballs  Hit_Outs  Hit_Outs_To_Advantage  \
# 27846               NaN        NaN       NaN                    NaN
# 27847               NaN        NaN       NaN                    NaN
# 27848               NaN        NaN       NaN                    NaN
# 27849               NaN        NaN       NaN                    NaN
# 27850               NaN        NaN       NaN                    NaN
#
#        Hit_Outs_To_Advantage_Rate  Hit_Out_Win_Percentage  Inside_50s  \
# 27846                         NaN                     NaN         NaN
# 27847                         NaN                     NaN         NaN
# 27848                         NaN                     NaN         NaN
# 27849                         NaN                     NaN         NaN
# 27850                         NaN                     NaN         NaN
#
#        Intercept_Marks  Intercepts  Kick_Efficiency  Kick_Ins  \
# 27846              NaN         NaN              NaN       NaN
# 27847              NaN         NaN              NaN       NaN
# 27848              NaN         NaN              NaN       NaN
# 27849              NaN         NaN              NaN       NaN
# 27850              NaN         NaN              NaN       NaN
#
#        Kick_Ins_Played_On  Kicks  Kick_To_Handball_Ratio  Marks  \
# 27846                 NaN    NaN                     NaN    NaN
# 27847                 NaN    NaN                     NaN    NaN
# 27848                 NaN    NaN                     NaN    NaN
# 27849                 NaN    NaN                     NaN    NaN
# 27850                 NaN    NaN                     NaN    NaN
#
#        Marks_Inside_50  Marks_On_Lead  Metres_Gained  One_Percenters  \
# 27846              NaN            NaN            NaN             NaN
# 27847              NaN            NaN            NaN             NaN
# 27848              NaN            NaN            NaN             NaN
# 27849              NaN            NaN            NaN             NaN
# 27850              NaN            NaN            NaN             NaN
#
#        Pressure_Acts  Player_Rating_Points  Rebound_50s  Ruck_Contests  \
# 27846            NaN                   NaN          NaN            NaN
# 27847            NaN                   NaN          NaN            NaN
# 27848            NaN                   NaN          NaN            NaN
# 27849            NaN                   NaN          NaN            NaN
# 27850            NaN                   NaN          NaN            NaN
#
#        Score_Involvements  Score_Launches  Shots_At_Goal  Spoils  \
# 27846                 NaN             NaN            NaN     NaN
# 27847                 NaN             NaN            NaN     NaN
# 27848                 NaN             NaN            NaN     NaN
# 27849                 NaN             NaN            NaN     NaN
# 27850                 NaN             NaN            NaN     NaN
#
#        Stoppage_Clearances  Tackles  Tackles_Inside_50  Clearances  \
# 27846                  NaN      NaN                NaN         NaN
# 27847                  NaN      NaN                NaN         NaN
# 27848                  NaN      NaN                NaN         NaN
# 27849                  NaN      NaN                NaN         NaN
# 27850                  NaN      NaN                NaN         NaN
#
#        Possessions  Turnovers  Uncontested_Possessions AFLCA_Player_ID  \
# 27846          NaN        NaN                      NaN             NaN
# 27847          NaN        NaN                      NaN             NaN
# 27848          NaN        NaN                      NaN             NaN
# 27849          NaN        NaN                      NaN             NaN
# 27850          NaN        NaN                      NaN             NaN
#
#        Coaches_Votes                  Position Team_Status Position_Sub_Group  \
# 27846            NaN  Half Forward Flank Right  FINAL_TEAM       Half-Forward
# 27847            NaN      Forward Pocket Right  FINAL_TEAM     Forward-Pocket
# 27848            NaN       Forward Pocket Left  FINAL_TEAM     Forward-Pocket
# 27849            NaN         Back Pocket Right  FINAL_TEAM        Back-Pocket
# 27850            NaN                      Ruck  FINAL_TEAM               Ruck
#
#       Position_Group  Year  Brownlow_Votes  Season   xScore  xT_created  \
# 27846        Forward   NaN             NaN    2023   7.9598     -0.3226
# 27847        Forward   NaN             NaN    2023   9.7706      0.1389
# 27848        Forward   NaN             NaN    2023  17.1166     -0.1439
# 27849           Back   NaN             NaN    2023   0.0000      0.1609
# 27850           Ruck   NaN             NaN    2023   3.0435     -0.0350
#
#        xT_denied  vaep_value  offensive_value  defensive_value  \
# 27846     0.0167      0.3991           0.7006          -0.3015
# 27847     0.0000      0.5694           0.6452          -0.0758
# 27848    -0.0025      1.7295           1.8518          -0.1224
# 27849     0.0000      0.2253           0.1578           0.0675
# 27850     0.0320      1.4000           1.3565           0.0435
#
#        exp_vaep_value  exp_offensive_value  exp_defensive_value  xT_received  \
# 27846          2.8523               3.8194              -0.9671      -0.3267
# 27847          7.0749               7.4761              -0.4012       0.4868
# 27848         11.1693              12.7523              -1.5830       0.4878
# 27849          1.4341               1.4510              -0.0170      -0.1781
# 27850          6.4647               4.8051               1.6596      -0.1352
#
#        xT_prevented  vaep_value_received  exp_vaep_value_received  \
# 27846        0.0713               1.0483                   3.4625
# 27847        0.0043               0.9269                   6.2204
# 27848       -0.0002               1.1501                  10.5511
# 27849        0.0223              -0.0554                  -1.4566
# 27850        0.0585               1.3824                   5.9993
#
#             Player_Season  Score  xScore_Diff         Home_Team   Away_Team  \
# 27846    Oskar Baker_2023    NaN          NaN  Western Bulldogs  West Coast
# 27847    Rhylee West_2023    NaN          NaN  Western Bulldogs  West Coast
# 27848      Rory Lobb_2023    NaN          NaN  Western Bulldogs  West Coast
# 27849  Taylor Duryea_2023    NaN          NaN  Western Bulldogs  West Coast
# 27850    Tim English_2023    NaN          NaN  Western Bulldogs  West Coast
#
#          Opponent  Round Round_str  Round_ID_num
# 27846  West Coast     23        23        202323
# 27847  West Coast     23        23        202323
# 27848  West Coast     23        23        202323
# 27849  West Coast     23        23        202323
# 27850  West Coast     23        23        202323

# %% [markdown]
# Pre-Season

# %%
def get_previous_round_id(round_id):
    
    finals_round_map = {'F1':24,
                        'F2':25,
                        'F3':26,
                        'F4':27}
    
    season = round_id[:4]
    if 'F' in round_id:
        round_num = finals_round_map[round_id[4:]]
    else:
        round_num = round_id[4:]
    
    previous_round_num = int(round_num)-1
    previous_round_num = str(previous_round_num).zfill(2)
    if previous_round_num == 1:
        previous_season = int(season) - 1
    else:
        previous_season = season
    previous_round_id = str(previous_season) + str(previous_round_num)
    
    return previous_round_id

# %%
round_id = "2022F1"
season = round_id[:4]
if 'F' in round_id:
    round_num = finals_round_map[round_id[4:]]
else:
    round_num = round_id[4:]

previous_round_num = int(round_num)-1
previous_round_num = str(previous_round_num).zfill(2)
if previous_round_num == 1:
    previous_season = int(season) - 1
else:
    previous_season = season
previous_round_id = str(previous_season) + str(previous_round_num)

# %%
def get_score_standard_deviation(data):
    return data.groupby(['Match_ID', 'Team']).sum()['Score'].std()

# %%
def create_team_summary(player_stats, rounds = None):
    
    player_stats_copy = player_stats.copy()
    
    if rounds is not None:
        all_rounds = sorted(list(set(player_stats_copy['Round_ID'])))
        rating_rounds = all_rounds[-rounds:]
        player_stats_copy = player_stats_copy[player_stats_copy['Round_ID'].isin(rating_rounds)]
    
    team_for = player_stats_copy.groupby(['Team']).sum()[['Score', 'xScore','vaep_value', 'vaep_value_received', 'offensive_value', 'defensive_value', 'exp_vaep_value', 'exp_vaep_value_received', 'exp_offensive_value', 'exp_defensive_value']]
    team_for.columns = [x+"_F" for x in list(team_for)]
    team_against = player_stats_copy.groupby(['Opponent']).sum()[['Score', 'xScore', 'vaep_value', 'vaep_value_received', 'offensive_value', 'defensive_value', 'exp_vaep_value', 'exp_vaep_value_received', 'exp_offensive_value', 'exp_defensive_value']]
    team_against.columns = [x+"_A" for x in list(team_against)]
    team_games = player_stats_copy.groupby(['Match_ID', 'Team']).size().reset_index().groupby(['Team']).count()[['Match_ID']]
    team_games.columns = ['Games']
    team_summary = pd.concat([team_games, team_for, team_against], axis=1)
    
    for col in [x.replace("_F", "") for x in list(team_for)]:
        team_summary[col+"_pergame_F"] = team_summary[col+"_F"] / team_summary["Games"]
        team_summary[col+"_pergame_A"] = team_summary[col+"_A"] / team_summary["Games"]

        team_summary[col+"_diff"] = team_summary[col+"_F"] - team_summary[col+"_A"]
        team_summary[col+"_pergame_diff"] = team_summary[col+"_pergame_F"] - team_summary[col+"_pergame_A"]

    return team_summary

# %%
def get_teams(match_id):
    
    home_team = re.sub(r"\B([A-Z])", r" \1", match_id.split("_")[1])
    away_team = re.sub(r"\B([A-Z])", r" \1", match_id.split("_")[-1])

    return home_team, away_team

# %%
def calculate_match_projections(home_attack_rating, home_defence_rating, away_attack_rating, away_defence_rating):
    
    home_projected_score = (home_attack_rating + away_defence_rating)*0.5
    away_projected_score = (home_defence_rating + away_attack_rating)*0.5
    projected_margin = home_projected_score - away_projected_score
    
    return home_projected_score, away_projected_score, projected_margin

# %%
def get_match_ratings(team_summary, home_team, away_team):
    
    match_ratings_dict = {'home_attack_rating':team_summary.loc[home_team]['exp_vaep_value_pergame_F'],
                          'home_defence_rating':team_summary.loc[home_team]['exp_vaep_value_pergame_A'],
                          'away_attack_rating':team_summary.loc[away_team]['exp_vaep_value_pergame_F'],
                          'away_defence_rating':team_summary.loc[away_team]['exp_vaep_value_pergame_A']}
    
    return match_ratings_dict

# %%
def calculate_projected_probabilities(home_projected_score, away_projected_score, score_std=25):
    
    projected_margin = home_projected_score - away_projected_score
    projected_margin_distribution = stats.norm(loc = projected_margin, scale = score_std)
    
    away_team_win_probability = projected_margin_distribution.cdf(0)
    draw_probability = projected_margin_distribution.pdf(0)
    home_team_win_probability = 1 - away_team_win_probability - draw_probability
    
    return home_team_win_probability, draw_probability, away_team_win_probability

# %%
def get_match_prediction_metrics(projected_margin, margin):
    
    mae = abs(projected_margin - margin)
    mse = ((projected_margin)**2 + (margin)**2)
    rmse = ((projected_margin)**2 + (margin)**2)**0.5
    
    return mae, mse, rmse

# %%
def get_match_result(data, match_id):
    
    home_team, away_team = get_teams(match_id)
    match_player_stats = data[data['Match_ID'] == match_id]
    match_score = match_player_stats.groupby('Team').sum()[['Score', 'xScore']]
    home_score, home_xscore = match_score.loc[home_team]['Score'], match_score.loc[home_team]['xScore']
    away_score, away_xscore = match_score.loc[away_team]['Score'], match_score.loc[away_team]['xScore']
    margin, xmargin = home_score - away_score, home_xscore - away_xscore
    
    return home_score, away_score, margin

# %%
def calculate_match_projection_error(player_stats, match_id, match_ratings_dict, score_std = 25):
    
    home_projected_score, away_projected_score, projected_margin = calculate_match_projections(match_ratings_dict['home_attack_rating'], 
                                                                             match_ratings_dict['home_defence_rating'], 
                                                                             match_ratings_dict['away_attack_rating'], 
                                                                             match_ratings_dict['away_defence_rating'])
    
    home_team_win_probability, draw_probability, away_team_win_probability = calculate_projected_probabilities(home_projected_score, away_projected_score, score_std)
    home_score, away_score, margin = get_match_result(player_stats, match_id)
    
    mae, mse, rmse = get_match_prediction_metrics(projected_margin, margin)
    
    return mae, mse, rmse

# %%
def get_latest_rounds(round_id, player_stats, rounds):
    
    all_rounds = sorted(list(set(player_stats['Round_ID'])))
    rating_rounds = all_rounds[all_rounds.index(round_id)-rounds:all_rounds.index(round_id)]
    player_stats_latest = player_stats[player_stats['Round_ID'].isin(rating_rounds)]
    
    return player_stats_latest

# %%
def update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae):
    
    previous_round_id = get_previous_round_id(round_id)
    player_stats_latest = get_latest_rounds(round_id, player_stats, rounds)
    team_summary = create_team_summary(player_stats_latest, rounds = rounds)
    team_summary = team_summary[['exp_vaep_value_pergame_F', 'exp_vaep_value_pergame_A', 'exp_vaep_value_pergame_diff']]

    round_projection_dict[round_id] = create_round_match_projections(player_stats, team_summary, round_id)
    round_mae[round_id] = np.mean(np.array(list({v['MAE'] for (k, v) in round_projection_dict[round_id].items()})))
    print("Round MAE: {}".format(round_mae[round_id]))
    print("Overall MAE: {}".format(np.mean(np.array(list(round_mae.values())))))
    return team_summary.sort_values('exp_vaep_value_pergame_diff', ascending = False)

# %%
def create_round_match_projections(player_stats, team_summary, round_id):
    
    player_stats_round = player_stats[player_stats['Round_ID'] == round_id]
    match_id_list = list(player_stats_round['Match_ID'].unique())

    match_projection_dict = {}
    for match_id in match_id_list:
        home_team, away_team = get_teams(match_id)
        match_ratings_dict = get_match_ratings(team_summary, home_team, away_team)
        home_projected_score, away_projected_score, projected_margin = calculate_match_projections(match_ratings_dict['home_attack_rating'], 
                                                                                                    match_ratings_dict['home_defence_rating'], 
                                                                                                    match_ratings_dict['away_attack_rating'], 
                                                                                                    match_ratings_dict['away_defence_rating'])
        home_team_win_probability, draw_probability, away_team_win_probability = calculate_projected_probabilities(home_projected_score, away_projected_score, score_std)
        home_score, away_score, margin = get_match_result(player_stats_round, match_id)
        mae, mse, rmse = calculate_match_projection_error(player_stats_round, match_id, match_ratings_dict, score_std = 25)

        match_projection_dict[match_id] = {}
        if home_projected_score > away_projected_score:
            match_projection_dict[match_id]['tip'] = home_team
            match_projection_dict[match_id]['projected_prob'] = home_team_win_probability
        else:
            match_projection_dict[match_id]['tip'] = away_team
            match_projection_dict[match_id]['projected_prob'] = away_team_win_probability
        match_projection_dict[match_id]['projected_margin'] = abs(projected_margin)
        if home_score > away_score:
            match_projection_dict[match_id]['result'] = home_team
        else:
            match_projection_dict[match_id]['result'] = away_team
        match_projection_dict[match_id]['actual_margin'] = abs(margin)   
        match_projection_dict[match_id]['MAE'] = mae
    
    return match_projection_dict

# %%
score_std = get_score_standard_deviation(player_stats)

# %%
round_projection_dict = {}
round_mae = {}
rounds = 10

# %% [markdown]
# 202201

# %%
round_id = '202201'
player_stats_latest = player_stats[player_stats['Season'] == 2021]
team_summary = create_team_summary(player_stats_latest, rounds = rounds)
team_summary = team_summary[['exp_vaep_value_pergame_F', 'exp_vaep_value_pergame_A', 'exp_vaep_value_pergame_diff']]

round_projection_dict[round_id] = create_round_match_projections(player_stats, team_summary, round_id)
round_mae[round_id] = np.mean(np.array(list({v['MAE'] for (k, v) in round_projection_dict[round_id].items()})))
print("Round MAE: {}".format(round_mae[round_id]))
print("Overall MAE: {}".format(np.mean(np.array(list(round_mae.values())))))
team_summary.sort_values('exp_vaep_value_pergame_diff', ascending = False)
# Out:
# Round MAE: 23.52035197400336
# Overall MAE: 23.52035197400336
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Melbourne                               123.4076                   88.3974
# Brisbane Lions                          135.4402                  113.9884
# Port Adelaide                           115.7847                   97.4364
# Sydney                                  116.0347                  101.4422
# Geelong                                 108.2664                  100.1929
# Essendon                                114.8386                  110.3172
# Richmond                                106.1284                  104.3544
# St Kilda                                100.4031                   99.0970
# Western Bulldogs                        106.3053                  105.4237
# Greater Western Sydney                  112.6354                  112.6492
# Hawthorn                                107.5690                  111.4751
# West Coast                              101.6390                  106.1025
# Adelaide                                105.3562                  114.1126
# Carlton                                 106.3812                  121.8260
# Collingwood                              96.0505                  115.0574
# North Melbourne                          92.3163                  116.5193
# Fremantle                                84.0943                  116.6048
# Gold Coast                               95.5595                  131.7914
#
#                         exp_vaep_value_pergame_diff
# Melbourne                                   35.0102
# Brisbane Lions                              21.4518
# Port Adelaide                               18.3483
# Sydney                                      14.5925
# Geelong                                      8.0735
# Essendon                                     4.5214
# Richmond                                     1.7740
# St Kilda                                     1.3061
# Western Bulldogs                             0.8816
# Greater Western Sydney                      -0.0139
# Hawthorn                                    -3.9060
# West Coast                                  -4.4636
# Adelaide                                    -8.7564
# Carlton                                    -15.4447
# Collingwood                                -19.0069
# North Melbourne                            -24.2030
# Fremantle                                  -32.5104
# Gold Coast                                 -36.2318

# %%
round_id = '202202'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 27.726401068808514
# Overall MAE: 25.623376521405937
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Melbourne                               125.8118                   88.0446
# Brisbane Lions                          134.2051                  109.9072
# Sydney                                  119.9734                  104.2079
# Port Adelaide                           112.6901                   98.9718
# Geelong                                 109.4059                  103.4612
# St Kilda                                102.1498                   99.3261
# Hawthorn                                110.0446                  107.8808
# Greater Western Sydney                  115.0554                  116.0956
# Western Bulldogs                        105.3058                  106.8299
# Adelaide                                110.3438                  113.0838
# Richmond                                100.4664                  103.2096
# Essendon                                112.7721                  116.3820
# Collingwood                             100.6682                  112.0572
# Carlton                                 104.1834                  121.8679
# Fremantle                                94.0589                  114.9741
# West Coast                               93.6177                  115.0154
# North Melbourne                          90.6422                  115.6822
# Gold Coast                              100.0377                  129.6262
#
#                         exp_vaep_value_pergame_diff
# Melbourne                                   37.7673
# Brisbane Lions                              24.2979
# Sydney                                      15.7655
# Port Adelaide                               13.7183
# Geelong                                      5.9447
# St Kilda                                     2.8237
# Hawthorn                                     2.1638
# Greater Western Sydney                      -1.0402
# Western Bulldogs                            -1.5241
# Adelaide                                    -2.7399
# Richmond                                    -2.7433
# Essendon                                    -3.6099
# Collingwood                                -11.3890
# Carlton                                    -17.6844
# Fremantle                                  -20.9152
# West Coast                                 -21.3977
# North Melbourne                            -25.0400
# Gold Coast                                 -29.5885

# %%
round_id = '202203'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 28.44490032573428
# Overall MAE: 26.563884456182052
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Melbourne                               125.1826                   87.8133
# Brisbane Lions                          129.1236                  111.6696
# Sydney                                  115.7264                  104.3061
# Port Adelaide                           113.5659                  104.6049
# St Kilda                                101.9997                   94.1166
# Hawthorn                                112.5976                  107.1431
# Geelong                                 108.7158                  104.5373
# Richmond                                107.9190                  104.1145
# Western Bulldogs                        107.3850                  107.0828
# Collingwood                             106.5877                  108.0805
# Essendon                                115.3722                  117.4174
# Greater Western Sydney                  115.4128                  120.9203
# Adelaide                                104.4618                  114.0455
# Fremantle                                90.8751                  109.2042
# Carlton                                 104.1176                  123.6421
# Gold Coast                              100.4705                  120.5169
# North Melbourne                          91.1444                  115.1644
# West Coast                               92.9574                  118.7425
#
#                         exp_vaep_value_pergame_diff
# Melbourne                                   37.3693
# Brisbane Lions                              17.4540
# Sydney                                      11.4203
# Port Adelaide                                8.9610
# St Kilda                                     7.8831
# Hawthorn                                     5.4545
# Geelong                                      4.1785
# Richmond                                     3.8044
# Western Bulldogs                             0.3022
# Collingwood                                 -1.4928
# Essendon                                    -2.0452
# Greater Western Sydney                      -5.5075
# Adelaide                                    -9.5838
# Fremantle                                  -18.3291
# Carlton                                    -19.5246
# Gold Coast                                 -20.0465
# North Melbourne                            -24.0200
# West Coast                                 -25.7851

# %% [markdown]
# 202204

# %%
round_id = '202204'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 28.53766370857302
# Overall MAE: 27.057329269279794
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Melbourne                               122.2762                   90.4050
# Brisbane Lions                          136.5118                  107.3656
# St Kilda                                108.8364                   95.4277
# Port Adelaide                           114.6902                  106.4009
# Sydney                                  112.7667                  107.4388
# Hawthorn                                110.2474                  105.8159
# Western Bulldogs                        108.7919                  107.9863
# Greater Western Sydney                  118.8821                  119.7366
# Geelong                                 108.4438                  110.1188
# Richmond                                109.8456                  114.2866
# Collingwood                             109.9390                  114.7870
# Adelaide                                110.8151                  115.6811
# Essendon                                111.6642                  119.0940
# Gold Coast                              108.5522                  117.8269
# Fremantle                                97.6499                  107.1793
# Carlton                                 108.2728                  125.6050
# West Coast                               93.4185                  120.6215
# North Melbourne                          93.1795                  126.4849
#
#                         exp_vaep_value_pergame_diff
# Melbourne                                   31.8712
# Brisbane Lions                              29.1462
# St Kilda                                    13.4087
# Port Adelaide                                8.2893
# Sydney                                       5.3279
# Hawthorn                                     4.4315
# Western Bulldogs                             0.8056
# Greater Western Sydney                      -0.8546
# Geelong                                     -1.6750
# Richmond                                    -4.4409
# Collingwood                                 -4.8481
# Adelaide                                    -4.8660
# Essendon                                    -7.4298
# Gold Coast                                  -9.2746
# Fremantle                                   -9.5294
# Carlton                                    -17.3322
# West Coast                                 -27.2030
# North Melbourne                            -33.3054

# %% [markdown]
# 202205

# %%
round_id = '202205'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 28.597258902531948
# Overall MAE: 27.365315195930226
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Melbourne                               122.3176                   90.4845
# Brisbane Lions                          128.9047                  110.1383
# St Kilda                                111.5495                   97.0796
# Sydney                                  117.3378                  107.0018
# Fremantle                               103.7744                   97.0980
# Port Adelaide                           109.2234                  105.3548
# Geelong                                 107.1785                  106.4692
# Collingwood                             112.8439                  112.2399
# Hawthorn                                109.2801                  110.5611
# Adelaide                                113.5601                  115.4926
# Essendon                                112.0052                  115.3321
# Western Bulldogs                        104.7966                  108.5483
# Greater Western Sydney                  114.8226                  120.1338
# Gold Coast                              112.0341                  118.9550
# Richmond                                110.4789                  118.8192
# Carlton                                 109.4009                  129.0869
# West Coast                               98.2138                  126.3248
# North Melbourne                         100.1008                  129.4157
#
#                         exp_vaep_value_pergame_diff
# Melbourne                                   31.8331
# Brisbane Lions                              18.7663
# St Kilda                                    14.4699
# Sydney                                      10.3360
# Fremantle                                    6.6764
# Port Adelaide                                3.8686
# Geelong                                      0.7092
# Collingwood                                  0.6040
# Hawthorn                                    -1.2810
# Adelaide                                    -1.9325
# Essendon                                    -3.3269
# Western Bulldogs                            -3.7516
# Greater Western Sydney                      -5.3113
# Gold Coast                                  -6.9209
# Richmond                                    -8.3403
# Carlton                                    -19.6860
# West Coast                                 -28.1110
# North Melbourne                            -29.3150

# %% [markdown]
# 202206

# %%
round_id = '202206'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 24.6257061743883
# Overall MAE: 26.908713692339905
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Melbourne                               122.4691                   90.0269
# St Kilda                                113.2081                   92.7274
# Sydney                                  119.6761                  103.7942
# Brisbane Lions                          125.8105                  111.0756
# Fremantle                               108.3221                   96.0373
# Collingwood                             114.0936                  108.1143
# Western Bulldogs                        114.2921                  109.7454
# Adelaide                                114.6619                  113.1992
# Gold Coast                              109.5245                  109.4663
# Geelong                                 110.6388                  111.7656
# Richmond                                113.6062                  115.5151
# Hawthorn                                113.4049                  119.3446
# Port Adelaide                           103.8403                  109.9878
# Carlton                                 115.5783                  121.9094
# Greater Western Sydney                  111.0032                  124.3698
# Essendon                                104.3701                  119.7564
# North Melbourne                         102.6160                  138.8451
# West Coast                               94.4709                  133.0848
#
#                         exp_vaep_value_pergame_diff
# Melbourne                                   32.4422
# St Kilda                                    20.4806
# Sydney                                      15.8819
# Brisbane Lions                              14.7349
# Fremantle                                   12.2849
# Collingwood                                  5.9793
# Western Bulldogs                             4.5467
# Adelaide                                     1.4627
# Gold Coast                                   0.0582
# Geelong                                     -1.1268
# Richmond                                    -1.9088
# Hawthorn                                    -5.9398
# Port Adelaide                               -6.1475
# Carlton                                     -6.3312
# Greater Western Sydney                     -13.3665
# Essendon                                   -15.3862
# North Melbourne                            -36.2291
# West Coast                                 -38.6138

# %% [markdown]
# 202207

# %%
round_id = '202207'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 33.639892974686916
# Overall MAE: 27.870310732675193
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Melbourne                               124.5965                   85.8894
# Fremantle                               117.7547                   96.0683
# St Kilda                                116.2285                   97.2051
# Sydney                                  122.0146                  106.4469
# Brisbane Lions                          125.3999                  111.7856
# Collingwood                             114.9515                  105.4291
# Gold Coast                              118.8155                  112.1976
# Geelong                                 116.2979                  110.9842
# Western Bulldogs                        116.0308                  112.8973
# Adelaide                                113.9635                  115.6820
# Port Adelaide                           106.0148                  108.2520
# Carlton                                 115.2622                  120.6288
# Hawthorn                                110.7801                  123.1022
# Richmond                                103.3192                  117.0545
# Essendon                                102.0686                  120.4918
# Greater Western Sydney                  106.3266                  126.3748
# North Melbourne                         104.8510                  141.4710
# West Coast                               84.0581                  127.5065
#
#                         exp_vaep_value_pergame_diff
# Melbourne                                   38.7071
# Fremantle                                   21.6864
# St Kilda                                    19.0234
# Sydney                                      15.5677
# Brisbane Lions                              13.6143
# Collingwood                                  9.5224
# Gold Coast                                   6.6179
# Geelong                                      5.3136
# Western Bulldogs                             3.1334
# Adelaide                                    -1.7184
# Port Adelaide                               -2.2372
# Carlton                                     -5.3665
# Hawthorn                                   -12.3221
# Richmond                                   -13.7353
# Essendon                                   -18.4232
# Greater Western Sydney                     -20.0482
# North Melbourne                            -36.6199
# West Coast                                 -43.4484

# %% [markdown]
# 202208

# %%
round_id = '202208'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 31.59158219105568
# Overall MAE: 28.335469664972752
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Melbourne                               122.9116                   86.2584
# Fremantle                               116.6902                   96.2498
# Brisbane Lions                          126.4140                  108.4694
# St Kilda                                117.4868                   99.9511
# Collingwood                             118.2939                  105.5720
# Sydney                                  120.1013                  110.6300
# Geelong                                 116.9446                  109.2015
# Carlton                                 122.3204                  117.5004
# Western Bulldogs                        117.2484                  112.9848
# Richmond                                114.5101                  111.0113
# Gold Coast                              117.0460                  115.9334
# Adelaide                                110.8679                  117.4667
# Port Adelaide                           104.7747                  112.4418
# Hawthorn                                111.9864                  123.3921
# Greater Western Sydney                  110.5067                  122.0165
# Essendon                                102.1936                  122.2312
# North Melbourne                         103.9766                  144.7850
# West Coast                               82.7286                  135.2421
#
#                         exp_vaep_value_pergame_diff
# Melbourne                                   36.6532
# Fremantle                                   20.4404
# Brisbane Lions                              17.9445
# St Kilda                                    17.5358
# Collingwood                                 12.7220
# Sydney                                       9.4713
# Geelong                                      7.7431
# Carlton                                      4.8200
# Western Bulldogs                             4.2636
# Richmond                                     3.4988
# Gold Coast                                   1.1126
# Adelaide                                    -6.5988
# Port Adelaide                               -7.6671
# Hawthorn                                   -11.4058
# Greater Western Sydney                     -11.5098
# Essendon                                   -20.0376
# North Melbourne                            -40.8084
# West Coast                                 -52.5135

# %% [markdown]
# 202209

# %%
round_id = '202209'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 29.653987611963277
# Overall MAE: 28.481971659082813
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Melbourne                               122.4363                   87.2306
# Fremantle                               120.1344                   93.7931
# Brisbane Lions                          129.7298                  106.3181
# St Kilda                                114.7985                  102.2271
# Collingwood                             119.3787                  109.2155
# Carlton                                 125.3162                  115.4519
# Geelong                                 117.2311                  108.9655
# Sydney                                  117.3043                  111.4060
# Richmond                                117.0363                  113.0063
# Gold Coast                              117.0200                  113.6574
# Western Bulldogs                        117.3619                  114.7056
# Port Adelaide                           107.8739                  111.7661
# Adelaide                                109.6484                  121.0691
# Greater Western Sydney                  110.2413                  122.3389
# Hawthorn                                113.0454                  125.7602
# Essendon                                107.2115                  122.0096
# North Melbourne                         100.5541                  144.7175
# West Coast                               83.3895                  136.0851
#
#                         exp_vaep_value_pergame_diff
# Melbourne                                   35.2057
# Fremantle                                   26.3413
# Brisbane Lions                              23.4116
# St Kilda                                    12.5715
# Collingwood                                 10.1632
# Carlton                                      9.8642
# Geelong                                      8.2656
# Sydney                                       5.8983
# Richmond                                     4.0300
# Gold Coast                                   3.3626
# Western Bulldogs                             2.6563
# Port Adelaide                               -3.8923
# Adelaide                                   -11.4207
# Greater Western Sydney                     -12.0976
# Hawthorn                                   -12.7148
# Essendon                                   -14.7981
# North Melbourne                            -44.1633
# West Coast                                 -52.6957

# %% [markdown]
# 202210

# %%
round_id = '202210'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 19.57648712774609
# Overall MAE: 27.591423205949138
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Melbourne                               120.9738                   86.5037
# Fremantle                               117.7525                   94.5237
# Brisbane Lions                          127.6706                  106.1241
# St Kilda                                118.0046                  103.0290
# Carlton                                 126.9440                  113.8307
# Geelong                                 121.2482                  109.3814
# Sydney                                  120.2743                  109.8400
# Richmond                                119.2237                  111.6708
# Port Adelaide                           112.9358                  105.9326
# Collingwood                             116.2583                  112.2789
# Gold Coast                              115.1699                  111.9952
# Western Bulldogs                        118.6522                  115.5164
# Adelaide                                109.0844                  119.9722
# Greater Western Sydney                  109.1990                  124.2975
# Hawthorn                                111.7055                  126.9783
# Essendon                                106.1116                  124.4568
# North Melbourne                          97.3127                  142.9427
# West Coast                               81.4598                  134.8850
#
#                         exp_vaep_value_pergame_diff
# Melbourne                                   34.4701
# Fremantle                                   23.2288
# Brisbane Lions                              21.5464
# St Kilda                                    14.9755
# Carlton                                     13.1133
# Geelong                                     11.8668
# Sydney                                      10.4343
# Richmond                                     7.5529
# Port Adelaide                                7.0032
# Collingwood                                  3.9794
# Gold Coast                                   3.1747
# Western Bulldogs                             3.1358
# Adelaide                                   -10.8878
# Greater Western Sydney                     -15.0985
# Hawthorn                                   -15.2728
# Essendon                                   -18.3452
# North Melbourne                            -45.6300
# West Coast                                 -53.4253

# %% [markdown]
# 202211

# %%
round_id = '202211'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 28.494068521476454
# Overall MAE: 27.673481870997076
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Melbourne                               119.1144                   85.3909
# Brisbane Lions                          128.9624                  110.7134
# Fremantle                               115.3522                   97.4144
# Carlton                                 129.6215                  115.6124
# Geelong                                 121.5159                  107.7885
# Richmond                                121.2206                  109.0507
# Western Bulldogs                        125.4488                  113.5035
# St Kilda                                115.6959                  104.7312
# Sydney                                  121.4116                  114.2279
# Collingwood                             116.9755                  110.4259
# Port Adelaide                           110.9874                  107.7319
# Gold Coast                              114.6632                  115.5186
# Adelaide                                110.1810                  117.4668
# Greater Western Sydney                  113.7429                  122.8981
# Hawthorn                                115.7366                  128.3394
# Essendon                                104.0474                  125.9303
# North Melbourne                          94.3949                  139.8122
# West Coast                               84.3442                  136.8603
#
#                         exp_vaep_value_pergame_diff
# Melbourne                                   33.7236
# Brisbane Lions                              18.2490
# Fremantle                                   17.9377
# Carlton                                     14.0091
# Geelong                                     13.7274
# Richmond                                    12.1699
# Western Bulldogs                            11.9453
# St Kilda                                    10.9647
# Sydney                                       7.1837
# Collingwood                                  6.5496
# Port Adelaide                                3.2556
# Gold Coast                                  -0.8554
# Adelaide                                    -7.2858
# Greater Western Sydney                      -9.1553
# Hawthorn                                   -12.6028
# Essendon                                   -21.8830
# North Melbourne                            -45.4173
# West Coast                                 -52.5162

# %% [markdown]
# 202212

# %%
round_id = '202212'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 19.43019711802407
# Overall MAE: 26.98654147491599
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Melbourne                               114.4917                   87.2458
# Western Bulldogs                        133.6208                  108.3787
# Brisbane Lions                          129.4528                  109.5389
# Fremantle                               113.3112                   93.8662
# St Kilda                                115.6543                  100.8022
# Richmond                                122.5942                  108.6334
# Geelong                                 117.2525                  106.2738
# Collingwood                             118.3913                  109.2465
# Carlton                                 127.9607                  119.7737
# Sydney                                  120.2516                  112.6357
# Port Adelaide                           113.1437                  107.4532
# Gold Coast                              114.1258                  114.4220
# Adelaide                                106.0636                  114.7728
# Greater Western Sydney                  109.7348                  122.3445
# Essendon                                105.5390                  123.1194
# Hawthorn                                112.5376                  133.4032
# North Melbourne                          93.3617                  140.4164
# West Coast                               84.0548                  139.2158
#
#                         exp_vaep_value_pergame_diff
# Melbourne                                   27.2459
# Western Bulldogs                            25.2421
# Brisbane Lions                              19.9139
# Fremantle                                   19.4450
# St Kilda                                    14.8521
# Richmond                                    13.9607
# Geelong                                     10.9787
# Collingwood                                  9.1448
# Carlton                                      8.1870
# Sydney                                       7.6159
# Port Adelaide                                5.6905
# Gold Coast                                  -0.2962
# Adelaide                                    -8.7092
# Greater Western Sydney                     -12.6096
# Essendon                                   -17.5804
# Hawthorn                                   -20.8656
# North Melbourne                            -47.0547
# West Coast                                 -55.1610

# %% [markdown]
# 202213

# %%
round_id = '202213'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 16.624086157692336
# Overall MAE: 26.189429527437248
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Melbourne                               114.0977                   88.1332
# Western Bulldogs                        130.6263                  107.8989
# Fremantle                               118.0987                   96.5243
# Brisbane Lions                          130.1553                  110.7478
# St Kilda                                118.0375                  103.3421
# Richmond                                121.3128                  108.5512
# Geelong                                 117.7945                  105.8800
# Carlton                                 130.1840                  119.1818
# Sydney                                  121.4522                  112.4442
# Gold Coast                              122.4276                  114.4331
# Port Adelaide                           113.5475                  106.0335
# Collingwood                             118.0830                  110.9200
# Adelaide                                109.6319                  111.0518
# Greater Western Sydney                  109.7750                  121.0353
# Essendon                                104.6289                  124.1591
# Hawthorn                                110.0523                  133.2122
# North Melbourne                          91.6018                  148.4170
# West Coast                               80.8782                  138.9015
#
#                         exp_vaep_value_pergame_diff
# Melbourne                                   25.9645
# Western Bulldogs                            22.7274
# Fremantle                                   21.5744
# Brisbane Lions                              19.4075
# St Kilda                                    14.6955
# Richmond                                    12.7616
# Geelong                                     11.9145
# Carlton                                     11.0022
# Sydney                                       9.0080
# Gold Coast                                   7.9944
# Port Adelaide                                7.5141
# Collingwood                                  7.1629
# Adelaide                                    -1.4198
# Greater Western Sydney                     -11.2603
# Essendon                                   -19.5302
# Hawthorn                                   -23.1599
# North Melbourne                            -56.8152
# West Coast                                 -58.0233

# %% [markdown]
# 202214

# %%
round_id = '202214'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 24.426055191826123
# Overall MAE: 26.063474217750734
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Richmond                                125.3694                  103.8648
# Western Bulldogs                        130.4455                  109.8489
# Melbourne                               111.3687                   93.0091
# Fremantle                               120.0361                  101.9300
# Geelong                                 118.6262                  103.8596
# Sydney                                  124.9081                  110.2431
# Brisbane Lions                          124.7612                  111.7871
# Gold Coast                              123.8601                  112.3901
# Carlton                                 128.4711                  117.0449
# Collingwood                             118.9895                  109.4405
# St Kilda                                113.6842                  106.6968
# Port Adelaide                           109.7073                  107.5470
# Adelaide                                108.5428                  109.1688
# Greater Western Sydney                  108.1001                  118.7236
# Essendon                                104.9366                  121.4248
# Hawthorn                                112.1045                  135.3114
# North Melbourne                          91.8707                  142.1236
# West Coast                               81.7717                  141.5317
#
#                         exp_vaep_value_pergame_diff
# Richmond                                    21.5045
# Western Bulldogs                            20.5966
# Melbourne                                   18.3596
# Fremantle                                   18.1061
# Geelong                                     14.7666
# Sydney                                      14.6650
# Brisbane Lions                              12.9741
# Gold Coast                                  11.4700
# Carlton                                     11.4262
# Collingwood                                  9.5490
# St Kilda                                     6.9875
# Port Adelaide                                2.1603
# Adelaide                                    -0.6260
# Greater Western Sydney                     -10.6235
# Essendon                                   -16.4882
# Hawthorn                                   -23.2069
# North Melbourne                            -50.2529
# West Coast                                 -59.7601

# %% [markdown]
# 202215

# %%
round_id = '202215'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 25.19191116347408
# Overall MAE: 26.00537001413229
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Western Bulldogs                        137.0211                  111.6349
# Richmond                                126.0095                  104.4315
# Melbourne                               113.1616                   96.0228
# Brisbane Lions                          129.0802                  112.0006
# Fremantle                               119.5478                  103.6711
# Geelong                                 118.7345                  103.2766
# Carlton                                 128.1758                  114.5109
# Sydney                                  122.5604                  110.3751
# Gold Coast                              123.9611                  112.1627
# Port Adelaide                           115.9391                  108.5630
# Collingwood                             117.8682                  111.1626
# St Kilda                                109.5591                  111.3874
# Adelaide                                107.6640                  112.8031
# Essendon                                109.0641                  119.5275
# Greater Western Sydney                  112.7152                  123.3016
# Hawthorn                                113.0694                  134.7769
# North Melbourne                          88.6581                  143.9699
# West Coast                               80.2941                  139.5050
#
#                         exp_vaep_value_pergame_diff
# Western Bulldogs                            25.3862
# Richmond                                    21.5780
# Melbourne                                   17.1388
# Brisbane Lions                              17.0796
# Fremantle                                   15.8767
# Geelong                                     15.4579
# Carlton                                     13.6649
# Sydney                                      12.1853
# Gold Coast                                  11.7984
# Port Adelaide                                7.3761
# Collingwood                                  6.7056
# St Kilda                                    -1.8283
# Adelaide                                    -5.1391
# Essendon                                   -10.4634
# Greater Western Sydney                     -10.5864
# Hawthorn                                   -21.7075
# North Melbourne                            -55.3119
# West Coast                                 -59.2109

# %% [markdown]
# 202216

# %%
round_id = '202216'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 22.477962969050324
# Overall MAE: 25.784907073814672
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Western Bulldogs                        133.6158                  110.6242
# Richmond                                124.7133                  104.7539
# Melbourne                               114.1572                   95.2178
# Geelong                                 116.1510                  100.9848
# Carlton                                 129.3447                  115.1700
# Gold Coast                              131.8410                  118.1067
# Collingwood                             120.6362                  107.9951
# Fremantle                               120.0280                  109.0630
# Sydney                                  120.5699                  110.3710
# Brisbane Lions                          125.0679                  115.8654
# Port Adelaide                           118.4383                  110.3420
# Adelaide                                109.9159                  111.1559
# Essendon                                111.3378                  118.3959
# St Kilda                                108.1543                  115.9859
# Greater Western Sydney                  112.7549                  123.2005
# Hawthorn                                110.6390                  136.0665
# North Melbourne                          87.4350                  138.6210
# West Coast                               84.1869                  137.0676
#
#                         exp_vaep_value_pergame_diff
# Western Bulldogs                            22.9916
# Richmond                                    19.9594
# Melbourne                                   18.9394
# Geelong                                     15.1662
# Carlton                                     14.1746
# Gold Coast                                  13.7343
# Collingwood                                 12.6411
# Fremantle                                   10.9650
# Sydney                                      10.1989
# Brisbane Lions                               9.2025
# Port Adelaide                                8.0963
# Adelaide                                    -1.2399
# Essendon                                    -7.0580
# St Kilda                                    -7.8316
# Greater Western Sydney                     -10.4456
# Hawthorn                                   -25.4275
# North Melbourne                            -51.1861
# West Coast                                 -52.8807

# %% [markdown]
# 202217

# %%
round_id = '202217'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 32.20502810913804
# Overall MAE: 26.162561252363105
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Richmond                                130.8763                  103.7870
# Western Bulldogs                        135.1655                  110.6843
# Geelong                                 116.2950                   96.3323
# Carlton                                 132.5798                  112.8799
# Melbourne                               113.4240                   96.5798
# Collingwood                             123.7734                  108.3968
# Gold Coast                              129.2741                  115.3906
# Brisbane Lions                          123.3434                  113.3168
# Fremantle                               119.8702                  110.9418
# Sydney                                  117.9232                  111.9431
# Port Adelaide                           118.7393                  117.8975
# Greater Western Sydney                  115.1339                  122.3913
# Adelaide                                103.6975                  113.1662
# Essendon                                111.7478                  121.6005
# St Kilda                                107.4651                  118.9305
# Hawthorn                                112.4999                  133.8064
# West Coast                               89.4383                  137.2195
# North Melbourne                          82.7824                  138.7651
#
#                         exp_vaep_value_pergame_diff
# Richmond                                    27.0894
# Western Bulldogs                            24.4812
# Geelong                                     19.9628
# Carlton                                     19.6998
# Melbourne                                   16.8442
# Collingwood                                 15.3767
# Gold Coast                                  13.8835
# Brisbane Lions                              10.0265
# Fremantle                                    8.9285
# Sydney                                       5.9801
# Port Adelaide                                0.8418
# Greater Western Sydney                      -7.2574
# Adelaide                                    -9.4687
# Essendon                                    -9.8527
# St Kilda                                   -11.4654
# Hawthorn                                   -21.3064
# West Coast                                 -47.7811
# North Melbourne                            -55.9826

# %% [markdown]
# 202218

# %%
round_id = '202218'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 22.4882418745474
# Overall MAE: 25.95843239804001
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Geelong                                 120.2167                   93.3920
# Carlton                                 129.8192                  110.5894
# Western Bulldogs                        131.8562                  113.2774
# Richmond                                126.0799                  107.8980
# Gold Coast                              129.8653                  115.4060
# Collingwood                             124.0543                  110.3918
# Melbourne                               108.8361                   98.0697
# Fremantle                               122.2298                  111.7497
# Sydney                                  119.8002                  109.8547
# Brisbane Lions                          121.0212                  114.3193
# Port Adelaide                           115.9197                  111.6567
# Essendon                                113.4665                  118.0575
# Adelaide                                104.4202                  112.8991
# Greater Western Sydney                  108.5444                  122.2532
# St Kilda                                105.1954                  120.6096
# Hawthorn                                113.2273                  130.8803
# West Coast                               89.8120                  132.5716
# North Melbourne                          85.6329                  136.1214
#
#                         exp_vaep_value_pergame_diff
# Geelong                                     26.8246
# Carlton                                     19.2299
# Western Bulldogs                            18.5788
# Richmond                                    18.1820
# Gold Coast                                  14.4593
# Collingwood                                 13.6624
# Melbourne                                   10.7664
# Fremantle                                   10.4801
# Sydney                                       9.9455
# Brisbane Lions                               6.7019
# Port Adelaide                                4.2630
# Essendon                                    -4.5910
# Adelaide                                    -8.4789
# Greater Western Sydney                     -13.7087
# St Kilda                                   -15.4142
# Hawthorn                                   -17.6530
# West Coast                                 -42.7596
# North Melbourne                            -50.4884

# %% [markdown]
# 202219

# %%
round_id = '202219'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 13.404454033702088
# Overall MAE: 25.297696694653805
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Geelong                                 116.4679                   90.0844
# Western Bulldogs                        129.2956                  108.3587
# Richmond                                126.3511                  106.2739
# Collingwood                             122.3393                  107.8948
# Sydney                                  121.7845                  107.8354
# Carlton                                 121.0804                  110.5806
# Melbourne                               106.9528                   98.9554
# Brisbane Lions                          119.1379                  114.0750
# Gold Coast                              127.3123                  122.9146
# Port Adelaide                           112.7291                  111.0844
# Fremantle                               117.1653                  116.0816
# Essendon                                116.0182                  115.1021
# Adelaide                                105.6573                  109.0382
# St Kilda                                104.3530                  116.7381
# Hawthorn                                112.7869                  125.8741
# Greater Western Sydney                  107.2567                  121.1715
# West Coast                               90.8415                  129.7392
# North Melbourne                          89.6061                  135.3342
#
#                         exp_vaep_value_pergame_diff
# Geelong                                     26.3835
# Western Bulldogs                            20.9369
# Richmond                                    20.0771
# Collingwood                                 14.4445
# Sydney                                      13.9491
# Carlton                                     10.4998
# Melbourne                                    7.9974
# Brisbane Lions                               5.0630
# Gold Coast                                   4.3977
# Port Adelaide                                1.6447
# Fremantle                                    1.0838
# Essendon                                     0.9160
# Adelaide                                    -3.3808
# St Kilda                                   -12.3850
# Hawthorn                                   -13.0872
# Greater Western Sydney                     -13.9148
# West Coast                                 -38.8977
# North Melbourne                            -45.7281

# %% [markdown]
# 202220

# %%
round_id = '202220'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 25.196197262236012
# Overall MAE: 25.292621723032916
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Geelong                                 116.3349                   86.5117
# Collingwood                             122.2014                  104.1304
# Richmond                                122.9217                  106.3149
# Western Bulldogs                        127.7868                  111.5141
# Sydney                                  123.0184                  109.7056
# Carlton                                 119.9438                  109.7168
# Essendon                                116.6398                  109.1043
# Brisbane Lions                          119.3115                  114.6494
# Gold Coast                              128.3538                  124.4770
# Melbourne                               106.3316                  105.3093
# Fremantle                               117.4607                  116.6917
# Port Adelaide                           110.8128                  115.1806
# Adelaide                                106.7208                  113.9206
# Hawthorn                                113.7775                  122.2419
# Greater Western Sydney                  106.3929                  120.0348
# St Kilda                                 99.6077                  113.6740
# West Coast                               92.6022                  127.0347
# North Melbourne                          93.2342                  133.2406
#
#                         exp_vaep_value_pergame_diff
# Geelong                                     29.8232
# Collingwood                                 18.0710
# Richmond                                    16.6069
# Western Bulldogs                            16.2727
# Sydney                                      13.3128
# Carlton                                     10.2270
# Essendon                                     7.5355
# Brisbane Lions                               4.6621
# Gold Coast                                   3.8768
# Melbourne                                    1.0223
# Fremantle                                    0.7690
# Port Adelaide                               -4.3678
# Adelaide                                    -7.1998
# Hawthorn                                    -8.4645
# Greater Western Sydney                     -13.6420
# St Kilda                                   -14.0664
# West Coast                                 -34.4326
# North Melbourne                            -40.0064

# %% [markdown]
# 202221

# %%
round_id = '202221'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 22.21307543994119
# Overall MAE: 25.14597666193331
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Geelong                                 113.7901                   84.9859
# Sydney                                  123.4533                   99.8436
# Collingwood                             121.0980                  105.9685
# Essendon                                121.4552                  106.6501
# Richmond                                121.2093                  110.9207
# Western Bulldogs                        120.2858                  110.5052
# Gold Coast                              128.6282                  120.4633
# Brisbane Lions                          117.7929                  111.5120
# Carlton                                 113.4150                  108.1173
# Fremantle                               117.3553                  116.9982
# Melbourne                               107.9485                  108.0500
# Port Adelaide                           112.6839                  114.0222
# Adelaide                                106.4100                  113.9253
# St Kilda                                102.7278                  110.5071
# Hawthorn                                107.0587                  120.2875
# Greater Western Sydney                   96.4288                  122.8413
# West Coast                               92.6914                  122.3608
# North Melbourne                          98.6754                  135.1484
#
#                         exp_vaep_value_pergame_diff
# Geelong                                     28.8042
# Sydney                                      23.6097
# Collingwood                                 15.1295
# Essendon                                    14.8051
# Richmond                                    10.2886
# Western Bulldogs                             9.7807
# Gold Coast                                   8.1649
# Brisbane Lions                               6.2809
# Carlton                                      5.2977
# Fremantle                                    0.3571
# Melbourne                                   -0.1015
# Port Adelaide                               -1.3383
# Adelaide                                    -7.5153
# St Kilda                                    -7.7793
# Hawthorn                                   -13.2288
# Greater Western Sydney                     -26.4125
# West Coast                                 -29.6694
# North Melbourne                            -36.4730

# %% [markdown]
# 202222

# %%
round_id = '202222'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 27.719704940809788
# Overall MAE: 25.262964310973153
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Geelong                                 115.2801                   83.4021
# Sydney                                  124.6125                   98.7567
# Richmond                                123.6461                  108.3845
# Essendon                                118.1946                  106.5288
# Collingwood                             118.9019                  109.3265
# Carlton                                 114.1583                  107.7275
# Brisbane Lions                          118.9673                  114.4172
# Melbourne                               112.8132                  108.8229
# Western Bulldogs                        113.4917                  112.4500
# Gold Coast                              122.6973                  123.4309
# Fremantle                               116.5847                  119.3806
# Hawthorn                                110.0263                  114.3566
# Adelaide                                107.8138                  113.5234
# Port Adelaide                           109.9906                  115.7802
# St Kilda                                 97.7406                  114.2412
# Greater Western Sydney                  100.0083                  118.7262
# West Coast                               94.2794                  113.9557
# North Melbourne                         100.4297                  136.4253
#
#                         exp_vaep_value_pergame_diff
# Geelong                                     31.8780
# Sydney                                      25.8558
# Richmond                                    15.2616
# Essendon                                    11.6659
# Collingwood                                  9.5754
# Carlton                                      6.4308
# Brisbane Lions                               4.5500
# Melbourne                                    3.9904
# Western Bulldogs                             1.0417
# Gold Coast                                  -0.7336
# Fremantle                                   -2.7959
# Hawthorn                                    -4.3303
# Adelaide                                    -5.7097
# Port Adelaide                               -5.7897
# St Kilda                                   -16.5006
# Greater Western Sydney                     -18.7179
# West Coast                                 -19.6763
# North Melbourne                            -35.9956

# %% [markdown]
# 202223

# %%
round_id = '202223'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 36.502575180772396
# Overall MAE: 25.751643044442684
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Geelong                                 119.1001                   81.6611
# Sydney                                  127.0181                   99.3928
# Richmond                                123.8750                  106.4059
# Brisbane Lions                          117.0989                  110.1377
# Melbourne                               113.9466                  108.1540
# Carlton                                 113.2505                  107.5565
# Essendon                                115.7912                  110.4942
# Collingwood                             118.2289                  113.4792
# Western Bulldogs                        115.1640                  111.8313
# Fremantle                               115.7436                  114.5119
# Port Adelaide                           113.6098                  113.6183
# Hawthorn                                109.2731                  116.3939
# Adelaide                                109.6761                  119.2959
# St Kilda                                 96.6968                  113.2143
# Gold Coast                              110.9465                  127.6156
# Greater Western Sydney                   99.7659                  117.8744
# West Coast                               94.6677                  114.3916
# North Melbourne                         103.2692                  130.4077
#
#                         exp_vaep_value_pergame_diff
# Geelong                                     37.4390
# Sydney                                      27.6254
# Richmond                                    17.4691
# Brisbane Lions                               6.9611
# Melbourne                                    5.7926
# Carlton                                      5.6940
# Essendon                                     5.2970
# Collingwood                                  4.7497
# Western Bulldogs                             3.3327
# Fremantle                                    1.2317
# Port Adelaide                               -0.0085
# Hawthorn                                    -7.1208
# Adelaide                                    -9.6198
# St Kilda                                   -16.5174
# Gold Coast                                 -16.6690
# Greater Western Sydney                     -18.1085
# West Coast                                 -19.7238
# North Melbourne                            -27.1385

# %% [markdown]
# 202224

# %%
round_id = '2022F1'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 13.929136655589456
# Overall MAE: 25.2590386115738
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Geelong                                 121.9372                   79.4770
# Sydney                                  125.4900                   98.3682
# Richmond                                126.7123                  108.4629
# Melbourne                               117.2093                  104.6436
# Port Adelaide                           117.0048                  106.7568
# Western Bulldogs                        117.2852                  108.9524
# Carlton                                 115.5793                  108.9677
# Fremantle                               115.7533                  112.0226
# Essendon                                118.4780                  116.8176
# Brisbane Lions                          114.2984                  113.2982
# Collingwood                             114.6868                  116.3645
# Gold Coast                              114.7376                  124.1871
# Hawthorn                                104.4007                  116.5908
# Adelaide                                105.1526                  120.1049
# St Kilda                                 95.9681                  111.7140
# Greater Western Sydney                   98.4403                  122.4705
# West Coast                               91.1830                  117.6996
# North Melbourne                         103.7805                  133.8645
#
#                         exp_vaep_value_pergame_diff
# Geelong                                     42.4602
# Sydney                                      27.1218
# Richmond                                    18.2493
# Melbourne                                   12.5657
# Port Adelaide                               10.2480
# Western Bulldogs                             8.3328
# Carlton                                      6.6116
# Fremantle                                    3.7307
# Essendon                                     1.6604
# Brisbane Lions                               1.0002
# Collingwood                                 -1.6777
# Gold Coast                                  -9.4495
# Hawthorn                                   -12.1901
# Adelaide                                   -14.9523
# St Kilda                                   -15.7459
# Greater Western Sydney                     -24.0303
# West Coast                                 -26.5166
# North Melbourne                            -30.0840

# %%
round_id = '2022F2'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 21.09624047367133
# Overall MAE: 25.0925266860577
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Geelong                                 122.6046                   82.0305
# Sydney                                  127.6244                   98.0220
# Richmond                                128.5454                  111.9350
# Melbourne                               117.3394                  106.7514
# Port Adelaide                           116.4528                  107.0212
# Carlton                                 116.0267                  108.0216
# Western Bulldogs                        112.5740                  107.7668
# Fremantle                               115.7719                  112.6724
# Brisbane Lions                          117.4958                  115.5499
# Collingwood                             113.8360                  116.4794
# Essendon                                115.4604                  118.3533
# Hawthorn                                104.4007                  116.5908
# St Kilda                                 95.1873                  107.9449
# Adelaide                                104.3736                  117.7613
# Gold Coast                              111.7976                  125.5231
# Greater Western Sydney                   95.1786                  117.6747
# West Coast                               92.3541                  118.4617
# North Melbourne                         103.7805                  133.8645
#
#                         exp_vaep_value_pergame_diff
# Geelong                                     40.5740
# Sydney                                      29.6024
# Richmond                                    16.6105
# Melbourne                                   10.5880
# Port Adelaide                                9.4317
# Carlton                                      8.0052
# Western Bulldogs                             4.8072
# Fremantle                                    3.0995
# Brisbane Lions                               1.9460
# Collingwood                                 -2.6434
# Essendon                                    -2.8929
# Hawthorn                                   -12.1901
# St Kilda                                   -12.7576
# Adelaide                                   -13.3876
# Gold Coast                                 -13.7255
# Greater Western Sydney                     -22.4961
# West Coast                                 -26.1077
# North Melbourne                            -30.0840

# %%
round_id = '2022F3'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 31.815742412462647
# Overall MAE: 25.351111906304045
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Geelong                                 124.0978                   79.4044
# Sydney                                  128.8550                  100.4762
# Richmond                                131.0876                  112.2427
# Port Adelaide                           113.2504                  102.1386
# Carlton                                 112.9563                  105.8353
# Melbourne                               115.3892                  108.3043
# Brisbane Lions                          119.0488                  113.5997
# Fremantle                               112.4770                  109.9499
# Western Bulldogs                        109.0796                  108.1387
# Essendon                                115.8271                  119.2718
# Collingwood                             112.0180                  116.1466
# Hawthorn                                104.3984                  113.1617
# St Kilda                                 97.5940                  106.8694
# Gold Coast                              107.5121                  123.4545
# Adelaide                                101.6040                  119.6681
# Greater Western Sydney                   95.0895                  115.9409
# West Coast                               90.0226                  119.2036
# North Melbourne                         103.9397                  134.7812
#
#                         exp_vaep_value_pergame_diff
# Geelong                                     44.6934
# Sydney                                      28.3787
# Richmond                                    18.8449
# Port Adelaide                               11.1118
# Carlton                                      7.1211
# Melbourne                                    7.0850
# Brisbane Lions                               5.4490
# Fremantle                                    2.5270
# Western Bulldogs                             0.9408
# Essendon                                    -3.4447
# Collingwood                                 -4.1286
# Hawthorn                                    -8.7633
# St Kilda                                    -9.2754
# Gold Coast                                 -15.9424
# Adelaide                                   -18.0641
# Greater Western Sydney                     -20.8514
# West Coast                                 -29.1809
# North Melbourne                            -30.8414

# %%
round_id = '2022F4'
update_round_projections(round_id, player_stats, rounds, round_projection_dict, round_mae)
# Out:
# Round MAE: 75.12662863034176
# Overall MAE: 27.194649562749888
#                         exp_vaep_value_pergame_F  exp_vaep_value_pergame_A  \
# Geelong                                 121.6086                   83.8244
# Sydney                                  129.3646                  101.3271
# Richmond                                132.7049                  112.1766
# Port Adelaide                           112.3588                   97.6574
# Carlton                                 110.2789                  104.6237
# Western Bulldogs                        108.8735                  105.2253
# Melbourne                               115.4464                  112.0114
# Fremantle                               110.1403                  108.8897
# Brisbane Lions                          115.2244                  115.5015
# Essendon                                116.5684                  118.7206
# Collingwood                             111.5953                  117.8619
# Hawthorn                                103.1358                  111.2407
# St Kilda                                 95.2051                  103.3223
# Adelaide                                105.4131                  120.3528
# Gold Coast                              107.0763                  123.5877
# North Melbourne                         111.1565                  132.3002
# Greater Western Sydney                   90.5867                  116.3272
# West Coast                               86.7728                  119.3541
#
#                         exp_vaep_value_pergame_diff
# Geelong                                     37.7843
# Sydney                                      28.0375
# Richmond                                    20.5283
# Port Adelaide                               14.7014
# Carlton                                      5.6551
# Western Bulldogs                             3.6482
# Melbourne                                    3.4350
# Fremantle                                    1.2505
# Brisbane Lions                              -0.2771
# Essendon                                    -2.1523
# Collingwood                                 -6.2666
# Hawthorn                                    -8.1049
# St Kilda                                    -8.1172
# Adelaide                                   -14.9397
# Gold Coast                                 -16.5113
# North Melbourne                            -21.1437
# Greater Western Sydney                     -25.7405
# West Coast                                 -32.5814
